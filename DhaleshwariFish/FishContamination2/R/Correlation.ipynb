# %%
!pip install pandas
import pandas as pd
# Out:
# Collecting pandas
#   Downloading pandas-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 878.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pytz>=2020.1 in /home/RHHLab/anaconda3/envs/R-Base/lib/python3.10/site-packages (from pandas) (2022.7)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 3.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting numpy>=1.21.0
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/RHHLab/anaconda3/envs/R-Base/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/RHHLab/anaconda3/envs/R-Base/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-1.24.3 pandas-2.0.2 tzdata-2023.3

# %%
df = pd.read_csv("../Python/data/metals.csv")

# %%
df
# Out:
#    Metals  Ghagra (Clupisoma garua)  Koi\n(Anabas testudineus)  \
# 0      Cr                      0.69                       0.95
# 1      Mn                      1.63                       0.49
# 2      Fe                    105.47                      83.99
# 3      Co                      1.27                       2.68
# 4      Cu                     22.16                      19.82
# 5      Zn                     82.25                     149.47
# 6      As                      0.43                       0.47
# 7      Se                      2.79                       3.99
# 8      Cd                      0.53                       0.87
# 9      Hg                      0.55                       0.76
# 10     Pb                      0.78                       1.18
#
#     Tatkini\n(Cirrhinus reba)  Tengra (Mystus vittatus)  \
# 0                        1.36                      2.37
# 1                        0.42                      0.74
# 2                       77.85                     90.12
# 3                        3.61                      5.13
# 4                       17.15                     21.59
# 5                      135.34                     81.27
# 6                        0.56                      0.61
# 7                        4.77                      5.37
# 8                        2.17                      3.15
# 9                        0.98                      1.24
# 10                       0.63                      0.97
#
#     Batashi (Neotropius atherinoides)  Jatka (juvenile) Tenualosa ilisha  \
# 0                                0.27                               1.13
# 1                                0.35                               0.93
# 2                               43.52                              94.58
# 3                                3.49                               3.05
# 4                               15.19                              28.90
# 5                              129.11                             172.53
# 6                                0.42                               0.51
# 7                                3.21                               4.39
# 8                                0.72                               1.76
# 9                                0.69                               1.71
# 10                               0.58                               0.46
#
#     Rani (Botia dario)  Chanda\n(Pseudambassis ranga)
# 0                 1.02                           1.98
# 1                 1.65                           1.78
# 2               114.31                         133.25
# 3                 3.52                           4.77
# 4                11.48                          23.95
# 5               161.89                         158.31
# 6                 0.52                           0.57
# 7                 4.15                           5.10
# 8                 2.11                           2.79
# 9                 0.93                           1.50
# 10                0.61                           0.78

# %%
df = df.T

# %%
columns = df.iloc[0]
columns
# Out:
# 0     Cr
# 1     Mn
# 2     Fe
# 3     Co
# 4     Cu
# 5     Zn
# 6     As
# 7     Se
# 8     Cd
# 9     Hg
# 10    Pb
# Name: Metals, dtype: object

# %%
df.columns = columns
df
# Out:
# Metals                               Cr    Mn      Fe    Co     Cu      Zn  \
# Metals                               Cr    Mn      Fe    Co     Cu      Zn
# Ghagra (Clupisoma garua)           0.69  1.63  105.47  1.27  22.16   82.25
# Koi\n(Anabas testudineus)          0.95  0.49   83.99  2.68  19.82  149.47
# Tatkini\n(Cirrhinus reba)          1.36  0.42   77.85  3.61  17.15  135.34
# Tengra (Mystus vittatus)           2.37  0.74   90.12  5.13  21.59   81.27
# Batashi (Neotropius atherinoides)  0.27  0.35   43.52  3.49  15.19  129.11
# Jatka (juvenile) Tenualosa ilisha  1.13  0.93   94.58  3.05   28.9  172.53
# Rani (Botia dario)                 1.02  1.65  114.31  3.52  11.48  161.89
# Chanda\n(Pseudambassis ranga)      1.98  1.78  133.25  4.77  23.95  158.31
#
# Metals                               As    Se    Cd    Hg    Pb
# Metals                               As    Se    Cd    Hg    Pb
# Ghagra (Clupisoma garua)           0.43  2.79  0.53  0.55  0.78
# Koi\n(Anabas testudineus)          0.47  3.99  0.87  0.76  1.18
# Tatkini\n(Cirrhinus reba)          0.56  4.77  2.17  0.98  0.63
# Tengra (Mystus vittatus)           0.61  5.37  3.15  1.24  0.97
# Batashi (Neotropius atherinoides)  0.42  3.21  0.72  0.69  0.58
# Jatka (juvenile) Tenualosa ilisha  0.51  4.39  1.76  1.71  0.46
# Rani (Botia dario)                 0.52  4.15  2.11  0.93  0.61
# Chanda\n(Pseudambassis ranga)      0.57   5.1  2.79   1.5  0.78

# %%
df = df.iloc[1:]

# %%
df
# Out:
# Metals                               Cr    Mn      Fe    Co     Cu      Zn  \
# Ghagra (Clupisoma garua)           0.69  1.63  105.47  1.27  22.16   82.25
# Koi\n(Anabas testudineus)          0.95  0.49   83.99  2.68  19.82  149.47
# Tatkini\n(Cirrhinus reba)          1.36  0.42   77.85  3.61  17.15  135.34
# Tengra (Mystus vittatus)           2.37  0.74   90.12  5.13  21.59   81.27
# Batashi (Neotropius atherinoides)  0.27  0.35   43.52  3.49  15.19  129.11
# Jatka (juvenile) Tenualosa ilisha  1.13  0.93   94.58  3.05   28.9  172.53
# Rani (Botia dario)                 1.02  1.65  114.31  3.52  11.48  161.89
# Chanda\n(Pseudambassis ranga)      1.98  1.78  133.25  4.77  23.95  158.31
#
# Metals                               As    Se    Cd    Hg    Pb
# Ghagra (Clupisoma garua)           0.43  2.79  0.53  0.55  0.78
# Koi\n(Anabas testudineus)          0.47  3.99  0.87  0.76  1.18
# Tatkini\n(Cirrhinus reba)          0.56  4.77  2.17  0.98  0.63
# Tengra (Mystus vittatus)           0.61  5.37  3.15  1.24  0.97
# Batashi (Neotropius atherinoides)  0.42  3.21  0.72  0.69  0.58
# Jatka (juvenile) Tenualosa ilisha  0.51  4.39  1.76  1.71  0.46
# Rani (Botia dario)                 0.52  4.15  2.11  0.93  0.61
# Chanda\n(Pseudambassis ranga)      0.57   5.1  2.79   1.5  0.78

# %%
df = df.reset_index()
df
# Out:
# Metals                              index    Cr    Mn      Fe    Co     Cu  \
# 0                Ghagra (Clupisoma garua)  0.69  1.63  105.47  1.27  22.16
# 1               Koi\n(Anabas testudineus)  0.95  0.49   83.99  2.68  19.82
# 2               Tatkini\n(Cirrhinus reba)  1.36  0.42   77.85  3.61  17.15
# 3                Tengra (Mystus vittatus)  2.37  0.74   90.12  5.13  21.59
# 4       Batashi (Neotropius atherinoides)  0.27  0.35   43.52  3.49  15.19
# 5       Jatka (juvenile) Tenualosa ilisha  1.13  0.93   94.58  3.05   28.9
# 6                      Rani (Botia dario)  1.02  1.65  114.31  3.52  11.48
# 7           Chanda\n(Pseudambassis ranga)  1.98  1.78  133.25  4.77  23.95
#
# Metals      Zn    As    Se    Cd    Hg    Pb
# 0        82.25  0.43  2.79  0.53  0.55  0.78
# 1       149.47  0.47  3.99  0.87  0.76  1.18
# 2       135.34  0.56  4.77  2.17  0.98  0.63
# 3        81.27  0.61  5.37  3.15  1.24  0.97
# 4       129.11  0.42  3.21  0.72  0.69  0.58
# 5       172.53  0.51  4.39  1.76  1.71  0.46
# 6       161.89  0.52  4.15  2.11  0.93  0.61
# 7       158.31  0.57   5.1  2.79   1.5  0.78

# %%
df = df.drop(columns="index")
df
# Out:
# Metals    Cr    Mn      Fe    Co     Cu      Zn    As    Se    Cd    Hg    Pb
# 0       0.69  1.63  105.47  1.27  22.16   82.25  0.43  2.79  0.53  0.55  0.78
# 1       0.95  0.49   83.99  2.68  19.82  149.47  0.47  3.99  0.87  0.76  1.18
# 2       1.36  0.42   77.85  3.61  17.15  135.34  0.56  4.77  2.17  0.98  0.63
# 3       2.37  0.74   90.12  5.13  21.59   81.27  0.61  5.37  3.15  1.24  0.97
# 4       0.27  0.35   43.52  3.49  15.19  129.11  0.42  3.21  0.72  0.69  0.58
# 5       1.13  0.93   94.58  3.05   28.9  172.53  0.51  4.39  1.76  1.71  0.46
# 6       1.02  1.65  114.31  3.52  11.48  161.89  0.52  4.15  2.11  0.93  0.61
# 7       1.98  1.78  133.25  4.77  23.95  158.31  0.57   5.1  2.79   1.5  0.78

# %%
df.to_csv("MetalsRaw.csv")

# %%
df <- read.csv("MetalsRaw.csv")

# %%
df
# Out:
#   X Cr   Mn   Fe     Co   Cu    Zn     As   Se   Cd   Hg   Pb
# 1 0 0.69 1.63 105.47 1.27 22.16  82.25 0.43 2.79 0.53 0.55 0.78
# 2 1 0.95 0.49  83.99 2.68 19.82 149.47 0.47 3.99 0.87 0.76 1.18
# 3 2 1.36 0.42  77.85 3.61 17.15 135.34 0.56 4.77 2.17 0.98 0.63
# 4 3 2.37 0.74  90.12 5.13 21.59  81.27 0.61 5.37 3.15 1.24 0.97
# 5 4 0.27 0.35  43.52 3.49 15.19 129.11 0.42 3.21 0.72 0.69 0.58
# 6 5 1.13 0.93  94.58 3.05 28.90 172.53 0.51 4.39 1.76 1.71 0.46
# 7 6 1.02 1.65 114.31 3.52 11.48 161.89 0.52 4.15 2.11 0.93 0.61
# 8 7 1.98 1.78 133.25 4.77 23.95 158.31 0.57 5.10 2.79 1.50 0.78

# %%
str(df)
# Out:
# 'data.frame':	8 obs. of  12 variables:
#  $ X : int  0 1 2 3 4 5 6 7
#  $ Cr: num  0.69 0.95 1.36 2.37 0.27 1.13 1.02 1.98
#  $ Mn: num  1.63 0.49 0.42 0.74 0.35 0.93 1.65 1.78
#  $ Fe: num  105.5 84 77.8 90.1 43.5 ...
#  $ Co: num  1.27 2.68 3.61 5.13 3.49 3.05 3.52 4.77
#  $ Cu: num  22.2 19.8 17.1 21.6 15.2 ...
#  $ Zn: num  82.2 149.5 135.3 81.3 129.1 ...
#  $ As: num  0.43 0.47 0.56 0.61 0.42 0.51 0.52 0.57
#  $ Se: num  2.79 3.99 4.77 5.37 3.21 4.39 4.15 5.1
#  $ Cd: num  0.53 0.87 2.17 3.15 0.72 1.76 2.11 2.79
#  $ Hg: num  0.55 0.76 0.98 1.24 0.69 1.71 0.93 1.5
#  $ Pb: num  0.78 1.18 0.63 0.97 0.58 0.46 0.61 0.78

# %%
require(corrplot)
# Out:
# Loading required package: corrplot
#
# corrplot 0.92 loaded

# %%
df <- df[,-1]

# %%
corr_metals <- cor(df)

# %%
corr_metals
# Out:
#    Cr         Mn          Fe         Co          Cu          Zn
# Cr  1.0000000  0.17902300 0.50082379  0.75436054  0.34185485 -0.13905828
# Mn  0.1790230  1.00000000 0.88467353 -0.08589325  0.12026677  0.06809758
# Fe  0.5008238  0.88467353 1.00000000  0.10898806  0.29242154  0.18666545
# Co  0.7543605 -0.08589325 0.10898806  1.00000000 -0.03261591  0.10514004
# Cu  0.3418548  0.12026677 0.29242154 -0.03261591  1.00000000  0.01706053
# Zn -0.1390583  0.06809758 0.18666545  0.10514004  0.01706053  1.00000000
# As  0.9431125  0.09401155 0.42500996  0.80126841  0.16883557  0.02975153
# Se  0.9092261 -0.03104256 0.34077077  0.84971890  0.22649090  0.19007640
# Cd  0.9162263  0.19191825 0.45366440  0.86621008  0.12503026  0.07120135
# Hg  0.6216506  0.16684403 0.41151658  0.56399089  0.64018389  0.46228209
# Pb  0.3086870 -0.12721485 0.08833094  0.04723629  0.02565030 -0.35255169
#    As         Se          Cd           Hg         Pb
# Cr 0.94311248  0.90922607  0.916226280  0.6216506  0.308687028
# Mn 0.09401155 -0.03104256  0.191918254  0.1668440 -0.127214847
# Fe 0.42500996  0.34077077  0.453664404  0.4115166  0.088330939
# Co 0.80126841  0.84971890  0.866210078  0.5639909  0.047236290
# Cu 0.16883557  0.22649090  0.125030256  0.6401839  0.025650302
# Zn 0.02975153  0.19007640  0.071201353  0.4622821 -0.352551690
# As 1.00000000  0.96629551  0.974795658  0.6485455  0.109052384
# Se 0.96629551  1.00000000  0.940003999  0.7268121  0.139945960
# Cd 0.97479566  0.94000400  1.000000000  0.6855616 -0.002677854
# Hg 0.64854550  0.72681205  0.685561621  1.0000000 -0.284935470
# Pb 0.10905238  0.13994596 -0.002677854 -0.2849355  1.000000000

# %%
corrplot(corr_metals,title = "", method = "square", outline = T, 
         addgrid.col = "darkgray", order="hclust", mar = c(4,0,4,0), 
         addrect = 4, rect.col = "black", rect.lwd = 5,cl.pos = "b", 
         tl.col = "black", tl.cex = 1.5, cl.cex = 1.5)
# Out:
# Plot with title “”

# %%
corrplot(corr_metals, method = "color", outline = T, addgrid.col = "darkgray", 
         order="hclust", addrect = 4, 
         rect.col = "black", rect.lwd = 5,cl.pos = "b", 
         tl.col = "black", tl.cex = 1.5, cl.cex = 1.5, 
         addCoef.col = "white", number.digits = 2, 
         number.cex = 1.5, col = colorRampPalette(c("darkred","white","midnightblue"))(100))
# Out:
# Plot with title “”

# %%
corrplot.mixed(corr_metals, lower = 'shade', upper = 'pie', 
               tl.pos = "lt", tl.col = "black", tl.cex = 1.8)
# Out:
# Plot with title “”

# %%
require(corrplot)
df <- read.csv("MetalsRaw.csv")
df <- df[,-1]
corr_metals <- cor(df)
corrplot(corr_metals,title = "", method = "square", outline = T, 
         addgrid.col = "darkgray", order="hclust", mar = c(4,0,4,0), 
         addrect = 4, rect.col = "black", rect.lwd = 5,cl.pos = "b", 
         tl.col = "black", tl.cex = 1.5, cl.cex = 1.5)
# Out:
# Plot with title “”

# %%
require(corrplot)
df <- read.csv("MetalsRaw.csv")
df <- df[,-1]
corr_metals <- cor(df)
corrplot.mixed(corr_metals, lower = 'shade', upper = 'pie', 
               tl.pos = "lt", tl.col = "black", tl.cex = 1.8)
# Out:
# Plot with title “”

# %%
require(corrplot)
df <- read.csv("MetalsRaw.csv")
df <- df[,-1]
corr_metals <- cor(df)
corrplot(corr_metals, method = "color", outline = T, addgrid.col = "darkgray", 
         order="hclust", addrect = 4, 
         rect.col = "black", rect.lwd = 5,cl.pos = "b", 
         tl.col = "black", tl.cex = 1.5, cl.cex = 1.5, 
         addCoef.col = "white", number.digits = 2, 
         number.cex = 1.5, col = colorRampPalette(c("darkred","white","midnightblue"))(100))
# Out:
# Plot with title “”

# %%
require(corrplot)
df <- read.csv("MetalsRaw.csv")
df <- df[,-1]
corr_metals <- cor(df)
corrplot(
   corr_metals,
   addCoef.col = "white",
   number.cex = 1.5,
   number.digits = 2,
   tl.col = "black",
   tl.cex = 1.4,
   diag = FALSE,
   bg = "grey",
   outline = "black",
   addgrid.col = "white",
   mar = c(1,1,1,1))
# Out:
# Plot with title “”

# %% [markdown]
# ## PCA

# %%
require(psych)
require(haven)
require(FactoMineR)
require(factoextra)

# %%
pca_metals <- PCA(df, graph = FALSE, ncp = 4,  
               scale.unit = TRUE)
eig.val <- get_eigenvalue(pca_metals)
eig.val
# Out:
#       eigenvalue variance.percent cumulative.variance.percent
# Dim.1 5.4443810  49.4943730        49.49437
# Dim.2 1.9515074  17.7409768        67.23535
# Dim.3 1.5842750  14.4024999        81.63785
# Dim.4 1.1268795  10.2443587        91.88221
# Dim.5 0.6875597   6.2505430        98.13275
# Dim.6 0.1909733   1.7361213        99.86887
# Dim.7 0.0144240   0.1311273       100.00000

# %%
pca_metals$var$coord
# Out:
#    Dim.1      Dim.2      Dim.3        Dim.4
# Cr 0.94387866 -0.1544701  0.273477424  0.0872420426
# Mn 0.22424891  0.7980679  0.427946065 -0.3171270588
# Fe 0.53866157  0.6909950  0.428429782 -0.1642591649
# Co 0.81629237 -0.3808649 -0.181917417 -0.2115737250
# Cu 0.33659329  0.3724900  0.014999802  0.8593402109
# Zn 0.15759501  0.4190930 -0.677009699 -0.1648671992
# As 0.95604978 -0.1875091  0.044819735 -0.0918933263
# Se 0.95788665 -0.2224520 -0.100407594 -0.0001003258
# Cd 0.96590891 -0.1145284 -0.008512092 -0.1902574040
# Hg 0.79946436  0.3066373 -0.401982347  0.3050072108
# Pb 0.06974589 -0.4025251  0.690927890  0.2088916715

# %%
rotate <- pca(df, nfactors=4, rotate="varimax")
rotate
# Out:
# Warning message in cor.smooth(r):
# “Matrix was not positive definite, smoothing was done”
# Warning message in principal(r = r, nfactors = nfactors, residuals = residuals, :
# “The matrix is not positive semi-definite, scores found from Structure loadings”
# Principal Components Analysis
# Call: principal(r = r, nfactors = nfactors, residuals = residuals,
#     rotate = rotate, n.obs = n.obs, covar = covar, scores = scores,
#     missing = missing, impute = impute, oblique.scores = oblique.scores,
#     method = method, use = use, cor = cor, correct = 0.5, weight = NULL)
# Standardized loadings (pattern matrix) based upon correlation matrix
#      RC1   RC2   RC3   RC4   h2     u2 com
# Cr  0.90  0.23 -0.27  0.25 1.00 0.0028 1.5
# Mn -0.03  0.98  0.08  0.00 0.97 0.0291 1.0
# Fe  0.28  0.93  0.01  0.19 0.98 0.0218 1.3
# Co  0.93 -0.12  0.08 -0.10 0.89 0.1108 1.1
# Cu  0.06  0.11 -0.03  0.99 0.99 0.0093 1.0
# Zn  0.08  0.07  0.82  0.07 0.69 0.3140 1.0
# As  0.96  0.14 -0.05  0.10 0.96 0.0404 1.1
# Se  0.97  0.02  0.04  0.18 0.98 0.0229 1.1
# Cd  0.97  0.21  0.05  0.04 0.98 0.0176 1.1
# Hg  0.63  0.13  0.46  0.60 0.99 0.0122 2.9
# Pb  0.12 -0.01 -0.82  0.04 0.69 0.3121 1.0
#
#                        RC1  RC2  RC3  RC4
# SS loadings           4.97 1.99 1.65 1.50
# Proportion Var        0.45 0.18 0.15 0.14
# Cumulative Var        0.45 0.63 0.78 0.92
# Proportion Explained  0.49 0.20 0.16 0.15
# Cumulative Proportion 0.49 0.69 0.85 1.00
#
# Mean item complexity =  1.3
# Test of the hypothesis that 4 components are sufficient.
#
# The root mean square of the residuals (RMSR) is  0.05
#  with the empirical chi square  2.38  with prob <  1
#
# Fit based upon off diagonal values = 0.99

# %%
rotate$loadings
# Out:
# Loadings:
#    RC1    RC2    RC3    RC4
# Cr  0.899  0.226 -0.271  0.254
# Mn         0.982
# Fe  0.278  0.930         0.189
# Co  0.927 -0.116
# Cu         0.108         0.987
# Zn                0.819
# As  0.963  0.144
# Se  0.971                0.178
# Cd  0.967  0.206
# Hg  0.628  0.134  0.458  0.604
# Pb  0.117        -0.820
#
#                  RC1   RC2   RC3   RC4
# SS loadings    4.971 1.991 1.647 1.497
# Proportion Var 0.452 0.181 0.150 0.136
# Cumulative Var 0.452 0.633 0.783 0.919

# %%
nonrotate <- pca_metals$var$coord
nonrotate
# Out:
#    Dim.1      Dim.2      Dim.3        Dim.4
# Cr 0.94387866 -0.1544701  0.273477424  0.0872420426
# Mn 0.22424891  0.7980679  0.427946065 -0.3171270588
# Fe 0.53866157  0.6909950  0.428429782 -0.1642591649
# Co 0.81629237 -0.3808649 -0.181917417 -0.2115737250
# Cu 0.33659329  0.3724900  0.014999802  0.8593402109
# Zn 0.15759501  0.4190930 -0.677009699 -0.1648671992
# As 0.95604978 -0.1875091  0.044819735 -0.0918933263
# Se 0.95788665 -0.2224520 -0.100407594 -0.0001003258
# Cd 0.96590891 -0.1145284 -0.008512092 -0.1902574040
# Hg 0.79946436  0.3066373 -0.401982347  0.3050072108
# Pb 0.06974589 -0.4025251  0.690927890  0.2088916715

# %%
write.csv(nonrotate,"nonrotate.csv")
write.csv(rotate$loadings,"rotate.csv")

# %%
!pip install scikit-learn
from sklearn.decomposition import PCA
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 4.1 MB/s eta 0:00:004.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /home/RHHLab/anaconda3/envs/R-Base/lib/python3.10/site-packages (from scikit-learn) (1.24.3)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2 scipy-1.10.1 threadpoolctl-3.1.0

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("MetalsRaw.csv")

# %%
df = df.drop(columns="Unnamed: 0")
df
# Out:
#      Cr    Mn      Fe    Co     Cu      Zn    As    Se    Cd    Hg    Pb
# 0  0.69  1.63  105.47  1.27  22.16   82.25  0.43  2.79  0.53  0.55  0.78
# 1  0.95  0.49   83.99  2.68  19.82  149.47  0.47  3.99  0.87  0.76  1.18
# 2  1.36  0.42   77.85  3.61  17.15  135.34  0.56  4.77  2.17  0.98  0.63
# 3  2.37  0.74   90.12  5.13  21.59   81.27  0.61  5.37  3.15  1.24  0.97
# 4  0.27  0.35   43.52  3.49  15.19  129.11  0.42  3.21  0.72  0.69  0.58
# 5  1.13  0.93   94.58  3.05  28.90  172.53  0.51  4.39  1.76  1.71  0.46
# 6  1.02  1.65  114.31  3.52  11.48  161.89  0.52  4.15  2.11  0.93  0.61
# 7  1.98  1.78  133.25  4.77  23.95  158.31  0.57  5.10  2.79  1.50  0.78

# %%
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)

# %%
pca = PCA(n_components=4)
pca.fit(scaled_df)
# Out:
# PCA(n_components=4)

# %%
compo = pd.DataFrame(pca.components_)
compo.T
# Out:
#            0         1         2         3
# 0   0.404522  0.110576  0.217273 -0.082184
# 1   0.096107 -0.571287  0.339996  0.298741
# 2   0.230856 -0.494641  0.340380  0.154736
# 3   0.349842  0.272638 -0.144530  0.199307
# 4   0.144255 -0.266643  0.011917 -0.809518
# 5   0.067541 -0.300003 -0.537873  0.155309
# 6   0.409738  0.134226  0.035609  0.086566
# 7   0.410525  0.159240 -0.079772  0.000095
# 8   0.413963  0.081984 -0.006763  0.179227
# 9   0.342630 -0.219503 -0.319368 -0.287324
# 10  0.029891  0.288143  0.548931 -0.196781

# %%
pca.explained_variance_
# Out:
# array([1279.55150501,  663.33882512,   26.84757729,    3.05519644])
