# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/pca3.csv")

# %%
df.head()
# Out:
#   Element   PC1   PC2   PC3
# 0      Cr  0.94  0.03  0.20
# 1      Mn  0.08  0.66  0.71
# 2      Fe   0.4  0.68  0.60
# 3      Co  0.88 -0.36  0.02
# 4      Cu  0.29  0.65 -0.37

# %%
df.columns
# Out:
# Index(['Element', 'PC1', 'PC2', 'PC3'], dtype='object')

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(df["PC1"], df["PC2"], df["PC3"])
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(df["PC1"], df["PC2"], df["PC3"], s=100)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(df["PC1"], df["PC2"], df["PC3"],s=100, c= "black")

ax.set_xlabel("PC1")
plt.colorbar(fg)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(df["PC1"], df["PC2"], df["PC3"],s=100, c= "black", alpha= 0.9)

ax.set_label("df.Element")
ax.set_xlabel("PC1")
plt.colorbar(fg)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
pca = pd.read_csv("data/pca_scores.csv")

# %%
pca
# Out:
#    Unnamed: 0      Comp.1     Comp.2     Comp.3    Comp.4    Comp.5    Comp.6  \
# 0          Cr  -55.435664  -1.548130  -1.845450 -1.129890 -0.127578 -0.292413
# 1          Mn  -55.946901  -1.428017  -2.620968 -0.132888  1.446824  0.313311
# 2          Fe  206.414568  57.849049  -2.041158  0.047060  0.087767  0.000556
# 3          Co  -49.235845  -2.155227  -1.683549 -1.474310 -2.065640  0.879373
# 4          Cu   -2.984061   3.337488  13.690817 -2.647765  1.533267  0.057006
# 5          Zn  328.925673 -39.588002  -1.131932 -0.343371  0.142993 -0.003833
# 6          As  -57.422805  -2.508123  -2.077538 -0.219761  0.769137 -0.063682
# 7          Se  -47.014448  -1.758181  -1.109903 -0.853153 -1.351170 -0.327142
# 8          Pb  -56.804396  -2.330780  -1.901333  0.014514  0.706810  0.014377
# 9          Cd  -53.841708  -1.578058  -2.281204 -1.551340 -0.840595 -0.331045
# 10         Hg  -55.832036  -2.496036  -1.805911 -0.928835  0.795171 -0.135589
# 11    Protein  -12.826241  -0.529430   5.100819  2.668828 -3.858506 -0.152408
# 12      O3PFA  -57.923640  -2.519781  -2.016357  0.121677  1.253864 -0.057790
# 13      Lipid  -30.072496  -2.746771   1.723667  6.429233  1.507659  0.099278
#
#       Comp.7    Comp.8
# 0  -0.228397 -0.039019
# 1   0.390990  0.096929
# 2  -0.007595 -0.000389
# 3  -0.095972 -0.060119
# 4  -0.024917 -0.012020
# 5  -0.001888  0.001164
# 6   0.003659  0.094463
# 7  -0.267882  0.021395
# 8  -0.567067  0.017781
# 9   0.331566 -0.125991
# 10  0.274317 -0.082559
# 11  0.173362  0.084867
# 12  0.072031  0.100455
# 13 -0.052206 -0.096956

# %%
pca.rename(columns = {'Unnamed: 0':'Elements'}, inplace = True)

# %%
pca
# Out:
#    Elements      Comp.1     Comp.2     Comp.3    Comp.4    Comp.5    Comp.6  \
# 0        Cr  -55.435664  -1.548130  -1.845450 -1.129890 -0.127578 -0.292413
# 1        Mn  -55.946901  -1.428017  -2.620968 -0.132888  1.446824  0.313311
# 2        Fe  206.414568  57.849049  -2.041158  0.047060  0.087767  0.000556
# 3        Co  -49.235845  -2.155227  -1.683549 -1.474310 -2.065640  0.879373
# 4        Cu   -2.984061   3.337488  13.690817 -2.647765  1.533267  0.057006
# 5        Zn  328.925673 -39.588002  -1.131932 -0.343371  0.142993 -0.003833
# 6        As  -57.422805  -2.508123  -2.077538 -0.219761  0.769137 -0.063682
# 7        Se  -47.014448  -1.758181  -1.109903 -0.853153 -1.351170 -0.327142
# 8        Pb  -56.804396  -2.330780  -1.901333  0.014514  0.706810  0.014377
# 9        Cd  -53.841708  -1.578058  -2.281204 -1.551340 -0.840595 -0.331045
# 10       Hg  -55.832036  -2.496036  -1.805911 -0.928835  0.795171 -0.135589
# 11  Protein  -12.826241  -0.529430   5.100819  2.668828 -3.858506 -0.152408
# 12    O3PFA  -57.923640  -2.519781  -2.016357  0.121677  1.253864 -0.057790
# 13    Lipid  -30.072496  -2.746771   1.723667  6.429233  1.507659  0.099278
#
#       Comp.7    Comp.8
# 0  -0.228397 -0.039019
# 1   0.390990  0.096929
# 2  -0.007595 -0.000389
# 3  -0.095972 -0.060119
# 4  -0.024917 -0.012020
# 5  -0.001888  0.001164
# 6   0.003659  0.094463
# 7  -0.267882  0.021395
# 8  -0.567067  0.017781
# 9   0.331566 -0.125991
# 10  0.274317 -0.082559
# 11  0.173362  0.084867
# 12  0.072031  0.100455
# 13 -0.052206 -0.096956

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(pca["Comp.1"],pca["Comp.2"],pca["Comp.3"], s= 70, c= "black")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
arrayx = np.array([pca["Comp.1"]])
arrayy = np.array([pca["Comp.2"]])
arrayz = np.array([pca["Comp.3"]])

# %%
labels = list(pca["Elements"])
labels
# Out:
# ['Cr',
#  'Mn',
#  'Fe',
#  'Co',
#  'Cu',
#  'Zn',
#  'As',
#  'Se',
#  'Pb',
#  'Cd',
#  'Hg',
#  'Protein',
#  'O3PFA',
#  'Lipid']

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

ax3d = plt.figure().gca(projection='3d')

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

ax3d.scatter(arrayx, arrayy, arrayz, c="black")

#give the labels to each point
for x_label, y_label, z_label, label in zip(arrayx, arrayy, arrayz, labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
plt.savefig("pca_3d.png", format="png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_25481/1088736004.py:5: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
arrayx
# Out:
# array([-55.43566367, -55.94690129, 206.41456777, -49.23584526,
#         -2.98406062, 328.92567261, -57.42280503, -47.01444792,
#        -56.80439576, -53.84170811, -55.83203577, -12.82624146,
#        -57.92363987, -30.07249561])

# %%
from sklearn import preprocessing

# %%
x = preprocessing.normalize([arrayx])
x
# Out:
# array([[-0.13117058, -0.13238025,  0.48841334, -0.11650071, -0.00706081,
#          0.77829626, -0.1358725 , -0.11124449, -0.13440924, -0.127399  ,
#         -0.13210846, -0.03034915, -0.13705757, -0.07115684]])

# %%
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])
y,z
# Out:
# (array([[-0.0219562 , -0.02025271,  0.82043823, -0.03056628,  0.04733358,
#          -0.5614528 , -0.0355712 , -0.02493522, -0.03305605, -0.02238064,
#          -0.03539978, -0.00750859, -0.03573654, -0.0389558 ]]),
#  array([[-0.11518795, -0.16359371, -0.12740351, -0.10508253,  0.85454362,
#          -0.07065213, -0.12967425, -0.06927714, -0.11867607, -0.14238658,
#          -0.11272008,  0.31837923, -0.12585552,  0.10758662]]))

# %%
ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x, y, z, c="black")

#give the labels to each point
for x_label, y_label, z_label, label in zip(x, y, z, labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_25481/3727692418.py:1: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
arrayx.shape
# Out:
# (14,)

# %%
labels
# Out:
# ['Cr',
#  'Mn',
#  'Fe',
#  'Co',
#  'Cu',
#  'Zn',
#  'As',
#  'Se',
#  'Pb',
#  'Cd',
#  'Hg',
#  'Protein',
#  'O3PFA',
#  'Lipid']

# %%
x.shape
# Out:
# (1, 14)

# %%
x
# Out:
# array([[-0.13117058, -0.13238025,  0.48841334, -0.11650071, -0.00706081,
#          0.77829626, -0.1358725 , -0.11124449, -0.13440924, -0.127399  ,
#         -0.13210846, -0.03034915, -0.13705757, -0.07115684]])

# %%
x_reshape = x.reshape(14,)

# %%
x_reshape.shape
# Out:
# (14,)

# %%
y_reshape = y.reshape(14,)
z_reshape = z.reshape(14,)

# %%
ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="black")

#give the labels to each point
for x_label, y_label, z_label, label in zip(x_reshape, y_reshape, z_reshape, labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_25481/44562996.py:1: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

pca = pd.read_csv("data/pca_scores.csv")
pca.rename(columns = {'Unnamed: 0':'Elements'}, inplace = True)

arrayx = np.array([pca["Comp.1"]])
arrayy = np.array([pca["Comp.2"]])
arrayz = np.array([pca["Comp.3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

labels = list(pca["Elements"])
x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])

x_reshape = x.reshape(14,)
y_reshape = y.reshape(14,)
z_reshape = z.reshape(14,)

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="black")

for x_label, y_label, z_label, label in zip(x_reshape, y_reshape, z_reshape, labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
plt.savefig("pca_3d.png", format="png", dpi=300)
# Out:
# /tmp/ipykernel_28868/1329051722.py:26: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
n_labels = ['Cr',
 'Mn',
 'Fe',
 'Co',
 'Cu',
 'Zn',
 'As',
 'Se',
 'Pb',
 'Cd',
 'Hg',
 'Pr',
 'Om',
 'Lip']

# %%
ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="black")

for x_label, y_label, z_label, label in zip(x_reshape, y_reshape, z_reshape, n_labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_25481/1425716219.py:1: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
param = [ "Temperature","pH","EC","TSS","Turbidity","Salinity","TDS","DO","COD","NH4","NO3","Phosphate",
"Sulfates","K","Ca","Mg","Cl","Br","Cd","Cr","Ni","Cu","Zn","Mn","Hg","As","Pb","THB","TC","FC",
"FS","Vibrio C","E Coli"]

# %%
fa = pd.read_csv("../Buriganga/Factor_Analysis_All_Param.csv")
fa
# Out:
#     Unnamed: 0  Factor 1 W  Factor 1 S  Factor 2 W  Factor 2 S  Factor 3 W  \
# 0            0    0.906167    0.940349   -0.035840    0.084346   -0.038100
# 1            1   -0.864374   -0.969055    0.495155    0.075777    0.009661
# 2            2    0.212881    0.175925    0.896704    0.971012    0.136403
# 3            3    0.507284    0.776180   -0.131413    0.197253    0.133478
# 4            4    0.824248    0.681834    0.280855    0.278258   -0.042003
# 5            5   -0.207263    0.266804    0.750870    0.857122    0.094029
# 6            6    0.425220    0.395712   -0.103541    0.247571    0.036552
# 7            7   -0.884095   -0.981979   -0.076105    0.016209    0.053262
# 8            8    0.890301    0.906366   -0.047761    0.080972    0.144356
# 9            9    0.924184    0.929130    0.050988    0.114378   -0.029156
# 10          10    0.855796    0.688050    0.005288   -0.229068   -0.199639
# 11          11    0.205555    0.508194    0.860114    0.684239    0.281491
# 12          12    0.024063    0.163752    0.674140   -0.000073    0.416042
# 13          13   -0.219222   -0.485380    0.373116    0.442604    0.800038
# 14          14   -0.009797   -0.331533    0.439532    0.589735    0.865877
# 15          15    0.048349   -0.661908    0.382216    0.408450    0.869385
# 16          16    0.218692    0.522477    0.749048    0.718022    0.523983
# 17          17   -0.131988   -0.241482   -0.145920   -0.815077    0.001346
# 18          18    0.330610    0.308318   -0.742307   -0.600224    0.104511
# 19          19    0.752612    0.631906   -0.494266   -0.179948    0.020157
# 20          20    0.335087   -0.336580   -0.554212    0.611627    0.446537
# 21          21    0.002799    0.003338    0.023464    0.055992    0.916794
# 22          22   -0.094892    0.062321   -0.135404   -0.059288    0.744511
# 23          23    0.452777    0.078286   -0.488045   -0.161934    0.474236
# 24          24    0.813869    0.629311   -0.001814    0.122597    0.263905
# 25          25   -0.108196    0.168594   -0.232097    0.221142    0.243493
# 26          26    0.868402    0.411863   -0.247181    0.120777   -0.076617
# 27          27    0.953538    0.890431   -0.068908    0.095324   -0.097108
# 28          28    0.949411    0.881323    0.044447    0.228058   -0.158204
# 29          29    0.972979    0.909810   -0.004455    0.189759   -0.140153
# 30          30    0.396995    0.804348   -0.040812    0.361941   -0.730085
# 31          31    0.898131    0.967287    0.015898    0.005535   -0.030425
# 32          32    0.933191    0.894933    0.083045    0.260305    0.001344
#
#     Factor 3 S  Factor 4 W  Factor 4 S
# 0     0.092405   -0.187900    0.103985
# 1    -0.189770   -0.083704    0.005864
# 2    -0.095089    0.053860   -0.008293
# 3     0.398124    0.600148   -0.001130
# 4     0.354853   -0.393453   -0.314804
# 5     0.134741    0.178400    0.146762
# 6     0.541227    0.753272    0.330763
# 7     0.000633   -0.154322    0.107580
# 8     0.200310    0.407891   -0.254624
# 9     0.165653    0.317573   -0.203793
# 10    0.050185    0.315528    0.289735
# 11    0.028038    0.241910   -0.324851
# 12   -0.031812    0.494893   -0.684711
# 13   -0.163722   -0.348263    0.076928
# 14    0.182782   -0.164912    0.420936
# 15    0.268798   -0.056539    0.292008
# 16   -0.238164   -0.087433   -0.326735
# 17   -0.340338   -0.818849    0.176610
# 18    0.548994    0.305105   -0.013793
# 19    0.728736    0.358238   -0.131759
# 20    0.494128    0.495102    0.350099
# 21    0.023562    0.097700    0.915787
# 22    0.182592    0.067856    0.846886
# 23    0.970911    0.478933    0.184616
# 24    0.554224    0.376289   -0.419455
# 25    0.556493   -0.753417    0.193393
# 26    0.907427    0.239628   -0.024714
# 27    0.409383    0.191880   -0.112160
# 28    0.294475    0.079212   -0.073412
# 29    0.140259    0.133854   -0.176227
# 30    0.182699   -0.156481   -0.248328
# 31    0.181569    0.218528    0.162925
# 32    0.241453    0.041642    0.170666

# %%
fw = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 W"],
    "F2": fa["Factor 2 W"],
    "F3": fa["Factor 3 W"],
    
})
fs = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 S"],
    "F2": fa["Factor 2 S"],
    "F3": fa["Factor 3 S"],
    
})
fw
# Out:
#      Parameters        F1        F2        F3
# 0   Temperature  0.906167 -0.035840 -0.038100
# 1            pH -0.864374  0.495155  0.009661
# 2            EC  0.212881  0.896704  0.136403
# 3           TSS  0.507284 -0.131413  0.133478
# 4     Turbidity  0.824248  0.280855 -0.042003
# 5      Salinity -0.207263  0.750870  0.094029
# 6           TDS  0.425220 -0.103541  0.036552
# 7            DO -0.884095 -0.076105  0.053262
# 8           COD  0.890301 -0.047761  0.144356
# 9           NH4  0.924184  0.050988 -0.029156
# 10          NO3  0.855796  0.005288 -0.199639
# 11    Phosphate  0.205555  0.860114  0.281491
# 12     Sulfates  0.024063  0.674140  0.416042
# 13            K -0.219222  0.373116  0.800038
# 14           Ca -0.009797  0.439532  0.865877
# 15           Mg  0.048349  0.382216  0.869385
# 16           Cl  0.218692  0.749048  0.523983
# 17           Br -0.131988 -0.145920  0.001346
# 18           Cd  0.330610 -0.742307  0.104511
# 19           Cr  0.752612 -0.494266  0.020157
# 20           Ni  0.335087 -0.554212  0.446537
# 21           Cu  0.002799  0.023464  0.916794
# 22           Zn -0.094892 -0.135404  0.744511
# 23           Mn  0.452777 -0.488045  0.474236
# 24           Hg  0.813869 -0.001814  0.263905
# 25           As -0.108196 -0.232097  0.243493
# 26           Pb  0.868402 -0.247181 -0.076617
# 27          THB  0.953538 -0.068908 -0.097108
# 28           TC  0.949411  0.044447 -0.158204
# 29           FC  0.972979 -0.004455 -0.140153
# 30           FS  0.396995 -0.040812 -0.730085
# 31     Vibrio C  0.898131  0.015898 -0.030425
# 32       E Coli  0.933191  0.083045  0.001344

# %%
arrayx = np.array([fw["F1"]])
arrayy = np.array([fw["F2"]])
arrayz = np.array([fw["F3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

# %%
x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])

# %%
labels = list(fw["Parameters"])

# %%
len(labels)
# Out:
# 33

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

param = [ "Temperature","pH","EC","TSS","Turbidity","Salinity","TDS","DO","COD","NH4","NO3","Phosphate",
"Sulfates","K","Ca","Mg","Cl","Br","Cd","Cr","Ni","Cu","Zn","Mn","Hg","As","Pb","THB","TC","FC",
"FS","Vibrio C","E Coli"]

fa = pd.read_csv("../Buriganga/Factor_Analysis_All_Param.csv")
fw = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 W"],
    "F2": fa["Factor 2 W"],
    "F3": fa["Factor 3 W"],
    
})
fs = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 S"],
    "F2": fa["Factor 2 S"],
    "F3": fa["Factor 3 S"],
    
})


arrayx = np.array([fw["F1"]])
arrayy = np.array([fw["F2"]])
arrayz = np.array([fw["F3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])
labels = list(fw["Parameters"])

x_reshape = x.reshape(33,)
y_reshape = y.reshape(33,)
z_reshape = z.reshape(33,)

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="red", s= 1)

for x_label, y_label, z_label, label in zip(x_reshape, y_reshape, z_reshape, labels):
    ax3d.text(x_label, y_label, z_label, label, size=12)

ax3d.set_xlabel("Factor 1 (39.75%)", size = 15)
ax3d.set_ylabel("Factor 2 (16.60%)", size = 15)
ax3d.set_zlabel("Factor 3 (16.18%)", size = 15)
plt.show()
# Out:
# /tmp/ipykernel_4108/2762538518.py:44: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

param = [ "Temperature","pH","EC","TSS","Turbidity","Salinity","TDS","DO","COD","NH4","NO3","Phosphate",
"Sulfates","K","Ca","Mg","Cl","Br","Cd","Cr","Ni","Cu","Zn","Mn","Hg","As","Pb","THB","TC","FC",
"FS","Vibrio C","E Coli"]

fa = pd.read_csv("../Buriganga/Factor_Analysis_All_Param.csv")
fw = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 W"],
    "F2": fa["Factor 2 W"],
    "F3": fa["Factor 3 W"],
    
})
fs = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 S"],
    "F2": fa["Factor 2 S"],
    "F3": fa["Factor 3 S"],
    
})


arrayx = np.array([fw["F1"]])
arrayy = np.array([fw["F2"]])
arrayz = np.array([fw["F3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])
labels = list(fw["Parameters"])

x_reshape = x.reshape(33,)
y_reshape = y.reshape(33,)
z_reshape = z.reshape(33,)

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="red", s= 1)

ax3d.set_xlabel("Factor 1 (39.75%)", size = 15)
ax3d.set_ylabel("Factor 2 (16.60%)", size = 15)
ax3d.set_zlabel("Factor 3 (16.18%)", size = 15)
plt.show()
# Out:
# /tmp/ipykernel_4108/4101392458.py:44: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %% [markdown]
# ## Summer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

param = [ "Temperature","pH","EC","TSS","Turbidity","Salinity","TDS","DO","COD","NH4","NO3","Phosphate",
"Sulfates","K","Ca","Mg","Cl","Br","Cd","Cr","Ni","Cu","Zn","Mn","Hg","As","Pb","THB","TC","FC",
"FS","Vibrio C","E Coli"]

fa = pd.read_csv("../Buriganga/Factor_Analysis_All_Param.csv")
fw = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 W"],
    "F2": fa["Factor 2 W"],
    "F3": fa["Factor 3 W"],
    
})
fs = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 S"],
    "F2": fa["Factor 2 S"],
    "F3": fa["Factor 3 S"],
    
})


arrayx = np.array([fs["F1"]])
arrayy = np.array([fs["F2"]])
arrayz = np.array([fs["F3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])
labels = list(fw["Parameters"])

x_reshape = x.reshape(33,)
y_reshape = y.reshape(33,)
z_reshape = z.reshape(33,)

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="red", s= 1)

ax3d.set_xlabel("Factor 1 (41.41%)", size = 15)
ax3d.set_ylabel("Factor 2 (16.59%)", size = 15)
ax3d.set_zlabel("Factor 3 (14.90%)", size = 15)
plt.show()
# Out:
# /tmp/ipykernel_4108/3344556753.py:44: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

param = [ "Temperature","pH","EC","TSS","Turbidity","Salinity","TDS","DO","COD","NH4","NO3","Phosphate",
"Sulfates","K","Ca","Mg","Cl","Br","Cd","Cr","Ni","Cu","Zn","Mn","Hg","As","Pb","THB","TC","FC",
"FS","Vibrio C","E Coli"]

fa = pd.read_csv("../Buriganga/Factor_Analysis_All_Param.csv")
fw = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 W"],
    "F2": fa["Factor 2 W"],
    "F3": fa["Factor 3 W"],
    
})
fs = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 S"],
    "F2": fa["Factor 2 S"],
    "F3": fa["Factor 3 S"],
    
})


arrayx = np.array([fs["F1"]])
arrayy = np.array([fs["F2"]])
arrayz = np.array([fs["F3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])
labels = list(fs["Parameters"])

x_reshape = x.reshape(33,)
y_reshape = y.reshape(33,)
z_reshape = z.reshape(33,)

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="red", s= 1)

for x_label, y_label, z_label, label in zip(x_reshape, y_reshape, z_reshape, labels):
    ax3d.text(x_label, y_label, z_label, label, size=12)

ax3d.set_xlabel("Factor 1 (41.41%)", size = 15)
ax3d.set_ylabel("Factor 2 (16.59%)", size = 15)
ax3d.set_zlabel("Factor 3 (14.90%)", size = 15)
plt.show()
# Out:
# /tmp/ipykernel_4108/1053093719.py:44: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

param = [ "Temperature","pH","EC","TSS","Turbidity","Salinity","TDS","DO","COD","NH4","NO3","Phosphate",
"Sulfates","K","Ca","Mg","Cl","Br","Cd","Cr","Ni","Cu","Zn","Mn","Hg","As","Pb","THB","TC","FC",
"FS","Vibrio C","E Coli"]

fa = pd.read_csv("../Buriganga/Factor_Analysis_All_Param.csv")
fw = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 W"],
    "F2": fa["Factor 2 W"],
    "F3": fa["Factor 3 W"],
    
})
fs = pd.DataFrame(data={
    "Parameters": param,
    "F1": fa["Factor 1 S"],
    "F2": fa["Factor 2 S"],
    "F3": fa["Factor 3 S"],
    
})


arrayx = np.array([fs["F1"]])
arrayy = np.array([fs["F2"]])
arrayz = np.array([fs["F3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])
labels = list(fs["Parameters"])

x_reshape = x.reshape(33,)
y_reshape = y.reshape(33,)
z_reshape = z.reshape(33,)

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="red", s= 1)


ax3d.set_xlabel("Factor 1 (41.41%)", size = 15)
ax3d.set_ylabel("Factor 2 (16.59%)", size = 15)
ax3d.set_zlabel("Factor 3 (14.90%)", size = 15)
plt.show()
# Out:
# /tmp/ipykernel_4108/3191137184.py:44: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import pandas as pd

fa = pd.read_csv("../Buriganga/Factor_Analysis_All_Param.csv")
fw = pd.DataFrame(data={
    "F1": fa["Factor 1 W"],
    "F2": fa["Factor 2 W"],
    "F3": fa["Factor 3 W"],
    
})
fs = pd.DataFrame(data={
    "F1": fa["Factor 1 S"],
    "F2": fa["Factor 2 S"],
    "F3": fa["Factor 3 S"],
    
})


X = fs.values

kmeans = KMeans(n_clusters=5)
# Fitting with inputs
kmeans = kmeans.fit(X)
# Predicting the clusters
labelsC = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_

fig = plt.figure()

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, s= 30)
ax3d.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#050505', s=200)

ax3d.set_xlabel("F1 (%)")
ax3d.set_ylabel("F2 (%)")
ax3d.set_zlabel("F3 (%)")
plt.show()
# Out:
# /tmp/ipykernel_4108/2526488367.py:35: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5)
# Fitting with inputs
kmeans = kmeans.fit(X)
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_

# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn import preprocessing


fa = pd.read_csv("../Buriganga/Factor_Analysis_All_Param.csv")
fw = pd.DataFrame(data={
    "F1": fa["Factor 1 W"],
    "F2": fa["Factor 2 W"],
    "F3": fa["Factor 3 W"],
    
})

X = fw.values

kmeans = KMeans(n_clusters=5)
# Fitting with inputs
kmeans = kmeans.fit(X)
# Predicting the clusters
labelsC = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_


arrayx = np.array([fs["F1"]])
arrayy = np.array([fs["F2"]])
arrayz = np.array([fs["F3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])

x_reshape = x.reshape(33,)
y_reshape = y.reshape(33,)
z_reshape = z.reshape(33,)


fig = plt.figure()

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, s= 30)
ax3d.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#050505', s=200)

ax3d.set_xlabel("F1 (%)")
ax3d.set_ylabel("F2 (%)")
ax3d.set_zlabel("F3 (%)")
plt.show()
# Out:
# /tmp/ipykernel_4108/1813835481.py:46: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
labels
# Out:
# array([3, 1, 4, 0, 3, 4, 0, 1, 3, 3, 3, 4, 4, 2, 2, 2, 4, 0, 0, 0, 0, 2,
#        2, 0, 3, 0, 3, 3, 3, 3, 3, 3, 3], dtype=int32)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2])
# Out:
# /tmp/ipykernel_5099/2780865410.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
pca = pd.read_csv("data/pca_scores.csv")
pca.rename(columns = {'Unnamed: 0':'Elements'}, inplace = True)

arrayx = np.array([pca["Comp.1"]])
arrayy = np.array([pca["Comp.2"]])
arrayz = np.array([pca["Comp.3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

labels = list(pca["Elements"])
x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])

x_reshape = x.reshape(14,)
y_reshape = y.reshape(14,)
z_reshape = z.reshape(14,)

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="black")

for x_label, y_label, z_label, label in zip(x_reshape, y_reshape, z_reshape, labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
