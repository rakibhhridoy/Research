# %%
! tree data
# Out:
# data
# ├── 350DaysData.csv
# ├── 350DaysData.xlsx
# ├── 350DaysDate.csv
# ├── days
# │   ├── Day0.csv
# │   ├── Day10.csv
# │   ├── Day11.csv
# │   ├── Day12.csv
# │   ├── Day13.csv
# │   ├── Day14.csv
# │   ├── Day15.csv
# │   ├── Day16.csv
# │   ├── Day17.csv
# │   ├── Day18.csv
# │   ├── Day19.csv
# │   ├── Day1.csv
# │   ├── Day20.csv
# │   ├── Day21.csv
# │   ├── Day22.csv
# │   ├── day24.csv
# │   ├── Day2.csv
# │   ├── Day3.csv
# │   ├── Day4.csv
# │   ├── Day5.csv
# │   ├── Day6.csv
# │   ├── Day7.csv
# │   ├── Day8.csv
# │   └── Day9.csv
# ├── LocationA.csv
# ├── LocationB.csv
# ├── LocationC.csv
# ├── LocationD.csv
# ├── param_data
# │   ├── BODA.csv
# │   ├── BODB.csv
# │   ├── BODC.csv
# │   ├── BODD.csv
# │   ├── DOA.csv
# │   ├── DOB.csv
# │   ├── DOC.csv
# │   ├── DOD.csv
# │   ├── ECA.csv
# │   ├── ECB.csv
# │   ├── ECC.csv
# │   ├── ECD.csv
# │   ├── pHA.csv
# │   ├── pHB.csv
# │   ├── pHC.csv
# │   ├── pHD.csv
# │   ├── tempA.csv
# │   ├── tempB.csv
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data/350DaysData.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    object
#  1   TempA   365 non-null    float64
#  2   TempB   365 non-null    float64
#  3   TempC   365 non-null    float64
#  4   TempD   365 non-null    float64
#  5   pHA     365 non-null    float64
#  6   pHB     365 non-null    float64
#  7   pHC     365 non-null    float64
#  8   pHD     365 non-null    float64
#  9   ECA     365 non-null    int64
#  10  ECB     365 non-null    int64
#  11  ECC     365 non-null    int64
#  12  ECD     365 non-null    int64
#  13  DOA     365 non-null    float64
#  14  DOB     365 non-null    float64
#  15  DOC     365 non-null    float64
#  16  DOD     365 non-null    float64
#  17  BODA    365 non-null    float64
#  18  BODB    365 non-null    float64
#  19  BODC    365 non-null    float64
#  20  BODD    365 non-null    float64
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#           TempA     TempB     TempC     TempD       pHA       pHB       pHC  \
# TempA  1.000000  0.990243  0.989833  0.989667 -0.925932 -0.957502 -0.926050
# TempB  0.990243  1.000000  0.989858  0.988078 -0.917609 -0.954828 -0.918731
# TempC  0.989833  0.989858  1.000000  0.989877 -0.922549 -0.955982 -0.927562
# TempD  0.989667  0.988078  0.989877  1.000000 -0.919222 -0.951583 -0.919565
# pHA   -0.925932 -0.917609 -0.922549 -0.919222  1.000000  0.952867  0.958239
# pHB   -0.957502 -0.954828 -0.955982 -0.951583  0.952867  1.000000  0.950419
# pHC   -0.926050 -0.918731 -0.927562 -0.919565  0.958239  0.950419  1.000000
# pHD   -0.916301 -0.909328 -0.918417 -0.903419  0.938030  0.936018  0.973065
# ECA   -0.245265 -0.272497 -0.262804 -0.239649  0.290176  0.280863  0.370458
# ECB   -0.207018 -0.237229 -0.228332 -0.207305  0.251717  0.242289  0.321959
# ECC   -0.120801 -0.154501 -0.142947 -0.124895  0.185127  0.178179  0.242564
# ...

# %%
df.columns
# Out:
# Index(['Date', 'TempA', 'TempB', 'TempC', 'TempD', 'pHA', 'pHB', 'pHC', 'pHD',
#        'ECA', 'ECB', 'ECC', 'ECD', 'DOA', 'DOB', 'DOC', 'DOD', 'BODA', 'BODB',
#        'BODC', 'BODD', 'TNA', 'TNB', 'TNC', 'TND'],
#       dtype='object')

# %%
locA = pd.DataFrame()
locB = pd.DataFrame()
locC = pd.DataFrame()
locD = pd.DataFrame()

locA["Date"] = df.Date
locB["Date"] = df.Date
locC["Date"] = df.Date
locD["Date"] = df.Date

for col in df.columns:
    if col.endswith("A"):
        locA[col] = df[col]
    elif col.endswith("B"):
        locB[col] = df[col]
    elif col.endswith("C"):
        locC[col] = df[col]
    elif col.endswith("D"):
        locD[col] = df[col]

# %%
locA
# Out:
#            Date  TempA   pHA   ECA   DOA   BODA   TNA
# 0    12/15/2021  21.50  7.73  1748  2.55  27.96  1.28
# 1    12/16/2021  21.21  7.82  1765  2.60  27.90  1.08
# 2    12/17/2021  21.21  7.73  1769  2.59  27.88  1.17
# 3    12/18/2021  21.26  7.82  1776  2.63  27.66  1.15
# 4    12/19/2021  21.09  7.76  1822  2.60  27.71  1.22
# ..          ...    ...   ...   ...   ...    ...   ...
# 360  12/10/2022  21.70  7.71  1642  2.45  27.90  1.28
# 361  12/11/2022  21.86  7.72  1640  2.42  28.19  1.29
# 362  12/12/2022  21.67  7.74  1650  2.43  28.12  1.31
# 363  12/13/2022  21.66  7.72  1645  2.43  27.89  1.27
# 364  12/14/2022  21.75  7.72  1636  2.44  28.24  1.29
#
# [365 rows x 7 columns]

# %%
locA.to_csv("data/LocationA.csv")
locB.to_csv("data/LocationB.csv")
locC.to_csv("data/LocationC.csv")
locD.to_csv("data/LocationD.csv")

# %%
sns.set()

fig, axes = plt.subplots(2, 2, figsize= (15,10))

sns.heatmap(locA.corr(), ax= axes[0,0])
sns.heatmap(locB.corr(), ax= axes[0,1])
sns.heatmap(locC.corr(), ax= axes[1,0])
sns.heatmap(locD.corr(), ax= axes[1,1])
# Out:
# <AxesSubplot:>

# %%
locA["pHA"].corr(locA["ECA"])
# Out:
# 0.2901758273639485

# %%
from sklearn import preprocessing

# %%
dataA = locA[["TempA", "pHA", "ECA", "TNA", "BODA"]]

# %%
import numpy as np

# %%
dataA = np.array(dataA)

# %%
dataA
# Out:
# array([[2.150e+01, 7.730e+00, 1.748e+03, 1.280e+00, 2.796e+01],
#        [2.121e+01, 7.820e+00, 1.765e+03, 1.080e+00, 2.790e+01],
#        [2.121e+01, 7.730e+00, 1.769e+03, 1.170e+00, 2.788e+01],
#        ...,
#        [2.167e+01, 7.740e+00, 1.650e+03, 1.310e+00, 2.812e+01],
#        [2.166e+01, 7.720e+00, 1.645e+03, 1.270e+00, 2.789e+01],
#        [2.175e+01, 7.720e+00, 1.636e+03, 1.290e+00, 2.824e+01]])

# %%
#dataA = preprocessing.normalize([dataA])

# %%
dataA
# Out:
# array([2.150e+01, 7.730e+00, 1.748e+03, ..., 1.636e+03, 1.290e+00,
#        2.824e+01])

# %%
dataA.shape
# Out:
# (1825,)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataA, locA.DOA, test_size=0.3,random_state=109)

# %%
X_train.shape
# Out:
# (255, 5)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

X_train, X_test, y_train, y_test = train_test_split(locA[["TempA", "pHA", "ECA", "TNA", "BODA"]], locA.DOA, test_size=0.3,random_state=109)

# %%
X_train.shape
# Out:
# (255, 5)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
print(model.score(X_test, y_test))
# Out:
# 0.97890633825835

# %%
from sklearn.svm import SVR

# %%
model = SVR()

# %%
model.fit(X_train, y_train)
# Out:
# SVR()

# %%
predictions = model.predict(X_test)
print(model.score(X_test, y_test))
# Out:
# -0.07843904465637452

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
predictions = model.predict(X_test)
print(model.score(X_test, y_test))
# Out:
# 0.979898913075035

# %%
model = DecisionTreeRegressor(criterion="friedman_mse")

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse')

# %%
predictions = model.predict(X_test)
print(model.score(X_test, y_test))
# Out:
# 0.9739911068427045

# %%
model = DecisionTreeRegressor(min_samples_split=5)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(min_samples_split=5)

# %%
predictions = model.predict(X_test)
print(model.score(X_test, y_test))
# Out:
# 0.9745838921666004
