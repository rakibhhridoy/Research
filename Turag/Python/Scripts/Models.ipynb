# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_squared_error as mse
from functions_learning import *
from feed_data import data_extract

# %% [markdown]
# ## CNN

# %%
x_train, x_test, y_train, y_test, x_val, y_val = data_extract()

model = Sequential()
model.add(InputLayer((3, 1)))
model.add(Conv1D(64, kernel_size=2))
model.add(Flatten())
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))



cp = ModelCheckpoint('cnn/', save_best_only=True)

model = fit_model(model, cp, 10, x_train, y_train, x_val, y_val)

plot_train("cnn", 50, x_train, y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
plot_predictions1(model,x_test, y_test)
# Out:
# Epoch 1/10
# 1/8 [==>...........................] - ETA: 3s - loss: 5.5064 - root_mean_squared_error: 2.3466
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 147ms/step - loss: 5.1875 - root_mean_squared_error: 2.2776 - val_loss: 4.4620 - val_root_mean_squared_error: 2.1123
# Epoch 2/10
# 1/8 [==>...........................] - ETA: 0s - loss: 5.2664 - root_mean_squared_error: 2.2949
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 92ms/step - loss: 4.9761 - root_mean_squared_error: 2.2307 - val_loss: 4.2832 - val_root_mean_squared_error: 2.0696
# Epoch 3/10
# 1/8 [==>...........................] - ETA: 0s - loss: 4.9978 - root_mean_squared_error: 2.2356
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 101ms/step - loss: 4.7787 - root_mean_squared_error: 2.1860 - val_loss: 4.1205 - val_root_mean_squared_error: 2.0299
# Epoch 4/10
# 1/8 [==>...........................] - ETA: 0s - loss: 5.6058 - root_mean_squared_error: 2.3677
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 91ms/step - loss: 4.6000 - root_mean_squared_error: 2.1448 - val_loss: 3.9607 - val_root_mean_squared_error: 1.9902
# Epoch 5/10
# 1/8 [==>...........................] - ETA: 0s - loss: 4.4080 - root_mean_squared_error: 2.0995
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 90ms/step - loss: 4.4169 - root_mean_squared_error: 2.1016 - val_loss: 3.8110 - val_root_mean_squared_error: 1.9522
# Epoch 6/10
# 1/8 [==>...........................] - ETA: 0s - loss: 3.8651 - root_mean_squared_error: 1.9660
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 165ms/step - loss: 4.2511 - root_mean_squared_error: 2.0618 - val_loss: 3.6625 - val_root_mean_squared_error: 1.9138
# Epoch 7/10
# 1/8 [==>...........................] - ETA: 0s - loss: 4.4233 - root_mean_squared_error: 2.1032
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 89ms/step - loss: 4.0855 - root_mean_squared_error: 2.0213 - val_loss: 3.5233 - val_root_mean_squared_error: 1.8771
# Epoch 8/10
# 1/8 [==>...........................] - ETA: 0s - loss: 4.0897 - root_mean_squared_error: 2.0223
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 90ms/step - loss: 3.9276 - root_mean_squared_error: 1.9818 - val_loss: 3.3875 - val_root_mean_squared_error: 1.8405
# Epoch 9/10
# 1/8 [==>...........................] - ETA: 0s - loss: 3.5971 - root_mean_squared_error: 1.8966
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 119ms/step - loss: 3.7760 - root_mean_squared_error: 1.9432 - val_loss: 3.2552 - val_root_mean_squared_error: 1.8042
# Epoch 10/10
# 1/8 [==>...........................] - ETA: 0s - loss: 3.9504 - root_mean_squared_error: 1.9876
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn/assets
# INFO:tensorflow:Assets written to: cnn/assets
# 8/8 [==============================] - 1s 117ms/step - loss: 3.6298 - root_mean_squared_error: 1.9052 - val_loss: 3.1357 - val_root_mean_squared_error: 1.7708
# 8/8 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 4ms/step
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [4], in <cell line: 19>()
#      17 plot_val(model, 50, x_val, y_val)
#      18 plot_test(model, 50, x_test, y_test)
# ---> 19 plot_predictions1(model,x_test, y_test)
#
# File ~/Research/Turag/Python/Scripts/functions_learning.py:53, in plot_predictions1(model, X, y, start, end)
#      52 def plot_predictions1(model, X, y, start=0, end=100):
# ---> 53     mse_val = mse(y, predictions)
#      54     predictions = model.predict(X).flatten()
#      55     prediction_data = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
#
# UnboundLocalError: local variable 'predictions' referenced before assignment
