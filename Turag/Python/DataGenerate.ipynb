# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/TuragOr.csv")

# %%
df
# Out:
#          Date  TempA  TempB  TempC  TempD   pHA   pHB   pHC   pHD  EC_A  ...  \
# 0   15-Dec-21   21.5   21.2   21.3   21.4  7.73  8.12  7.91  8.48  1748  ...
# 1   30-Dec-21   21.0   20.8   20.5   20.7  7.82  8.06  8.12  8.35  1832  ...
# 2   15-Jan-22   20.5   20.2   20.3   20.2  7.95  8.04  8.29  8.40  2049  ...
# 3   30-Jan-22   20.3   20.0   20.1   19.9  8.17  8.11  8.22  8.43  2105  ...
# 4   15-Feb-22   21.0   20.6   21.1   20.9  8.26  8.17  8.25  8.49  1855  ...
# 5   28-Feb-22   21.8   22.0   21.7   21.5  8.49  8.33  8.32  8.56  1809  ...
# 6   15-Mar-22   24.9   24.6   24.8   24.7  8.02  7.98  8.10  8.17  1796  ...
# 7   30-Mar-22   26.8   26.9   27.0   26.9  7.32  7.65  7.68  7.83  1813  ...
# 8   15-Apr-22   29.1   28.9   29.3   29.7  6.83  6.91  7.12  7.35  1914  ...
# 9   30-Apr-22   31.7   31.5   31.2   31.3  6.22  6.35  6.37  6.29  1928  ...
# 10  15-May-22   33.1   32.7   32.9   32.8  6.30  6.42  6.25  6.18  1609  ...
# ...

# %%
df.columns
# Out:
# Index(['Date', 'TempA', 'TempB', 'TempC', 'TempD', 'pHA', 'pHB', 'pHC', 'pHD',
#        'EC_A', 'EC_B', 'EC_C', 'EC_D', 'DO_A', 'DO_B', 'DO_C', 'DO_D', 'BOD_A',
#        'BOD_B', 'BOD_C', 'BOD_D', 'TN_A', 'TN_B', 'TN_C', 'TN_D'],
#       dtype='object')

# %%
df.describe()
# Out:
#            TempA      TempB      TempC      TempD        pHA        pHB  \
# count  24.000000  24.000000  24.000000  24.000000  24.000000  24.000000
# mean   25.533333  25.387500  25.404167  25.275000   7.366667   7.484167
# std     3.977946   4.034128   3.945220   3.980523   0.615126   0.625536
# min    20.300000  20.000000  20.100000  19.900000   6.220000   6.350000
# 25%    21.950000  21.925000  21.850000  21.725000   7.077500   7.110000
# 50%    24.900000  24.700000  25.050000  24.850000   7.385000   7.670000
# 75%    28.400000  28.300000  28.025000  27.950000   7.752500   7.995000
# max    33.100000  32.700000  32.900000  32.800000   8.490000   8.330000
#
#              pHC        pHD         EC_A         EC_B  ...       DO_C  \
# count  24.000000  24.000000    24.000000    24.000000  ...  24.000000
# mean    7.422500   7.483333  1521.125000  1544.166667  ...   1.729583
# std     0.662251   0.790353   369.459689   326.482128  ...   0.933849
# ...

# %%
temp = df[["TempA", "TempB", "TempC", "TempD"]]
pH   = df[["pHA", "pHB", "pHC", "pHD"]]
ec   = df[["EC_A", "EC_B", "EC_C", "EC_D"]]
do   = df[["DO_A", "DO_B", "DO_C", "DO_D"]]
bod  = df[["BOD_A", "BOD_B", "BOD_C", "BOD_D"]]
tn = df[["TN_A", "TN_B", "TN_C", "TN_D"]]

# %%
temp.head()
# Out:
#    TempA  TempB  TempC  TempD
# 0   21.5   21.2   21.3   21.4
# 1   21.0   20.8   20.5   20.7
# 2   20.5   20.2   20.3   20.2
# 3   20.3   20.0   20.1   19.9
# 4   21.0   20.6   21.1   20.9

# %%
temp.describe()
# Out:
#            TempA      TempB      TempC      TempD
# count  24.000000  24.000000  24.000000  24.000000
# mean   25.533333  25.387500  25.404167  25.275000
# std     3.977946   4.034128   3.945220   3.980523
# min    20.300000  20.000000  20.100000  19.900000
# 25%    21.950000  21.925000  21.850000  21.725000
# 50%    24.900000  24.700000  25.050000  24.850000
# 75%    28.400000  28.300000  28.025000  27.950000
# max    33.100000  32.700000  32.900000  32.800000

# %%
#temp.loc[20:21] = [[2, 3, 4,5],[5,4,3,2]]  
#temp.index = temp.index + 1  
#temp = temp.sort_index()  
#temp

# %%
temp
# Out:
#     TempA  TempB  TempC  TempD
# 0    21.5   21.2   21.3   21.4
# 1    21.0   20.8   20.5   20.7
# 2    20.5   20.2   20.3   20.2
# 3    20.3   20.0   20.1   19.9
# 4    21.0   20.6   21.1   20.9
# 5    21.8   22.0   21.7   21.5
# 6    24.9   24.6   24.8   24.7
# 7    26.8   26.9   27.0   26.9
# 8    29.1   28.9   29.3   29.7
# 9    31.7   31.5   31.2   31.3
# 10   33.1   32.7   32.9   32.8
# 11   32.6   32.2   32.3   32.1
# 12   30.4   30.5   30.3   30.1
# 13   28.7   28.9   28.4   28.1
# 14   28.3   28.1   27.9   27.9
# 15   27.5   27.8   27.2   27.1
# 16   26.8   27.0   26.4   26.2
# 17   26.3   26.5   26.2   26.1
# 18   24.9   24.8   25.3   25.0
# 19   24.2   24.3   24.7   24.5
# 20   23.7   23.2   23.5   23.1
# 21   23.1   22.8   23.0   22.6
# 22   22.6   22.1   22.4   22.0
# 23   22.0   21.7   21.9   21.8

# %%
np.random.uniform(21, 21.5, 2)
# Out:
# array([21.08567965, 21.03327379])

# %%
tempa_mat = []

i=0
while i < len(temp["TempA"]) - 1:
    if temp["TempA"][i] < temp["TempA"][i+1]:
        val = np.random.uniform(temp["TempA"][i+1], temp["TempA"][i], 14)
        tempa_mat.append(val)
    
    val = np.random.uniform(temp["TempA"][i], temp["TempA"][i+1], 14)
    tempa_mat.append(val)
    
    i+=1

# %%
tempa_mat[0].min(),tempa_mat[0].max()
# Out:
# (21.026850468703923, 21.46830133701039)

# %%
tempa_mat[2].min(),tempa_mat[2].max()
# Out:
# (20.303820001887082, 20.48651032528013)

# %%
df.columns
# Out:
# Index(['Date', 'TempA', 'TempB', 'TempC', 'TempD', 'pHA', 'pHB', 'pHC', 'pHD',
#        'EC_A', 'EC_B', 'EC_C', 'EC_D', 'DO_A', 'DO_B', 'DO_C', 'DO_D', 'BOD_A',
#        'BOD_B', 'BOD_C', 'BOD_D', 'TN_A', 'TN_B', 'TN_C', 'TN_D'],
#       dtype='object')

# %%
def data_gen(df):
    paramA = ["TempA", "pHA", "EC_A", "DO_A", "BOD_A", "TN_A"]
    paramB = ["TempB", "pHB", "EC_B", "DO_B", "BOD_B", "TN_B"]
    paramC = ["TempC", "pHC", "EC_C", "DO_C", "BOD_C", "TN_C"]
    paramD = ["TempD", "pHD", "EC_D", "DO_D", "BOD_D", "TN_D"]
    

    
    tempA_mat,tempB_mat,tempC_mat,tempD_mat,pHA_mat,pHB_mat,pHC_mat,pHD_mat,ECA_mat,ECB_mat,ECC_mat,ECD_mat,DOA_mat,DOB_mat,DOC_mat,DOD_mat,BODA_mat,BODB_mat,BODC_mat,BODD_mat,TNA_mat, TNB_mat, TNC_mat, TND_mat = val_append(df, paramA, paramB, paramC, paramD, i )
    
    return tempA_mat,tempB_mat,tempC_mat,tempD_mat,pHA_mat,pHB_mat,pHC_mat,pHD_mat,ECA_mat,ECB_mat,ECC_mat,ECD_mat,DOA_mat,DOB_mat,DOC_mat,DOD_mat,BODA_mat,BODB_mat,BODC_mat,BODD_mat,TNA_mat, TNB_mat, TNC_mat, TND_mat

        

        
        
def val_append(df, paramA, paramB, paramC, paramD, i):
    
    
    tempA_mat = []
    tempB_mat = []
    tempC_mat = []
    tempD_mat = []

    pHA_mat = []
    pHB_mat = []
    pHC_mat = []
    pHD_mat = []
    
    ECA_mat = []
    ECB_mat = []
    ECC_mat = []
    ECD_mat = []
    
    DOA_mat = []
    DOB_mat = []
    DOC_mat = []
    DOD_mat = []

    BODA_mat = []
    BODB_mat = []
    BODC_mat = []
    BODD_mat = []
    
    TNA_mat = []
    TNB_mat = []
    TNC_mat = []
    TND_mat = []

    
    i = 0
    while i < len(temp["TempA"]) - 1:
    
    #temp
    
        if df[paramA[0]][i] < df[paramA[0]][i+1]:
                val = np.random.uniform(df[paramA[0]][i+1], df[paramA[0]][i], 15)
                tempA_mat.append(val)
        else:
            val = np.random.uniform(df[paramA[0]][i], df[paramA[0]][i+1], 15)
            tempA_mat.append(val)

        if df[paramB[0]][i] < df[paramB[0]][i+1]:
                val = np.random.uniform(df[paramB[0]][i+1], df[paramB[0]][i], 15)
                tempB_mat.append(val)
        else:
            val = np.random.uniform(df[paramB[0]][i], df[paramB[0]][i+1], 15)
            tempB_mat.append(val)

        if df[paramC[0]][i] < df[paramC[0]][i+1]:
                val = np.random.uniform(df[paramC[0]][i+1], df[paramC[0]][i], 15)
                tempC_mat.append(val)
        else:
            val = np.random.uniform(df[paramC[0]][i], df[paramC[0]][i+1], 15)
            tempC_mat.append(val)

        if df[paramD[0]][i] < df[paramD[0]][i+1]:
                val = np.random.uniform(df[paramD[0]][i+1], df[paramD[0]][i], 15)
                tempD_mat.append(val)
        else:
            val = np.random.uniform(df[paramD[0]][i], df[paramD[0]][i+1], 15)
            tempD_mat.append(val)


        #pH

        if df[paramA[1]][i] < df[paramA[1]][i+1]:
                val = np.random.uniform(df[paramA[1]][i+1], df[paramA[1]][i], 15)
                pHA_mat.append(val)
        else:
            val = np.random.uniform(df[paramA[1]][i], df[paramA[1]][i+1], 15)
            pHA_mat.append(val)

        if df[paramB[1]][i] < df[paramB[1]][i+1]:
                val = np.random.uniform(df[paramB[1]][i+1], df[paramB[1]][i], 15)
                pHB_mat.append(val)
        else:
            val = np.random.uniform(df[paramB[1]][i], df[paramB[1]][i+1], 15)
            pHB_mat.append(val)

        if df[paramC[1]][i] < df[paramC[1]][i+1]:
                val = np.random.uniform(df[paramC[1]][i+1], df[paramC[1]][i], 15)
                pHC_mat.append(val)
        else:
            val = np.random.uniform(df[paramC[1]][i], df[paramC[1]][i+1], 15)
            pHC_mat.append(val)

        if df[paramD[1]][i] < df[paramD[1]][i+1]:
                val = np.random.uniform(df[paramD[1]][i+1], df[paramD[1]][i], 15)
                pHD_mat.append(val)
        else:
            val = np.random.uniform(df[paramD[1]][i], df[paramD[1]][i+1], 15)
            pHD_mat.append(val)

        #EC

        if df[paramA[2]][i] < df[paramA[2]][i+1]:
                val = np.random.uniform(df[paramA[2]][i+1], df[paramA[2]][i], 15)
                ECA_mat.append(val)
        else:
            val = np.random.uniform(df[paramA[2]][i], df[paramA[2]][i+1], 15)
            ECA_mat.append(val)

        if df[paramB[2]][i] < df[paramB[2]][i+1]:
                val = np.random.uniform(df[paramB[2]][i+1], df[paramB[2]][i], 15)
                ECB_mat.append(val)
        else:
            val = np.random.uniform(df[paramB[2]][i], df[paramB[2]][i+1], 15)
            ECB_mat.append(val)

        if df[paramC[2]][i] < df[paramC[2]][i+1]:
                val = np.random.uniform(df[paramC[2]][i+1], df[paramC[2]][i], 15)
                ECC_mat.append(val)
        else:
            val = np.random.uniform(df[paramC[2]][i], df[paramC[2]][i+1], 15)
            ECC_mat.append(val)

        if df[paramD[2]][i] < df[paramD[2]][i+1]:
                val = np.random.uniform(df[paramD[2]][i+1], df[paramD[2]][i], 15)
                ECD_mat.append(val)
        else:
            val = np.random.uniform(df[paramD[2]][i], df[paramD[2]][i+1], 15)
            ECD_mat.append(val)


        #DO

        if df[paramA[3]][i] < df[paramA[3]][i+1]:
                val = np.random.uniform(df[paramA[3]][i+1], df[paramA[3]][i], 15)
                DOA_mat.append(val)
        else:
            val = np.random.uniform(df[paramA[3]][i], df[paramA[3]][i+1], 15)
            DOA_mat.append(val)

        if df[paramB[3]][i] < df[paramB[3]][i+1]:
                val = np.random.uniform(df[paramB[3]][i+1], df[paramB[3]][i], 15)
                DOB_mat.append(val)
        else:
            val = np.random.uniform(df[paramB[3]][i], df[paramB[3]][i+1], 15)
            DOB_mat.append(val)

        if df[paramC[3]][i] < df[paramC[3]][i+1]:
                val = np.random.uniform(df[paramC[3]][i+1], df[paramC[3]][i], 15)
                DOC_mat.append(val)
        else:
            val = np.random.uniform(df[paramC[3]][i], df[paramC[3]][i+1], 15)
            DOC_mat.append(val)

        if df[paramD[3]][i] < df[paramD[3]][i+1]:
                val = np.random.uniform(df[paramD[3]][i+1], df[paramD[3]][i], 15)
                DOD_mat.append(val)
        else:
            val = np.random.uniform(df[paramD[3]][i], df[paramD[3]][i+1], 15)
            DOD_mat.append(val)



        #BOD

        if df[paramA[4]][i] < df[paramA[4]][i+1]:
                val = np.random.uniform(df[paramA[4]][i+1], df[paramA[4]][i], 15)
                BODA_mat.append(val)
        else:
            val = np.random.uniform(df[paramA[4]][i], df[paramA[4]][i+1], 15)
            BODA_mat.append(val)

        if df[paramB[4]][i] < df[paramB[4]][i+1]:
                val = np.random.uniform(df[paramB[4]][i+1], df[paramB[4]][i], 15)
                BODB_mat.append(val)
        else:
            val = np.random.uniform(df[paramB[4]][i], df[paramB[4]][i+1], 15)
            BODB_mat.append(val)

        if df[paramC[4]][i] < df[paramC[4]][i+1]:
                val = np.random.uniform(df[paramC[4]][i+1], df[paramC[4]][i], 15)
                BODC_mat.append(val)
        else:
            val = np.random.uniform(df[paramC[4]][i], df[paramC[4]][i+1], 15)
            BODC_mat.append(val)

        if df[paramD[4]][i] < df[paramD[4]][i+1]:
                val = np.random.uniform(df[paramD[4]][i+1], df[paramD[4]][i], 15)
                BODD_mat.append(val)
        else:
            val = np.random.uniform(df[paramD[4]][i], df[paramD[4]][i+1], 15)
            BODD_mat.append(val)


        #TN

        if df[paramA[5]][i] < df[paramA[5]][i+1]:
                val = np.random.uniform(df[paramA[5]][i+1], df[paramA[5]][i], 15)
                TNA_mat.append(val)
        else:
            val = np.random.uniform(df[paramA[5]][i], df[paramA[5]][i+1], 15)
            TNA_mat.append(val)

        if df[paramB[5]][i] < df[paramB[5]][i+1]:
                val = np.random.uniform(df[paramB[5]][i+1], df[paramB[5]][i], 15)
                TNB_mat.append(val)
        else:
            val = np.random.uniform(df[paramB[5]][i], df[paramB[5]][i+1], 15)
            TNB_mat.append(val)

        if df[paramC[5]][i] < df[paramC[5]][i+1]:
                val = np.random.uniform(df[paramC[5]][i+1], df[paramC[5]][i], 15)
                TNC_mat.append(val)
        else:
            val = np.random.uniform(df[paramC[5]][i], df[paramC[5]][i+1], 15)
            TNC_mat.append(val)

        if df[paramD[5]][i] < df[paramD[5]][i+1]:
                val = np.random.uniform(df[paramD[5]][i+1], df[paramD[5]][i], 15)
                TND_mat.append(val)
        else:
            val = np.random.uniform(df[paramD[5]][i], df[paramD[5]][i+1], 15)
            TND_mat.append(val)

        i+=1
    
    return tempA_mat,tempB_mat,tempC_mat,tempD_mat,pHA_mat,pHB_mat,pHC_mat,pHD_mat,ECA_mat,ECB_mat,ECC_mat,ECD_mat,DOA_mat,DOB_mat,DOC_mat,DOD_mat,BODA_mat,BODB_mat,BODC_mat,BODD_mat,TNA_mat, TNB_mat, TNC_mat, TND_mat

# %%
tempA_mat,tempB_mat,tempC_mat,tempD_mat,pHA_mat,pHB_mat,pHC_mat,pHD_mat,ECA_mat,ECB_mat,ECC_mat,ECD_mat,DOA_mat,DOB_mat,DOC_mat,DOD_mat,BODA_mat,BODB_mat,BODC_mat,BODD_mat,TNA_mat, TNB_mat, TNC_mat, TND_mat = data_gen(df)

# %%
tempA_list = []
tempB_list = []
tempC_list = []
tempD_list = []

pHA_list = []
pHB_list = []
pHC_list = []
pHD_list = []

ECA_list = []
ECB_list = []
ECC_list = []
ECD_list = []

DOA_list = []
DOB_list = []
DOC_list = []
DOD_list = []

BODA_list = []
BODB_list = []
BODC_list = []
BODD_list = []

TNA_list = []
TNB_list = []
TNC_list = []
TND_list = []


i=0
while i< len(tempA_mat):
    tempA_list.append(tempA_mat[i].tolist())
    tempB_list.append(tempB_mat[i].tolist())
    tempC_list.append(tempC_mat[i].tolist())
    tempD_list.append(tempD_mat[i].tolist())
    
    pHA_list.append(pHA_mat[i].tolist())
    pHB_list.append(pHB_mat[i].tolist())
    pHC_list.append(pHC_mat[i].tolist())
    pHD_list.append(pHD_mat[i].tolist())
    
    ECA_list.append(ECA_mat[i].tolist())
    ECB_list.append(ECB_mat[i].tolist())
    ECC_list.append(ECC_mat[i].tolist())
    ECD_list.append(ECD_mat[i].tolist())
    
    DOA_list.append(DOA_mat[i].tolist())
    DOB_list.append(DOB_mat[i].tolist())
    DOC_list.append(DOC_mat[i].tolist())
    DOD_list.append(DOD_mat[i].tolist())
    
    BODA_list.append(BODA_mat[i].tolist())
    BODB_list.append(BODB_mat[i].tolist())
    BODC_list.append(BODC_mat[i].tolist())
    BODD_list.append(BODD_mat[i].tolist())
    
    TNA_list.append(TNA_mat[i].tolist())
    TNB_list.append(TNB_mat[i].tolist())
    TNC_list.append(TNC_mat[i].tolist())
    TND_list.append(TND_mat[i].tolist())
    
    
    i += 1

tempA_list
# Out:
# [[21.20619169199319,
#   21.210902468590238,
#   21.257416475726465,
#   21.093704869879527,
#   21.20844155436343,
#   21.448270144069557,
#   21.228976703133487,
#   21.015191755577792,
#   21.2503309740264,
#   21.331753928970205,
#   21.070343034615306,
#   21.47695308574595,
#   21.46012376385791,
#   21.172848197043635,
#   21.346330516729868],
#  [20.89339891590937,
#   20.553093843029206,
#   20.84013269063882,
#   20.947527545042416,
#   20.72837897032652,
#   20.766414243939717,
#   20.706632234439414,
#   20.832312996915753,
#   20.78268996964264,
#   20.94693516044031,
#   20.652473200296647,
#   20.717388094519812,
#   20.812309793278718,
#   20.66792430039754,
#   20.983164143926324],
#  [20.359393123338613,
#   20.472738988802867,
#   20.432174644396653,
#   20.37756208346038,
#   20.38035546754564,
#   20.45862972893119,
#   20.407704975830168,
#   20.476708310975706,
#   20.350422919078465,
#   20.344439203765624,
#   20.393503352642494,
#   20.38905356661099,
# ...

# %%
pHA_list
# Out:
# [[7.818670991515116,
#   7.733692760242836,
#   7.818442715357965,
#   7.760057974471307,
#   7.803024148512008,
#   7.78039593162075,
#   7.787964496539523,
#   7.743336361046309,
#   7.74873108296885,
#   7.7547501717383795,
#   7.759525278246768,
#   7.752960301590294,
#   7.77088244405124,
#   7.759082825606604,
#   7.763946988879247],
#  [7.8378497379137775,
#   7.895135785582795,
#   7.849716246323789,
#   7.864562506750583,
#   7.915522474265804,
#   7.8778705842089645,
#   7.941976426937999,
#   7.903908085078946,
#   7.832495981031882,
#   7.936830771026462,
#   7.8905438183226,
#   7.8451358082614115,
#   7.931996443863841,
#   7.850850218773281,
#   7.825201707635054],
#  [8.111086640254504,
#   8.105480515101814,
#   8.12747205035217,
#   7.965806554839446,
#   8.11527005079688,
#   7.978750116096995,
#   8.033387996544413,
#   8.137773849503311,
#   7.978886336815607,
#   8.109644768192878,
#   8.102585716651214,
#   7.961105280417475,
#   8.044932839417536,
# ...

# %%
test = temp.copy()

# %%
test
# Out:
#     TempA  TempB  TempC  TempD
# 0    21.5   21.2   21.3   21.4
# 1    21.0   20.8   20.5   20.7
# 2    20.5   20.2   20.3   20.2
# 3    20.3   20.0   20.1   19.9
# 4    21.0   20.6   21.1   20.9
# 5    21.8   22.0   21.7   21.5
# 6    24.9   24.6   24.8   24.7
# 7    26.8   26.9   27.0   26.9
# 8    29.1   28.9   29.3   29.7
# 9    31.7   31.5   31.2   31.3
# 10   33.1   32.7   32.9   32.8
# 11   32.6   32.2   32.3   32.1
# 12   30.4   30.5   30.3   30.1
# 13   28.7   28.9   28.4   28.1
# 14   28.3   28.1   27.9   27.9
# 15   27.5   27.8   27.2   27.1
# 16   26.8   27.0   26.4   26.2
# 17   26.3   26.5   26.2   26.1
# 18   24.9   24.8   25.3   25.0
# 19   24.2   24.3   24.7   24.5
# 20   23.7   23.2   23.5   23.1
# 21   23.1   22.8   23.0   22.6
# 22   22.6   22.1   22.4   22.0
# 23   22.0   21.7   21.9   21.8

# %%
tempA_list[0]
# Out:
# [21.20619169199319,
#  21.210902468590238,
#  21.257416475726465,
#  21.093704869879527,
#  21.20844155436343,
#  21.448270144069557,
#  21.228976703133487,
#  21.015191755577792,
#  21.2503309740264,
#  21.331753928970205,
#  21.070343034615306,
#  21.47695308574595,
#  21.46012376385791,
#  21.172848197043635,
#  21.346330516729868]

# %%
tempA_mat[0]
# Out:
# array([21.20619169, 21.21090247, 21.25741648, 21.09370487, 21.20844155,
#        21.44827014, 21.2289767 , 21.01519176, 21.25033097, 21.33175393,
#        21.07034303, 21.47695309, 21.46012376, 21.1728482 , 21.34633052])

# %%
temp = pd.DataFrame(tempA_list)

# %%
temp.T
# Out:
#            0          1          2          3          4          5   \
# 0   21.206192  20.893399  20.359393  20.924390  21.249288  23.514003
# 1   21.210902  20.553094  20.472739  20.953833  21.527635  22.545370
# 2   21.257416  20.840133  20.432175  20.776236  21.187028  21.860403
# 3   21.093705  20.947528  20.377562  20.558153  21.524502  24.439887
# 4   21.208442  20.728379  20.380355  20.710097  21.240873  23.301225
# 5   21.448270  20.766414  20.458630  20.404766  21.338511  22.614765
# 6   21.228977  20.706632  20.407705  20.383632  21.092605  24.672310
# 7   21.015192  20.832313  20.476708  20.460869  21.033699  23.961031
# 8   21.250331  20.782690  20.350423  20.659353  21.668217  23.824478
# 9   21.331754  20.946935  20.344439  20.964541  21.123518  23.110478
# 10  21.070343  20.652473  20.393503  20.362513  21.291384  22.516593
# 11  21.476953  20.717388  20.389054  20.795170  21.684438  23.493657
# 12  21.460124  20.812310  20.300157  20.927156  21.738416  22.763259
# ...

# %%
tempA = pd.DataFrame(tempA_list)
tempB = pd.DataFrame(tempB_list)
tempC = pd.DataFrame(tempC_list)
tempD = pd.DataFrame(tempD_list)

pHA = pd.DataFrame(pHA_list)
pHB = pd.DataFrame(pHB_list)
pHC = pd.DataFrame(pHC_list)
pHD = pd.DataFrame(pHD_list)

DOA = pd.DataFrame(DOA_list)
DOB = pd.DataFrame(DOB_list)
DOC = pd.DataFrame(DOC_list)
DOD = pd.DataFrame(DOD_list)

BODA = pd.DataFrame(BODA_list)
BODB = pd.DataFrame(BODB_list)
BODC = pd.DataFrame(BODC_list)
BODD = pd.DataFrame(BODD_list)

ECA = pd.DataFrame(ECA_list)
ECB = pd.DataFrame(ECB_list)
ECC = pd.DataFrame(ECC_list)
ECD = pd.DataFrame(ECD_list)

TNA = pd.DataFrame(TNA_list)
TNB = pd.DataFrame(TNB_list)
TNC = pd.DataFrame(TNC_list)
TND = pd.DataFrame(TND_list)

# %%
tempA = tempA.T
tempB = tempB.T
tempC = tempC.T
tempD = tempD.T

pHA = pHA.T
pHB = pHB.T
pHC = pHC.T
pHD = pHD.T

ECA = ECA.T
ECB = ECB.T
ECC = ECC.T
ECD = ECD.T

DOA = DOA.T
DOB = DOB.T
DOC = DOC.T
DOD = DOD.T

BODA = BODA.T
BODB = BODB.T
BODC = BODC.T
BODD = BODD.T

TNA = TNA.T
TNB = TNB.T
TNC = TNC.T
TND = TND.T

# %%
tempA.to_csv("tempA.csv")
tempB.to_csv("tempB.csv")
tempC.to_csv("tempC.csv")
tempD.to_csv("tempD.csv")


pHA.to_csv("pHA.csv")
pHB.to_csv("pHB.csv")
pHC.to_csv("pHC.csv")
pHD.to_csv("pHD.csv")   

ECA.to_csv("ECA.csv")
ECB.to_csv("ECB.csv")
ECC.to_csv("ECC.csv")
ECD.to_csv("ECD.csv")   

DOA.to_csv("DOA.csv")
DOB.to_csv("DOB.csv")
DOC.to_csv("DOC.csv")
DOD.to_csv("DOD.csv")   

BODA.to_csv("BODA.csv")
BODB.to_csv("BODB.csv")
BODC.to_csv("BODC.csv")
BODD.to_csv("BODD.csv")   

TNA.to_csv("TNA.csv")
TNB.to_csv("TNB.csv")
TNC.to_csv("TNC.csv")
TND.to_csv("TND.csv")

# %%
tempA
# Out:
#            0          1          2          3          4          5   \
# 0   21.206192  20.893399  20.359393  20.924390  21.249288  23.514003
# 1   21.210902  20.553094  20.472739  20.953833  21.527635  22.545370
# 2   21.257416  20.840133  20.432175  20.776236  21.187028  21.860403
# 3   21.093705  20.947528  20.377562  20.558153  21.524502  24.439887
# 4   21.208442  20.728379  20.380355  20.710097  21.240873  23.301225
# 5   21.448270  20.766414  20.458630  20.404766  21.338511  22.614765
# 6   21.228977  20.706632  20.407705  20.383632  21.092605  24.672310
# 7   21.015192  20.832313  20.476708  20.460869  21.033699  23.961031
# 8   21.250331  20.782690  20.350423  20.659353  21.668217  23.824478
# 9   21.331754  20.946935  20.344439  20.964541  21.123518  23.110478
# 10  21.070343  20.652473  20.393503  20.362513  21.291384  22.516593
# 11  21.476953  20.717388  20.389054  20.795170  21.684438  23.493657
# 12  21.460124  20.812310  20.300157  20.927156  21.738416  22.763259
# ...

# %%
import datetime
import pandas as pd
 
# initializing date
test_date = datetime.datetime.strptime("16-12-2021", "%d-%m-%Y")
 
# initializing K
K = 14
 
date_generated = pd.date_range(test_date, periods=K)
date_generated
# Out:
# DatetimeIndex(['2021-12-16', '2021-12-17', '2021-12-18', '2021-12-19',
#                '2021-12-20', '2021-12-21', '2021-12-22', '2021-12-23',
#                '2021-12-24', '2021-12-25', '2021-12-26', '2021-12-27',
#                '2021-12-28', '2021-12-29'],
#               dtype='datetime64[ns]', freq='D')

# %%
test_date = datetime.datetime.strptime("16-12-2021", "%d-%m-%Y")
day0 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("31-12-2021", "%d-%m-%Y")
day1 = pd.date_range(test_date, periods=15)

test_date = datetime.datetime.strptime("16-1-2022", "%d-%m-%Y")
day2 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("31-1-2022", "%d-%m-%Y")
day3 = pd.date_range(test_date, periods=15)

test_date = datetime.datetime.strptime("16-2-2022", "%d-%m-%Y")
day4 = pd.date_range(test_date, periods=12)

test_date = datetime.datetime.strptime("1-3-2022", "%d-%m-%Y")
day5 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("16-3-2022", "%d-%m-%Y")
day6 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("31-3-2022", "%d-%m-%Y")
day7 = pd.date_range(test_date, periods=15)

test_date = datetime.datetime.strptime("16-4-2022", "%d-%m-%Y")
day8 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("1-5-2022", "%d-%m-%Y")
day9 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("16-5-2022", "%d-%m-%Y")
day10 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("31-5-2022", "%d-%m-%Y")
day11 = pd.date_range(test_date, periods=15)

test_date = datetime.datetime.strptime("16-6-2022", "%d-%m-%Y")
day12 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("1-7-2022", "%d-%m-%Y")
day13 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("15-7-2022", "%d-%m-%Y")
day14 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("31-7-2022", "%d-%m-%Y")
day15 = pd.date_range(test_date, periods=15)

test_date = datetime.datetime.strptime("16-8-2022", "%d-%m-%Y")
day16 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("31-8-2022", "%d-%m-%Y")
day17 = pd.date_range(test_date, periods=15)

test_date = datetime.datetime.strptime("16-9-2022", "%d-%m-%Y")
day18 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("1-10-2022", "%d-%m-%Y")
day19 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("16-10-2022", "%d-%m-%Y")
day20 = pd.date_range(test_date, periods=14)

test_date = datetime.datetime.strptime("31-10-2022", "%d-%m-%Y")
day21 = pd.date_range(test_date, periods=15)

test_date = datetime.datetime.strptime("16-11-2022", "%d-%m-%Y")
day22 = pd.date_range(test_date, periods=14)

# %%
day1
# Out:
# DatetimeIndex(['2021-12-31', '2022-01-01', '2022-01-02', '2022-01-03',
#                '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-07',
#                '2022-01-08', '2022-01-09', '2022-01-10', '2022-01-11',
#                '2022-01-12', '2022-01-13', '2022-01-14'],
#               dtype='datetime64[ns]', freq='D')

# %%
cols = ["day0",
        "day1",
        "day2",
        "day3",
        "day4",
        "day5",
        "day6",
        "day7",
        "day8",
        "day9",
        "day10",
        "day11",
        "day12",
        "day13",
        "day14",
        "day15",
        "day16",
        "day17",
        "day18",
        "day19",
        "day20",
        "day21",
        "day22"]

# %%
temp = [tempA,tempB,tempC,tempD]
pH = [pHA,pHB,pHC,pHD]
EC = [ECA,ECB,ECC,ECD]
DO = [DOA,DOB,DOC,DOD]
BOD = [BODA,BODB,BODC,BODD]
TN = [TNA,TNB,TNC,TND]

# %%
for df in temp:
    df.columns = cols

for df in pH:
    df.columns = cols

for df in EC:
    df.columns = cols

for df in DO:
    df.columns = cols

for df in BOD:
    df.columns = cols

for df in TN:
    df.columns = cols

# %%
tempA
# Out:
#          day0       day1       day2       day3       day4       day5  \
# 0   21.206192  20.893399  20.359393  20.924390  21.249288  23.514003
# 1   21.210902  20.553094  20.472739  20.953833  21.527635  22.545370
# 2   21.257416  20.840133  20.432175  20.776236  21.187028  21.860403
# 3   21.093705  20.947528  20.377562  20.558153  21.524502  24.439887
# 4   21.208442  20.728379  20.380355  20.710097  21.240873  23.301225
# 5   21.448270  20.766414  20.458630  20.404766  21.338511  22.614765
# 6   21.228977  20.706632  20.407705  20.383632  21.092605  24.672310
# 7   21.015192  20.832313  20.476708  20.460869  21.033699  23.961031
# 8   21.250331  20.782690  20.350423  20.659353  21.668217  23.824478
# 9   21.331754  20.946935  20.344439  20.964541  21.123518  23.110478
# 10  21.070343  20.652473  20.393503  20.362513  21.291384  22.516593
# 11  21.476953  20.717388  20.389054  20.795170  21.684438  23.493657
# 12  21.460124  20.812310  20.300157  20.927156  21.738416  22.763259
# ...

# %%
range0 = pd.DataFrame(data={
    
    "TempA": tempA["day0"],
    "TempB": tempB["day0"],
    "TempC": tempC["day0"],
    "TempD": tempD["day0"],
    
    "pHA": pHA["day0"],
    "pHB": pHB["day0"],
    "pHC": pHC["day0"],
    "pHD": pHD["day0"],
    
    "ECA": ECA["day0"],
    "ECB": ECB["day0"],
    "ECC": ECC["day0"],
    "ECD": ECD["day0"],
    
    "DOA": DOA["day0"],
    "DOB": DOB["day0"],
    "DOC": DOC["day0"],
    "DOD": DOD["day0"],
    
    "BODA": BODA["day0"],
    "BODB": BODB["day0"],
    "BODC": BODC["day0"],
    "BODD": BODD["day0"],
    
    "TNA": TNA["day0"],
    "TNB": TNB["day0"],
    "TNC": TNC["day0"],
    "TND": TND["day0"],

})

range1 = pd.DataFrame(data={
    
    "TempA": tempA["day1"],
    "TempB": tempB["day1"],
    "TempC": tempC["day1"],
    "TempD": tempD["day1"],
    
    "pHA": pHA["day1"],
    "pHB": pHB["day1"],
    "pHC": pHC["day1"],
    "pHD": pHD["day1"],
    
    "ECA": ECA["day1"],
    "ECB": ECB["day1"],
    "ECC": ECC["day1"],
    "ECD": ECD["day1"],
    
    "DOA": DOA["day1"],
    "DOB": DOB["day1"],
    "DOC": DOC["day1"],
    "DOD": DOD["day1"],
    
    "BODA": BODA["day1"],
    "BODB": BODB["day1"],
    "BODC": BODC["day1"],
    "BODD": BODD["day1"],
    
    "TNA": TNA["day1"],
    "TNB": TNB["day1"],
    "TNC": TNC["day1"],
    "TND": TND["day1"],

})

range2 = pd.DataFrame(data={
    
    "TempA": tempA["day2"],
    "TempB": tempB["day2"],
    "TempC": tempC["day2"],
    "TempD": tempD["day2"],
    
    "pHA": pHA["day2"],
    "pHB": pHB["day2"],
    "pHC": pHC["day2"],
    "pHD": pHD["day2"],
    
    "ECA": ECA["day2"],
    "ECB": ECB["day2"],
    "ECC": ECC["day2"],
    "ECD": ECD["day2"],
    
    "DOA": DOA["day2"],
    "DOB": DOB["day2"],
    "DOC": DOC["day2"],
    "DOD": DOD["day2"],
    
    "BODA": BODA["day2"],
    "BODB": BODB["day2"],
    "BODC": BODC["day2"],
    "BODD": BODD["day2"],
    
    "TNA": TNA["day2"],
    "TNB": TNB["day2"],
    "TNC": TNC["day2"],
    "TND": TND["day2"],

})


range3 = pd.DataFrame(data={
    
    "TempA": tempA["day3"],
    "TempB": tempB["day3"],
    "TempC": tempC["day3"],
    "TempD": tempD["day3"],
    
    "pHA": pHA["day3"],
    "pHB": pHB["day3"],
    "pHC": pHC["day3"],
    "pHD": pHD["day3"],
    
    "ECA": ECA["day3"],
    "ECB": ECB["day3"],
    "ECC": ECC["day3"],
    "ECD": ECD["day3"],
    
    "DOA": DOA["day3"],
    "DOB": DOB["day3"],
    "DOC": DOC["day3"],
    "DOD": DOD["day3"],
    
    "BODA": BODA["day3"],
    "BODB": BODB["day3"],
    "BODC": BODC["day3"],
    "BODD": BODD["day3"],
    
    "TNA": TNA["day3"],
    "TNB": TNB["day3"],
    "TNC": TNC["day3"],
    "TND": TND["day3"],

})

range4 = pd.DataFrame(data={
    
    "TempA": tempA["day4"],
    "TempB": tempB["day4"],
    "TempC": tempC["day4"],
    "TempD": tempD["day4"],
    
    "pHA": pHA["day4"],
    "pHB": pHB["day4"],
    "pHC": pHC["day4"],
    "pHD": pHD["day4"],
    
    "ECA": ECA["day4"],
    "ECB": ECB["day4"],
    "ECC": ECC["day4"],
    "ECD": ECD["day4"],
    
    "DOA": DOA["day4"],
    "DOB": DOB["day4"],
    "DOC": DOC["day4"],
    "DOD": DOD["day4"],
    
    "BODA": BODA["day4"],
    "BODB": BODB["day4"],
    "BODC": BODC["day4"],
    "BODD": BODD["day4"],
    
    "TNA": TNA["day4"],
    "TNB": TNB["day4"],
    "TNC": TNC["day4"],
    "TND": TND["day4"],

})

range5 = pd.DataFrame(data={

    
    "TempA": tempA["day5"],
    "TempB": tempB["day5"],
    "TempC": tempC["day5"],
    "TempD": tempD["day5"],
    
    "pHA": pHA["day5"],
    "pHB": pHB["day5"],
    "pHC": pHC["day5"],
    "pHD": pHD["day5"],
    
    "ECA": ECA["day5"],
    "ECB": ECB["day5"],
    "ECC": ECC["day5"],
    "ECD": ECD["day5"],
    
    "DOA": DOA["day5"],
    "DOB": DOB["day5"],
    "DOC": DOC["day5"],
    "DOD": DOD["day5"],
    
    "BODA": BODA["day5"],
    "BODB": BODB["day5"],
    "BODC": BODC["day5"],
    "BODD": BODD["day5"],
    
    "TNA": TNA["day5"],
    "TNB": TNB["day5"],
    "TNC": TNC["day5"],
    "TND": TND["day5"],

})


range6 = pd.DataFrame(data={
    
    "TempA": tempA["day6"],
    "TempB": tempB["day6"],
    "TempC": tempC["day6"],
    "TempD": tempD["day6"],
    
    "pHA": pHA["day6"],
    "pHB": pHB["day6"],
    "pHC": pHC["day6"],
    "pHD": pHD["day6"],
    
    "ECA": ECA["day6"],
    "ECB": ECB["day6"],
    "ECC": ECC["day6"],
    "ECD": ECD["day6"],
    
    "DOA": DOA["day6"],
    "DOB": DOB["day6"],
    "DOC": DOC["day6"],
    "DOD": DOD["day6"],
    
    "BODA": BODA["day6"],
    "BODB": BODB["day6"],
    "BODC": BODC["day6"],
    "BODD": BODD["day6"],
    
    "TNA": TNA["day6"],
    "TNB": TNB["day6"],
    "TNC": TNC["day6"],
    "TND": TND["day6"],

})


range7 = pd.DataFrame(data={
    
    "TempA": tempA["day7"],
    "TempB": tempB["day7"],
    "TempC": tempC["day7"],
    "TempD": tempD["day7"],
    
    "pHA": pHA["day7"],
    "pHB": pHB["day7"],
    "pHC": pHC["day7"],
    "pHD": pHD["day7"],
    
    "ECA": ECA["day7"],
    "ECB": ECB["day7"],
    "ECC": ECC["day7"],
    "ECD": ECD["day7"],
    
    "DOA": DOA["day7"],
    "DOB": DOB["day7"],
    "DOC": DOC["day7"],
    "DOD": DOD["day7"],
    
    "BODA": BODA["day7"],
    "BODB": BODB["day7"],
    "BODC": BODC["day7"],
    "BODD": BODD["day7"],
    
    "TNA": TNA["day7"],
    "TNB": TNB["day7"],
    "TNC": TNC["day7"],
    "TND": TND["day7"],

})


range8 = pd.DataFrame(data={
    
    "TempA": tempA["day8"],
    "TempB": tempB["day8"],
    "TempC": tempC["day8"],
    "TempD": tempD["day8"],
    
    "pHA": pHA["day8"],
    "pHB": pHB["day8"],
    "pHC": pHC["day8"],
    "pHD": pHD["day8"],
    
    "ECA": ECA["day8"],
    "ECB": ECB["day8"],
    "ECC": ECC["day8"],
    "ECD": ECD["day8"],
    
    "DOA": DOA["day8"],
    "DOB": DOB["day8"],
    "DOC": DOC["day8"],
    "DOD": DOD["day8"],
    
    "BODA": BODA["day8"],
    "BODB": BODB["day8"],
    "BODC": BODC["day8"],
    "BODD": BODD["day8"],
    
    "TNA": TNA["day8"],
    "TNB": TNB["day8"],
    "TNC": TNC["day8"],
    "TND": TND["day8"],

})


range9 = pd.DataFrame(data={
    
    "TempA": tempA["day9"],
    "TempB": tempB["day9"],
    "TempC": tempC["day9"],
    "TempD": tempD["day9"],
    
    "pHA": pHA["day9"],
    "pHB": pHB["day9"],
    "pHC": pHC["day9"],
    "pHD": pHD["day9"],
    
    "ECA": ECA["day9"],
    "ECB": ECB["day9"],
    "ECC": ECC["day9"],
    "ECD": ECD["day9"],
    
    "DOA": DOA["day9"],
    "DOB": DOB["day9"],
    "DOC": DOC["day9"],
    "DOD": DOD["day9"],
    
    "BODA": BODA["day9"],
    "BODB": BODB["day9"],
    "BODC": BODC["day9"],
    "BODD": BODD["day9"],
    
    "TNA": TNA["day9"],
    "TNB": TNB["day9"],
    "TNC": TNC["day9"],
    "TND": TND["day9"],

})


range10 = pd.DataFrame(data={
    
    "TempA": tempA["day10"],
    "TempB": tempB["day10"],
    "TempC": tempC["day10"],
    "TempD": tempD["day10"],
    
    "pHA": pHA["day10"],
    "pHB": pHB["day10"],
    "pHC": pHC["day10"],
    "pHD": pHD["day10"],
    
    "ECA": ECA["day10"],
    "ECB": ECB["day10"],
    "ECC": ECC["day10"],
    "ECD": ECD["day10"],
    
    "DOA": DOA["day10"],
    "DOB": DOB["day10"],
    "DOC": DOC["day10"],
    "DOD": DOD["day10"],
    
    "BODA": BODA["day10"],
    "BODB": BODB["day10"],
    "BODC": BODC["day10"],
    "BODD": BODD["day10"],
    
    "TNA": TNA["day10"],
    "TNB": TNB["day10"],
    "TNC": TNC["day10"],
    "TND": TND["day10"],

})


range11 = pd.DataFrame(data={
    
    "TempA": tempA["day11"],
    "TempB": tempB["day11"],
    "TempC": tempC["day11"],
    "TempD": tempD["day11"],
    
    "pHA": pHA["day11"],
    "pHB": pHB["day11"],
    "pHC": pHC["day11"],
    "pHD": pHD["day11"],
    
    "ECA": ECA["day11"],
    "ECB": ECB["day11"],
    "ECC": ECC["day11"],
    "ECD": ECD["day11"],
    
    "DOA": DOA["day11"],
    "DOB": DOB["day11"],
    "DOC": DOC["day11"],
    "DOD": DOD["day11"],
    
    "BODA": BODA["day11"],
    "BODB": BODB["day11"],
    "BODC": BODC["day11"],
    "BODD": BODD["day11"],
    
    "TNA": TNA["day11"],
    "TNB": TNB["day11"],
    "TNC": TNC["day11"],
    "TND": TND["day11"],

})

range12 = pd.DataFrame(data={
    
    "TempA": tempA["day12"],
    "TempB": tempB["day12"],
    "TempC": tempC["day12"],
    "TempD": tempD["day12"],
    
    "pHA": pHA["day12"],
    "pHB": pHB["day12"],
    "pHC": pHC["day12"],
    "pHD": pHD["day12"],
    
    "ECA": ECA["day12"],
    "ECB": ECB["day12"],
    "ECC": ECC["day12"],
    "ECD": ECD["day12"],
    
    "DOA": DOA["day12"],
    "DOB": DOB["day12"],
    "DOC": DOC["day12"],
    "DOD": DOD["day12"],
    
    "BODA": BODA["day12"],
    "BODB": BODB["day12"],
    "BODC": BODC["day12"],
    "BODD": BODD["day12"],
    
    "TNA": TNA["day12"],
    "TNB": TNB["day12"],
    "TNC": TNC["day12"],
    "TND": TND["day12"],

})

range13 = pd.DataFrame(data={
    
    "TempA": tempA["day13"],
    "TempB": tempB["day13"],
    "TempC": tempC["day13"],
    "TempD": tempD["day13"],
    
    "pHA": pHA["day13"],
    "pHB": pHB["day13"],
    "pHC": pHC["day13"],
    "pHD": pHD["day13"],
    
    "ECA": ECA["day13"],
    "ECB": ECB["day13"],
    "ECC": ECC["day13"],
    "ECD": ECD["day13"],
    
    "DOA": DOA["day13"],
    "DOB": DOB["day13"],
    "DOC": DOC["day13"],
    "DOD": DOD["day13"],
    
    "BODA": BODA["day13"],
    "BODB": BODB["day13"],
    "BODC": BODC["day13"],
    "BODD": BODD["day13"],
    
    "TNA": TNA["day13"],
    "TNB": TNB["day13"],
    "TNC": TNC["day13"],
    "TND": TND["day13"],

})

range14 = pd.DataFrame(data={
    
    "TempA": tempA["day14"],
    "TempB": tempB["day14"],
    "TempC": tempC["day14"],
    "TempD": tempD["day14"],
    
    "pHA": pHA["day14"],
    "pHB": pHB["day14"],
    "pHC": pHC["day14"],
    "pHD": pHD["day14"],
    
    "ECA": ECA["day14"],
    "ECB": ECB["day14"],
    "ECC": ECC["day14"],
    "ECD": ECD["day14"],
    
    "DOA": DOA["day14"],
    "DOB": DOB["day14"],
    "DOC": DOC["day14"],
    "DOD": DOD["day14"],
    
    "BODA": BODA["day14"],
    "BODB": BODB["day14"],
    "BODC": BODC["day14"],
    "BODD": BODD["day14"],
    
    "TNA": TNA["day14"],
    "TNB": TNB["day14"],
    "TNC": TNC["day14"],
    "TND": TND["day14"],

})


range15 = pd.DataFrame(data={
    
    "TempA": tempA["day15"],
    "TempB": tempB["day15"],
    "TempC": tempC["day15"],
    "TempD": tempD["day15"],
    
    "pHA": pHA["day15"],
    "pHB": pHB["day15"],
    "pHC": pHC["day15"],
    "pHD": pHD["day15"],
    
    "ECA": ECA["day15"],
    "ECB": ECB["day15"],
    "ECC": ECC["day15"],
    "ECD": ECD["day15"],
    
    "DOA": DOA["day15"],
    "DOB": DOB["day15"],
    "DOC": DOC["day15"],
    "DOD": DOD["day15"],
    
    "BODA": BODA["day15"],
    "BODB": BODB["day15"],
    "BODC": BODC["day15"],
    "BODD": BODD["day15"],
    
    "TNA": TNA["day15"],
    "TNB": TNB["day15"],
    "TNC": TNC["day15"],
    "TND": TND["day15"],

})

range16 = pd.DataFrame(data={
    
    "TempA": tempA["day16"],
    "TempB": tempB["day16"],
    "TempC": tempC["day16"],
    "TempD": tempD["day16"],
    
    "pHA": pHA["day16"],
    "pHB": pHB["day16"],
    "pHC": pHC["day16"],
    "pHD": pHD["day16"],
    
    "ECA": ECA["day16"],
    "ECB": ECB["day16"],
    "ECC": ECC["day16"],
    "ECD": ECD["day16"],
    
    "DOA": DOA["day16"],
    "DOB": DOB["day16"],
    "DOC": DOC["day16"],
    "DOD": DOD["day16"],
    
    "BODA": BODA["day16"],
    "BODB": BODB["day16"],
    "BODC": BODC["day16"],
    "BODD": BODD["day16"],
    
    "TNA": TNA["day16"],
    "TNB": TNB["day16"],
    "TNC": TNC["day16"],
    "TND": TND["day16"],

})

range17 = pd.DataFrame(data={
    
    "TempA": tempA["day17"],
    "TempB": tempB["day17"],
    "TempC": tempC["day17"],
    "TempD": tempD["day17"],
    
    "pHA": pHA["day17"],
    "pHB": pHB["day17"],
    "pHC": pHC["day17"],
    "pHD": pHD["day17"],
    
    "ECA": ECA["day17"],
    "ECB": ECB["day17"],
    "ECC": ECC["day17"],
    "ECD": ECD["day17"],
    
    "DOA": DOA["day17"],
    "DOB": DOB["day17"],
    "DOC": DOC["day17"],
    "DOD": DOD["day17"],
    
    "BODA": BODA["day17"],
    "BODB": BODB["day17"],
    "BODC": BODC["day17"],
    "BODD": BODD["day17"],
    
    "TNA": TNA["day17"],
    "TNB": TNB["day17"],
    "TNC": TNC["day17"],
    "TND": TND["day17"],

})

range18 = pd.DataFrame(data={
    
    "TempA": tempA["day18"],
    "TempB": tempB["day18"],
    "TempC": tempC["day18"],
    "TempD": tempD["day18"],
    
    "pHA": pHA["day18"],
    "pHB": pHB["day18"],
    "pHC": pHC["day18"],
    "pHD": pHD["day18"],
    
    "ECA": ECA["day18"],
    "ECB": ECB["day18"],
    "ECC": ECC["day18"],
    "ECD": ECD["day18"],
    
    "DOA": DOA["day18"],
    "DOB": DOB["day18"],
    "DOC": DOC["day18"],
    "DOD": DOD["day18"],
    
    "BODA": BODA["day18"],
    "BODB": BODB["day18"],
    "BODC": BODC["day18"],
    "BODD": BODD["day18"],
    
    "TNA": TNA["day18"],
    "TNB": TNB["day18"],
    "TNC": TNC["day18"],
    "TND": TND["day18"],

})

range19 = pd.DataFrame(data={
    
    "TempA": tempA["day19"],
    "TempB": tempB["day19"],
    "TempC": tempC["day19"],
    "TempD": tempD["day19"],
    
    "pHA": pHA["day19"],
    "pHB": pHB["day19"],
    "pHC": pHC["day19"],
    "pHD": pHD["day19"],
    
    "ECA": ECA["day19"],
    "ECB": ECB["day19"],
    "ECC": ECC["day19"],
    "ECD": ECD["day19"],
    
    "DOA": DOA["day19"],
    "DOB": DOB["day19"],
    "DOC": DOC["day19"],
    "DOD": DOD["day19"],
    
    "BODA": BODA["day19"],
    "BODB": BODB["day19"],
    "BODC": BODC["day19"],
    "BODD": BODD["day19"],
    
    "TNA": TNA["day19"],
    "TNB": TNB["day19"],
    "TNC": TNC["day19"],
    "TND": TND["day19"],

})


range20 = pd.DataFrame(data={
    
    "TempA": tempA["day20"],
    "TempB": tempB["day20"],
    "TempC": tempC["day20"],
    "TempD": tempD["day20"],
    
    "pHA": pHA["day20"],
    "pHB": pHB["day20"],
    "pHC": pHC["day20"],
    "pHD": pHD["day20"],
    
    "ECA": ECA["day20"],
    "ECB": ECB["day20"],
    "ECC": ECC["day20"],
    "ECD": ECD["day20"],
    
    "DOA": DOA["day20"],
    "DOB": DOB["day20"],
    "DOC": DOC["day20"],
    "DOD": DOD["day20"],
    
    "BODA": BODA["day20"],
    "BODB": BODB["day20"],
    "BODC": BODC["day20"],
    "BODD": BODD["day20"],
    
    "TNA": TNA["day20"],
    "TNB": TNB["day20"],
    "TNC": TNC["day20"],
    "TND": TND["day20"],

})


range21 = pd.DataFrame(data={
    
    "TempA": tempA["day21"],
    "TempB": tempB["day21"],
    "TempC": tempC["day21"],
    "TempD": tempD["day21"],
    
    "pHA": pHA["day21"],
    "pHB": pHB["day21"],
    "pHC": pHC["day21"],
    "pHD": pHD["day21"],
    
    "ECA": ECA["day21"],
    "ECB": ECB["day21"],
    "ECC": ECC["day21"],
    "ECD": ECD["day21"],
    
    "DOA": DOA["day21"],
    "DOB": DOB["day21"],
    "DOC": DOC["day21"],
    "DOD": DOD["day21"],
    
    "BODA": BODA["day21"],
    "BODB": BODB["day21"],
    "BODC": BODC["day21"],
    "BODD": BODD["day21"],
    
    "TNA": TNA["day21"],
    "TNB": TNB["day21"],
    "TNC": TNC["day21"],
    "TND": TND["day21"],

})



range22 = pd.DataFrame(data={
    
    "TempA": tempA["day22"],
    "TempB": tempB["day22"],
    "TempC": tempC["day22"],
    "TempD": tempD["day22"],
    
    "pHA": pHA["day22"],
    "pHB": pHB["day22"],
    "pHC": pHC["day22"],
    "pHD": pHD["day22"],
    
    "ECA": ECA["day22"],
    "ECB": ECB["day22"],
    "ECC": ECC["day22"],
    "ECD": ECD["day22"],
    
    "DOA": DOA["day22"],
    "DOB": DOB["day22"],
    "DOC": DOC["day22"],
    "DOD": DOD["day22"],
    
    "BODA": BODA["day22"],
    "BODB": BODB["day22"],
    "BODC": BODC["day22"],
    "BODD": BODD["day22"],
    
    "TNA": TNA["day22"],
    "TNB": TNB["day22"],
    "TNC": TNC["day22"],
    "TND": TND["day22"],

})

# %%
range0
# Out:
#         TempA      TempB      TempC      TempD       pHA       pHB       pHC  \
# 0   21.206192  21.100335  21.035532  20.751988  7.818671  8.084655  7.993220
# 1   21.210902  20.935008  21.160186  21.168722  7.733693  8.062786  8.116770
# 2   21.257416  20.941035  21.273460  21.197541  7.818443  8.087802  7.941933
# 3   21.093705  21.186132  20.513038  20.812852  7.760058  8.106052  7.996784
# 4   21.208442  20.867321  21.274380  21.217716  7.803024  8.112096  8.068508
# 5   21.448270  20.946112  20.888478  21.144002  7.780396  8.077898  7.916353
# 6   21.228977  21.051472  20.591673  21.221164  7.787964  8.091348  7.973434
# 7   21.015192  21.048416  20.647787  21.195120  7.743336  8.063406  8.056185
# 8   21.250331  20.910134  20.555041  20.871665  7.748731  8.069253  8.108102
# 9   21.331754  21.019296  21.250167  21.122047  7.754750  8.110731  8.033576
# 10  21.070343  20.966023  20.854593  20.952440  7.759525  8.112497  7.968768
# ...

# %%
cols = df.columns

# %%
cols = ['Date', 'TempA', 'TempB', 'TempC', 'TempD', 'pHA', 'pHB', 'pHC', 'pHD',
       'ECA', 'ECB', 'ECC', 'ECD', 'DOA', 'DOB', 'DOC', 'DOD', 'BODA',
       'BODB', 'BODC', 'BODD', 'TNA', 'TNB', 'TNC', 'TND']

# %%
sample = pd.DataFrame(columns=cols)

# %%
sample
# Out:
# Empty DataFrame
# Columns: [Date, TempA, TempB, TempC, TempD, pHA, pHB, pHC, pHD, ECA, ECB, ECC, ECD, DOA, DOB, DOC, DOD, BODA, BODB, BODC, BODD, TNA, TNB, TNC, TND]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.columns = cols

# %%
a = df.iloc[0]
a
# Out:
# Date     15-Dec-21
# TempA         21.5
# TempB         21.2
# TempC         21.3
# TempD         21.4
# pHA           7.73
# pHB           8.12
# pHC           7.91
# pHD           8.48
# ECA           1748
# ECB           1679
# ECC           1577
# ECD           1695
# DOA           2.55
# DOB           2.62
# DOC            2.6
# DOD           2.59
# BODA         27.96
# BODB          27.7
# BODC         27.88
# BODD         27.93
# TNA           1.28
# TNB           1.25
# TNC           1.26
# TND           1.27
# Name: 0, dtype: object

# %%
sample.append(a)
# Out:
# /tmp/ipykernel_4266/3583891468.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sample.append(a)
#         Date TempA TempB TempC TempD   pHA   pHB   pHC   pHD   ECA  ...  DOC  \
# 0  15-Dec-21  21.5  21.2  21.3  21.4  7.73  8.12  7.91  8.48  1748  ...  2.6
#
#     DOD   BODA  BODB   BODC   BODD   TNA   TNB   TNC   TND
# 0  2.59  27.96  27.7  27.88  27.93  1.28  1.25  1.26  1.27
#
# [1 rows x 25 columns]

# %%
sample0 = sample.copy()

# %%
sample0.append(range0, ignore_index=True)
# Out:
# /tmp/ipykernel_4266/3925787615.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sample0.append(range0, ignore_index=True)
#    Date      TempA      TempB      TempC      TempD       pHA       pHB  \
# 0   NaN  21.206192  21.100335  21.035532  20.751988  7.818671  8.084655
# 1   NaN  21.210902  20.935008  21.160186  21.168722  7.733693  8.062786
# 2   NaN  21.257416  20.941035   21.27346  21.197541  7.818443  8.087802
# 3   NaN  21.093705  21.186132  20.513038  20.812852  7.760058  8.106052
# 4   NaN  21.208442  20.867321   21.27438  21.217716  7.803024  8.112096
# 5   NaN   21.44827  20.946112  20.888478  21.144002  7.780396  8.077898
# 6   NaN  21.228977  21.051472  20.591673  21.221164  7.787964  8.091348
# 7   NaN  21.015192  21.048416  20.647787   21.19512  7.743336  8.063406
# 8   NaN  21.250331  20.910134  20.555041  20.871665  7.748731  8.069253
# ...

# %%
date = datetime.datetime.strptime("15-12-2021", "%d-%m-%Y")
all_day = pd.date_range(date, periods=366)
all_day
# Out:
# DatetimeIndex(['2021-12-15', '2021-12-16', '2021-12-17', '2021-12-18',
#                '2021-12-19', '2021-12-20', '2021-12-21', '2021-12-22',
#                '2021-12-23', '2021-12-24',
#                ...
#                '2022-12-06', '2022-12-07', '2022-12-08', '2022-12-09',
#                '2022-12-10', '2022-12-11', '2022-12-12', '2022-12-13',
#                '2022-12-14', '2022-12-15'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
all_day = pd.DataFrame(all_day)

# %%
all_day.to_csv("350DaysDate.csv")

# %%
all_day
# Out:
#              0
# 0   2021-12-15
# 1   2021-12-16
# 2   2021-12-17
# 3   2021-12-18
# 4   2021-12-19
# ..         ...
# 345 2022-11-25
# 346 2022-11-26
# 347 2022-11-27
# 348 2022-11-28
# 349 2022-11-29
#
# [350 rows x 1 columns]

# %%
range0
# Out:
#         TempA      TempB      TempC      TempD       pHA       pHB       pHC  \
# 0   21.206192  21.100335  21.035532  20.751988  7.818671  8.084655  7.993220
# 1   21.210902  20.935008  21.160186  21.168722  7.733693  8.062786  8.116770
# 2   21.257416  20.941035  21.273460  21.197541  7.818443  8.087802  7.941933
# 3   21.093705  21.186132  20.513038  20.812852  7.760058  8.106052  7.996784
# 4   21.208442  20.867321  21.274380  21.217716  7.803024  8.112096  8.068508
# 5   21.448270  20.946112  20.888478  21.144002  7.780396  8.077898  7.916353
# 6   21.228977  21.051472  20.591673  21.221164  7.787964  8.091348  7.973434
# 7   21.015192  21.048416  20.647787  21.195120  7.743336  8.063406  8.056185
# 8   21.250331  20.910134  20.555041  20.871665  7.748731  8.069253  8.108102
# 9   21.331754  21.019296  21.250167  21.122047  7.754750  8.110731  8.033576
# 10  21.070343  20.966023  20.854593  20.952440  7.759525  8.112497  7.968768
# ...

# %%
range0.to_csv("data/days/Day0.csv")
range1.to_csv("data/days/Day1.csv")
range2.to_csv("data/days/Day2.csv")
range3.to_csv("data/days/Day3.csv")
range4.to_csv("data/days/Day4.csv")
range5.to_csv("data/days/Day5.csv")
range6.to_csv("data/days/Day6.csv")
range7.to_csv("data/days/Day7.csv")
range8.to_csv("data/days/Day8.csv")
range9.to_csv("data/days/Day9.csv")
range10.to_csv("data/days/Day10.csv")
range11.to_csv("data/days/Day11.csv")
range12.to_csv("data/days/Day12.csv")
range13.to_csv("data/days/Day13.csv")
range14.to_csv("data/days/Day14.csv")
range15.to_csv("data/days/Day15.csv")
range16.to_csv("data/days/Day16.csv")
range17.to_csv("data/days/Day17.csv")
range18.to_csv("data/days/Day18.csv")
range19.to_csv("data/days/Day19.csv")
range20.to_csv("data/days/Day20.csv")
range21.to_csv("data/days/Day21.csv")
range22.to_csv("data/days/Day22.csv")

# %%
tempA = np.random.uniform(21.6,22 , 15)
tempB = np.random.uniform(21.2, 21.7 , 15)
tempC = np.random.uniform(21.1,21.9 , 15)
tempD = np.random.uniform(21.5, 21.8, 15)

pHA = np.random.uniform(7.69, 7.75 , 15)
pHB = np.random.uniform(7.95, 8.1 , 15)
pHC = np.random.uniform(7.68, 7.9 , 15)
pHD = np.random.uniform(8.11, 8.15 , 15)

ECA = np.random.uniform(1627, 1650, 15)
ECB = np.random.uniform(1676, 1690, 15)
ECC = np.random.uniform(1610, 1650, 15)
ECD = np.random.uniform(1690, 1705, 15)

DOA = np.random.uniform(2.41,2.45 , 15)
DOB = np.random.uniform(2.53,2.6 , 15)
DOC = np.random.uniform(2.49,2.52, 15)
DOD = np.random.uniform(2.5, 2.58, 15)

BODA = np.random.uniform(27.8,28.3 , 15)
BODB = np.random.uniform(27.5,28 , 15)
BODC = np.random.uniform(27.7,28.17 , 15)
BODD = np.random.uniform(27.7,28.14 , 15)

TNA = np.random.uniform(1.27, 1.31 , 15)
TNB = np.random.uniform(1.26 , 1.30, 15)
TNC = np.random.uniform(1.17 , 1.23, 15)
TND = np.random.uniform(1.29 , 1.34, 15)

# %%
range24 = pd.DataFrame(data={
    
    "TempA": tempA,
    "TempB": tempB,
    "TempC": tempC,
    "TempD": tempD,
    
    "pHA": pHA,
    "pHB": pHB,
    "pHC": pHC,
    "pHD": pHD,
    
    "ECA": ECA,
    "ECB": ECB,
    "ECC": ECC,
    "ECD": ECD,
    
    "DOA": DOA,
    "DOB": DOB,
    "DOC": DOC,
    "DOD": DOD,
    
    "BODA": BODA,
    "BODB": BODB,
    "BODC": BODC,
    "BODD": BODD,
    
    "TNA": TNA,
    "TNB": TNB,
    "TNC": TNC,
    "TND": TND,

})

# %%
range24
# Out:
#         TempA      TempB      TempC      TempD       pHA       pHB       pHC  \
# 0   21.800380  21.588891  21.431331  21.674068  7.695580  8.056819  7.731145
# 1   21.920235  21.248133  21.380457  21.622880  7.712974  8.041537  7.833355
# 2   21.863995  21.491546  21.541366  21.578873  7.700187  8.074371  7.793505
# 3   21.931220  21.629135  21.735895  21.545204  7.739543  8.080734  7.889516
# 4   21.981116  21.341949  21.608124  21.545000  7.737124  7.997164  7.755385
# 5   21.846276  21.454246  21.423953  21.554248  7.738150  8.095599  7.870155
# 6   21.913429  21.652317  21.744931  21.697999  7.700908  8.030211  7.806385
# 7   21.989238  21.399812  21.560160  21.551050  7.702410  8.044477  7.771116
# 8   21.625402  21.271953  21.299290  21.533548  7.724137  7.977696  7.788280
# 9   21.700084  21.442542  21.100646  21.579922  7.711304  7.978739  7.711859
# 10  21.859082  21.307084  21.515496  21.794283  7.718914  7.973155  7.775976
# ...

# %%
range24.to_csv("data/days/day24.csv")
