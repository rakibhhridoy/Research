# %%
install.packages("ggrepel")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
require(factoextra)
require(FactoMineR)
require(ggplot2)
require(ggrepel)
# Out:
# Loading required package: ggrepel

# %%
df_renamed <- read.csv("/home/RHHLab/renamed_haor.csv")
df_renamed

# %%
df_renamed <- read.csv("/home/RHHLab/renamed_haor.csv")
df_renamed <- df_renamed[, -1]
sample <- PCA(data.frame(df_renamed[2:10]), graph = FALSE, ncp = 10,  scale.unit = TRUE)
eig.val <- get_eigenvalue(sample)
scree.plot <- fviz_eig(sample, addlabels = TRUE, ylim = c(0,50))
var.plot <- fviz_pca_var(sample, col.var = "cos2", gradient.cols = c('#00AFBB', "#E7B800", "#FC4E07"), repel = TRUE)
ind.plot <- fviz_pca_ind(sample, col.ind = "cos2", gradient.cols = c('#00AFBB', "#E7B800", "#FC4E07"), repel = TRUE)
bi.plot <- fviz_pca_biplot(sample, repel = TRUE, col.var = "red", col.ind = "black", circle= TRUE)
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, label = "var",col.var= "black",repel= TRUE, legend.title = "Soil Profile", title = "Individuals PCA")

fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, 
                label = "var",col.var= "black",
                repel= TRUE, legend.title = "Soil Profile", 
                title = "Individuals PCA")+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("RdGy")+    # Variable colors
theme(text = element_text(size = 15),
         axis.title = element_text(size = 7.5),
         axis.text = element_text(size = 7.5)
         )
# Out:
#    X  SoilProfile Sand  Silt  Clay  BulkDen pH   OrgC  N     Moisture CEC
# 1   1 Hakaluki     1.05 63.25 35.70 1.55    4.15 2.145 0.162 3.15     181.20
# 2   2 Hakaluki     0.88 67.71 31.41 1.76    4.52 0.517 0.053 1.90     153.75
# 3   3 Hakaluki     1.43 59.84 38.72 1.78    5.24 0.356 0.042 0.91     185.70
# 4   4 Hakaluki     0.84 80.74 18.42 1.81    5.31 0.334 0.037 0.92      69.98
# 5   5 Azmiriganj   3.37 48.58 48.05 1.82    4.02 2.407 0.167 5.03     198.75
# 6   6 Azmiriganj   2.80 34.38 62.82 1.29    4.17 2.861 0.126 7.03     310.40
# 7   7 Azmiriganj   1.48 42.26 56.26 1.54    3.89 2.865 0.078 5.65     253.12
# 8   8 Azmiriganj   0.98 51.72 47.30 1.87    3.92 1.671 0.074 3.46     195.87
# 9   9 Azmiriganj   2.56 61.02 36.42 1.93    4.11 0.975 0.093 2.60     183.75
# 10 10 Sulla        4.22 69.15 26.63 1.94    4.39 1.346 0.163 3.41     147.37
# 11 11 Sulla        1.59 61.67 36.74 1.74    4.23 1.482 0.104 2.77     187.60
# ...

# %%
df_renamed <- df_renamed[, -1]
head(df_renamed)
# Out:
#   SoilProfile Sand Silt  Clay  BulkDen pH   OrgC  N     Moisture CEC
# 1 Hakaluki    1.05 63.25 35.70 1.55    4.15 2.145 0.162 3.15     181.20
# 2 Hakaluki    0.88 67.71 31.41 1.76    4.52 0.517 0.053 1.90     153.75
# 3 Hakaluki    1.43 59.84 38.72 1.78    5.24 0.356 0.042 0.91     185.70
# 4 Hakaluki    0.84 80.74 18.42 1.81    5.31 0.334 0.037 0.92      69.98
# 5 Azmiriganj  3.37 48.58 48.05 1.82    4.02 2.407 0.167 5.03     198.75
# 6 Azmiriganj  2.80 34.38 62.82 1.29    4.17 2.861 0.126 7.03     310.40

# %%
df_pca <- df_renamed[, -1]
sample <- PCA(data.frame(df_renamed[2:10]), graph = FALSE, ncp = 10,  scale.unit = TRUE)
sample
sample$eig
eig.val <- get_eigenvalue(sample)
df_renamed
# Out:
# **Results for the Principal Component Analysis (PCA)**
# The analysis was performed on 48 individuals, described by 9 variables
# *The results are available in the following objects:
#
#    name               description
# 1  "$eig"             "eigenvalues"
# 2  "$var"             "results for the variables"
# 3  "$var$coord"       "coord. for the variables"
# 4  "$var$cor"         "correlations variables - dimensions"
# 5  "$var$cos2"        "cos2 for the variables"
# 6  "$var$contrib"     "contributions of the variables"
# 7  "$ind"             "results for the individuals"
# 8  "$ind$coord"       "coord. for the individuals"
# 9  "$ind$cos2"        "cos2 for the individuals"
# 10 "$ind$contrib"     "contributions of the individuals"
# 11 "$call"            "summary statistics"
# 12 "$call$centre"     "mean of the variables"
# 13 "$call$ecart.type" "standard error of the variables"
# 14 "$call$row.w"      "weights for the individuals"
# ...

# %%
eig.val
# Out:
#       eigenvalue variance.percent cumulative.variance.percent
# Dim.1 4.43313614 49.2570682        49.25707
# Dim.2 1.91098000 21.2331111        70.49018
# Dim.3 0.87983159  9.7759065        80.26609
# Dim.4 0.66517130  7.3907923        87.65688
# Dim.5 0.51287944  5.6986604        93.35554
# Dim.6 0.28597800  3.1775333        96.53307
# Dim.7 0.18377120  2.0419022        98.57497
# Dim.8 0.10192636  1.1325151        99.70749
# Dim.9 0.02632598  0.2925109       100.00000

# %%
scree.plot <- fviz_eig(sample, addlabels = TRUE, ylim = c(0,50))
var.plot <- fviz_pca_var(sample, col.var = "cos2", gradient.cols = c('#00AFBB', "#E7B800", "#FC4E07"), repel = TRUE)
ind.plot <- fviz_pca_ind(sample, col.ind = "cos2", gradient.cols = c('#00AFBB', "#E7B800", "#FC4E07"), repel = TRUE)
bi.plot <- fviz_pca_biplot(sample, repel = TRUE, col.var = "red", col.ind = "black", circle= TRUE)
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, label = "var",col.var= "black",repel= TRUE, legend.title = "Soil Profile", title = "Individuals PCA")
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 9. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 15 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title

# %%
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, label = "var",col.var= "black",repel= TRUE, legend.title = "Soil Profile", title = "Individuals PCA")+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("npg")      # Variable colors
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 9. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 15 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title

# %%
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, label = "var",col.var= "black",repel= TRUE, legend.title = "Soil Profile", title = "Individuals PCA")+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("YlGnBu")      # Variable colors
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 9. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 15 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title

# %%
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, label = "var",col.var= "black",repel= TRUE, legend.title = "Soil Profile", title = "Individuals PCA")+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("Spectral")      # Variable colors
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 9. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 15 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title

# %%
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, label = "var",col.var= "black",repel= TRUE, legend.title = "Soil Profile", title = "Individuals PCA")+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("RdGy")      # Variable colors
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 9. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 15 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title

# %%
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, 
                label = "var",col.var= "black",
                repel= TRUE, legend.title = "Soil Profile", 
                title = "Individuals PCA")+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("RdGy")+    # Variable colors
theme(text = element_text(size = 15),
         axis.title = element_text(size = 7.5),
         axis.text = element_text(size = 7.5)
         )
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 9. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 15 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title

# %%
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, 
                label = "var",col.var= "black",
                repel= TRUE, legend.title = "Soil Profile", 
                title = "Individuals PCA") +
geom_label_repel(size= 20)+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("RdGy")+    # Variable colors
theme(text = element_text(size = 15),
         axis.title = element_text(size = 7.5),
         axis.text = element_text(size = 7.5),
         )
# Out:
# ERROR while rich displaying an object: Error in `geom_label_repel()`:
# ! Problem while setting up geom.
# ℹ Error occurred in the 10th layer.
# Caused by error in `compute_geom_1()`:
# ! `geom_label_repel()` requires the following missing aesthetics: label
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
# ...

# %%
?geom_label

# %%
sample$ind$coord
# Out:
#    Dim.1       Dim.2       Dim.3        Dim.4       Dim.5       Dim.6
# 1   0.52265137 -2.95437059  0.771848425  0.64558287 -0.45440926  0.8667553148
# 2  -1.83966523 -0.39863980 -0.683368349 -1.25562914 -1.00777005 -0.3524233872
# 3  -1.59059143  0.52403022 -0.952820686 -1.26667042 -1.36727297  0.0114147044
# 4  -3.71223778  0.07841885 -0.717265203 -1.09044970 -1.01757538  0.3509777397
# 5   1.64480124 -2.90676752  0.745343275  0.68276535  0.87418035  0.4019668075
# 6   4.39003509 -2.14822785  0.093003500 -0.82061703  0.77712181  0.7873435596
# 7   2.63434664 -2.16570009 -0.155046128 -2.03541107  0.90498339  0.9642284122
# 8   0.22959896 -1.56804688 -0.366961654 -1.48025042  0.14308636  0.0001164187
# 9  -0.89078119 -1.28097105 -0.142532205 -0.58191888 -0.35703469 -0.5299262593
# 10 -0.94131287 -2.29563756  0.734225473  1.31675620  0.18980171 -0.1373284991
# 11 -0.31578320 -1.72328607  0.035932242 -0.51120896 -0.41936361  0.1996506889
# ...

# %%
colnames(sample$ind$coord)[1] = "PC1"

# %%
sample$ind$coord
# Out:
#    PC1         Dim.2       Dim.3        Dim.4       Dim.5       Dim.6
# 1   0.52265137 -2.95437059  0.771848425  0.64558287 -0.45440926  0.8667553148
# 2  -1.83966523 -0.39863980 -0.683368349 -1.25562914 -1.00777005 -0.3524233872
# 3  -1.59059143  0.52403022 -0.952820686 -1.26667042 -1.36727297  0.0114147044
# 4  -3.71223778  0.07841885 -0.717265203 -1.09044970 -1.01757538  0.3509777397
# 5   1.64480124 -2.90676752  0.745343275  0.68276535  0.87418035  0.4019668075
# 6   4.39003509 -2.14822785  0.093003500 -0.82061703  0.77712181  0.7873435596
# 7   2.63434664 -2.16570009 -0.155046128 -2.03541107  0.90498339  0.9642284122
# 8   0.22959896 -1.56804688 -0.366961654 -1.48025042  0.14308636  0.0001164187
# 9  -0.89078119 -1.28097105 -0.142532205 -0.58191888 -0.35703469 -0.5299262593
# 10 -0.94131287 -2.29563756  0.734225473  1.31675620  0.18980171 -0.1373284991
# 11 -0.31578320 -1.72328607  0.035932242 -0.51120896 -0.41936361  0.1996506889
# ...

# %%
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, 
                label = "var",col.var= "black",
                repel= TRUE, legend.title = "Soil Profile", 
                title = "Individuals PCA")+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("RdGy")+    # Variable colors
theme(text = element_text(size = 15),
         axis.title = element_text(size = 7.5),
         axis.text = element_text(size = 7.5)
         )
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 9. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 15 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title

# %%
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, label = "var",col.var= "black",repel= TRUE, legend.title = "Soil Profile", title = "Individuals PCA")+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("Dark2")      # Variable colors
# Out:
# Warning message in RColorBrewer::brewer.pal(n, pal):
# “n too large, allowed maximum for palette Dark2 is 8
# Returning the palette you asked for with that many colors
# ”
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 9. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 15 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title

# %%
fviz_pca_biplot(sample, 
                # Individuals
                geom.ind = "point",
                col.ind = "black",
                fill.ind = df_renamed$SoilProfile,
                pointshape = 21, pointsize = 2,
                palette = "jco",
                title = "Individuals PCA",
                addEllipses = TRUE,
                # Variables
                alpha.var ="contrib", col.var = "contrib",
                gradient.cols = "RdYlBu",
                
                legend.title = list(fill = "Soil Profile", color = "Contrib",
                                    alpha = "Contrib")
                )
# Out:
# plot without title

# %%
fviz_pca_biplot(sample, 
                # Individuals
                geom.ind = "point",
                col.ind = "black",
                fill.ind = df_renamed$SoilProfile,
                pointshape = 21, pointsize = 2,
                palette = "jco",
                title = "Individuals PCA",
                addEllipses = TRUE,
                # Variables
                alpha.var ="contrib", col.var = "contrib",
                gradient.cols = "PiYG",
                
                legend.title = list(fill = "Soil Profile", color = "Contrib",
                                    alpha = "Contrib")
                )
# Out:
# plot without title

# %%
fviz_pca_biplot(sample, 
                # Individuals
                geom.ind = "point",
                col.ind = "black",
                fill.ind = df_renamed$SoilProfile,
                pointshape = 21, pointsize = 2,
                palette = "jco",
                title = "Individuals PCA",
                addEllipses = TRUE,
                # Variables
                alpha.var ="contrib", col.var = "contrib",
                gradient.cols = "PRGn",
                
                legend.title = list(fill = "Soil Profile", color = "Contrib",
                                    alpha = "Contrib")
                )+
theme(text = element_text(size = 10),
        axis.title = element_text(size = 7.5),
        axis.text = element_text(size = 7.5))
# Out:
# plot without title

# %%
fviz_pca_biplot(sample, 
                # Individuals
                geom.ind = "point",
                col.ind = "black",
                fill.ind = df_renamed$SoilProfile,
                pointshape = 21, pointsize = 2,
                palette = "jco",
                title = "Individuals PCA",
                addEllipses = TRUE,
                # Variables
                alpha.var ="contrib", col.var = "contrib",
                gradient.cols = "RdBu",
                
                legend.title = list(fill = "Soil Profile", color = "Contrib",
                                    alpha = "Contrib")
                )
# Out:
# plot without title

# %%
fviz_pca_biplot(sample, 
                # Individuals
                geom.ind = "point",
                col.ind = "black",
                fill.ind = df_renamed$SoilProfile,
                pointshape = 21, pointsize = 2,
                palette = "jco",
                title = "Individuals PCA",
                addEllipses = TRUE,
                # Variables
                alpha.var ="contrib", col.var = "contrib",
                gradient.cols = "BrBG",
                
                legend.title = list(fill = "Soil Profile", color = "Contrib",
                                    alpha = "Contrib")
                )
# Out:
# plot without title

# %%
fviz_pca_biplot(sample, col.ind= df_renamed$SoilProfile, addEllipses = TRUE, label = "var",col.var= "black",repel= TRUE, legend.title = "Soil Profile", title = "Individuals PCA")+
ggpubr::fill_palette("jco")+      # Indiviual fill color
ggpubr::color_palette("npg")      # Variable colors
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 9. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 15 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title
