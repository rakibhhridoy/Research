# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/Turag/Python/DL Lab/Univariate/TNA/')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_squared_error as mse
from functions_learning import *
from feed_data import data_extract
from tensorflow import keras
from keras import layers

# %%
epochs = 50

# %%
df = pd.read_csv("/content/drive/MyDrive/Turag/Python/DL Lab/Univariate/pHA/data/LocationA.csv")

df.drop(columns=["Unnamed: 0", "Date"], inplace=True)
df.head()
# Out:
#    TempA   pHA   ECA   DOA   BODA   TNA
# 0  21.50  7.73  1748  2.55  27.96  1.28
# 1  21.21  7.82  1765  2.60  27.90  1.08
# 2  21.21  7.73  1769  2.59  27.88  1.17
# 3  21.26  7.82  1776  2.63  27.66  1.15
# 4  21.09  7.76  1822  2.60  27.71  1.22

# %%
WINDOW_SIZE = 3
TNA = df["TNA"]
TNA
# Out:
# 0      1.28
# 1      1.08
# 2      1.17
# 3      1.15
# 4      1.22
#        ...
# 360    1.28
# 361    1.29
# 362    1.31
# 363    1.27
# 364    1.29
# Name: TNA, Length: 365, dtype: float64

# %%
X1, y1 = df_to_X_y(TNA, WINDOW_SIZE)
x_train, x_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=1)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=1)

# %% [markdown]
# # General Model

# %% [markdown]
# ### CNN

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(Conv1D(64, kernel_size=2))
model.add(Flatten())
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))



cp = ModelCheckpoint('cnn/', save_best_only=True)

model = fit_model(model, cp, epochs, x_train, y_train, x_val, y_val)

plot_train("cnn", 50, x_train, y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
cnn_mse = plot_predictions1(model,x_test, y_test)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 3s 250ms/step - loss: 4.1002 - root_mean_squared_error: 2.0249 - val_loss: 3.4173 - val_root_mean_squared_error: 1.8486
# Epoch 2/50
# 8/8 [==============================] - 1s 119ms/step - loss: 3.7352 - root_mean_squared_error: 1.9327 - val_loss: 3.1020 - val_root_mean_squared_error: 1.7613
# Epoch 3/50
# 8/8 [==============================] - 1s 91ms/step - loss: 3.3840 - root_mean_squared_error: 1.8396 - val_loss: 2.8053 - val_root_mean_squared_error: 1.6749
# Epoch 4/50
# 8/8 [==============================] - 1s 84ms/step - loss: 3.0558 - root_mean_squared_error: 1.7481 - val_loss: 2.5330 - val_root_mean_squared_error: 1.5915
# Epoch 5/50
# 8/8 [==============================] - 1s 88ms/step - loss: 2.7477 - root_mean_squared_error: 1.6576 - val_loss: 2.2811 - val_root_mean_squared_error: 1.5103
# Epoch 6/50
# 8/8 [==============================] - 1s 82ms/step - loss: 2.4770 - root_mean_squared_error: 1.5738 - val_loss: 2.0399 - val_root_mean_squared_error: 1.4282
# Epoch 7/50
# 8/8 [==============================] - 1s 89ms/step - loss: 2.2131 - root_mean_squared_error: 1.4877 - val_loss: 1.8221 - val_root_mean_squared_error: 1.3498
# Epoch 8/50
# 8/8 [==============================] - 1s 92ms/step - loss: 1.9760 - root_mean_squared_error: 1.4057 - val_loss: 1.6239 - val_root_mean_squared_error: 1.2743
# Epoch 9/50
# 8/8 [==============================] - 1s 85ms/step - loss: 1.7622 - root_mean_squared_error: 1.3275 - val_loss: 1.4442 - val_root_mean_squared_error: 1.2017
# Epoch 10/50
# 8/8 [==============================] - 1s 87ms/step - loss: 1.5641 - root_mean_squared_error: 1.2506 - val_loss: 1.2809 - val_root_mean_squared_error: 1.1318
# Epoch 11/50
# 8/8 [==============================] - 1s 89ms/step - loss: 1.3824 - root_mean_squared_error: 1.1758 - val_loss: 1.1317 - val_root_mean_squared_error: 1.0638
# Epoch 12/50
# 8/8 [==============================] - 1s 90ms/step - loss: 1.2179 - root_mean_squared_error: 1.1036 - val_loss: 0.9922 - val_root_mean_squared_error: 0.9961
# Epoch 13/50
# 8/8 [==============================] - 1s 85ms/step - loss: 1.0688 - root_mean_squared_error: 1.0338 - val_loss: 0.8655 - val_root_mean_squared_error: 0.9303
# Epoch 14/50
# 8/8 [==============================] - 1s 147ms/step - loss: 0.9320 - root_mean_squared_error: 0.9654 - val_loss: 0.7513 - val_root_mean_squared_error: 0.8668
# Epoch 15/50
# 8/8 [==============================] - 1s 88ms/step - loss: 0.8085 - root_mean_squared_error: 0.8992 - val_loss: 0.6469 - val_root_mean_squared_error: 0.8043
# Epoch 16/50
# 8/8 [==============================] - 1s 87ms/step - loss: 0.6967 - root_mean_squared_error: 0.8347 - val_loss: 0.5557 - val_root_mean_squared_error: 0.7455
# Epoch 17/50
# 8/8 [==============================] - 1s 89ms/step - loss: 0.5991 - root_mean_squared_error: 0.7740 - val_loss: 0.4749 - val_root_mean_squared_error: 0.6891
# Epoch 18/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.5117 - root_mean_squared_error: 0.7153 - val_loss: 0.4053 - val_root_mean_squared_error: 0.6366
# Epoch 19/50
# 8/8 [==============================] - 1s 123ms/step - loss: 0.4377 - root_mean_squared_error: 0.6616 - val_loss: 0.3450 - val_root_mean_squared_error: 0.5874
# Epoch 20/50
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3744 - root_mean_squared_error: 0.6118 - val_loss: 0.2934 - val_root_mean_squared_error: 0.5416
# Epoch 21/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3174 - root_mean_squared_error: 0.5634 - val_loss: 0.2502 - val_root_mean_squared_error: 0.5002
# Epoch 22/50
# 8/8 [==============================] - 1s 89ms/step - loss: 0.2723 - root_mean_squared_error: 0.5218 - val_loss: 0.2134 - val_root_mean_squared_error: 0.4619
# Epoch 23/50
# 8/8 [==============================] - 1s 89ms/step - loss: 0.2338 - root_mean_squared_error: 0.4835 - val_loss: 0.1815 - val_root_mean_squared_error: 0.4260
# Epoch 24/50
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1995 - root_mean_squared_error: 0.4467 - val_loss: 0.1541 - val_root_mean_squared_error: 0.3925
# Epoch 25/50
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1713 - root_mean_squared_error: 0.4139 - val_loss: 0.1310 - val_root_mean_squared_error: 0.3619
# Epoch 26/50
# 8/8 [==============================] - 1s 85ms/step - loss: 0.1469 - root_mean_squared_error: 0.3833 - val_loss: 0.1117 - val_root_mean_squared_error: 0.3342
# Epoch 27/50
# 8/8 [==============================] - 1s 195ms/step - loss: 0.1264 - root_mean_squared_error: 0.3555 - val_loss: 0.0953 - val_root_mean_squared_error: 0.3087
# Epoch 28/50
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1093 - root_mean_squared_error: 0.3307 - val_loss: 0.0816 - val_root_mean_squared_error: 0.2856
# Epoch 29/50
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0953 - root_mean_squared_error: 0.3087 - val_loss: 0.0697 - val_root_mean_squared_error: 0.2641
# Epoch 30/50
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0831 - root_mean_squared_error: 0.2883 - val_loss: 0.0601 - val_root_mean_squared_error: 0.2451
# Epoch 31/50
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0735 - root_mean_squared_error: 0.2711 - val_loss: 0.0522 - val_root_mean_squared_error: 0.2284
# Epoch 32/50
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0654 - root_mean_squared_error: 0.2558 - val_loss: 0.0459 - val_root_mean_squared_error: 0.2143
# Epoch 33/50
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0590 - root_mean_squared_error: 0.2430 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2015
# Epoch 34/50
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0538 - root_mean_squared_error: 0.2320 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1911
# Epoch 35/50
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0497 - root_mean_squared_error: 0.2228 - val_loss: 0.0334 - val_root_mean_squared_error: 0.1828
# Epoch 36/50
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0464 - root_mean_squared_error: 0.2155 - val_loss: 0.0309 - val_root_mean_squared_error: 0.1757
# Epoch 37/50
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0440 - root_mean_squared_error: 0.2098 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1698
# Epoch 38/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0420 - root_mean_squared_error: 0.2049 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1648
# Epoch 39/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0404 - root_mean_squared_error: 0.2010 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1610
# Epoch 40/50
# 8/8 [==============================] - 1s 116ms/step - loss: 0.0393 - root_mean_squared_error: 0.1983 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 41/50
# 8/8 [==============================] - 1s 159ms/step - loss: 0.0384 - root_mean_squared_error: 0.1959 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1555
# Epoch 42/50
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0377 - root_mean_squared_error: 0.1941 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1537
# Epoch 43/50
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0371 - root_mean_squared_error: 0.1927 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1522
# Epoch 44/50
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0367 - root_mean_squared_error: 0.1915 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1510
# Epoch 45/50
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0364 - root_mean_squared_error: 0.1907 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1500
# Epoch 46/50
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0361 - root_mean_squared_error: 0.1900 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1491
# Epoch 47/50
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0358 - root_mean_squared_error: 0.1893 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1486
# Epoch 48/50
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0357 - root_mean_squared_error: 0.1890 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1480
# Epoch 49/50
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0356 - root_mean_squared_error: 0.1886 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 50/50
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0354 - root_mean_squared_error: 0.1883 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# 8/8 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 3ms/step

# %% [markdown]
# ### GRU

# %%
model = keras.Sequential([
    layers.GRU(units=64, input_shape=(3, 1)),
    layers.Dense(units=1)
])

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('gru/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train, y_train, x_val, y_val)

plot_train("gru", 50, x_train, y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
gru_mse = plot_predictions1(model,x_test, y_test)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 6s 480ms/step - loss: 2.8940 - root_mean_squared_error: 1.7012 - val_loss: 2.4750 - val_root_mean_squared_error: 1.5732
# Epoch 2/50
# 8/8 [==============================] - 3s 412ms/step - loss: 2.7413 - root_mean_squared_error: 1.6557 - val_loss: 2.3411 - val_root_mean_squared_error: 1.5301
# Epoch 3/50
# 8/8 [==============================] - 4s 625ms/step - loss: 2.5902 - root_mean_squared_error: 1.6094 - val_loss: 2.2108 - val_root_mean_squared_error: 1.4869
# Epoch 4/50
# 8/8 [==============================] - 3s 415ms/step - loss: 2.4456 - root_mean_squared_error: 1.5638 - val_loss: 2.0826 - val_root_mean_squared_error: 1.4431
# Epoch 5/50
# 8/8 [==============================] - 3s 413ms/step - loss: 2.3030 - root_mean_squared_error: 1.5176 - val_loss: 1.9607 - val_root_mean_squared_error: 1.4002
# Epoch 6/50
# 8/8 [==============================] - 3s 420ms/step - loss: 2.1678 - root_mean_squared_error: 1.4723 - val_loss: 1.8407 - val_root_mean_squared_error: 1.3567
# Epoch 7/50
# 8/8 [==============================] - 6s 837ms/step - loss: 2.0327 - root_mean_squared_error: 1.4257 - val_loss: 1.7235 - val_root_mean_squared_error: 1.3128
# Epoch 8/50
# 8/8 [==============================] - 3s 418ms/step - loss: 1.9033 - root_mean_squared_error: 1.3796 - val_loss: 1.6092 - val_root_mean_squared_error: 1.2685
# Epoch 9/50
# 8/8 [==============================] - 3s 421ms/step - loss: 1.7756 - root_mean_squared_error: 1.3325 - val_loss: 1.4976 - val_root_mean_squared_error: 1.2237
# Epoch 10/50
# 8/8 [==============================] - 4s 572ms/step - loss: 1.6527 - root_mean_squared_error: 1.2856 - val_loss: 1.3906 - val_root_mean_squared_error: 1.1792
# Epoch 11/50
# 8/8 [==============================] - 4s 510ms/step - loss: 1.5335 - root_mean_squared_error: 1.2383 - val_loss: 1.2868 - val_root_mean_squared_error: 1.1344
# Epoch 12/50
# 8/8 [==============================] - 3s 416ms/step - loss: 1.4162 - root_mean_squared_error: 1.1900 - val_loss: 1.1843 - val_root_mean_squared_error: 1.0883
# Epoch 13/50
# 8/8 [==============================] - 4s 501ms/step - loss: 1.3032 - root_mean_squared_error: 1.1416 - val_loss: 1.0881 - val_root_mean_squared_error: 1.0431
# Epoch 14/50
# 8/8 [==============================] - 3s 488ms/step - loss: 1.1974 - root_mean_squared_error: 1.0943 - val_loss: 0.9938 - val_root_mean_squared_error: 0.9969
# Epoch 15/50
# 8/8 [==============================] - 4s 517ms/step - loss: 1.0922 - root_mean_squared_error: 1.0451 - val_loss: 0.9017 - val_root_mean_squared_error: 0.9496
# Epoch 16/50
# 8/8 [==============================] - 3s 417ms/step - loss: 0.9891 - root_mean_squared_error: 0.9946 - val_loss: 0.8138 - val_root_mean_squared_error: 0.9021
# Epoch 17/50
# 8/8 [==============================] - 4s 518ms/step - loss: 0.8914 - root_mean_squared_error: 0.9442 - val_loss: 0.7295 - val_root_mean_squared_error: 0.8541
# Epoch 18/50
# 8/8 [==============================] - 3s 482ms/step - loss: 0.7984 - root_mean_squared_error: 0.8935 - val_loss: 0.6499 - val_root_mean_squared_error: 0.8061
# Epoch 19/50
# 8/8 [==============================] - 4s 511ms/step - loss: 0.7110 - root_mean_squared_error: 0.8432 - val_loss: 0.5752 - val_root_mean_squared_error: 0.7584
# Epoch 20/50
# 8/8 [==============================] - 3s 494ms/step - loss: 0.6282 - root_mean_squared_error: 0.7926 - val_loss: 0.5039 - val_root_mean_squared_error: 0.7099
# Epoch 21/50
# 8/8 [==============================] - 3s 423ms/step - loss: 0.5485 - root_mean_squared_error: 0.7406 - val_loss: 0.4388 - val_root_mean_squared_error: 0.6624
# Epoch 22/50
# 8/8 [==============================] - 4s 508ms/step - loss: 0.4779 - root_mean_squared_error: 0.6913 - val_loss: 0.3778 - val_root_mean_squared_error: 0.6146
# Epoch 23/50
# 8/8 [==============================] - 4s 527ms/step - loss: 0.4101 - root_mean_squared_error: 0.6404 - val_loss: 0.3221 - val_root_mean_squared_error: 0.5675
# Epoch 24/50
# 8/8 [==============================] - 4s 574ms/step - loss: 0.3506 - root_mean_squared_error: 0.5921 - val_loss: 0.2718 - val_root_mean_squared_error: 0.5214
# Epoch 25/50
# 8/8 [==============================] - 3s 417ms/step - loss: 0.2971 - root_mean_squared_error: 0.5451 - val_loss: 0.2280 - val_root_mean_squared_error: 0.4775
# Epoch 26/50
# 8/8 [==============================] - 4s 507ms/step - loss: 0.2485 - root_mean_squared_error: 0.4985 - val_loss: 0.1905 - val_root_mean_squared_error: 0.4364
# Epoch 27/50
# 8/8 [==============================] - 4s 590ms/step - loss: 0.2078 - root_mean_squared_error: 0.4559 - val_loss: 0.1579 - val_root_mean_squared_error: 0.3974
# Epoch 28/50
# 8/8 [==============================] - 3s 418ms/step - loss: 0.1747 - root_mean_squared_error: 0.4180 - val_loss: 0.1300 - val_root_mean_squared_error: 0.3606
# Epoch 29/50
# 8/8 [==============================] - 3s 417ms/step - loss: 0.1447 - root_mean_squared_error: 0.3804 - val_loss: 0.1083 - val_root_mean_squared_error: 0.3291
# Epoch 30/50
# 8/8 [==============================] - 4s 605ms/step - loss: 0.1215 - root_mean_squared_error: 0.3486 - val_loss: 0.0901 - val_root_mean_squared_error: 0.3002
# Epoch 31/50
# 8/8 [==============================] - 3s 467ms/step - loss: 0.1028 - root_mean_squared_error: 0.3207 - val_loss: 0.0764 - val_root_mean_squared_error: 0.2765
# Epoch 32/50
# 8/8 [==============================] - 3s 412ms/step - loss: 0.0887 - root_mean_squared_error: 0.2978 - val_loss: 0.0661 - val_root_mean_squared_error: 0.2570
# Epoch 33/50
# 8/8 [==============================] - 4s 506ms/step - loss: 0.0787 - root_mean_squared_error: 0.2806 - val_loss: 0.0581 - val_root_mean_squared_error: 0.2411
# Epoch 34/50
# 8/8 [==============================] - 4s 528ms/step - loss: 0.0704 - root_mean_squared_error: 0.2653 - val_loss: 0.0528 - val_root_mean_squared_error: 0.2297
# Epoch 35/50
# 8/8 [==============================] - 3s 474ms/step - loss: 0.0649 - root_mean_squared_error: 0.2548 - val_loss: 0.0488 - val_root_mean_squared_error: 0.2210
# Epoch 36/50
# 8/8 [==============================] - 3s 414ms/step - loss: 0.0608 - root_mean_squared_error: 0.2466 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2149
# Epoch 37/50
# 8/8 [==============================] - 4s 529ms/step - loss: 0.0584 - root_mean_squared_error: 0.2416 - val_loss: 0.0442 - val_root_mean_squared_error: 0.2103
# Epoch 38/50
# 8/8 [==============================] - 4s 512ms/step - loss: 0.0565 - root_mean_squared_error: 0.2377 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2075
# Epoch 39/50
# 8/8 [==============================] - 3s 478ms/step - loss: 0.0552 - root_mean_squared_error: 0.2350 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2055
# Epoch 40/50
# 8/8 [==============================] - 4s 507ms/step - loss: 0.0544 - root_mean_squared_error: 0.2332 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2039
# Epoch 41/50
# 8/8 [==============================] - 3s 418ms/step - loss: 0.0538 - root_mean_squared_error: 0.2319 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 42/50
# 8/8 [==============================] - 4s 506ms/step - loss: 0.0532 - root_mean_squared_error: 0.2306 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2015
# Epoch 43/50
# 8/8 [==============================] - 3s 488ms/step - loss: 0.0528 - root_mean_squared_error: 0.2297 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2005
# Epoch 44/50
# 8/8 [==============================] - 4s 524ms/step - loss: 0.0524 - root_mean_squared_error: 0.2288 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1996
# Epoch 45/50
# 8/8 [==============================] - 3s 419ms/step - loss: 0.0520 - root_mean_squared_error: 0.2280 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1987
# Epoch 46/50
# 8/8 [==============================] - 4s 509ms/step - loss: 0.0516 - root_mean_squared_error: 0.2272 - val_loss: 0.0392 - val_root_mean_squared_error: 0.1979
# Epoch 47/50
# 8/8 [==============================] - 4s 583ms/step - loss: 0.0513 - root_mean_squared_error: 0.2264 - val_loss: 0.0388 - val_root_mean_squared_error: 0.1970
# Epoch 48/50
# 8/8 [==============================] - 3s 414ms/step - loss: 0.0509 - root_mean_squared_error: 0.2256 - val_loss: 0.0385 - val_root_mean_squared_error: 0.1961
# Epoch 49/50
# 8/8 [==============================] - 3s 411ms/step - loss: 0.0506 - root_mean_squared_error: 0.2249 - val_loss: 0.0381 - val_root_mean_squared_error: 0.1953
# Epoch 50/50
# 8/8 [==============================] - 4s 606ms/step - loss: 0.0502 - root_mean_squared_error: 0.2241 - val_loss: 0.0378 - val_root_mean_squared_error: 0.1944
# 8/8 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step

# %% [markdown]
# ### LSTM

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))

cp = ModelCheckpoint('lstm/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train, y_train, x_val, y_val)


plot_train("lstm", 50, x_train, y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
lstm_mse = plot_predictions1(model,x_test, y_test)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 7s 723ms/step - loss: 3.4497 - root_mean_squared_error: 1.8573 - val_loss: 3.0033 - val_root_mean_squared_error: 1.7330
# Epoch 2/50
# 8/8 [==============================] - 4s 600ms/step - loss: 3.3657 - root_mean_squared_error: 1.8346 - val_loss: 2.9293 - val_root_mean_squared_error: 1.7115
# Epoch 3/50
# 8/8 [==============================] - 3s 483ms/step - loss: 3.2825 - root_mean_squared_error: 1.8118 - val_loss: 2.8561 - val_root_mean_squared_error: 1.6900
# Epoch 4/50
# 8/8 [==============================] - 4s 613ms/step - loss: 3.2014 - root_mean_squared_error: 1.7893 - val_loss: 2.7853 - val_root_mean_squared_error: 1.6689
# Epoch 5/50
# 8/8 [==============================] - 4s 613ms/step - loss: 3.1222 - root_mean_squared_error: 1.7670 - val_loss: 2.7150 - val_root_mean_squared_error: 1.6477
# Epoch 6/50
# 8/8 [==============================] - 3s 481ms/step - loss: 3.0409 - root_mean_squared_error: 1.7438 - val_loss: 2.6452 - val_root_mean_squared_error: 1.6264
# Epoch 7/50
# 8/8 [==============================] - 4s 519ms/step - loss: 2.9623 - root_mean_squared_error: 1.7211 - val_loss: 2.5731 - val_root_mean_squared_error: 1.6041
# Epoch 8/50
# 8/8 [==============================] - 5s 683ms/step - loss: 2.8791 - root_mean_squared_error: 1.6968 - val_loss: 2.4948 - val_root_mean_squared_error: 1.5795
# Epoch 9/50
# 8/8 [==============================] - 3s 477ms/step - loss: 2.7889 - root_mean_squared_error: 1.6700 - val_loss: 2.4123 - val_root_mean_squared_error: 1.5532
# Epoch 10/50
# 8/8 [==============================] - 3s 475ms/step - loss: 2.6956 - root_mean_squared_error: 1.6418 - val_loss: 2.3304 - val_root_mean_squared_error: 1.5266
# Epoch 11/50
# 8/8 [==============================] - 5s 748ms/step - loss: 2.6031 - root_mean_squared_error: 1.6134 - val_loss: 2.2478 - val_root_mean_squared_error: 1.4993
# Epoch 12/50
# 8/8 [==============================] - 3s 486ms/step - loss: 2.5106 - root_mean_squared_error: 1.5845 - val_loss: 2.1652 - val_root_mean_squared_error: 1.4715
# Epoch 13/50
# 8/8 [==============================] - 3s 477ms/step - loss: 2.4168 - root_mean_squared_error: 1.5546 - val_loss: 2.0851 - val_root_mean_squared_error: 1.4440
# Epoch 14/50
# 8/8 [==============================] - 5s 674ms/step - loss: 2.3262 - root_mean_squared_error: 1.5252 - val_loss: 2.0052 - val_root_mean_squared_error: 1.4161
# Epoch 15/50
# 8/8 [==============================] - 4s 569ms/step - loss: 2.2361 - root_mean_squared_error: 1.4954 - val_loss: 1.9243 - val_root_mean_squared_error: 1.3872
# Epoch 16/50
# 8/8 [==============================] - 3s 479ms/step - loss: 2.1472 - root_mean_squared_error: 1.4653 - val_loss: 1.8463 - val_root_mean_squared_error: 1.3588
# Epoch 17/50
# 8/8 [==============================] - 4s 588ms/step - loss: 2.0586 - root_mean_squared_error: 1.4348 - val_loss: 1.7687 - val_root_mean_squared_error: 1.3299
# Epoch 18/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.9705 - root_mean_squared_error: 1.4037 - val_loss: 1.6905 - val_root_mean_squared_error: 1.3002
# Epoch 19/50
# 8/8 [==============================] - 4s 588ms/step - loss: 1.8837 - root_mean_squared_error: 1.3725 - val_loss: 1.6124 - val_root_mean_squared_error: 1.2698
# Epoch 20/50
# 8/8 [==============================] - 5s 719ms/step - loss: 1.7958 - root_mean_squared_error: 1.3401 - val_loss: 1.5353 - val_root_mean_squared_error: 1.2391
# Epoch 21/50
# 8/8 [==============================] - 4s 516ms/step - loss: 1.7075 - root_mean_squared_error: 1.3067 - val_loss: 1.4579 - val_root_mean_squared_error: 1.2074
# Epoch 22/50
# 8/8 [==============================] - 3s 477ms/step - loss: 1.6204 - root_mean_squared_error: 1.2729 - val_loss: 1.3803 - val_root_mean_squared_error: 1.1749
# Epoch 23/50
# 8/8 [==============================] - 4s 593ms/step - loss: 1.5320 - root_mean_squared_error: 1.2377 - val_loss: 1.3042 - val_root_mean_squared_error: 1.1420
# Epoch 24/50
# 8/8 [==============================] - 4s 627ms/step - loss: 1.4460 - root_mean_squared_error: 1.2025 - val_loss: 1.2267 - val_root_mean_squared_error: 1.1076
# Epoch 25/50
# 8/8 [==============================] - 3s 489ms/step - loss: 1.3598 - root_mean_squared_error: 1.1661 - val_loss: 1.1492 - val_root_mean_squared_error: 1.0720
# Epoch 26/50
# 8/8 [==============================] - 4s 596ms/step - loss: 1.2723 - root_mean_squared_error: 1.1280 - val_loss: 1.0731 - val_root_mean_squared_error: 1.0359
# Epoch 27/50
# 8/8 [==============================] - 5s 642ms/step - loss: 1.1866 - root_mean_squared_error: 1.0893 - val_loss: 0.9996 - val_root_mean_squared_error: 0.9998
# Epoch 28/50
# 8/8 [==============================] - 4s 509ms/step - loss: 1.1035 - root_mean_squared_error: 1.0505 - val_loss: 0.9263 - val_root_mean_squared_error: 0.9624
# Epoch 29/50
# 8/8 [==============================] - 4s 635ms/step - loss: 1.0206 - root_mean_squared_error: 1.0103 - val_loss: 0.8537 - val_root_mean_squared_error: 0.9240
# Epoch 30/50
# 8/8 [==============================] - 4s 569ms/step - loss: 0.9399 - root_mean_squared_error: 0.9695 - val_loss: 0.7817 - val_root_mean_squared_error: 0.8841
# Epoch 31/50
# 8/8 [==============================] - 4s 589ms/step - loss: 0.8588 - root_mean_squared_error: 0.9267 - val_loss: 0.7120 - val_root_mean_squared_error: 0.8438
# Epoch 32/50
# 8/8 [==============================] - 4s 605ms/step - loss: 0.7823 - root_mean_squared_error: 0.8845 - val_loss: 0.6444 - val_root_mean_squared_error: 0.8027
# Epoch 33/50
# 8/8 [==============================] - 3s 485ms/step - loss: 0.7055 - root_mean_squared_error: 0.8399 - val_loss: 0.5803 - val_root_mean_squared_error: 0.7618
# Epoch 34/50
# 8/8 [==============================] - 5s 653ms/step - loss: 0.6337 - root_mean_squared_error: 0.7961 - val_loss: 0.5182 - val_root_mean_squared_error: 0.7198
# Epoch 35/50
# 8/8 [==============================] - 4s 614ms/step - loss: 0.5641 - root_mean_squared_error: 0.7511 - val_loss: 0.4591 - val_root_mean_squared_error: 0.6775
# Epoch 36/50
# 8/8 [==============================] - 3s 495ms/step - loss: 0.4992 - root_mean_squared_error: 0.7065 - val_loss: 0.4022 - val_root_mean_squared_error: 0.6342
# Epoch 37/50
# 8/8 [==============================] - 4s 613ms/step - loss: 0.4391 - root_mean_squared_error: 0.6626 - val_loss: 0.3504 - val_root_mean_squared_error: 0.5920
# Epoch 38/50
# 8/8 [==============================] - 4s 536ms/step - loss: 0.3824 - root_mean_squared_error: 0.6184 - val_loss: 0.3046 - val_root_mean_squared_error: 0.5519
# Epoch 39/50
# 8/8 [==============================] - 5s 660ms/step - loss: 0.3326 - root_mean_squared_error: 0.5767 - val_loss: 0.2627 - val_root_mean_squared_error: 0.5125
# Epoch 40/50
# 8/8 [==============================] - 5s 691ms/step - loss: 0.2876 - root_mean_squared_error: 0.5363 - val_loss: 0.2251 - val_root_mean_squared_error: 0.4745
# Epoch 41/50
# 8/8 [==============================] - 5s 645ms/step - loss: 0.2464 - root_mean_squared_error: 0.4964 - val_loss: 0.1913 - val_root_mean_squared_error: 0.4374
# Epoch 42/50
# 8/8 [==============================] - 3s 498ms/step - loss: 0.2102 - root_mean_squared_error: 0.4584 - val_loss: 0.1620 - val_root_mean_squared_error: 0.4025
# Epoch 43/50
# 8/8 [==============================] - 3s 481ms/step - loss: 0.1796 - root_mean_squared_error: 0.4238 - val_loss: 0.1361 - val_root_mean_squared_error: 0.3690
# Epoch 44/50
# 8/8 [==============================] - 5s 646ms/step - loss: 0.1515 - root_mean_squared_error: 0.3892 - val_loss: 0.1147 - val_root_mean_squared_error: 0.3387
# Epoch 45/50
# 8/8 [==============================] - 4s 613ms/step - loss: 0.1290 - root_mean_squared_error: 0.3592 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3115
# Epoch 46/50
# 8/8 [==============================] - 3s 480ms/step - loss: 0.1106 - root_mean_squared_error: 0.3326 - val_loss: 0.0822 - val_root_mean_squared_error: 0.2868
# Epoch 47/50
# 8/8 [==============================] - 4s 623ms/step - loss: 0.0952 - root_mean_squared_error: 0.3086 - val_loss: 0.0700 - val_root_mean_squared_error: 0.2645
# Epoch 48/50
# 8/8 [==============================] - 4s 617ms/step - loss: 0.0827 - root_mean_squared_error: 0.2876 - val_loss: 0.0600 - val_root_mean_squared_error: 0.2449
# Epoch 49/50
# 8/8 [==============================] - 3s 486ms/step - loss: 0.0724 - root_mean_squared_error: 0.2691 - val_loss: 0.0521 - val_root_mean_squared_error: 0.2284
# Epoch 50/50
# 8/8 [==============================] - 4s 521ms/step - loss: 0.0644 - root_mean_squared_error: 0.2538 - val_loss: 0.0461 - val_root_mean_squared_error: 0.2147
# 8/8 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step

# %% [markdown]
# ### RNN

# %%
model = keras.Sequential([
    layers.SimpleRNN(units=64, input_shape=(3, 1)),
    layers.Dense(units=1)
])

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('rnn/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train, y_train, x_val, y_val)

plot_train("rnn", 50, x_train, y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
rnn_mse = plot_predictions1(model,x_test, y_test)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 3s 231ms/step - loss: 1.3307 - root_mean_squared_error: 1.1535 - val_loss: 0.9432 - val_root_mean_squared_error: 0.9712
# Epoch 2/50
# 8/8 [==============================] - 1s 202ms/step - loss: 0.9255 - root_mean_squared_error: 0.9620 - val_loss: 0.6283 - val_root_mean_squared_error: 0.7927
# Epoch 3/50
# 8/8 [==============================] - 1s 195ms/step - loss: 0.6127 - root_mean_squared_error: 0.7827 - val_loss: 0.3967 - val_root_mean_squared_error: 0.6299
# Epoch 4/50
# 8/8 [==============================] - 2s 299ms/step - loss: 0.3866 - root_mean_squared_error: 0.6218 - val_loss: 0.2370 - val_root_mean_squared_error: 0.4869
# Epoch 5/50
# 8/8 [==============================] - 2s 291ms/step - loss: 0.2350 - root_mean_squared_error: 0.4847 - val_loss: 0.1384 - val_root_mean_squared_error: 0.3720
# Epoch 6/50
# 8/8 [==============================] - 2s 277ms/step - loss: 0.1462 - root_mean_squared_error: 0.3824 - val_loss: 0.0833 - val_root_mean_squared_error: 0.2887
# Epoch 7/50
# 8/8 [==============================] - 1s 202ms/step - loss: 0.0972 - root_mean_squared_error: 0.3118 - val_loss: 0.0566 - val_root_mean_squared_error: 0.2378
# Epoch 8/50
# 8/8 [==============================] - 1s 200ms/step - loss: 0.0756 - root_mean_squared_error: 0.2749 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2124
# Epoch 9/50
# 8/8 [==============================] - 1s 197ms/step - loss: 0.0651 - root_mean_squared_error: 0.2552 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2043
# Epoch 10/50
# 8/8 [==============================] - 1s 202ms/step - loss: 0.0626 - root_mean_squared_error: 0.2502 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2023
# Epoch 11/50
# 8/8 [==============================] - 2s 299ms/step - loss: 0.0619 - root_mean_squared_error: 0.2488 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2012
# Epoch 12/50
# 8/8 [==============================] - 1s 203ms/step - loss: 0.0610 - root_mean_squared_error: 0.2470 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1993
# Epoch 13/50
# 8/8 [==============================] - 2s 272ms/step - loss: 0.0600 - root_mean_squared_error: 0.2450 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1975
# Epoch 14/50
# 8/8 [==============================] - 2s 295ms/step - loss: 0.0591 - root_mean_squared_error: 0.2431 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1954
# Epoch 15/50
# 8/8 [==============================] - 1s 199ms/step - loss: 0.0581 - root_mean_squared_error: 0.2411 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1934
# Epoch 16/50
# 8/8 [==============================] - 1s 192ms/step - loss: 0.0572 - root_mean_squared_error: 0.2391 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1916
# Epoch 17/50
# 8/8 [==============================] - 1s 193ms/step - loss: 0.0563 - root_mean_squared_error: 0.2372 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1899
# Epoch 18/50
# 8/8 [==============================] - 2s 309ms/step - loss: 0.0554 - root_mean_squared_error: 0.2354 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1882
# Epoch 19/50
# 8/8 [==============================] - 1s 205ms/step - loss: 0.0545 - root_mean_squared_error: 0.2335 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1866
# Epoch 20/50
# 8/8 [==============================] - 1s 200ms/step - loss: 0.0537 - root_mean_squared_error: 0.2317 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1849
# Epoch 21/50
# 8/8 [==============================] - 2s 238ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1833
# Epoch 22/50
# 8/8 [==============================] - 2s 289ms/step - loss: 0.0520 - root_mean_squared_error: 0.2281 - val_loss: 0.0330 - val_root_mean_squared_error: 0.1816
# Epoch 23/50
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0511 - root_mean_squared_error: 0.2261 - val_loss: 0.0324 - val_root_mean_squared_error: 0.1800
# Epoch 24/50
# 8/8 [==============================] - 1s 192ms/step - loss: 0.0504 - root_mean_squared_error: 0.2246 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1785
# Epoch 25/50
# 8/8 [==============================] - 2s 299ms/step - loss: 0.0496 - root_mean_squared_error: 0.2228 - val_loss: 0.0313 - val_root_mean_squared_error: 0.1770
# Epoch 26/50
# 8/8 [==============================] - 1s 208ms/step - loss: 0.0489 - root_mean_squared_error: 0.2211 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1756
# Epoch 27/50
# 8/8 [==============================] - 1s 199ms/step - loss: 0.0481 - root_mean_squared_error: 0.2193 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1743
# Epoch 28/50
# 8/8 [==============================] - 1s 196ms/step - loss: 0.0474 - root_mean_squared_error: 0.2178 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1729
# Epoch 29/50
# 8/8 [==============================] - 1s 197ms/step - loss: 0.0468 - root_mean_squared_error: 0.2164 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1716
# Epoch 30/50
# 8/8 [==============================] - 2s 280ms/step - loss: 0.0460 - root_mean_squared_error: 0.2146 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1704
# Epoch 31/50
# 8/8 [==============================] - 2s 272ms/step - loss: 0.0456 - root_mean_squared_error: 0.2136 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1694
# Epoch 32/50
# 8/8 [==============================] - 2s 291ms/step - loss: 0.0449 - root_mean_squared_error: 0.2118 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1682
# Epoch 33/50
# 8/8 [==============================] - 1s 204ms/step - loss: 0.0442 - root_mean_squared_error: 0.2103 - val_loss: 0.0279 - val_root_mean_squared_error: 0.1670
# Epoch 34/50
# 8/8 [==============================] - 1s 203ms/step - loss: 0.0437 - root_mean_squared_error: 0.2090 - val_loss: 0.0276 - val_root_mean_squared_error: 0.1660
# Epoch 35/50
# 8/8 [==============================] - 1s 199ms/step - loss: 0.0431 - root_mean_squared_error: 0.2076 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1651
# Epoch 36/50
# 8/8 [==============================] - 1s 200ms/step - loss: 0.0427 - root_mean_squared_error: 0.2067 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1642
# Epoch 37/50
# 8/8 [==============================] - 1s 198ms/step - loss: 0.0421 - root_mean_squared_error: 0.2051 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1633
# Epoch 38/50
# 8/8 [==============================] - 2s 253ms/step - loss: 0.0416 - root_mean_squared_error: 0.2040 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1625
# Epoch 39/50
# 8/8 [==============================] - 3s 398ms/step - loss: 0.0411 - root_mean_squared_error: 0.2028 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1616
# Epoch 40/50
# 8/8 [==============================] - 1s 204ms/step - loss: 0.0407 - root_mean_squared_error: 0.2017 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1609
# Epoch 41/50
# 8/8 [==============================] - 1s 194ms/step - loss: 0.0404 - root_mean_squared_error: 0.2009 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1601
# Epoch 42/50
# 8/8 [==============================] - 1s 194ms/step - loss: 0.0398 - root_mean_squared_error: 0.1996 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1595
# Epoch 43/50
# 8/8 [==============================] - 1s 197ms/step - loss: 0.0394 - root_mean_squared_error: 0.1986 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1586
# Epoch 44/50
# 8/8 [==============================] - 1s 195ms/step - loss: 0.0389 - root_mean_squared_error: 0.1973 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1581
# Epoch 45/50
# 8/8 [==============================] - 1s 199ms/step - loss: 0.0386 - root_mean_squared_error: 0.1964 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1575
# Epoch 46/50
# 8/8 [==============================] - 2s 355ms/step - loss: 0.0382 - root_mean_squared_error: 0.1954 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1569
# Epoch 47/50
# 8/8 [==============================] - 2s 298ms/step - loss: 0.0378 - root_mean_squared_error: 0.1945 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1564
# Epoch 48/50
# 8/8 [==============================] - 1s 199ms/step - loss: 0.0376 - root_mean_squared_error: 0.1938 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1560
# Epoch 49/50
# 8/8 [==============================] - 1s 197ms/step - loss: 0.0372 - root_mean_squared_error: 0.1927 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1554
# Epoch 50/50
# 8/8 [==============================] - 1s 200ms/step - loss: 0.0368 - root_mean_squared_error: 0.1919 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1549
# 8/8 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step

# %% [markdown]
# # Moving Average

# %%
window_size = 3

def moving_average(data, window_size):
    cumsum = np.cumsum(data, axis=0)
    cumsum[window_size:] = cumsum[window_size:] - cumsum[:-window_size]
    return cumsum[window_size - 1:] / window_size

moving_avg_data = np.apply_along_axis(lambda x: moving_average(x, window_size), axis=0, arr=x_train)
target = y_train[window_size - 1:].flatten()

# %% [markdown]
# #### CNN

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(Conv1D(64, kernel_size=2))
model.add(Flatten())
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))

cp = ModelCheckpoint('mavg_cnn/', save_best_only=True)

model = fit_model(model, cp, epochs, moving_avg_data, target,x_val, y_val)

plot_train("mavg_cnn", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mvg_cnn_mse = plot_predictions1(model,x_test, y_test)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 107ms/step - loss: 2.5948 - root_mean_squared_error: 1.6108 - val_loss: 1.9976 - val_root_mean_squared_error: 1.4134
# Epoch 2/50
# 8/8 [==============================] - 1s 88ms/step - loss: 2.3979 - root_mean_squared_error: 1.5485 - val_loss: 1.8090 - val_root_mean_squared_error: 1.3450
# Epoch 3/50
# 8/8 [==============================] - 1s 185ms/step - loss: 2.2165 - root_mean_squared_error: 1.4888 - val_loss: 1.6303 - val_root_mean_squared_error: 1.2769
# Epoch 4/50
# 8/8 [==============================] - 1s 92ms/step - loss: 2.0440 - root_mean_squared_error: 1.4297 - val_loss: 1.4632 - val_root_mean_squared_error: 1.2096
# Epoch 5/50
# 8/8 [==============================] - 1s 131ms/step - loss: 1.8830 - root_mean_squared_error: 1.3722 - val_loss: 1.3033 - val_root_mean_squared_error: 1.1416
# Epoch 6/50
# 8/8 [==============================] - 1s 127ms/step - loss: 1.7312 - root_mean_squared_error: 1.3158 - val_loss: 1.1559 - val_root_mean_squared_error: 1.0751
# Epoch 7/50
# 8/8 [==============================] - 1s 122ms/step - loss: 1.5904 - root_mean_squared_error: 1.2611 - val_loss: 1.0267 - val_root_mean_squared_error: 1.0132
# Epoch 8/50
# 8/8 [==============================] - 1s 124ms/step - loss: 1.4696 - root_mean_squared_error: 1.2123 - val_loss: 0.9052 - val_root_mean_squared_error: 0.9514
# Epoch 9/50
# 8/8 [==============================] - 1s 87ms/step - loss: 1.3552 - root_mean_squared_error: 1.1641 - val_loss: 0.7996 - val_root_mean_squared_error: 0.8942
# Epoch 10/50
# 8/8 [==============================] - 1s 89ms/step - loss: 1.2561 - root_mean_squared_error: 1.1208 - val_loss: 0.7041 - val_root_mean_squared_error: 0.8391
# Epoch 11/50
# 8/8 [==============================] - 1s 86ms/step - loss: 1.1650 - root_mean_squared_error: 1.0793 - val_loss: 0.6173 - val_root_mean_squared_error: 0.7857
# Epoch 12/50
# 8/8 [==============================] - 1s 88ms/step - loss: 1.0853 - root_mean_squared_error: 1.0418 - val_loss: 0.5403 - val_root_mean_squared_error: 0.7350
# Epoch 13/50
# 8/8 [==============================] - 1s 85ms/step - loss: 1.0112 - root_mean_squared_error: 1.0056 - val_loss: 0.4675 - val_root_mean_squared_error: 0.6837
# Epoch 14/50
# 8/8 [==============================] - 1s 89ms/step - loss: 0.9434 - root_mean_squared_error: 0.9713 - val_loss: 0.4010 - val_root_mean_squared_error: 0.6332
# Epoch 15/50
# 8/8 [==============================] - 1s 89ms/step - loss: 0.8834 - root_mean_squared_error: 0.9399 - val_loss: 0.3437 - val_root_mean_squared_error: 0.5862
# Epoch 16/50
# 8/8 [==============================] - 1s 87ms/step - loss: 0.8291 - root_mean_squared_error: 0.9106 - val_loss: 0.2915 - val_root_mean_squared_error: 0.5399
# Epoch 17/50
# 8/8 [==============================] - 1s 91ms/step - loss: 0.7810 - root_mean_squared_error: 0.8837 - val_loss: 0.2481 - val_root_mean_squared_error: 0.4981
# Epoch 18/50
# 8/8 [==============================] - 1s 156ms/step - loss: 0.7429 - root_mean_squared_error: 0.8619 - val_loss: 0.2114 - val_root_mean_squared_error: 0.4597
# Epoch 19/50
# 8/8 [==============================] - 1s 91ms/step - loss: 0.7084 - root_mean_squared_error: 0.8417 - val_loss: 0.1790 - val_root_mean_squared_error: 0.4231
# Epoch 20/50
# 8/8 [==============================] - 1s 89ms/step - loss: 0.6779 - root_mean_squared_error: 0.8233 - val_loss: 0.1507 - val_root_mean_squared_error: 0.3882
# Epoch 21/50
# 8/8 [==============================] - 1s 90ms/step - loss: 0.6551 - root_mean_squared_error: 0.8094 - val_loss: 0.1267 - val_root_mean_squared_error: 0.3560
# Epoch 22/50
# 8/8 [==============================] - 1s 90ms/step - loss: 0.6348 - root_mean_squared_error: 0.7967 - val_loss: 0.1084 - val_root_mean_squared_error: 0.3293
# Epoch 23/50
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6199 - root_mean_squared_error: 0.7873 - val_loss: 0.0918 - val_root_mean_squared_error: 0.3029
# Epoch 24/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.6054 - root_mean_squared_error: 0.7781 - val_loss: 0.0781 - val_root_mean_squared_error: 0.2795
# Epoch 25/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.5932 - root_mean_squared_error: 0.7702 - val_loss: 0.0680 - val_root_mean_squared_error: 0.2607
# Epoch 26/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.5863 - root_mean_squared_error: 0.7657 - val_loss: 0.0589 - val_root_mean_squared_error: 0.2427
# Epoch 27/50
# 8/8 [==============================] - 1s 103ms/step - loss: 0.5780 - root_mean_squared_error: 0.7603 - val_loss: 0.0518 - val_root_mean_squared_error: 0.2277
# Epoch 28/50
# 8/8 [==============================] - 1s 89ms/step - loss: 0.5719 - root_mean_squared_error: 0.7562 - val_loss: 0.0466 - val_root_mean_squared_error: 0.2160
# Epoch 29/50
# 8/8 [==============================] - 1s 86ms/step - loss: 0.5679 - root_mean_squared_error: 0.7536 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2069
# Epoch 30/50
# 8/8 [==============================] - 1s 84ms/step - loss: 0.5646 - root_mean_squared_error: 0.7514 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1975
# Epoch 31/50
# 8/8 [==============================] - 1s 86ms/step - loss: 0.5620 - root_mean_squared_error: 0.7496 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1913
# Epoch 32/50
# 8/8 [==============================] - 1s 85ms/step - loss: 0.5601 - root_mean_squared_error: 0.7484 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
# Epoch 33/50
# 8/8 [==============================] - 1s 86ms/step - loss: 0.5578 - root_mean_squared_error: 0.7469 - val_loss: 0.0317 - val_root_mean_squared_error: 0.1781
# Epoch 34/50
# 8/8 [==============================] - 1s 163ms/step - loss: 0.5560 - root_mean_squared_error: 0.7456 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1710
# Epoch 35/50
# 8/8 [==============================] - 1s 93ms/step - loss: 0.5547 - root_mean_squared_error: 0.7448 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1677
# Epoch 36/50
# 8/8 [==============================] - 1s 90ms/step - loss: 0.5544 - root_mean_squared_error: 0.7446 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1645
# Epoch 37/50
# 8/8 [==============================] - 1s 89ms/step - loss: 0.5535 - root_mean_squared_error: 0.7440 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1628
# Epoch 38/50
# 8/8 [==============================] - 1s 89ms/step - loss: 0.5532 - root_mean_squared_error: 0.7437 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1617
# Epoch 39/50
# 8/8 [==============================] - 1s 84ms/step - loss: 0.5528 - root_mean_squared_error: 0.7435 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1590
# Epoch 40/50
# 8/8 [==============================] - 1s 85ms/step - loss: 0.5521 - root_mean_squared_error: 0.7430 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1567
# Epoch 41/50
# 8/8 [==============================] - 1s 86ms/step - loss: 0.5518 - root_mean_squared_error: 0.7428 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1545
# Epoch 42/50
# 8/8 [==============================] - 1s 107ms/step - loss: 0.5516 - root_mean_squared_error: 0.7427 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1536
# Epoch 43/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.5514 - root_mean_squared_error: 0.7426 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1524
# Epoch 44/50
# 8/8 [==============================] - 1s 125ms/step - loss: 0.5513 - root_mean_squared_error: 0.7425 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1513
# Epoch 45/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.5511 - root_mean_squared_error: 0.7424 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1500
# Epoch 46/50
# 8/8 [==============================] - 1s 90ms/step - loss: 0.5510 - root_mean_squared_error: 0.7423 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1496
# Epoch 47/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5510 - root_mean_squared_error: 0.7423 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1497
# Epoch 48/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5510 - root_mean_squared_error: 0.7423 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1499
# Epoch 49/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5511 - root_mean_squared_error: 0.7424 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1505
# Epoch 50/50
# 8/8 [==============================] - 1s 86ms/step - loss: 0.5512 - root_mean_squared_error: 0.7424 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1495
# 8/8 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step

# %% [markdown]
# #### GRU

# %%
model = keras.Sequential([
    layers.GRU(units=64, input_shape=(3, 1)),
    layers.Dense(units=1)
])

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('mavg_gru/', save_best_only=True)
model = fit_model(model, cp, epochs,  moving_avg_data, target, x_val, y_val)

plot_train("mavg_gru", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mvg_gru_mse = plot_predictions1(model,x_test, y_test)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 6s 480ms/step - loss: 2.3794 - root_mean_squared_error: 1.5425 - val_loss: 1.8255 - val_root_mean_squared_error: 1.3511
# Epoch 2/50
# 8/8 [==============================] - 3s 402ms/step - loss: 2.2375 - root_mean_squared_error: 1.4958 - val_loss: 1.6862 - val_root_mean_squared_error: 1.2986
# Epoch 3/50
# 8/8 [==============================] - 3s 492ms/step - loss: 2.0971 - root_mean_squared_error: 1.4481 - val_loss: 1.5537 - val_root_mean_squared_error: 1.2465
# Epoch 4/50
# 8/8 [==============================] - 4s 557ms/step - loss: 1.9697 - root_mean_squared_error: 1.4035 - val_loss: 1.4256 - val_root_mean_squared_error: 1.1940
# Epoch 5/50
# 8/8 [==============================] - 3s 410ms/step - loss: 1.8445 - root_mean_squared_error: 1.3581 - val_loss: 1.3033 - val_root_mean_squared_error: 1.1416
# Epoch 6/50
# 8/8 [==============================] - 3s 416ms/step - loss: 1.7244 - root_mean_squared_error: 1.3132 - val_loss: 1.1890 - val_root_mean_squared_error: 1.0904
# Epoch 7/50
# 8/8 [==============================] - 4s 523ms/step - loss: 1.6152 - root_mean_squared_error: 1.2709 - val_loss: 1.0817 - val_root_mean_squared_error: 1.0401
# Epoch 8/50
# 8/8 [==============================] - 4s 552ms/step - loss: 1.5128 - root_mean_squared_error: 1.2300 - val_loss: 0.9841 - val_root_mean_squared_error: 0.9920
# Epoch 9/50
# 8/8 [==============================] - 3s 403ms/step - loss: 1.4192 - root_mean_squared_error: 1.1913 - val_loss: 0.8924 - val_root_mean_squared_error: 0.9447
# Epoch 10/50
# 8/8 [==============================] - 3s 410ms/step - loss: 1.3289 - root_mean_squared_error: 1.1528 - val_loss: 0.8072 - val_root_mean_squared_error: 0.8984
# Epoch 11/50
# 8/8 [==============================] - 4s 516ms/step - loss: 1.2451 - root_mean_squared_error: 1.1159 - val_loss: 0.7239 - val_root_mean_squared_error: 0.8508
# Epoch 12/50
# 8/8 [==============================] - 4s 560ms/step - loss: 1.1652 - root_mean_squared_error: 1.0794 - val_loss: 0.6423 - val_root_mean_squared_error: 0.8014
# Epoch 13/50
# 8/8 [==============================] - 3s 407ms/step - loss: 1.0851 - root_mean_squared_error: 1.0417 - val_loss: 0.5658 - val_root_mean_squared_error: 0.7522
# Epoch 14/50
# 8/8 [==============================] - 4s 510ms/step - loss: 1.0145 - root_mean_squared_error: 1.0072 - val_loss: 0.4955 - val_root_mean_squared_error: 0.7039
# Epoch 15/50
# 8/8 [==============================] - 3s 414ms/step - loss: 0.9476 - root_mean_squared_error: 0.9735 - val_loss: 0.4303 - val_root_mean_squared_error: 0.6560
# Epoch 16/50
# 8/8 [==============================] - 4s 561ms/step - loss: 0.8884 - root_mean_squared_error: 0.9426 - val_loss: 0.3724 - val_root_mean_squared_error: 0.6102
# Epoch 17/50
# 8/8 [==============================] - 3s 408ms/step - loss: 0.8368 - root_mean_squared_error: 0.9148 - val_loss: 0.3238 - val_root_mean_squared_error: 0.5690
# Epoch 18/50
# 8/8 [==============================] - 4s 526ms/step - loss: 0.7938 - root_mean_squared_error: 0.8910 - val_loss: 0.2811 - val_root_mean_squared_error: 0.5302
# Epoch 19/50
# 8/8 [==============================] - 3s 411ms/step - loss: 0.7554 - root_mean_squared_error: 0.8691 - val_loss: 0.2421 - val_root_mean_squared_error: 0.4921
# Epoch 20/50
# 8/8 [==============================] - 4s 565ms/step - loss: 0.7199 - root_mean_squared_error: 0.8485 - val_loss: 0.2072 - val_root_mean_squared_error: 0.4552
# Epoch 21/50
# 8/8 [==============================] - 3s 409ms/step - loss: 0.6881 - root_mean_squared_error: 0.8295 - val_loss: 0.1776 - val_root_mean_squared_error: 0.4214
# Epoch 22/50
# 8/8 [==============================] - 4s 530ms/step - loss: 0.6625 - root_mean_squared_error: 0.8140 - val_loss: 0.1504 - val_root_mean_squared_error: 0.3878
# Epoch 23/50
# 8/8 [==============================] - 3s 406ms/step - loss: 0.6383 - root_mean_squared_error: 0.7989 - val_loss: 0.1273 - val_root_mean_squared_error: 0.3567
# Epoch 24/50
# 8/8 [==============================] - 4s 555ms/step - loss: 0.6190 - root_mean_squared_error: 0.7868 - val_loss: 0.1059 - val_root_mean_squared_error: 0.3254
# Epoch 25/50
# 8/8 [==============================] - 3s 402ms/step - loss: 0.6032 - root_mean_squared_error: 0.7767 - val_loss: 0.0874 - val_root_mean_squared_error: 0.2956
# Epoch 26/50
# 8/8 [==============================] - 4s 516ms/step - loss: 0.5893 - root_mean_squared_error: 0.7676 - val_loss: 0.0749 - val_root_mean_squared_error: 0.2737
# Epoch 27/50
# 8/8 [==============================] - 3s 407ms/step - loss: 0.5796 - root_mean_squared_error: 0.7613 - val_loss: 0.0663 - val_root_mean_squared_error: 0.2576
# Epoch 28/50
# 8/8 [==============================] - 4s 552ms/step - loss: 0.5740 - root_mean_squared_error: 0.7576 - val_loss: 0.0598 - val_root_mean_squared_error: 0.2446
# Epoch 29/50
# 8/8 [==============================] - 4s 513ms/step - loss: 0.5693 - root_mean_squared_error: 0.7545 - val_loss: 0.0542 - val_root_mean_squared_error: 0.2328
# Epoch 30/50
# 8/8 [==============================] - 3s 411ms/step - loss: 0.5658 - root_mean_squared_error: 0.7522 - val_loss: 0.0500 - val_root_mean_squared_error: 0.2236
# Epoch 31/50
# 8/8 [==============================] - 3s 411ms/step - loss: 0.5631 - root_mean_squared_error: 0.7504 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2153
# Epoch 32/50
# 8/8 [==============================] - 4s 557ms/step - loss: 0.5610 - root_mean_squared_error: 0.7490 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2084
# Epoch 33/50
# 8/8 [==============================] - 4s 527ms/step - loss: 0.5595 - root_mean_squared_error: 0.7480 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2042
# Epoch 34/50
# 8/8 [==============================] - 3s 411ms/step - loss: 0.5586 - root_mean_squared_error: 0.7474 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1997
# Epoch 35/50
# 8/8 [==============================] - 3s 410ms/step - loss: 0.5579 - root_mean_squared_error: 0.7469 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1964
# Epoch 36/50
# 8/8 [==============================] - 4s 548ms/step - loss: 0.5577 - root_mean_squared_error: 0.7468 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1925
# Epoch 37/50
# 8/8 [==============================] - 4s 522ms/step - loss: 0.5572 - root_mean_squared_error: 0.7465 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1898
# Epoch 38/50
# 8/8 [==============================] - 3s 407ms/step - loss: 0.5568 - root_mean_squared_error: 0.7462 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1890
# Epoch 39/50
# 8/8 [==============================] - 3s 401ms/step - loss: 0.5568 - root_mean_squared_error: 0.7462 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1885
# Epoch 40/50
# 8/8 [==============================] - 4s 555ms/step - loss: 0.5566 - root_mean_squared_error: 0.7461 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 41/50
# 8/8 [==============================] - 4s 520ms/step - loss: 0.5567 - root_mean_squared_error: 0.7461 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1864
# Epoch 42/50
# 8/8 [==============================] - 3s 412ms/step - loss: 0.5570 - root_mean_squared_error: 0.7463 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1855
# Epoch 43/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5566 - root_mean_squared_error: 0.7461 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1873
# Epoch 44/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5568 - root_mean_squared_error: 0.7462 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1881
# Epoch 45/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5566 - root_mean_squared_error: 0.7460 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 46/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5564 - root_mean_squared_error: 0.7459 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1875
# Epoch 47/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5563 - root_mean_squared_error: 0.7459 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1866
# Epoch 48/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5563 - root_mean_squared_error: 0.7459 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 49/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5567 - root_mean_squared_error: 0.7461 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1883
# Epoch 50/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5564 - root_mean_squared_error: 0.7459 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1859
# 8/8 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 4ms/step

# %% [markdown]
# #### LSTM

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))

cp = ModelCheckpoint('mavg_lstm/', save_best_only=True)
model = fit_model(model, cp, epochs, moving_avg_data, target, x_val, y_val)

plot_train("mavg_lstm", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mvg_lstm_mse = plot_predictions1(model,x_test, y_test)

# %%
model = keras.Sequential([
    layers.SimpleRNN(units=64, input_shape=(3, 1)),
    layers.Dense(units=1)
])

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('mavg_rnn/', save_best_only=True)
model = fit_model(model, cp, epochs, moving_avg_data, target, x_val, y_val)

plot_train("mavg_rnn", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mvg_rnn_mse = plot_predictions1(model,x_test, y_test)

# %% [markdown]
# # AutoEncoder

# %% [markdown]
# ### CNN

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(Conv1D(64, kernel_size=2))
model.add(Dropout(0.2))
model.add(Conv1D(64, kernel_size=1))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))


model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('autoencoder_cnn/', save_best_only=True)

model = fit_model(model, cp, epochs, x_train, y_train, x_val, y_val)

plot_train("autoencoder_cnn", 50, x_train, y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
auto_cnn_mse = plot_predictions1(model,x_test, y_test)

# %%
auto_cnn_mse

# %% [markdown]
# ### GRU

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(GRU(64))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(1))


model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('autoencoder_gru/', save_best_only=True)

model = fit_model(model, cp, epochs, x_train, y_train, x_val, y_val)

plot_train("autoencoder_gru", 50, x_train, y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
auto_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
auto_gru_mse

# %% [markdown]
# ### LSTM

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(LSTM(64))
model.add(Dropout(0.3))
#model.add(RepeatVector(3))
#model.add(LSTM(64, return_sequences=True))
#model.add(Dropout(0.4))
model.add(Dense(8, 'relu'))
model.add(Flatten())
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('auto_lstm/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train, y_train, x_val, y_val)


plot_train("auto_lstm", 50, x_train, y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
auto_lstm_mse = plot_predictions1(model,x_test, y_test)

# %%
auto_lstm_mse

# %% [markdown]
# ### RNN

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(SimpleRNN(64))
model.add(Dropout(0.4))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('auto_rnn/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train, y_train, x_val, y_val)


plot_train("auto_rnn", 50, x_train, y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
auto_rnn_mse = plot_predictions1(model,x_test, y_test)

# %%
auto_rnn_mse

# %% [markdown]
# # Moving Average with Encoder

# %% [markdown]
# ### CNN

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(Conv1D(64, kernel_size=2))
model.add(Dropout(0.3))
model.add(Conv1D(64, kernel_size=1))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))


model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('mavg_autoencoder_cnn/', save_best_only=True)

model = fit_model(model, cp, 10, moving_avg_data, target, x_val, y_val)

plot_train("mavg_autoencoder_cnn", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_auto_cnn_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_auto_cnn_mse

# %% [markdown]
# ### RNN

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(SimpleRNN(64))
model.add(Dropout(0.4))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('mavg_auto_rnn/', save_best_only=True)
model = fit_model(model, cp, 10,moving_avg_data,target, x_val, y_val)


plot_train("mavg_auto_rnn", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_auto_rnn_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_auto_rnn_mse

# %% [markdown]
# ### GRU

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(GRU(64))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(1))


model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('mavg_auto_gru/', save_best_only=True)

model = fit_model(model, cp, 10, moving_avg_data, target, x_val, y_val)

plot_train("mavg_auto_gru", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_auto_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_auto_gru_mse

# %% [markdown]
# ### LSTM

# %%
model = Sequential()
model.add(InputLayer((3, 1)))
model.add(LSTM(64))
model.add(Dropout(0.3))
#model.add(RepeatVector(3))
#model.add(LSTM(64, return_sequences=True))
#model.add(Dropout(0.4))
#model.add(Dense(8, 'relu'))
#model.add(Flatten())
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('mavg_auto_lstm/', save_best_only=True)
model = fit_model(model, cp, 10,moving_avg_data, target, x_val, y_val)


plot_train("mavg_auto_lstm", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_auto_lstm_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_auto_lstm_mse

# %% [markdown]
# # Hybrid

# %% [markdown]
# ## General

# %% [markdown]
# ### CNN LSTM

# %%
input_shape = (15,1)
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(3,1)))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(RepeatVector(n=input_shape[0]))
model.add(LSTM(units=64, return_sequences=True))
model.add(LSTM(units=32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('hybrid_cnn_lstm/', save_best_only=True)

model = fit_model(model, cp, epochs, x_train,y_train, x_val, y_val)

plot_train("hybrid_cnn_lstm", 50, x_train,y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
hybrid_cnn_lstm_mse = plot_predictions1(model,x_test, y_test)

# %%
hybrid_cnn_lstm_mse

# %% [markdown]
# ### RNN LSTM

# %%
model = Sequential()
model.add(SimpleRNN(64,return_sequences=True, input_shape=(3,1)))
model.add(LSTM(32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('hybrid_rnn_lstm/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train,y_train, x_val, y_val)

plot_train("hybrid_rnn_lstm", 50, x_train,y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
hybrid_rnn_lstm_mse = plot_predictions1(model,x_test, y_test)

# %%
hybrid_rnn_lstm_mse

# %% [markdown]
# ### RNN GRU

# %%
model = Sequential()
model.add(SimpleRNN(64, return_sequences=True, input_shape=(3, 1)))
model.add(GRU(32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('hybrid_rnn_gru/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train,y_train, x_val, y_val)

plot_train("hybrid_rnn_gru", 50, x_train,y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
hybrid_rnn_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
hybrid_rnn_gru_mse

# %% [markdown]
# ### CNN GRU

# %%
model = Sequential()

model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(3,1)))
model.add(Flatten())

model.add(RepeatVector(n=15))
model.add(GRU(64, return_sequences=True))
model.add(GRU(32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('hybrid_cnn_gru/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train,y_train, x_val, y_val)

plot_train("hybrid_cnn_gru", 50, x_train,y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
hybrid_cnn_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
hybrid_cnn_gru_mse

# %% [markdown]
# ### CNN RNN GRU

# %%
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(3, 1)))
model.add(Flatten())
model.add(RepeatVector(n=15))
model.add(SimpleRNN(64, return_sequences=True))
model.add(GRU(32))
model.add(Dense(8))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('hybrid_cnn_rnn_gru/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train,y_train, x_val, y_val)

plot_train("hybrid_cnn_rnn_gru", 50, x_train,y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
hybrid_cnn_rnn_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
hybrid_cnn_rnn_gru_mse

# %% [markdown]
# ### LSTM RNN GRU

# %%
model = Sequential()
model.add(SimpleRNN(64, return_sequences=True, input_shape=(3,1)))
model.add(LSTM(128, return_sequences=True))
model.add(GRU(64))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('hybrid_lstm_rnn_gru/', save_best_only=True)
model = fit_model(model, cp, epochs, x_train,y_train, x_val, y_val)

plot_train("hybrid_lstm_rnn_gru", 50, x_train,y_train)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
hybrid_lstm_rnn_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
hybrid_lstm_rnn_gru_mse

# %% [markdown]
# ## Moving Average

# %% [markdown]
# ### CNN LSTM

# %%
input_shape = (15,1)
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(3,1)))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(RepeatVector(n=input_shape[0]))
model.add(LSTM(units=64, return_sequences=True))
model.add(LSTM(units=32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

cp = ModelCheckpoint('mavg_hybrid_cnn_lstm/', save_best_only=True)

model = fit_model(model, cp, epochs, moving_avg_data, target, x_val, y_val)

plot_train("mavg_hybrid_cnn_lstm", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_hybrid_cnn_lstm_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_hybrid_cnn_lstm_mse

# %% [markdown]
# ### RNN LSTM

# %%
model = Sequential()
model.add(SimpleRNN(64,return_sequences=True, input_shape=(3,1)))
model.add(LSTM(32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('mavg_hybrid_rnn_lstm/', save_best_only=True)
model = fit_model(model, cp, epochs, moving_avg_data, target, x_val, y_val)

plot_train("mavg_hybrid_rnn_lstm", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_hybrid_rnn_lstm_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_hybrid_rnn_lstm_mse

# %% [markdown]
# ### RNN GRU

# %%
model = Sequential()
model.add(SimpleRNN(64, return_sequences=True, input_shape=(3, 1)))
model.add(GRU(32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('mavg_hybrid_rnn_gru/', save_best_only=True)
model = fit_model(model, cp, epochs, moving_avg_data, target, x_val, y_val)

plot_train("mavg_hybrid_rnn_gru", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_hybrid_rnn_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_hybrid_rnn_gru_mse

# %% [markdown]
# ### CNN GRU

# %%
model = Sequential()

model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(3,1)))
#model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())

model.add(RepeatVector(n=15))
model.add(GRU(64, return_sequences=True))
model.add(GRU(32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('mavg_hybrid_cnn_gru/', save_best_only=True)
model = fit_model(model, cp, epochs, moving_avg_data, target, x_val, y_val)

plot_train("mavg_hybrid_cnn_gru", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_hybrid_cnn_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_hybrid_cnn_gru_mse

# %% [markdown]
# ### CNN RNN GRU

# %%
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(3, 1)))
#model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(RepeatVector(n=15))
model.add(SimpleRNN(64, return_sequences=True))
model.add(GRU(32))
model.add(Dense(8))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('mavg_hybrid_cnn_rnn_gru/', save_best_only=True)
model = fit_model(model, cp, epochs, moving_avg_data, target, x_val, y_val)

plot_train("mavg_hybrid_cnn_rnn_gru", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_hybrid_cnn_rnn_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_hybrid_cnn_rnn_gru_mse

# %% [markdown]
# ### RNN LSTM GRU

# %%
model = Sequential()
model.add(SimpleRNN(64, return_sequences=True, input_shape=(3,1)))
model.add(LSTM(128, return_sequences=True))
model.add(GRU(64))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
cp = ModelCheckpoint('mavg_hybrid_lstm_rnn_gru/', save_best_only=True)
model = fit_model(model, cp, epochs, moving_avg_data, target,x_val, y_val)

plot_train("mavg_hybrid_lstm_rnn_gru", 50, moving_avg_data, target)
plot_val(model, 50, x_val, y_val)
plot_test(model, 50, x_test, y_test)
mavg_hybrid_lstm_rnn_gru_mse = plot_predictions1(model,x_test, y_test)

# %%
mavg_hybrid_lstm_rnn_gru_mse

# %% [markdown]
# # MSE

# %%
mse_list = [cnn_mse, rnn_mse, gru_mse, lstm_mse,
            mvg_cnn_mse, mvg_rnn_mse, mvg_gru_mse, mvg_lstm_mse,
            auto_cnn_mse, auto_rnn_mse, auto_gru_mse, auto_lstm_mse,
            mavg_auto_cnn_mse, mavg_auto_rnn_mse, mavg_auto_gru_mse, mavg_auto_lstm_mse,
            hybrid_cnn_lstm_mse, hybrid_lstm_rnn_gru_mse,hybrid_cnn_rnn_gru_mse,hybrid_cnn_gru_mse,
            hybrid_rnn_gru_mse,hybrid_rnn_lstm_mse,
            mavg_hybrid_cnn_lstm_mse, mavg_hybrid_lstm_rnn_gru_mse,mavg_hybrid_cnn_rnn_gru_mse,
            mavg_hybrid_cnn_gru_mse,mavg_hybrid_rnn_gru_mse,mavg_hybrid_rnn_lstm_mse]

model_n = ["cnn", "rnn", "gru", "lstm",
           "mvg_cnn", "mvg_rnn", "mvg_gru", "mvg_lstm",
           "auto_cnn", "auto_rnn", "auto_gru", "auto_lstm",
           "mvg_auto_cnn", "mvg_auto_rnn", "mvg_auto_gru", "mvg_auto_lstm",
           "hybrid_cnn_lstm", "hybrid_lstm_rnn_gru" ,"hybrid_cnn_rnn_gru","hybrid_cnn_gru",
           "hybrid_rnn_gru","hybrid_rnn_lstm",
           "mavg_hybrid_cnn_lstm", "mavg_hybrid_lstm_rnn_gru","mavg_hybrid_cnn_rnn_gru",
           "mavg_hybrid_cnn_gru","mavg_hybrid_rnn_gru","mavg_hybrid_rnn_lstm"
          ]
msedf = pd.DataFrame({
    "Model": model_n,
    "MSE": mse_list
})

rmse = np.sqrt(msedf.MSE)
msedf["RMSE"] = rmse

# %%
msedf

# %%
msedf.to_csv("msedf.csv", index= False)

# %%
msedf.plot("Model", "RMSE", kind= "bar")
