# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
winter = pd.read_csv("data/Buriganga_W .csv")
summer = pd.read_csv("data/Buriganga_S.csv")

# %%
winter
# Out:
#         SamplingPoint  Temperature    pH    EC  TSS  Turbidity  Salinity  \
# 0     Gabtoli Dhalwes         25.0  8.25  1470  190       59.6       685
# 1       Gabtoli Turag         24.7  8.39  1593  156       78.6       706
# 2         Shah Cement         25.2  8.11  1656  142       85.3       642
# 3           Hazaribag         25.4  5.80   767  357       48.9       262
# 4          Rayerbazar         23.8  8.93   788  213       28.8       370
# 5           Kholamora         25.1  8.13  1472  320       42.5       712
# 6             Zinzira         24.2  8.62  1860  398       39.9       960
# 7  Sadarghat Terminal         25.9  5.55  1536  465      127.4       208
# 8       Postogola Bri         25.2  8.10  2502  300       75.5      1380
#
#     TDS    DO  COD  ...    Br     Cd     Cr     Ni     Cu     Zn     Mn  \
# 0   778  1.82  195  ...  3.15  0.007  0.049  0.102  0.388  0.286  1.084
# 1   912  1.37  252  ...  3.29  0.008  0.089  0.128  0.965  0.623  1.198
# ...

# %%
winter.columns
# Out:
# Index(['SamplingPoint', 'Temperature', 'pH', 'EC', 'TSS', 'Turbidity',
#        'Salinity', 'TDS', 'DO', 'COD', 'NH4+', 'NO3', 'Phosphate', 'Sulfates',
#        'K', 'Ca', 'Mg', 'Cl', 'Br', 'Cd', 'Cr', 'Ni', 'Cu', 'Zn', 'Mn', 'Hg',
#        'As', 'Pb'],
#       dtype='object')

# %%
cols = ['Temperature', 'pH', 'EC', 'TSS', 'Turbidity',
       'Salinity', 'TDS', 'DO', 'COD', 'NH4+', 'NO3', 'Phosphate', 'Sulfates',
       'K', 'Ca', 'Mg', 'Cl']

# %%
metals = ['Cd', 'Cr', 'Ni', 'Cu', 'Zn', 'Mn', 'Hg',
       'As', 'Pb']

# %%
mw = winter[metals]
ms = summer[metals]

# %%
mw
# Out:
#       Cd     Cr     Ni     Cu     Zn     Mn     Hg     As     Pb
# 0  0.007  0.049  0.102  0.388  0.286  1.084  0.014  0.191  0.376
# 1  0.008  0.089  0.128  0.965  0.623  1.198  0.036  0.156  0.395
# 2  0.015  0.095  0.207  1.420  0.669  1.178  0.081  0.095  0.441
# 3  2.210  1.423  1.252  0.926  0.612  3.791  0.124  0.102  1.388
# 4  0.003  0.025  0.058  0.198  0.307  1.100  0.002  0.079  0.316
# 5  0.005  0.031  0.062  0.850  0.598  0.998  0.009  0.061  0.294
# 6  0.092  0.296  0.721  1.832  0.753  3.262  0.092  0.098  0.567
# 7  0.165  1.102  0.356  0.652  0.335  2.979  0.137  0.107  1.979
# 8  0.082  0.511  0.256  0.095  0.173  1.245  0.107  0.062  0.953

# %%
label = []

for j in range(9):
    label.append("Winter")

for j in range(9):
    label.append("Summer")

# %%
hm = pd.concat([mw, ms])

# %%
hm
# Out:
#       Cd     Cr     Ni     Cu     Zn     Mn     Hg     As     Pb
# 0  0.007  0.049  0.102  0.388  0.286  1.084  0.014  0.191  0.376
# 1  0.008  0.089  0.128  0.965  0.623  1.198  0.036  0.156  0.395
# 2  0.015  0.095  0.207  1.420  0.669  1.178  0.081  0.095  0.441
# 3  2.210  1.423  1.252  0.926  0.612  3.791  0.124  0.102  1.388
# 4  0.003  0.025  0.058  0.198  0.307  1.100  0.002  0.079  0.316
# 5  0.005  0.031  0.062  0.850  0.598  0.998  0.009  0.061  0.294
# 6  0.092  0.296  0.721  1.832  0.753  3.262  0.092  0.098  0.567
# 7  0.165  1.102  0.356  0.652  0.335  2.979  0.137  0.107  1.979
# 8  0.082  0.511  0.256  0.095  0.173  1.245  0.107  0.062  0.953
# 0  0.003  0.044  0.107  0.458  0.187  0.995  0.009  0.109  0.188
# 1  0.007  0.083  0.495  0.932  0.659  1.178  0.027  0.102  0.452
# 2  0.018  0.082  0.149  1.597  0.573  1.073  0.108  0.063  0.337
# 3  2.100  1.139  0.065  0.988  0.602  3.450  0.176  0.098  1.836
# ...

# %%
l_ = []

for col in hm.columns:
    l_.append(hm[col].values)

# %%
l_
# Out:
# [array([0.007, 0.008, 0.015, 2.21 , 0.003, 0.005, 0.092, 0.165, 0.082,
#         0.003, 0.007, 0.018, 2.1  , 0.005, 0.007, 0.106, 0.193, 0.069]),
#  array([0.049, 0.089, 0.095, 1.423, 0.025, 0.031, 0.296, 1.102, 0.511,
#         0.044, 0.083, 0.082, 1.139, 0.029, 0.045, 0.198, 1.133, 0.37 ]),
#  array([0.102, 0.128, 0.207, 1.252, 0.058, 0.062, 0.721, 0.356, 0.256,
#         0.107, 0.495, 0.149, 0.065, 0.089, 0.216, 1.023, 0.451, 0.385]),
#  array([0.388, 0.965, 1.42 , 0.926, 0.198, 0.85 , 1.832, 0.652, 0.095,
#         0.458, 0.932, 1.597, 0.988, 0.114, 1.976, 1.851, 0.633, 0.115]),
#  array([0.286, 0.623, 0.669, 0.612, 0.307, 0.598, 0.753, 0.335, 0.173,
#         0.187, 0.659, 0.573, 0.602, 0.309, 0.759, 0.755, 0.442, 0.292]),
#  array([1.084, 1.198, 1.178, 3.791, 1.1  , 0.998, 3.262, 2.979, 1.245,
#         0.995, 1.178, 1.073, 3.45 , 1.002, 0.872, 3.107, 2.456, 1.114]),
#  array([0.014, 0.036, 0.081, 0.124, 0.002, 0.009, 0.092, 0.137, 0.107,
# ...

# %%
l = np.array(l_)

# %%
l = l.flatten()

# %%
l.shape
# Out:
# (162,)

# %%
hm.columns
# Out:
# Index(['Cd', 'Cr', 'Ni', 'Cu', 'Zn', 'Mn', 'Hg', 'As', 'Pb'], dtype='object')

# %%
param = []

cols = ['Cd', 'Cr', 'Ni', 'Cu', 'Zn', 'Mn', 'Hg', 'As', 'Pb']

for i in range(18):
    param.append(cols[0])
for i in range(18):
    param.append(cols[1])
for i in range(18):
    param.append(cols[2])
for i in range(18):
    param.append(cols[3])
for i in range(18):
    param.append(cols[4])
for i in range(18):
    param.append(cols[5])
for i in range(18):
    param.append(cols[6])
for i in range(18):
    param.append(cols[7])
for i in range(18):
    param.append(cols[8])


    
seasons = []

for i in range(9):
    for i in range(9):
        seasons.append("Winter")
    for i in range(9):
        seasons.append("Summer")

# %%
metals = pd.DataFrame()

# %%
metals["Values"] = l

# %%
metals["Param"] = param
metals["Season"] = seasons

# %%
metals
# Out:
#      Values Param  Season
# 0     0.007    Cd  Winter
# 1     0.008    Cd  Winter
# 2     0.015    Cd  Winter
# 3     2.210    Cd  Winter
# 4     0.003    Cd  Winter
# ..      ...   ...     ...
# 157   0.119    Pb  Summer
# 158   0.178    Pb  Summer
# 159   1.457    Pb  Summer
# 160   2.144    Pb  Summer
# 161   1.075    Pb  Summer
#
# [162 rows x 3 columns]

# %%
met = ["Cr", "Mn", "Ni", "Cu", "Zn", "As", "Cd", "Hg", "Pb"]

# %%
cr = metals[metals["Param"] == "Cr"]
mn = metals[metals["Param"] == "Mn"]
ni = metals[metals["Param"] == "Ni"]
cu = metals[metals["Param"] == "Cu"]
zn = metals[metals["Param"] == "Zn"]
As = metals[metals["Param"] == "As"]
cd = metals[metals["Param"] == "Cd"]
hg = metals[metals["Param"] == "Hg"]
pb = metals[metals["Param"] == "Pb"]

# %%
dm = pd.concat([cr, mn, ni, cu, zn, As, cd, hg, pb])

# %%
dm
# Out:
#      Values Param  Season
# 18    0.049    Cr  Winter
# 19    0.089    Cr  Winter
# 20    0.095    Cr  Winter
# 21    1.423    Cr  Winter
# 22    0.025    Cr  Winter
# ..      ...   ...     ...
# 157   0.119    Pb  Summer
# 158   0.178    Pb  Summer
# 159   1.457    Pb  Summer
# 160   2.144    Pb  Summer
# 161   1.075    Pb  Summer
#
# [162 rows x 3 columns]

# %%
dm.reset_index(drop= True, inplace=True)

# %%
dm
# Out:
#      Values Param  Season
# 0     0.049    Cr  Winter
# 1     0.089    Cr  Winter
# 2     0.095    Cr  Winter
# 3     1.423    Cr  Winter
# 4     0.025    Cr  Winter
# ..      ...   ...     ...
# 157   0.119    Pb  Summer
# 158   0.178    Pb  Summer
# 159   1.457    Pb  Summer
# 160   2.144    Pb  Summer
# 161   1.075    Pb  Summer
#
# [162 rows x 3 columns]

# %%
dm.to_csv("data/Cr_Pb_Violinplot.csv")

# %%
metals.to_csv("data/Metals_Flatten.csv")

# %%
summer = summer[cols]
winter = winter[cols]

# %%
summer
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO   COD  NH4+  \
# 0         30.4  6.17  1790  309        108       639   852  0.96   700   2.9
# 1         30.7  5.89  1453  322        126       702  1208  0.73   718   2.8
# 2         32.7  5.02  2047  434        174       730   783  0.15   870   7.6
# 3         32.8  4.37   538  461        162       360  1790  0.12   912   8.2
# 4         29.5  6.59   692  178         82       244   825  1.10   655   3.0
# 5         32.2  5.33  1596  296         76       930  2009  0.51   725   5.9
# 6         30.1  6.78  1963  302        108      1070  2036  1.39   530   2.2
# 7         32.9  4.11  2119  464        175      1156  2377  0.00  1180  10.4
# 8         32.4  5.24  2550  387        162      1332  1895  0.27   879   9.3
#
#     NO3  Phosphate  Sulfates     K     Ca    Mg      Cl
# 0  33.0       2.15      92.5  59.2  102.5  75.4   98.14
# 1  32.3       2.78      74.2  46.8   72.3  39.6  110.27
# ...

# %%
winter
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO  COD  NH4+  \
# 0         25.0  8.25  1470  190       59.6       685   778  1.82  195   2.6
# 1         24.7  8.39  1593  156       78.6       706   912  1.37  252   3.2
# 2         25.2  8.11  1656  142       85.3       642   986  0.14  493   8.0
# 3         25.4  5.80   767  357       48.9       262  1995  0.10  683   9.4
# 4         23.8  8.93   788  213       28.8       370  1502  2.12  189   2.1
# 5         25.1  8.13  1472  320       42.5       712  1986  0.85  320   5.6
# 6         24.2  8.62  1860  398       39.9       960  2155  1.72  480   4.6
# 7         25.9  5.55  1536  465      127.4       208  2407  0.00  816  11.2
# 8         25.2  8.10  2502  300       75.5      1380  1750  0.13  582   9.4
#
#     NO3  Phosphate  Sulfates     K     Ca    Mg     Cl
# 0  13.1        3.5      8.77  39.2   95.6  52.6  110.8
# 1  12.4        5.7     11.40  36.8   86.4  37.4  277.3
# ...

# %%
label = []

for j in range(9):
    label.append("Winter")

for j in range(9):
    label.append("Summer")

# %%
len(label)
# Out:
# 18

# %%
df = pd.concat([winter, summer])

# %%
df["Season"] = label

# %%
df
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO   COD  NH4+  \
# 0         25.0  8.25  1470  190       59.6       685   778  1.82   195   2.6
# 1         24.7  8.39  1593  156       78.6       706   912  1.37   252   3.2
# 2         25.2  8.11  1656  142       85.3       642   986  0.14   493   8.0
# 3         25.4  5.80   767  357       48.9       262  1995  0.10   683   9.4
# 4         23.8  8.93   788  213       28.8       370  1502  2.12   189   2.1
# 5         25.1  8.13  1472  320       42.5       712  1986  0.85   320   5.6
# 6         24.2  8.62  1860  398       39.9       960  2155  1.72   480   4.6
# 7         25.9  5.55  1536  465      127.4       208  2407  0.00   816  11.2
# 8         25.2  8.10  2502  300       75.5      1380  1750  0.13   582   9.4
# 0         30.4  6.17  1790  309      108.0       639   852  0.96   700   2.9
# 1         30.7  5.89  1453  322      126.0       702  1208  0.73   718   2.8
# ...

# %%
winter.tail()
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO  COD  NH4+  \
# 4         23.8  8.93   788  213       28.8       370  1502  2.12  189   2.1
# 5         25.1  8.13  1472  320       42.5       712  1986  0.85  320   5.6
# 6         24.2  8.62  1860  398       39.9       960  2155  1.72  480   4.6
# 7         25.9  5.55  1536  465      127.4       208  2407  0.00  816  11.2
# 8         25.2  8.10  2502  300       75.5      1380  1750  0.13  582   9.4
#
#     NO3  Phosphate  Sulfates     K     Ca    Mg     Cl
# 4   9.8        3.9      9.20  19.4   32.9  11.9   32.1
# 5  18.2        5.0      9.86  33.1   83.1  38.5  116.7
# 6  12.4        6.5     18.70  48.7  132.6  83.6  334.1
# 7  24.5        5.3     10.80  28.2   75.5  42.7  236.0
# 8  25.8        6.8     17.10  21.3   70.2  36.1  245.9

# %%
winter.columns
# Out:
# Index(['Temperature', 'pH', 'EC', 'TSS', 'Turbidity', 'Salinity', 'TDS', 'DO',
#        'COD', 'NH4+', 'NO3', 'Phosphate', 'Sulfates', 'K', 'Ca', 'Mg', 'Cl'],
#       dtype='object')

# %%
cols = ['Temperature', 'pH', 'EC', 'TSS', 'Turbidity', 'Salinity', 'TDS', 'DO',
       'COD', 'Ammonium', 'Nitrate', 'Phosphate', 'Sulfates', 'Potassium', 'Calcium', 'Magnesium', 'Chloride', "Season"]

# %%
df.columns = cols

# %%
df
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO   COD  \
# 0         25.0  8.25  1470  190       59.6       685   778  1.82   195
# 1         24.7  8.39  1593  156       78.6       706   912  1.37   252
# 2         25.2  8.11  1656  142       85.3       642   986  0.14   493
# 3         25.4  5.80   767  357       48.9       262  1995  0.10   683
# 4         23.8  8.93   788  213       28.8       370  1502  2.12   189
# 5         25.1  8.13  1472  320       42.5       712  1986  0.85   320
# 6         24.2  8.62  1860  398       39.9       960  2155  1.72   480
# 7         25.9  5.55  1536  465      127.4       208  2407  0.00   816
# 8         25.2  8.10  2502  300       75.5      1380  1750  0.13   582
# 0         30.4  6.17  1790  309      108.0       639   852  0.96   700
# 1         30.7  5.89  1453  322      126.0       702  1208  0.73   718
# 2         32.7  5.02  2047  434      174.0       730   783  0.15   870
# ...

# %%
df.to_csv("data/Temp_Cl_Both_Season.csv")

# %%
df
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO   COD  \
# 0         25.0  8.25  1470  190       59.6       685   778  1.82   195
# 1         24.7  8.39  1593  156       78.6       706   912  1.37   252
# 2         25.2  8.11  1656  142       85.3       642   986  0.14   493
# 3         25.4  5.80   767  357       48.9       262  1995  0.10   683
# 4         23.8  8.93   788  213       28.8       370  1502  2.12   189
# 5         25.1  8.13  1472  320       42.5       712  1986  0.85   320
# 6         24.2  8.62  1860  398       39.9       960  2155  1.72   480
# 7         25.9  5.55  1536  465      127.4       208  2407  0.00   816
# 8         25.2  8.10  2502  300       75.5      1380  1750  0.13   582
# 0         30.4  6.17  1790  309      108.0       639   852  0.96   700
# 1         30.7  5.89  1453  322      126.0       702  1208  0.73   718
# 2         32.7  5.02  2047  434      174.0       730   783  0.15   870
# ...

# %%
l_ = []

for col in df.columns:
    l_.append(df[col].values)

# %%
l_
# Out:
# [array([25. , 24.7, 25.2, 25.4, 23.8, 25.1, 24.2, 25.9, 25.2, 30.4, 30.7,
#         32.7, 32.8, 29.5, 32.2, 30.1, 32.9, 32.4]),
#  array([8.25, 8.39, 8.11, 5.8 , 8.93, 8.13, 8.62, 5.55, 8.1 , 6.17, 5.89,
#         5.02, 4.37, 6.59, 5.33, 6.78, 4.11, 5.24]),
#  array([1470, 1593, 1656,  767,  788, 1472, 1860, 1536, 2502, 1790, 1453,
#         2047,  538,  692, 1596, 1963, 2119, 2550]),
#  array([190, 156, 142, 357, 213, 320, 398, 465, 300, 309, 322, 434, 461,
#         178, 296, 302, 464, 387]),
#  array([ 59.6,  78.6,  85.3,  48.9,  28.8,  42.5,  39.9, 127.4,  75.5,
#         108. , 126. , 174. , 162. ,  82. ,  76. , 108. , 175. , 162. ]),
#  array([ 685,  706,  642,  262,  370,  712,  960,  208, 1380,  639,  702,
#          730,  360,  244,  930, 1070, 1156, 1332]),
#  array([ 778,  912,  986, 1995, 1502, 1986, 2155, 2407, 1750,  852, 1208,
#          783, 1790,  825, 2009, 2036, 2377, 1895]),
#  array([1.82, 1.37, 0.14, 0.1 , 2.12, 0.85, 1.72, 0.  , 0.13, 0.96, 0.73,
# ...

# %%
l_ = l_[:-1]

# %%
import numpy as np

# %%
l = np.array(l_)

# %%
l.shape
# Out:
# (17, 18)

# %%
l = l.flatten()

# %%
data = pd.DataFrame()

# %%
data["Values"] = l

# %%
data
# Out:
#      Values
# 0     25.00
# 1     24.70
# 2     25.20
# 3     25.40
# 4     23.80
# ..      ...
# 301   41.79
# 302   78.56
# 303   43.95
# 304  146.20
# 305  167.48
#
# [306 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Temperature', 'pH', 'EC', 'TSS', 'Turbidity', 'Salinity', 'TDS', 'DO',
#        'COD', 'Ammonium', 'Nitrate', 'Phosphate', 'Sulfates', 'Potassium',
#        'Calcium', 'Magnesium', 'Chloride', 'Season'],
#       dtype='object')

# %%
param = []

cols = ['Temperature', 'pH', 'EC', 'TSS', 'Turbidity', 'Salinity', 'TDS', 'DO',
       'COD', 'Ammonium', 'Nitrate', 'Phosphate', 'Sulfates', 'Potassium',
       'Calcium', 'Magnesium', 'Chloride']

for i in range(18):
    param.append(cols[0])
for i in range(18):
    param.append(cols[1])
for i in range(18):
    param.append(cols[2])
for i in range(18):
    param.append(cols[3])
for i in range(18):
    param.append(cols[4])
for i in range(18):
    param.append(cols[5])
for i in range(18):
    param.append(cols[6])
for i in range(18):
    param.append(cols[7])
for i in range(18):
    param.append(cols[8])
for i in range(18):
    param.append(cols[9])
for i in range(18):
    param.append(cols[10])
for i in range(18):
    param.append(cols[11])
for i in range(18):
    param.append(cols[12])
for i in range(18):
    param.append(cols[13])
for i in range(18):
    param.append(cols[14])
for i in range(18):
    param.append(cols[15])
for i in range(18):
    param.append(cols[16])

# %%
len(param)
# Out:
# 306

# %%
data["Param"] = param

# %%
data
# Out:
#      Values        Param
# 0     25.00  Temperature
# 1     24.70  Temperature
# 2     25.20  Temperature
# 3     25.40  Temperature
# 4     23.80  Temperature
# ..      ...          ...
# 301   41.79     Chloride
# 302   78.56     Chloride
# 303   43.95     Chloride
# 304  146.20     Chloride
# 305  167.48     Chloride
#
# [306 rows x 2 columns]

# %%
seasons = []

for i in range(17):
    for i in range(9):
        seasons.append("Winter")
    for i in range(9):
        seasons.append("Summer")

# %%
len(seasons)
# Out:
# 306

# %%
data["Seasons"] = seasons

# %%
data
# Out:
#      Values        Param Seasons
# 0     25.00  Temperature  Winter
# 1     24.70  Temperature  Winter
# 2     25.20  Temperature  Winter
# 3     25.40  Temperature  Winter
# 4     23.80  Temperature  Winter
# ..      ...          ...     ...
# 301   41.79     Chloride  Summer
# 302   78.56     Chloride  Summer
# 303   43.95     Chloride  Summer
# 304  146.20     Chloride  Summer
# 305  167.48     Chloride  Summer
#
# [306 rows x 3 columns]

# %%
data[18:39]
# Out:
#      Values Param Seasons
# 18     8.25    pH  Winter
# 19     8.39    pH  Winter
# 20     8.11    pH  Winter
# 21     5.80    pH  Winter
# 22     8.93    pH  Winter
# 23     8.13    pH  Winter
# 24     8.62    pH  Winter
# 25     5.55    pH  Winter
# 26     8.10    pH  Winter
# 27     6.17    pH  Summer
# 28     5.89    pH  Summer
# 29     5.02    pH  Summer
# 30     4.37    pH  Summer
# 31     6.59    pH  Summer
# 32     5.33    pH  Summer
# 33     6.78    pH  Summer
# 34     4.11    pH  Summer
# 35     5.24    pH  Summer
# 36  1470.00    EC  Winter
# 37  1593.00    EC  Winter
# 38  1656.00    EC  Winter

# %%
df
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO   COD  \
# 0         25.0  8.25  1470  190       59.6       685   778  1.82   195
# 1         24.7  8.39  1593  156       78.6       706   912  1.37   252
# 2         25.2  8.11  1656  142       85.3       642   986  0.14   493
# 3         25.4  5.80   767  357       48.9       262  1995  0.10   683
# 4         23.8  8.93   788  213       28.8       370  1502  2.12   189
# 5         25.1  8.13  1472  320       42.5       712  1986  0.85   320
# 6         24.2  8.62  1860  398       39.9       960  2155  1.72   480
# 7         25.9  5.55  1536  465      127.4       208  2407  0.00   816
# 8         25.2  8.10  2502  300       75.5      1380  1750  0.13   582
# 0         30.4  6.17  1790  309      108.0       639   852  0.96   700
# 1         30.7  5.89  1453  322      126.0       702  1208  0.73   718
# 2         32.7  5.02  2047  434      174.0       730   783  0.15   870
# ...

# %%
data.head()
# Out:
#    Values        Param Seasons
# 0    25.0  Temperature  Winter
# 1    24.7  Temperature  Winter
# 2    25.2  Temperature  Winter
# 3    25.4  Temperature  Winter
# 4    23.8  Temperature  Winter

# %%
data.to_csv("data/Temp_Cl_flatten.csv")

# %% [markdown]
# # Graphs

# %%
import seaborn as sns

# %%
sns.boxplot(x = "Param", y = "Values", hue = "Seasons", data = data)
# Out:
# <AxesSubplot:xlabel='Param', ylabel='Values'>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/Temp_Cl_flatten.csv")
sns.boxplot(x = "Param", y = "Values", hue = "Seasons", data = data)
plt.yscale('log')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/Temp_Cl_flatten.csv")
sns.boxplot(x = "Param", y = "Values", hue = "Seasons", data = data)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/Temp_Cl_flatten.csv")
sns.boxplot(x = "Param", y = "Values", hue = "Seasons", data = data)
plt.yscale('log')
plt.ylim(0.1, 1000)
plt.show()

# %%
sns.boxplot(x = "Param", y = "Values", hue = "Seasons", data = data)
plt.yscale('log')
plt.xlabel("")
plt.ylabel("Physicochemical Values", fontweight= "bold", size= 13)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/Temp_Cl_flatten.csv")
sns.boxplot(x = "Param", y = "Values", hue = "Seasons", data = data)
plt.yscale('log')
plt.xlabel("")
plt.ylabel("Physicochemical Values", fontweight= "bold", size= 13)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("temp.csv")

sns.boxplot(x = "Param", y = "Values", hue = "Seasons", data = data)
plt.yscale('log')
plt.xlabel("")
plt.ylabel("Physicochemical Values", fontweight= "bold", size= 13)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

metals = pd.read_csv("data/Metals_Flatten.csv")


sns.violinplot(x = "Param", y = "Values", hue = "Season", data = metals, split=True)
plt.xlabel("")
plt.ylabel("HM Concentration", fontweight= "bold", size= 13)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

metals = pd.read_csv("data/Metals_Flatten.csv")


sns.violinplot(x = "Param", y = "Values", hue = "Season", data = metals)
plt.xlabel("")
plt.ylabel("Metal's Concentration", fontweight= "bold", size= 13)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()

# %%
sns.swarmplot(x = metals["Param"], y = metals["Values"],
              hue = metals["Season"])
# Out:
# /home/RHHLab/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning:
#
# 38.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /home/RHHLab/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning:
#
# 27.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /home/RHHLab/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning:
#
# 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /home/RHHLab/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning:
#
# 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /home/RHHLab/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning:
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

metals = pd.read_csv("data/Metals_Flatten.csv")


sns.violinplot(x = "Param", y = "Values", hue = "Season", data = metals)
plt.xlabel("")
plt.ylabel("Metal's Concentration", fontweight= "bold", size= 13)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()

# %%
metals["Param"].unique()
# Out:
# array(['Cd', 'Cr', 'Ni', 'Cu', 'Zn', 'Mn', 'Hg', 'As', 'Pb'], dtype=object)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/Cr_Pb_Violinplot.csv")

sns.violinplot(x = "Param", y = "Values", hue = "Season", data = data)
plt.xlabel("")
plt.ylabel("Metal Concentration (mg/L)", fontweight= "bold", size= 13)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()
