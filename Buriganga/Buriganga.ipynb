# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("data/wpburiganga.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sampling Point    16 non-null     object
#  1   Temperature (◦C)  16 non-null     float64
#  2   pH                16 non-null     float64
#  3   EC (μS/cm)        16 non-null     float64
#  4   TSS (mg/l)        16 non-null     float64
#  5   Turbidity (NTU)   16 non-null     float64
#  6   Salinity (mg/l)   16 non-null     float64
#  7   TDS (mg/l)        16 non-null     float64
#  8   DO (mg/l)         16 non-null     float64
#  9   COD (mg/l)        16 non-null     float64
#  10  NH4+  (mg/l)      16 non-null     float64
#  11  NO3 (mg/l)        16 non-null     float64
#  12  Phosphate(mg/l)   16 non-null     float64
#  13  Sulfates(mg/l)    16 non-null     float64
#  14  K (mg/l)          16 non-null     float64
#  15  Ca (mg/l)         16 non-null     float64
#  16  Mg (mg/l)         16 non-null     float64
#  17  Cl- (mg/l)        16 non-null     float64
#  18  Br (mg/l)         16 non-null     float64
#  19  Cd (mg/l)         16 non-null     float64
#  20  Cr (mg/l)         16 non-null     float64
#  21  Ni (mg/l)         16 non-null     float64
#  22  Cu (mg/l)         16 non-null     float64
#  23  Zn (mg/l)         16 non-null     float64
#  24  Mn(mg/l)          16 non-null     float64
#  25  Hg(mg/l)          16 non-null     float64
#  26  As(mg/l)          16 non-null     float64
#  27  Pb(mg/l)          16 non-null     float64
#  28  Unnamed: 28       9 non-null      object
# dtypes: float64(27), object(2)
# memory usage: 3.8+ KB

# %%
df
# Out:
#            Sampling Point  Temperature (◦C)         pH   EC (μS/cm)  \
# 0      1(Gabtoli_Dhalwes)         25.000000   8.250000  1470.000000
# 1        2(Gabtoli_turag)         24.700000   8.390000  1593.000000
# 2          3(Shah Cement)         25.200000   8.110000  1656.000000
# 3            4(Hazaribag)         25.400000   5.800000   767.000000
# 4           5(Rayerbazar)         23.800000   8.930000   788.000000
# 5            6(Kholamora)         25.100000   8.130000  1472.000000
# 6              7(Zinzira)         24.200000   8.620000  1860.000000
# 7   8(Sadarghat_Terminal)         25.900000   5.550000  1536.000000
# 8        9(Postogola Bri)         25.200000   8.100000  2502.000000
# 9                 Average         24.944444   7.764444  1516.000000
# 10                    MAX         25.900000   8.930000  2502.000000
# 11                    Min         23.800000   5.550000   767.000000
# 12                     SD          0.632675   1.216862   525.773002
# 13                     CV          2.536337  15.672233    34.681596
# 14               Skewness         -0.584961  -1.404178     0.217061
# 15               Kurtosis          0.296941   0.507355     0.879829
#
#     TSS (mg/l)  Turbidity (NTU)  Salinity (mg/l)   TDS (mg/l)  DO (mg/l)  \
# 0   190.000000        59.600000       685.000000   778.000000   1.820000
# 1   156.000000        78.600000       706.000000   912.000000   1.370000
# 2   142.000000        85.300000       642.000000   986.000000   0.140000
# 3   357.000000        48.900000       262.000000  1995.000000   0.100000
# 4   213.000000        28.800000       370.000000  1502.000000   2.120000
# 5   320.000000        42.500000       712.000000  1986.000000   0.850000
# 6   398.000000        39.900000       960.000000  2155.000000   1.720000
# 7   465.000000       127.400000       208.000000  2407.000000   0.000000
# 8   300.000000        75.500000      1380.000000  1750.000000   0.130000
# 9   282.333333        65.166667       658.333333  1607.888889   0.916667
# 10  465.000000       127.400000      1380.000000  2407.000000   2.120000
# 11  142.000000        28.800000       208.000000   778.000000   0.000000
# 12  113.488986        30.281760       364.168917   593.913176   0.855029
# 13   40.196807        46.468174        55.316797    36.937451  93.275917
# 14    0.243797         0.997630         0.752134    -0.277136   0.210986
# 15   -1.238882         1.066893         0.793158    -1.559130  -2.005949
#
#     COD (mg/l)  ...   Cd (mg/l)   Cr (mg/l)   Ni (mg/l)  Cu (mg/l)  Zn (mg/l)  \
# 0   195.000000  ...    0.007000    0.049000    0.102000   0.388000   0.286000
# 1   252.000000  ...    0.008000    0.089000    0.128000   0.965000   0.623000
# 2   493.000000  ...    0.015000    0.095000    0.207000   1.420000   0.669000
# 3   683.000000  ...    2.210000    1.423000    1.252000   0.926000   0.612000
# 4   189.000000  ...    0.003000    0.025000    0.058000   0.198000   0.307000
# 5   320.000000  ...    0.005000    0.031000    0.062000   0.850000   0.598000
# 6   480.000000  ...    0.092000    0.296000    0.721000   1.832000   0.753000
# 7   816.000000  ...    0.165000    1.102000    0.356000   0.652000   0.335000
# 8   582.000000  ...    0.082000    0.511000    0.256000   0.095000   0.173000
# 9   445.555556  ...    0.287444    0.402333    0.349111   0.814000   0.484000
# 10  816.000000  ...    2.210000    1.423000    1.252000   1.832000   0.753000
# 11  189.000000  ...    0.003000    0.025000    0.058000   0.095000   0.173000
# 12  222.904190  ...    0.723124    0.518671    0.396793   0.563952   0.207588
# 13   50.028372  ...  251.569994  128.915656  113.657967  69.281615  42.890069
# 14    0.363706  ...    2.966078    1.378771    1.825381   0.533517  -0.262926
# 15   -1.068058  ...    8.845484    0.605024    3.038644  -0.190509  -1.746516
#
#      Mn(mg/l)   Hg(mg/l)   As(mg/l)   Pb(mg/l)            Unnamed: 28
# 0    1.084000   0.014000   0.191000   0.376000     1(Gabtoli_Dhalwes)
# 1    1.198000   0.036000   0.156000   0.395000       2(Gabtoli_turag)
# 2    1.178000   0.081000   0.095000   0.441000         3(Shah Cement)
# 3    3.791000   0.124000   0.102000   1.388000           4(Hazaribag)
# 4    1.100000   0.002000   0.079000   0.316000          5(Rayerbazar)
# 5    0.998000   0.009000   0.061000   0.294000           6(Kholamora)
# 6    3.262000   0.092000   0.098000   0.567000             7(Zinzira)
# 7    2.979000   0.137000   0.107000   1.979000  8(Sadarghat_Terminal)
# 8    1.245000   0.107000   0.062000   0.953000       9(Postogola Bri)
# 9    1.870556   0.066889   0.105667   0.745444                    NaN
# 10   3.791000   0.137000   0.191000   1.979000                    NaN
# 11   0.998000   0.002000   0.061000   0.294000                    NaN
# 12   1.126384   0.052356   0.042743   0.586267                    NaN
# 13  60.216575  78.272524  40.451187  78.646614                    NaN
# 14   0.972664  -0.034193   1.143929   1.477674                    NaN
# 15  -1.116439  -1.879165   0.851724   1.338771                    NaN
#
# [16 rows x 29 columns]

# %%
stat_df = df.loc[9:]
df = df.loc[:8]
df
# Out:
#           Sampling Point  Temperature (◦C)    pH  EC (μS/cm)  TSS (mg/l)  \
# 0     1(Gabtoli_Dhalwes)              25.0  8.25      1470.0       190.0
# 1       2(Gabtoli_turag)              24.7  8.39      1593.0       156.0
# 2         3(Shah Cement)              25.2  8.11      1656.0       142.0
# 3           4(Hazaribag)              25.4  5.80       767.0       357.0
# 4          5(Rayerbazar)              23.8  8.93       788.0       213.0
# 5           6(Kholamora)              25.1  8.13      1472.0       320.0
# 6             7(Zinzira)              24.2  8.62      1860.0       398.0
# 7  8(Sadarghat_Terminal)              25.9  5.55      1536.0       465.0
# 8       9(Postogola Bri)              25.2  8.10      2502.0       300.0
#
#    Turbidity (NTU)  Salinity (mg/l)  TDS (mg/l)  DO (mg/l)  COD (mg/l)  ...  \
# 0             59.6            685.0       778.0       1.82       195.0  ...
# 1             78.6            706.0       912.0       1.37       252.0  ...
# 2             85.3            642.0       986.0       0.14       493.0  ...
# 3             48.9            262.0      1995.0       0.10       683.0  ...
# 4             28.8            370.0      1502.0       2.12       189.0  ...
# 5             42.5            712.0      1986.0       0.85       320.0  ...
# 6             39.9            960.0      2155.0       1.72       480.0  ...
# 7            127.4            208.0      2407.0       0.00       816.0  ...
# 8             75.5           1380.0      1750.0       0.13       582.0  ...
#
#    Cd (mg/l)  Cr (mg/l)  Ni (mg/l)  Cu (mg/l)  Zn (mg/l)  Mn(mg/l)  Hg(mg/l)  \
# 0      0.007      0.049      0.102      0.388      0.286     1.084     0.014
# 1      0.008      0.089      0.128      0.965      0.623     1.198     0.036
# 2      0.015      0.095      0.207      1.420      0.669     1.178     0.081
# 3      2.210      1.423      1.252      0.926      0.612     3.791     0.124
# 4      0.003      0.025      0.058      0.198      0.307     1.100     0.002
# 5      0.005      0.031      0.062      0.850      0.598     0.998     0.009
# 6      0.092      0.296      0.721      1.832      0.753     3.262     0.092
# 7      0.165      1.102      0.356      0.652      0.335     2.979     0.137
# 8      0.082      0.511      0.256      0.095      0.173     1.245     0.107
#
#    As(mg/l)  Pb(mg/l)            Unnamed: 28
# 0     0.191     0.376     1(Gabtoli_Dhalwes)
# 1     0.156     0.395       2(Gabtoli_turag)
# 2     0.095     0.441         3(Shah Cement)
# 3     0.102     1.388           4(Hazaribag)
# 4     0.079     0.316          5(Rayerbazar)
# 5     0.061     0.294           6(Kholamora)
# 6     0.098     0.567             7(Zinzira)
# 7     0.107     1.979  8(Sadarghat_Terminal)
# 8     0.062     0.953       9(Postogola Bri)
#
# [9 rows x 29 columns]

# %%
sampling_point = df["Sampling Point"].str.split("(")
sampling_point
# Out:
# 0       [1, Gabtoli_Dhalwes)]
# 1         [2, Gabtoli_turag)]
# 2           [3, Shah Cement)]
# 3             [4, Hazaribag)]
# 4            [5, Rayerbazar)]
# 5             [6, Kholamora)]
# 6               [7, Zinzira)]
# 7    [8, Sadarghat_Terminal)]
# 8         [9, Postogola Bri)]
# Name: Sampling Point, dtype: object

# %%
i = 0
while i< len(sampling_point):
    sampling_point[i][1] = sampling_point[i][1][:-1]

    i+=1
    
sampling_point
# Out:
# 0       [1, Gabtoli_Dhalwes]
# 1         [2, Gabtoli_turag]
# 2           [3, Shah Cement]
# 3             [4, Hazaribag]
# 4            [5, Rayerbazar]
# 5             [6, Kholamora]
# 6               [7, Zinzira]
# 7    [8, Sadarghat_Terminal]
# 8         [9, Postogola Bri]
# Name: Sampling Point, dtype: object

# %%
sampling = pd.DataFrame(columns=[])

# %%
point = []
location = []

i = 0
while i < len(sampling_point):
    point.append(sampling_point[i][0])
    location.append(sampling_point[i][1])
    i+=1
    
point, location
# Out:
# (['1', '2', '3', '4', '5', '6', '7', '8', '9'],
#  ['Gabtoli_Dhalwes',
#   'Gabtoli_turag',
#   'Shah Cement',
#   'Hazaribag',
#   'Rayerbazar',
#   'Kholamora',
#   'Zinzira',
#   'Sadarghat_Terminal',
#   'Postogola Bri'])

# %%
df["Point"], df["location"] = point, location
df
# Out:
# /tmp/ipykernel_3762/1221773281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Point"], df["location"] = point, location
# /tmp/ipykernel_3762/1221773281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Point"], df["location"] = point, location
#           Sampling Point  Temperature (◦C)    pH  EC (μS/cm)  TSS (mg/l)  \
# 0     1(Gabtoli_Dhalwes)              25.0  8.25      1470.0       190.0
# 1       2(Gabtoli_turag)              24.7  8.39      1593.0       156.0
# 2         3(Shah Cement)              25.2  8.11      1656.0       142.0
# 3           4(Hazaribag)              25.4  5.80       767.0       357.0
# 4          5(Rayerbazar)              23.8  8.93       788.0       213.0
# 5           6(Kholamora)              25.1  8.13      1472.0       320.0
# 6             7(Zinzira)              24.2  8.62      1860.0       398.0
# 7  8(Sadarghat_Terminal)              25.9  5.55      1536.0       465.0
# 8       9(Postogola Bri)              25.2  8.10      2502.0       300.0
#
#    Turbidity (NTU)  Salinity (mg/l)  TDS (mg/l)  DO (mg/l)  COD (mg/l)  ...  \
# 0             59.6            685.0       778.0       1.82       195.0  ...
# 1             78.6            706.0       912.0       1.37       252.0  ...
# 2             85.3            642.0       986.0       0.14       493.0  ...
# 3             48.9            262.0      1995.0       0.10       683.0  ...
# 4             28.8            370.0      1502.0       2.12       189.0  ...
# 5             42.5            712.0      1986.0       0.85       320.0  ...
# 6             39.9            960.0      2155.0       1.72       480.0  ...
# 7            127.4            208.0      2407.0       0.00       816.0  ...
# 8             75.5           1380.0      1750.0       0.13       582.0  ...
#
#    Ni (mg/l)  Cu (mg/l)  Zn (mg/l)  Mn(mg/l)  Hg(mg/l)  As(mg/l)  Pb(mg/l)  \
# 0      0.102      0.388      0.286     1.084     0.014     0.191     0.376
# 1      0.128      0.965      0.623     1.198     0.036     0.156     0.395
# 2      0.207      1.420      0.669     1.178     0.081     0.095     0.441
# 3      1.252      0.926      0.612     3.791     0.124     0.102     1.388
# 4      0.058      0.198      0.307     1.100     0.002     0.079     0.316
# 5      0.062      0.850      0.598     0.998     0.009     0.061     0.294
# 6      0.721      1.832      0.753     3.262     0.092     0.098     0.567
# 7      0.356      0.652      0.335     2.979     0.137     0.107     1.979
# 8      0.256      0.095      0.173     1.245     0.107     0.062     0.953
#
#              Unnamed: 28  Point            location
# 0     1(Gabtoli_Dhalwes)      1     Gabtoli_Dhalwes
# 1       2(Gabtoli_turag)      2       Gabtoli_turag
# 2         3(Shah Cement)      3         Shah Cement
# 3           4(Hazaribag)      4           Hazaribag
# 4          5(Rayerbazar)      5          Rayerbazar
# 5           6(Kholamora)      6           Kholamora
# 6             7(Zinzira)      7             Zinzira
# 7  8(Sadarghat_Terminal)      8  Sadarghat_Terminal
# 8       9(Postogola Bri)      9       Postogola Bri
#
# [9 rows x 31 columns]

# %%
df.drop(columns=["Sampling Point"], inplace=True)
df
# Out:
# /tmp/ipykernel_3762/2669219012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Sampling Point"], inplace=True)
#    Temperature (◦C)    pH  EC (μS/cm)  TSS (mg/l)  Turbidity (NTU)  \
# 0              25.0  8.25      1470.0       190.0             59.6
# 1              24.7  8.39      1593.0       156.0             78.6
# 2              25.2  8.11      1656.0       142.0             85.3
# 3              25.4  5.80       767.0       357.0             48.9
# 4              23.8  8.93       788.0       213.0             28.8
# 5              25.1  8.13      1472.0       320.0             42.5
# 6              24.2  8.62      1860.0       398.0             39.9
# 7              25.9  5.55      1536.0       465.0            127.4
# 8              25.2  8.10      2502.0       300.0             75.5
#
#    Salinity (mg/l)  TDS (mg/l)  DO (mg/l)  COD (mg/l)  NH4+  (mg/l)  ...  \
# 0            685.0       778.0       1.82       195.0           2.6  ...
# 1            706.0       912.0       1.37       252.0           3.2  ...
# 2            642.0       986.0       0.14       493.0           8.0  ...
# 3            262.0      1995.0       0.10       683.0           9.4  ...
# 4            370.0      1502.0       2.12       189.0           2.1  ...
# 5            712.0      1986.0       0.85       320.0           5.6  ...
# 6            960.0      2155.0       1.72       480.0           4.6  ...
# 7            208.0      2407.0       0.00       816.0          11.2  ...
# 8           1380.0      1750.0       0.13       582.0           9.4  ...
#
#    Ni (mg/l)  Cu (mg/l)  Zn (mg/l)  Mn(mg/l)  Hg(mg/l)  As(mg/l)  Pb(mg/l)  \
# 0      0.102      0.388      0.286     1.084     0.014     0.191     0.376
# 1      0.128      0.965      0.623     1.198     0.036     0.156     0.395
# 2      0.207      1.420      0.669     1.178     0.081     0.095     0.441
# 3      1.252      0.926      0.612     3.791     0.124     0.102     1.388
# 4      0.058      0.198      0.307     1.100     0.002     0.079     0.316
# 5      0.062      0.850      0.598     0.998     0.009     0.061     0.294
# 6      0.721      1.832      0.753     3.262     0.092     0.098     0.567
# 7      0.356      0.652      0.335     2.979     0.137     0.107     1.979
# 8      0.256      0.095      0.173     1.245     0.107     0.062     0.953
#
#              Unnamed: 28  Point            location
# 0     1(Gabtoli_Dhalwes)      1     Gabtoli_Dhalwes
# 1       2(Gabtoli_turag)      2       Gabtoli_turag
# 2         3(Shah Cement)      3         Shah Cement
# 3           4(Hazaribag)      4           Hazaribag
# 4          5(Rayerbazar)      5          Rayerbazar
# 5           6(Kholamora)      6           Kholamora
# 6             7(Zinzira)      7             Zinzira
# 7  8(Sadarghat_Terminal)      8  Sadarghat_Terminal
# 8       9(Postogola Bri)      9       Postogola Bri
#
# [9 rows x 30 columns]

# %%
df.describe()
# Out:
#        Temperature (◦C)        pH   EC (μS/cm)  TSS (mg/l)  Turbidity (NTU)  \
# count          9.000000  9.000000     9.000000    9.000000         9.000000
# mean          24.944444  7.764444  1516.000000  282.333333        65.166667
# std            0.632675  1.216862   525.773002  113.488986        30.281760
# min           23.800000  5.550000   767.000000  142.000000        28.800000
# 25%           24.700000  8.100000  1470.000000  190.000000        42.500000
# 50%           25.100000  8.130000  1536.000000  300.000000        59.600000
# 75%           25.200000  8.390000  1656.000000  357.000000        78.600000
# max           25.900000  8.930000  2502.000000  465.000000       127.400000
#
#        Salinity (mg/l)   TDS (mg/l)  DO (mg/l)  COD (mg/l)  NH4+  (mg/l)  ...  \
# count         9.000000     9.000000   9.000000    9.000000      9.000000  ...
# mean        658.333333  1607.888889   0.916667  445.555556      6.233333  ...
# std         364.168917   593.913176   0.855029  222.904190      3.361547  ...
# min         208.000000   778.000000   0.000000  189.000000      2.100000  ...
# 25%         370.000000   986.000000   0.130000  252.000000      3.200000  ...
# 50%         685.000000  1750.000000   0.850000  480.000000      5.600000  ...
# 75%         712.000000  1995.000000   1.720000  582.000000      9.400000  ...
# max        1380.000000  2407.000000   2.120000  816.000000     11.200000  ...
#
#        Br (mg/l)  Cd (mg/l)  Cr (mg/l)  Ni (mg/l)  Cu (mg/l)  Zn (mg/l)  \
# count   9.000000   9.000000   9.000000   9.000000   9.000000   9.000000
# mean    1.744444   0.287444   0.402333   0.349111   0.814000   0.484000
# std     0.872011   0.723124   0.518671   0.396793   0.563952   0.207588
# min     0.870000   0.003000   0.025000   0.058000   0.095000   0.173000
# 25%     1.250000   0.007000   0.049000   0.102000   0.388000   0.307000
# 50%     1.310000   0.015000   0.095000   0.207000   0.850000   0.598000
# 75%     1.720000   0.092000   0.511000   0.356000   0.965000   0.623000
# max     3.290000   2.210000   1.423000   1.252000   1.832000   0.753000
#
#        Mn(mg/l)  Hg(mg/l)  As(mg/l)  Pb(mg/l)
# count  9.000000  9.000000  9.000000  9.000000
# mean   1.870556  0.066889  0.105667  0.745444
# std    1.126384  0.052356  0.042743  0.586267
# min    0.998000  0.002000  0.061000  0.294000
# 25%    1.100000  0.014000  0.079000  0.376000
# 50%    1.198000  0.081000  0.098000  0.441000
# 75%    2.979000  0.107000  0.107000  0.953000
# max    3.791000  0.137000  0.191000  1.979000
#
# [8 rows x 27 columns]

# %%
stat_df
# Out:
#    Sampling Point  Temperature (◦C)         pH   EC (μS/cm)  TSS (mg/l)  \
# 9         Average         24.944444   7.764444  1516.000000  282.333333
# 10            MAX         25.900000   8.930000  2502.000000  465.000000
# 11            Min         23.800000   5.550000   767.000000  142.000000
# 12             SD          0.632675   1.216862   525.773002  113.488986
# 13             CV          2.536337  15.672233    34.681596   40.196807
# 14       Skewness         -0.584961  -1.404178     0.217061    0.243797
# 15       Kurtosis          0.296941   0.507355     0.879829   -1.238882
#
#     Turbidity (NTU)  Salinity (mg/l)   TDS (mg/l)  DO (mg/l)  COD (mg/l)  ...  \
# 9         65.166667       658.333333  1607.888889   0.916667  445.555556  ...
# 10       127.400000      1380.000000  2407.000000   2.120000  816.000000  ...
# 11        28.800000       208.000000   778.000000   0.000000  189.000000  ...
# 12        30.281760       364.168917   593.913176   0.855029  222.904190  ...
# 13        46.468174        55.316797    36.937451  93.275917   50.028372  ...
# 14         0.997630         0.752134    -0.277136   0.210986    0.363706  ...
# 15         1.066893         0.793158    -1.559130  -2.005949   -1.068058  ...
#
#      Cd (mg/l)   Cr (mg/l)   Ni (mg/l)  Cu (mg/l)  Zn (mg/l)   Mn(mg/l)  \
# 9     0.287444    0.402333    0.349111   0.814000   0.484000   1.870556
# 10    2.210000    1.423000    1.252000   1.832000   0.753000   3.791000
# 11    0.003000    0.025000    0.058000   0.095000   0.173000   0.998000
# 12    0.723124    0.518671    0.396793   0.563952   0.207588   1.126384
# 13  251.569994  128.915656  113.657967  69.281615  42.890069  60.216575
# 14    2.966078    1.378771    1.825381   0.533517  -0.262926   0.972664
# 15    8.845484    0.605024    3.038644  -0.190509  -1.746516  -1.116439
#
#      Hg(mg/l)   As(mg/l)   Pb(mg/l)  Unnamed: 28
# 9    0.066889   0.105667   0.745444          NaN
# 10   0.137000   0.191000   1.979000          NaN
# 11   0.002000   0.061000   0.294000          NaN
# 12   0.052356   0.042743   0.586267          NaN
# 13  78.272524  40.451187  78.646614          NaN
# 14  -0.034193   1.143929   1.477674          NaN
# 15  -1.879165   0.851724   1.338771          NaN
#
# [7 rows x 29 columns]

# %%
df.to_excel("data.xlsx")

# %% [markdown]
# ## P values

# %%
summer = pd.read_csv("data/Buriganga_S.csv")
winter = pd.read_csv("data/Buriganga_W .csv")

# %%
summer
# Out:
#         SamplingPoint  Temperature    pH    EC  TSS  Turbidity  Salinity  \
# 0     Gabtoli Dhalwes         30.4  6.17  1790  309        108       639
# 1       Gabtoli Turag         30.7  5.89  1453  322        126       702
# 2         Shah Cement         32.7  5.02  2047  434        174       730
# 3           Hazaribag         32.8  4.37   538  461        162       360
# 4          Rayerbazar         29.5  6.59   692  178         82       244
# 5           Kholamora         32.2  5.33  1596  296         76       930
# 6             Zinzira         30.1  6.78  1963  302        108      1070
# 7  Sadarghat Terminal         32.9  4.11  2119  464        175      1156
# 8       Postogola Bri         32.4  5.24  2550  387        162      1332
#
#     TDS    DO   COD  ...    Br     Cd     Cr     Ni     Cu     Zn     Mn  \
# 0   852  0.96   700  ...  0.61  0.003  0.044  0.107  0.458  0.187  0.995
# 1  1208  0.73   718  ...  0.45  0.007  0.083  0.495  0.932  0.659  1.178
# 2   783  0.15   870  ...  0.42  0.018  0.082  0.149  1.597  0.573  1.073
# 3  1790  0.12   912  ...  0.66  2.100  1.139  0.065  0.988  0.602  3.450
# 4   825  1.10   655  ...  0.80  0.005  0.029  0.089  0.114  0.309  1.002
# 5  2009  0.51   725  ...  0.79  0.007  0.045  0.216  1.976  0.759  0.872
# 6  2036  1.39   530  ...  0.41  0.106  0.198  1.023  1.851  0.755  3.107
# 7  2377  0.00  1180  ...  0.35  0.193  1.133  0.451  0.633  0.442  2.456
# 8  1895  0.27   879  ...  0.32  0.069  0.370  0.385  0.115  0.292  1.114
#
#       Hg     As     Pb
# 0  0.009  0.109  0.188
# 1  0.027  0.102  0.452
# 2  0.108  0.063  0.337
# 3  0.176  0.098  1.836
# 4  0.093  0.057  0.119
# 5  0.017  0.075  0.178
# 6  0.089  0.112  1.457
# 7  0.255  0.161  2.144
# 8  0.198  0.059  1.075
#
# [9 rows x 28 columns]

# %%
winter
# Out:
#         SamplingPoint  Temperature    pH    EC  TSS  Turbidity  Salinity  \
# 0     Gabtoli Dhalwes         25.0  8.25  1470  190       59.6       685
# 1       Gabtoli Turag         24.7  8.39  1593  156       78.6       706
# 2         Shah Cement         25.2  8.11  1656  142       85.3       642
# 3           Hazaribag         25.4  5.80   767  357       48.9       262
# 4          Rayerbazar         23.8  8.93   788  213       28.8       370
# 5           Kholamora         25.1  8.13  1472  320       42.5       712
# 6             Zinzira         24.2  8.62  1860  398       39.9       960
# 7  Sadarghat Terminal         25.9  5.55  1536  465      127.4       208
# 8       Postogola Bri         25.2  8.10  2502  300       75.5      1380
#
#     TDS    DO  COD  ...    Br     Cd     Cr     Ni     Cu     Zn     Mn  \
# 0   778  1.82  195  ...  3.15  0.007  0.049  0.102  0.388  0.286  1.084
# 1   912  1.37  252  ...  3.29  0.008  0.089  0.128  0.965  0.623  1.198
# 2   986  0.14  493  ...  1.62  0.015  0.095  0.207  1.420  0.669  1.178
# 3  1995  0.10  683  ...  1.72  2.210  1.423  1.252  0.926  0.612  3.791
# 4  1502  2.12  189  ...  1.25  0.003  0.025  0.058  0.198  0.307  1.100
# 5  1986  0.85  320  ...  1.19  0.005  0.031  0.062  0.850  0.598  0.998
# 6  2155  1.72  480  ...  0.87  0.092  0.296  0.721  1.832  0.753  3.262
# 7  2407  0.00  816  ...  1.30  0.165  1.102  0.356  0.652  0.335  2.979
# 8  1750  0.13  582  ...  1.31  0.082  0.511  0.256  0.095  0.173  1.245
#
#       Hg     As     Pb
# 0  0.014  0.191  0.376
# 1  0.036  0.156  0.395
# 2  0.081  0.095  0.441
# 3  0.124  0.102  1.388
# 4  0.002  0.079  0.316
# 5  0.009  0.061  0.294
# 6  0.092  0.098  0.567
# 7  0.137  0.107  1.979
# 8  0.107  0.062  0.953
#
# [9 rows x 28 columns]

# %%
summer.columns
# Out:
# Index(['SamplingPoint', 'Temperature', 'pH', 'EC', 'TSS', 'Turbidity',
#        'Salinity', 'TDS', 'DO', 'COD', 'NH4+', 'NO3', 'Phosphate', 'Sulfates',
#        'K', 'Ca', 'Mg', 'Cl', 'Br', 'Cd', 'Cr', 'Ni', 'Cu', 'Zn', 'Mn', 'Hg',
#        'As', 'Pb'],
#       dtype='object')

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SamplingPoint  9 non-null      object
#  1   Temperature    9 non-null      float64
#  2   pH             9 non-null      float64
#  3   EC             9 non-null      int64
#  4   TSS            9 non-null      int64
#  5   Turbidity      9 non-null      int64
#  6   Salinity       9 non-null      int64
#  7   TDS            9 non-null      int64
#  8   DO             9 non-null      float64
#  9   COD            9 non-null      int64
#  10  NH4+           9 non-null      float64
#  11  NO3            9 non-null      float64
#  12  Phosphate      9 non-null      float64
#  13  Sulfates       9 non-null      float64
#  14  K              9 non-null      float64
#  15  Ca             9 non-null      float64
#  16  Mg             9 non-null      float64
#  17  Cl             9 non-null      float64
#  18  Br             9 non-null      float64
#  19  Cd             9 non-null      float64
#  20  Cr             9 non-null      float64
#  21  Ni             9 non-null      float64
#  22  Cu             9 non-null      float64
#  23  Zn             9 non-null      float64
#  24  Mn             9 non-null      float64
#  25  Hg             9 non-null      float64
#  26  As             9 non-null      float64
#  27  Pb             9 non-null      float64
# dtypes: float64(21), int64(6), object(1)
# memory usage: 2.1+ KB

# %%
summer_p = summer.drop(columns= ["SamplingPoint"])
winter_p = winter.drop(columns= ["SamplingPoint"])

# %%
summer_p
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO   COD  NH4+  \
# 0         30.4  6.17  1790  309        108       639   852  0.96   700   2.9
# 1         30.7  5.89  1453  322        126       702  1208  0.73   718   2.8
# 2         32.7  5.02  2047  434        174       730   783  0.15   870   7.6
# 3         32.8  4.37   538  461        162       360  1790  0.12   912   8.2
# 4         29.5  6.59   692  178         82       244   825  1.10   655   3.0
# 5         32.2  5.33  1596  296         76       930  2009  0.51   725   5.9
# 6         30.1  6.78  1963  302        108      1070  2036  1.39   530   2.2
# 7         32.9  4.11  2119  464        175      1156  2377  0.00  1180  10.4
# 8         32.4  5.24  2550  387        162      1332  1895  0.27   879   9.3
#
#    ...    Br     Cd     Cr     Ni     Cu     Zn     Mn     Hg     As     Pb
# 0  ...  0.61  0.003  0.044  0.107  0.458  0.187  0.995  0.009  0.109  0.188
# 1  ...  0.45  0.007  0.083  0.495  0.932  0.659  1.178  0.027  0.102  0.452
# 2  ...  0.42  0.018  0.082  0.149  1.597  0.573  1.073  0.108  0.063  0.337
# 3  ...  0.66  2.100  1.139  0.065  0.988  0.602  3.450  0.176  0.098  1.836
# 4  ...  0.80  0.005  0.029  0.089  0.114  0.309  1.002  0.093  0.057  0.119
# 5  ...  0.79  0.007  0.045  0.216  1.976  0.759  0.872  0.017  0.075  0.178
# 6  ...  0.41  0.106  0.198  1.023  1.851  0.755  3.107  0.089  0.112  1.457
# 7  ...  0.35  0.193  1.133  0.451  0.633  0.442  2.456  0.255  0.161  2.144
# 8  ...  0.32  0.069  0.370  0.385  0.115  0.292  1.114  0.198  0.059  1.075
#
# [9 rows x 27 columns]

# %%
winter_p
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO  COD  NH4+  \
# 0         25.0  8.25  1470  190       59.6       685   778  1.82  195   2.6
# 1         24.7  8.39  1593  156       78.6       706   912  1.37  252   3.2
# 2         25.2  8.11  1656  142       85.3       642   986  0.14  493   8.0
# 3         25.4  5.80   767  357       48.9       262  1995  0.10  683   9.4
# 4         23.8  8.93   788  213       28.8       370  1502  2.12  189   2.1
# 5         25.1  8.13  1472  320       42.5       712  1986  0.85  320   5.6
# 6         24.2  8.62  1860  398       39.9       960  2155  1.72  480   4.6
# 7         25.9  5.55  1536  465      127.4       208  2407  0.00  816  11.2
# 8         25.2  8.10  2502  300       75.5      1380  1750  0.13  582   9.4
#
#    ...    Br     Cd     Cr     Ni     Cu     Zn     Mn     Hg     As     Pb
# 0  ...  3.15  0.007  0.049  0.102  0.388  0.286  1.084  0.014  0.191  0.376
# 1  ...  3.29  0.008  0.089  0.128  0.965  0.623  1.198  0.036  0.156  0.395
# 2  ...  1.62  0.015  0.095  0.207  1.420  0.669  1.178  0.081  0.095  0.441
# 3  ...  1.72  2.210  1.423  1.252  0.926  0.612  3.791  0.124  0.102  1.388
# 4  ...  1.25  0.003  0.025  0.058  0.198  0.307  1.100  0.002  0.079  0.316
# 5  ...  1.19  0.005  0.031  0.062  0.850  0.598  0.998  0.009  0.061  0.294
# 6  ...  0.87  0.092  0.296  0.721  1.832  0.753  3.262  0.092  0.098  0.567
# 7  ...  1.30  0.165  1.102  0.356  0.652  0.335  2.979  0.137  0.107  1.979
# 8  ...  1.31  0.082  0.511  0.256  0.095  0.173  1.245  0.107  0.062  0.953
#
# [9 rows x 27 columns]

# %%
from scipy import stats

# %%
pH = stats.pearsonr(summer_p["pH"], winter_p["pH"])
pH[1]
# Out:
# 0.0021894015946822957

# %%
p_values = {}
for col in summer_p.columns:
    p = stats.pearsonr(summer_p[col], winter_p[col])
    p_values[col] = p[1]
    
p_values
# Out:
# {'Temperature': 0.001076968375195377,
#  'pH': 0.0021894015946822957,
#  'EC': 0.00036720604562929426,
#  'TSS': 0.3609610083171295,
#  'Turbidity': 0.020161785069534685,
#  'Salinity': 0.08270812335380208,
#  'TDS': 0.0011177140710890757,
#  'DO': 0.00011111871797177036,
#  'COD': 0.014656059289097793,
#  'NH4+': 5.0444673464050505e-05,
#  'NO3': 0.23462440551732291,
#  'Phosphate': 0.037112066423287834,
#  'Sulfates': 0.9194206744204306,
#  'K': 0.04516824437236833,
#  'Ca': 5.357416443075926e-06,
#  'Mg': 0.011191110820888837,
#  'Cl': 0.1831192573251837,
#  'Br': 0.9965574774774469,
#  'Cd': 3.552329931548303e-13,
#  'Cr': 1.2678571128890454e-06,
#  'Ni': 0.6691586817069658,
#  'Cu': 0.003579196262824652,
#  'Zn': 0.0007957680320265863,
#  'Mn': 4.1690587272488286e-08,
#  'Hg': 0.0025298431763958484,
#  'As': 0.20977603408294415,
#  'Pb': 0.0007874647112060948}

# %%
from scipy.stats import ttest_ind

# %%
ex = ttest_ind(summer_p["Pb"], winter_p["Pb"])
ex
# Out:
# Ttest_indResult(statistic=0.36690282103783917, pvalue=0.7184987651762235)

# %%
pH = stats.pearsonr(summer_p["pH"], winter_p["pH"])
pH
# Out:
# (0.8717483398066427, 0.0021894015946822957)

# %%
pH = stats.pearsonr(summer_p["Pb"], winter_p["Pb"])
pH
# Out:
# (0.9051623712335197, 0.0007874647112060948)

# %%
summer
# Out:
#         SamplingPoint  Temperature    pH    EC  TSS  Turbidity  Salinity  \
# 0     Gabtoli Dhalwes         30.4  6.17  1790  309        108       639
# 1       Gabtoli Turag         30.7  5.89  1453  322        126       702
# 2         Shah Cement         32.7  5.02  2047  434        174       730
# 3           Hazaribag         32.8  4.37   538  461        162       360
# 4          Rayerbazar         29.5  6.59   692  178         82       244
# 5           Kholamora         32.2  5.33  1596  296         76       930
# 6             Zinzira         30.1  6.78  1963  302        108      1070
# 7  Sadarghat Terminal         32.9  4.11  2119  464        175      1156
# 8       Postogola Bri         32.4  5.24  2550  387        162      1332
#
#     TDS    DO   COD  ...    Br     Cd     Cr     Ni     Cu     Zn     Mn  \
# 0   852  0.96   700  ...  0.61  0.003  0.044  0.107  0.458  0.187  0.995
# 1  1208  0.73   718  ...  0.45  0.007  0.083  0.495  0.932  0.659  1.178
# 2   783  0.15   870  ...  0.42  0.018  0.082  0.149  1.597  0.573  1.073
# 3  1790  0.12   912  ...  0.66  2.100  1.139  0.065  0.988  0.602  3.450
# 4   825  1.10   655  ...  0.80  0.005  0.029  0.089  0.114  0.309  1.002
# 5  2009  0.51   725  ...  0.79  0.007  0.045  0.216  1.976  0.759  0.872
# 6  2036  1.39   530  ...  0.41  0.106  0.198  1.023  1.851  0.755  3.107
# 7  2377  0.00  1180  ...  0.35  0.193  1.133  0.451  0.633  0.442  2.456
# 8  1895  0.27   879  ...  0.32  0.069  0.370  0.385  0.115  0.292  1.114
#
#       Hg     As     Pb
# 0  0.009  0.109  0.188
# 1  0.027  0.102  0.452
# 2  0.108  0.063  0.337
# 3  0.176  0.098  1.836
# 4  0.093  0.057  0.119
# 5  0.017  0.075  0.178
# 6  0.089  0.112  1.457
# 7  0.255  0.161  2.144
# 8  0.198  0.059  1.075
#
# [9 rows x 28 columns]

# %%
summer_p.T
# Out:
#                     0         1         2         3        4         5  \
# Temperature    30.400    30.700    32.700    32.800   29.500    32.200
# pH              6.170     5.890     5.020     4.370    6.590     5.330
# EC           1790.000  1453.000  2047.000   538.000  692.000  1596.000
# TSS           309.000   322.000   434.000   461.000  178.000   296.000
# Turbidity     108.000   126.000   174.000   162.000   82.000    76.000
# Salinity      639.000   702.000   730.000   360.000  244.000   930.000
# TDS           852.000  1208.000   783.000  1790.000  825.000  2009.000
# DO              0.960     0.730     0.150     0.120    1.100     0.510
# COD           700.000   718.000   870.000   912.000  655.000   725.000
# NH4+            2.900     2.800     7.600     8.200    3.000     5.900
# NO3            33.000    32.300    37.200    41.900   19.800    38.200
# Phosphate       2.150     2.780     3.110     2.230    1.510     2.120
# Sulfates       92.500    74.200   107.800    94.800   89.200    54.200
# K              59.200    46.800    32.500    18.900   23.800    29.400
# Ca            102.500    72.300    98.600    54.300   30.900    72.500
# Mg             75.400    39.600    38.900    28.800   16.500    30.400
# Cl             98.140   110.270   113.550    38.830   41.790    78.560
# Br              0.610     0.450     0.420     0.660    0.800     0.790
# Cd              0.003     0.007     0.018     2.100    0.005     0.007
# Cr              0.044     0.083     0.082     1.139    0.029     0.045
# Ni              0.107     0.495     0.149     0.065    0.089     0.216
# Cu              0.458     0.932     1.597     0.988    0.114     1.976
# Zn              0.187     0.659     0.573     0.602    0.309     0.759
# Mn              0.995     1.178     1.073     3.450    1.002     0.872
# Hg              0.009     0.027     0.108     0.176    0.093     0.017
# As              0.109     0.102     0.063     0.098    0.057     0.075
# Pb              0.188     0.452     0.337     1.836    0.119     0.178
#
#                     6         7         8
# Temperature    30.100    32.900    32.400
# pH              6.780     4.110     5.240
# EC           1963.000  2119.000  2550.000
# TSS           302.000   464.000   387.000
# Turbidity     108.000   175.000   162.000
# Salinity     1070.000  1156.000  1332.000
# TDS          2036.000  2377.000  1895.000
# DO              1.390     0.000     0.270
# COD           530.000  1180.000   879.000
# NH4+            2.200    10.400     9.300
# NO3            18.400    44.500    19.700
# Phosphate       2.290     3.240     4.570
# Sulfates       70.800    77.700   102.100
# K              40.100    31.200    29.000
# Ca            130.200    69.800    65.500
# Mg             95.100    21.800    30.700
# Cl             43.950   146.200   167.480
# Br              0.410     0.350     0.320
# Cd              0.106     0.193     0.069
# Cr              0.198     1.133     0.370
# Ni              1.023     0.451     0.385
# Cu              1.851     0.633     0.115
# Zn              0.755     0.442     0.292
# Mn              3.107     2.456     1.114
# Hg              0.089     0.255     0.198
# As              0.112     0.161     0.059
# Pb              1.457     2.144     1.075

# %%
winter_p
# Out:
#    Temperature    pH    EC  TSS  Turbidity  Salinity   TDS    DO  COD  NH4+  \
# 0         25.0  8.25  1470  190       59.6       685   778  1.82  195   2.6
# 1         24.7  8.39  1593  156       78.6       706   912  1.37  252   3.2
# 2         25.2  8.11  1656  142       85.3       642   986  0.14  493   8.0
# 3         25.4  5.80   767  357       48.9       262  1995  0.10  683   9.4
# 4         23.8  8.93   788  213       28.8       370  1502  2.12  189   2.1
# 5         25.1  8.13  1472  320       42.5       712  1986  0.85  320   5.6
# 6         24.2  8.62  1860  398       39.9       960  2155  1.72  480   4.6
# 7         25.9  5.55  1536  465      127.4       208  2407  0.00  816  11.2
# 8         25.2  8.10  2502  300       75.5      1380  1750  0.13  582   9.4
#
#    ...    Br     Cd     Cr     Ni     Cu     Zn     Mn     Hg     As     Pb
# 0  ...  3.15  0.007  0.049  0.102  0.388  0.286  1.084  0.014  0.191  0.376
# 1  ...  3.29  0.008  0.089  0.128  0.965  0.623  1.198  0.036  0.156  0.395
# 2  ...  1.62  0.015  0.095  0.207  1.420  0.669  1.178  0.081  0.095  0.441
# 3  ...  1.72  2.210  1.423  1.252  0.926  0.612  3.791  0.124  0.102  1.388
# 4  ...  1.25  0.003  0.025  0.058  0.198  0.307  1.100  0.002  0.079  0.316
# 5  ...  1.19  0.005  0.031  0.062  0.850  0.598  0.998  0.009  0.061  0.294
# 6  ...  0.87  0.092  0.296  0.721  1.832  0.753  3.262  0.092  0.098  0.567
# 7  ...  1.30  0.165  1.102  0.356  0.652  0.335  2.979  0.137  0.107  1.979
# 8  ...  1.31  0.082  0.511  0.256  0.095  0.173  1.245  0.107  0.062  0.953
#
# [9 rows x 27 columns]

# %%
sT = summer_p.T
wT = winter_p.T

# %%
wT
# Out:
#                     0         1         2         3         4         5  \
# Temperature    25.000    24.700    25.200    25.400    23.800    25.100
# pH              8.250     8.390     8.110     5.800     8.930     8.130
# EC           1470.000  1593.000  1656.000   767.000   788.000  1472.000
# TSS           190.000   156.000   142.000   357.000   213.000   320.000
# Turbidity      59.600    78.600    85.300    48.900    28.800    42.500
# Salinity      685.000   706.000   642.000   262.000   370.000   712.000
# TDS           778.000   912.000   986.000  1995.000  1502.000  1986.000
# DO              1.820     1.370     0.140     0.100     2.120     0.850
# COD           195.000   252.000   493.000   683.000   189.000   320.000
# NH4+            2.600     3.200     8.000     9.400     2.100     5.600
# NO3            13.100    12.400    17.300    24.600     9.800    18.200
# Phosphate       3.500     5.700     6.000     3.500     3.900     5.000
# Sulfates        8.770    11.400    12.400     9.250     9.200     9.860
# K              39.200    36.800    42.200    18.500    19.400    33.100
# Ca             95.600    86.400   108.200    56.300    32.900    83.100
# Mg             52.600    37.400    68.900    29.800    11.900    38.500
# Cl            110.800   277.300   289.900    15.800    32.100   116.700
# Br              3.150     3.290     1.620     1.720     1.250     1.190
# Cd              0.007     0.008     0.015     2.210     0.003     0.005
# Cr              0.049     0.089     0.095     1.423     0.025     0.031
# Ni              0.102     0.128     0.207     1.252     0.058     0.062
# Cu              0.388     0.965     1.420     0.926     0.198     0.850
# Zn              0.286     0.623     0.669     0.612     0.307     0.598
# Mn              1.084     1.198     1.178     3.791     1.100     0.998
# Hg              0.014     0.036     0.081     0.124     0.002     0.009
# As              0.191     0.156     0.095     0.102     0.079     0.061
# Pb              0.376     0.395     0.441     1.388     0.316     0.294
#
#                     6         7         8
# Temperature    24.200    25.900    25.200
# pH              8.620     5.550     8.100
# EC           1860.000  1536.000  2502.000
# TSS           398.000   465.000   300.000
# Turbidity      39.900   127.400    75.500
# Salinity      960.000   208.000  1380.000
# TDS          2155.000  2407.000  1750.000
# DO              1.720     0.000     0.130
# COD           480.000   816.000   582.000
# NH4+            4.600    11.200     9.400
# NO3            12.400    24.500    25.800
# Phosphate       6.500     5.300     6.800
# Sulfates       18.700    10.800    17.100
# K              48.700    28.200    21.300
# Ca            132.600    75.500    70.200
# Mg             83.600    42.700    36.100
# Cl            334.100   236.000   245.900
# Br              0.870     1.300     1.310
# Cd              0.092     0.165     0.082
# Cr              0.296     1.102     0.511
# Ni              0.721     0.356     0.256
# Cu              1.832     0.652     0.095
# Zn              0.753     0.335     0.173
# Mn              3.262     2.979     1.245
# Hg              0.092     0.137     0.107
# As              0.098     0.107     0.062
# Pb              0.567     1.979     0.953

# %%
sT[17:]
# Out:
#         0      1      2      3      4      5      6      7      8
# Br  0.610  0.450  0.420  0.660  0.800  0.790  0.410  0.350  0.320
# Cd  0.003  0.007  0.018  2.100  0.005  0.007  0.106  0.193  0.069
# Cr  0.044  0.083  0.082  1.139  0.029  0.045  0.198  1.133  0.370
# Ni  0.107  0.495  0.149  0.065  0.089  0.216  1.023  0.451  0.385
# Cu  0.458  0.932  1.597  0.988  0.114  1.976  1.851  0.633  0.115
# Zn  0.187  0.659  0.573  0.602  0.309  0.759  0.755  0.442  0.292
# Mn  0.995  1.178  1.073  3.450  1.002  0.872  3.107  2.456  1.114
# Hg  0.009  0.027  0.108  0.176  0.093  0.017  0.089  0.255  0.198
# As  0.109  0.102  0.063  0.098  0.057  0.075  0.112  0.161  0.059
# Pb  0.188  0.452  0.337  1.836  0.119  0.178  1.457  2.144  1.075

# %%
stations = summer["SamplingPoint"]
stations
# Out:
# 0       Gabtoli Dhalwes
# 1         Gabtoli Turag
# 2           Shah Cement
# 3             Hazaribag
# 4            Rayerbazar
# 5             Kholamora
# 6               Zinzira
# 7    Sadarghat Terminal
# 8         Postogola Bri
# Name: SamplingPoint, dtype: object

# %%
sT.columns = stations
sT
# Out:
# SamplingPoint  Gabtoli Dhalwes  Gabtoli Turag  Shah Cement  Hazaribag  \
# Temperature             30.400         30.700       32.700     32.800
# pH                       6.170          5.890        5.020      4.370
# EC                    1790.000       1453.000     2047.000    538.000
# TSS                    309.000        322.000      434.000    461.000
# Turbidity              108.000        126.000      174.000    162.000
# Salinity               639.000        702.000      730.000    360.000
# TDS                    852.000       1208.000      783.000   1790.000
# DO                       0.960          0.730        0.150      0.120
# COD                    700.000        718.000      870.000    912.000
# NH4+                     2.900          2.800        7.600      8.200
# NO3                     33.000         32.300       37.200     41.900
# Phosphate                2.150          2.780        3.110      2.230
# Sulfates                92.500         74.200      107.800     94.800
# K                       59.200         46.800       32.500     18.900
# Ca                     102.500         72.300       98.600     54.300
# Mg                      75.400         39.600       38.900     28.800
# Cl                      98.140        110.270      113.550     38.830
# Br                       0.610          0.450        0.420      0.660
# Cd                       0.003          0.007        0.018      2.100
# Cr                       0.044          0.083        0.082      1.139
# Ni                       0.107          0.495        0.149      0.065
# Cu                       0.458          0.932        1.597      0.988
# Zn                       0.187          0.659        0.573      0.602
# Mn                       0.995          1.178        1.073      3.450
# Hg                       0.009          0.027        0.108      0.176
# As                       0.109          0.102        0.063      0.098
# Pb                       0.188          0.452        0.337      1.836
#
# SamplingPoint  Rayerbazar  Kholamora   Zinzira  Sadarghat Terminal  \
# Temperature        29.500     32.200    30.100              32.900
# pH                  6.590      5.330     6.780               4.110
# EC                692.000   1596.000  1963.000            2119.000
# TSS               178.000    296.000   302.000             464.000
# Turbidity          82.000     76.000   108.000             175.000
# Salinity          244.000    930.000  1070.000            1156.000
# TDS               825.000   2009.000  2036.000            2377.000
# DO                  1.100      0.510     1.390               0.000
# COD               655.000    725.000   530.000            1180.000
# NH4+                3.000      5.900     2.200              10.400
# NO3                19.800     38.200    18.400              44.500
# Phosphate           1.510      2.120     2.290               3.240
# Sulfates           89.200     54.200    70.800              77.700
# K                  23.800     29.400    40.100              31.200
# Ca                 30.900     72.500   130.200              69.800
# Mg                 16.500     30.400    95.100              21.800
# Cl                 41.790     78.560    43.950             146.200
# Br                  0.800      0.790     0.410               0.350
# Cd                  0.005      0.007     0.106               0.193
# Cr                  0.029      0.045     0.198               1.133
# Ni                  0.089      0.216     1.023               0.451
# Cu                  0.114      1.976     1.851               0.633
# Zn                  0.309      0.759     0.755               0.442
# Mn                  1.002      0.872     3.107               2.456
# Hg                  0.093      0.017     0.089               0.255
# As                  0.057      0.075     0.112               0.161
# Pb                  0.119      0.178     1.457               2.144
#
# SamplingPoint  Postogola Bri
# Temperature           32.400
# pH                     5.240
# EC                  2550.000
# TSS                  387.000
# Turbidity            162.000
# Salinity            1332.000
# TDS                 1895.000
# DO                     0.270
# COD                  879.000
# NH4+                   9.300
# NO3                   19.700
# Phosphate              4.570
# Sulfates             102.100
# K                     29.000
# Ca                    65.500
# Mg                    30.700
# Cl                   167.480
# Br                     0.320
# Cd                     0.069
# Cr                     0.370
# Ni                     0.385
# Cu                     0.115
# Zn                     0.292
# Mn                     1.114
# Hg                     0.198
# As                     0.059
# Pb                     1.075

# %%
p = stats.pearsonr(sT["Gabtoli Dhalwes"][:9], sT["Gabtoli Turag"][:9])
p[1]
# Out:
# 6.053542846101845e-05

# %%
sT["Gabtoli Dhalwes"][:9]
# Out:
# Temperature      30.40
# pH                6.17
# EC             1790.00
# TSS             309.00
# Turbidity       108.00
# Salinity        639.00
# TDS             852.00
# DO                0.96
# COD             700.00
# Name: Gabtoli Dhalwes, dtype: float64

# %%
def p_gen_physio(i,j,p_values):
    a,b = sT.columns[i], sT.columns[j] 
    p = stats.pearsonr(sT[a][:9], sT[b][:9])
    notation = a + ' | ' + b
    p_values[notation] = p[1]
    
    return p_values

# %%
p_values = {}
p_gen_physio(0,1,p_values)
# Out:
# {'Gabtoli Dhalwes | Gabtoli Turag': 6.053542846101845e-05}

# %%
p_values = p_gen_physio(0,2,p_values)
p_values = p_gen_physio(0,3,p_values)
p_values = p_gen_physio(0,4,p_values)
p_values = p_gen_physio(0,5,p_values)
p_values = p_gen_physio(0,6,p_values)
p_values = p_gen_physio(0,7,p_values)
p_values = p_gen_physio(0,8,p_values)

p_values = p_gen_physio(1,2,p_values)
p_values = p_gen_physio(1,3,p_values)
p_values = p_gen_physio(1,4,p_values)
p_values = p_gen_physio(1,5,p_values)
p_values = p_gen_physio(1,6,p_values)
p_values = p_gen_physio(1,7,p_values)
p_values = p_gen_physio(1,8,p_values)

p_values = p_gen_physio(2,3,p_values)
p_values = p_gen_physio(2,4,p_values)
p_values = p_gen_physio(2,5,p_values)
p_values = p_gen_physio(2,6,p_values)
p_values = p_gen_physio(2,7,p_values)
p_values = p_gen_physio(2,8,p_values)

p_values = p_gen_physio(3,4,p_values)
p_values = p_gen_physio(3,5,p_values)
p_values = p_gen_physio(3,6,p_values)
p_values = p_gen_physio(3,7,p_values)
p_values = p_gen_physio(3,8,p_values)

p_values = p_gen_physio(4,5,p_values)
p_values = p_gen_physio(4,6,p_values)
p_values = p_gen_physio(4,7,p_values)
p_values = p_gen_physio(4,8,p_values)

p_values = p_gen_physio(5,6,p_values)
p_values = p_gen_physio(5,7,p_values)
p_values = p_gen_physio(5,8,p_values)

p_values = p_gen_physio(6,7,p_values)
p_values = p_gen_physio(6,8,p_values)

p_values = p_gen_physio(7,8,p_values)

p_values
# Out:
# {'Gabtoli Dhalwes | Gabtoli Turag': 6.053542846101845e-05,
#  'Gabtoli Dhalwes | Shah Cement': 9.152497612385768e-08,
#  'Gabtoli Dhalwes | Hazaribag': 0.1490435352135499,
#  'Gabtoli Dhalwes | Rayerbazar': 0.0056153743580701024,
#  'Gabtoli Dhalwes | Kholamora': 0.004007463751524915,
#  'Gabtoli Dhalwes | Zinzira': 0.0015422054467568729,
#  'Gabtoli Dhalwes | Sadarghat Terminal': 0.0014760666661167608,
#  'Gabtoli Dhalwes | Postogola Bri': 3.657790928555321e-05,
#  'Gabtoli Turag | Shah Cement': 0.00039658032379181145,
#  'Gabtoli Turag | Hazaribag': 0.023682364863202493,
#  'Gabtoli Turag | Rayerbazar': 0.0003069125937250012,
#  'Gabtoli Turag | Kholamora': 3.4118454173850195e-05,
#  'Gabtoli Turag | Zinzira': 2.2237063860349325e-05,
#  'Gabtoli Turag | Sadarghat Terminal': 2.043964948193203e-06,
#  'Gabtoli Turag | Postogola Bri': 6.084811615936489e-07,
#  'Shah Cement | Hazaribag': 0.2174757157122813,
#  'Shah Cement | Rayerbazar': 0.010844905416454255,
#  'Shah Cement | Kholamora': 0.012071121352470916,
#  'Shah Cement | Zinzira': 0.005857572437296758,
#  'Shah Cement | Sadarghat Terminal': 0.0049312876610447705,
#  'Shah Cement | Postogola Bri': 0.00031846820882849803,
#  'Hazaribag | Rayerbazar': 0.0016405732619565385,
#  'Hazaribag | Kholamora': 0.004546735870624299,
#  'Hazaribag | Zinzira': 0.020280288370316448,
#  'Hazaribag | Sadarghat Terminal': 0.005106534662526703,
#  'Hazaribag | Postogola Bri': 0.05685458947343067,
#  'Rayerbazar | Kholamora': 0.00048743834804207533,
#  'Rayerbazar | Zinzira': 0.002563186415203312,
#  'Rayerbazar | Sadarghat Terminal': 9.264351883910758e-05,
#  'Rayerbazar | Postogola Bri': 0.002703530598792629,
#  'Kholamora | Zinzira': 8.635997976558373e-07,
#  'Kholamora | Sadarghat Terminal': 1.1501542322986175e-07,
#  'Kholamora | Postogola Bri': 9.595324320836661e-05,
#  'Zinzira | Sadarghat Terminal': 6.259088929252109e-06,
#  'Zinzira | Postogola Bri': 8.269004296872016e-06,
#  'Sadarghat Terminal | Postogola Bri': 3.65344265121029e-05}

# %%
temp_cod_s = pd.DataFrame(data={
    "Point": p_values.keys(),
    "p value": p_values.values()
})
temp_cod_s
# Out:
#                                    Point       p value
# 0        Gabtoli Dhalwes | Gabtoli Turag  6.053543e-05
# 1          Gabtoli Dhalwes | Shah Cement  9.152498e-08
# 2            Gabtoli Dhalwes | Hazaribag  1.490435e-01
# 3           Gabtoli Dhalwes | Rayerbazar  5.615374e-03
# 4            Gabtoli Dhalwes | Kholamora  4.007464e-03
# 5              Gabtoli Dhalwes | Zinzira  1.542205e-03
# 6   Gabtoli Dhalwes | Sadarghat Terminal  1.476067e-03
# 7        Gabtoli Dhalwes | Postogola Bri  3.657791e-05
# 8            Gabtoli Turag | Shah Cement  3.965803e-04
# 9              Gabtoli Turag | Hazaribag  2.368236e-02
# 10            Gabtoli Turag | Rayerbazar  3.069126e-04
# 11             Gabtoli Turag | Kholamora  3.411845e-05
# 12               Gabtoli Turag | Zinzira  2.223706e-05
# 13    Gabtoli Turag | Sadarghat Terminal  2.043965e-06
# 14         Gabtoli Turag | Postogola Bri  6.084812e-07
# 15               Shah Cement | Hazaribag  2.174757e-01
# 16              Shah Cement | Rayerbazar  1.084491e-02
# 17               Shah Cement | Kholamora  1.207112e-02
# 18                 Shah Cement | Zinzira  5.857572e-03
# 19      Shah Cement | Sadarghat Terminal  4.931288e-03
# 20           Shah Cement | Postogola Bri  3.184682e-04
# 21                Hazaribag | Rayerbazar  1.640573e-03
# 22                 Hazaribag | Kholamora  4.546736e-03
# 23                   Hazaribag | Zinzira  2.028029e-02
# 24        Hazaribag | Sadarghat Terminal  5.106535e-03
# 25             Hazaribag | Postogola Bri  5.685459e-02
# 26                Rayerbazar | Kholamora  4.874383e-04
# 27                  Rayerbazar | Zinzira  2.563186e-03
# 28       Rayerbazar | Sadarghat Terminal  9.264352e-05
# 29            Rayerbazar | Postogola Bri  2.703531e-03
# 30                   Kholamora | Zinzira  8.635998e-07
# 31        Kholamora | Sadarghat Terminal  1.150154e-07
# 32             Kholamora | Postogola Bri  9.595324e-05
# 33          Zinzira | Sadarghat Terminal  6.259089e-06
# 34               Zinzira | Postogola Bri  8.269004e-06
# 35    Sadarghat Terminal | Postogola Bri  3.653443e-05

# %%
def p_gen_hm(i,j,p_values):
    a,b = sT.columns[i], sT.columns[j] 
    p = stats.pearsonr(sT[a][18:], sT[b][18:])
    notation = a + ' | ' + b
    p_values[notation] = p[1]
    
    return p_values

# %%
p_values = {}
p_values = p_gen_hm(0,1,p_values)

# %%
p_values = p_gen_hm(0,2,p_values)
p_values = p_gen_hm(0,3,p_values)
p_values = p_gen_hm(0,4,p_values)
p_values = p_gen_hm(0,5,p_values)
p_values = p_gen_hm(0,6,p_values)
p_values = p_gen_hm(0,7,p_values)
p_values = p_gen_hm(0,8,p_values)

p_values = p_gen_hm(1,2,p_values)
p_values = p_gen_hm(1,3,p_values)
p_values = p_gen_hm(1,4,p_values)
p_values = p_gen_hm(1,5,p_values)
p_values = p_gen_hm(1,6,p_values)
p_values = p_gen_hm(1,7,p_values)
p_values = p_gen_hm(1,8,p_values)

p_values = p_gen_hm(2,3,p_values)
p_values = p_gen_hm(2,4,p_values)
p_values = p_gen_hm(2,5,p_values)
p_values = p_gen_hm(2,6,p_values)
p_values = p_gen_hm(2,7,p_values)
p_values = p_gen_hm(2,8,p_values)

p_values = p_gen_hm(3,4,p_values)
p_values = p_gen_hm(3,5,p_values)
p_values = p_gen_hm(3,6,p_values)
p_values = p_gen_hm(3,7,p_values)
p_values = p_gen_hm(3,8,p_values)

p_values = p_gen_hm(4,5,p_values)
p_values = p_gen_hm(4,6,p_values)
p_values = p_gen_hm(4,7,p_values)
p_values = p_gen_hm(4,8,p_values)

p_values = p_gen_hm(5,6,p_values)
p_values = p_gen_hm(5,7,p_values)
p_values = p_gen_hm(5,8,p_values)

p_values = p_gen_hm(6,7,p_values)
p_values = p_gen_hm(6,8,p_values)

p_values = p_gen_hm(7,8,p_values)

p_values
# Out:
# {'Gabtoli Dhalwes | Gabtoli Turag': 0.0013283435256490562,
#  'Gabtoli Dhalwes | Shah Cement': 0.01669659075330105,
#  'Gabtoli Dhalwes | Hazaribag': 0.039745479529077476,
#  'Gabtoli Dhalwes | Rayerbazar': 0.0006057540971820561,
#  'Gabtoli Dhalwes | Kholamora': 0.08028776158822745,
#  'Gabtoli Dhalwes | Zinzira': 0.00016762605977362573,
#  'Gabtoli Dhalwes | Sadarghat Terminal': 0.04155538401977462,
#  'Gabtoli Dhalwes | Postogola Bri': 0.08392977152486765,
#  'Gabtoli Turag | Shah Cement': 0.002169737796285117,
#  'Gabtoli Turag | Hazaribag': 0.2030537788865327,
#  'Gabtoli Turag | Rayerbazar': 0.01760751822982012,
#  'Gabtoli Turag | Kholamora': 0.010925239849565668,
#  'Gabtoli Turag | Zinzira': 0.0001838222045724898,
#  'Gabtoli Turag | Sadarghat Terminal': 0.11524039765907794,
#  'Gabtoli Turag | Postogola Bri': 0.1476245283576844,
#  'Shah Cement | Hazaribag': 0.34821256129381045,
#  'Shah Cement | Rayerbazar': 0.16309752447259715,
#  'Shah Cement | Kholamora': 1.3780695281187786e-05,
#  'Shah Cement | Zinzira': 0.012841161628707246,
#  'Shah Cement | Sadarghat Terminal': 0.356015669790856,
#  'Shah Cement | Postogola Bri': 0.5744071642113422,
#  'Hazaribag | Rayerbazar': 0.041741196023504595,
#  'Hazaribag | Kholamora': 0.6570369086868163,
#  'Hazaribag | Zinzira': 0.05466206696838362,
#  'Hazaribag | Sadarghat Terminal': 0.01701924308836771,
#  'Hazaribag | Postogola Bri': 0.048158916517358194,
#  'Rayerbazar | Kholamora': 0.38085937305963097,
#  'Rayerbazar | Zinzira': 0.007992145596895595,
#  'Rayerbazar | Sadarghat Terminal': 0.04876240445753712,
#  'Rayerbazar | Postogola Bri': 0.0525864566219172,
#  'Kholamora | Zinzira': 0.0646734289831692,
#  'Kholamora | Sadarghat Terminal': 0.7108114020610956,
#  'Kholamora | Postogola Bri': 0.9748827549893442,
#  'Zinzira | Sadarghat Terminal': 0.01754038178765534,
#  'Zinzira | Postogola Bri': 0.029554241381558786,
#  'Sadarghat Terminal | Postogola Bri': 4.610892080618689e-05}

# %%
hm_s = pd.DataFrame(data={
    "Point": p_values.keys(),
    "p value": p_values.values()
})
hm_s
# Out:
#                                    Point   p value
# 0        Gabtoli Dhalwes | Gabtoli Turag  0.001328
# 1          Gabtoli Dhalwes | Shah Cement  0.016697
# 2            Gabtoli Dhalwes | Hazaribag  0.039745
# 3           Gabtoli Dhalwes | Rayerbazar  0.000606
# 4            Gabtoli Dhalwes | Kholamora  0.080288
# 5              Gabtoli Dhalwes | Zinzira  0.000168
# 6   Gabtoli Dhalwes | Sadarghat Terminal  0.041555
# 7        Gabtoli Dhalwes | Postogola Bri  0.083930
# 8            Gabtoli Turag | Shah Cement  0.002170
# 9              Gabtoli Turag | Hazaribag  0.203054
# 10            Gabtoli Turag | Rayerbazar  0.017608
# 11             Gabtoli Turag | Kholamora  0.010925
# 12               Gabtoli Turag | Zinzira  0.000184
# 13    Gabtoli Turag | Sadarghat Terminal  0.115240
# 14         Gabtoli Turag | Postogola Bri  0.147625
# 15               Shah Cement | Hazaribag  0.348213
# 16              Shah Cement | Rayerbazar  0.163098
# 17               Shah Cement | Kholamora  0.000014
# 18                 Shah Cement | Zinzira  0.012841
# 19      Shah Cement | Sadarghat Terminal  0.356016
# 20           Shah Cement | Postogola Bri  0.574407
# 21                Hazaribag | Rayerbazar  0.041741
# 22                 Hazaribag | Kholamora  0.657037
# 23                   Hazaribag | Zinzira  0.054662
# 24        Hazaribag | Sadarghat Terminal  0.017019
# 25             Hazaribag | Postogola Bri  0.048159
# 26                Rayerbazar | Kholamora  0.380859
# 27                  Rayerbazar | Zinzira  0.007992
# 28       Rayerbazar | Sadarghat Terminal  0.048762
# 29            Rayerbazar | Postogola Bri  0.052586
# 30                   Kholamora | Zinzira  0.064673
# 31        Kholamora | Sadarghat Terminal  0.710811
# 32             Kholamora | Postogola Bri  0.974883
# 33          Zinzira | Sadarghat Terminal  0.017540
# 34               Zinzira | Postogola Bri  0.029554
# 35    Sadarghat Terminal | Postogola Bri  0.000046

# %%
wT.columns = stations

# %%
wT
# Out:
# SamplingPoint  Gabtoli Dhalwes  Gabtoli Turag  Shah Cement  Hazaribag  \
# Temperature             25.000         24.700       25.200     25.400
# pH                       8.250          8.390        8.110      5.800
# EC                    1470.000       1593.000     1656.000    767.000
# TSS                    190.000        156.000      142.000    357.000
# Turbidity               59.600         78.600       85.300     48.900
# Salinity               685.000        706.000      642.000    262.000
# TDS                    778.000        912.000      986.000   1995.000
# DO                       1.820          1.370        0.140      0.100
# COD                    195.000        252.000      493.000    683.000
# NH4+                     2.600          3.200        8.000      9.400
# NO3                     13.100         12.400       17.300     24.600
# Phosphate                3.500          5.700        6.000      3.500
# Sulfates                 8.770         11.400       12.400      9.250
# K                       39.200         36.800       42.200     18.500
# Ca                      95.600         86.400      108.200     56.300
# Mg                      52.600         37.400       68.900     29.800
# Cl                     110.800        277.300      289.900     15.800
# Br                       3.150          3.290        1.620      1.720
# Cd                       0.007          0.008        0.015      2.210
# Cr                       0.049          0.089        0.095      1.423
# Ni                       0.102          0.128        0.207      1.252
# Cu                       0.388          0.965        1.420      0.926
# Zn                       0.286          0.623        0.669      0.612
# Mn                       1.084          1.198        1.178      3.791
# Hg                       0.014          0.036        0.081      0.124
# As                       0.191          0.156        0.095      0.102
# Pb                       0.376          0.395        0.441      1.388
#
# SamplingPoint  Rayerbazar  Kholamora   Zinzira  Sadarghat Terminal  \
# Temperature        23.800     25.100    24.200              25.900
# pH                  8.930      8.130     8.620               5.550
# EC                788.000   1472.000  1860.000            1536.000
# TSS               213.000    320.000   398.000             465.000
# Turbidity          28.800     42.500    39.900             127.400
# Salinity          370.000    712.000   960.000             208.000
# TDS              1502.000   1986.000  2155.000            2407.000
# DO                  2.120      0.850     1.720               0.000
# COD               189.000    320.000   480.000             816.000
# NH4+                2.100      5.600     4.600              11.200
# NO3                 9.800     18.200    12.400              24.500
# Phosphate           3.900      5.000     6.500               5.300
# Sulfates            9.200      9.860    18.700              10.800
# K                  19.400     33.100    48.700              28.200
# Ca                 32.900     83.100   132.600              75.500
# Mg                 11.900     38.500    83.600              42.700
# Cl                 32.100    116.700   334.100             236.000
# Br                  1.250      1.190     0.870               1.300
# Cd                  0.003      0.005     0.092               0.165
# Cr                  0.025      0.031     0.296               1.102
# Ni                  0.058      0.062     0.721               0.356
# Cu                  0.198      0.850     1.832               0.652
# Zn                  0.307      0.598     0.753               0.335
# Mn                  1.100      0.998     3.262               2.979
# Hg                  0.002      0.009     0.092               0.137
# As                  0.079      0.061     0.098               0.107
# Pb                  0.316      0.294     0.567               1.979
#
# SamplingPoint  Postogola Bri
# Temperature           25.200
# pH                     8.100
# EC                  2502.000
# TSS                  300.000
# Turbidity             75.500
# Salinity            1380.000
# TDS                 1750.000
# DO                     0.130
# COD                  582.000
# NH4+                   9.400
# NO3                   25.800
# Phosphate              6.800
# Sulfates              17.100
# K                     21.300
# Ca                    70.200
# Mg                    36.100
# Cl                   245.900
# Br                     1.310
# Cd                     0.082
# Cr                     0.511
# Ni                     0.256
# Cu                     0.095
# Zn                     0.173
# Mn                     1.245
# Hg                     0.107
# As                     0.062
# Pb                     0.953

# %%
def p_gen_physio_w(i,j,p_values):
    a,b = sT.columns[i], sT.columns[j] 
    p = stats.pearsonr(wT[a][:9], wT[b][:9])
    notation = a + ' | ' + b
    p_values[notation] = p[1]
    
    return p_values

# %%
p_values = {}
p_values = p_gen_physio_w(0,1,p_values)

# %%
p_values = p_gen_physio_w(0,2,p_values)
p_values = p_gen_physio_w(0,3,p_values)
p_values = p_gen_physio_w(0,4,p_values)
p_values = p_gen_physio_w(0,5,p_values)
p_values = p_gen_physio_w(0,6,p_values)
p_values = p_gen_physio_w(0,7,p_values)
p_values = p_gen_physio_w(0,8,p_values)

p_values = p_gen_physio_w(1,2,p_values)
p_values = p_gen_physio_w(1,3,p_values)
p_values = p_gen_physio_w(1,4,p_values)
p_values = p_gen_physio_w(1,5,p_values)
p_values = p_gen_physio_w(1,6,p_values)
p_values = p_gen_physio_w(1,7,p_values)
p_values = p_gen_physio_w(1,8,p_values)

p_values = p_gen_physio_w(2,3,p_values)
p_values = p_gen_physio_w(2,4,p_values)
p_values = p_gen_physio_w(2,5,p_values)
p_values = p_gen_physio_w(2,6,p_values)
p_values = p_gen_physio_w(2,7,p_values)
p_values = p_gen_physio_w(2,8,p_values)

p_values = p_gen_physio_w(3,4,p_values)
p_values = p_gen_physio_w(3,5,p_values)
p_values = p_gen_physio_w(3,6,p_values)
p_values = p_gen_physio_w(3,7,p_values)
p_values = p_gen_physio_w(3,8,p_values)

p_values = p_gen_physio_w(4,5,p_values)
p_values = p_gen_physio_w(4,6,p_values)
p_values = p_gen_physio_w(4,7,p_values)
p_values = p_gen_physio_w(4,8,p_values)

p_values = p_gen_physio_w(5,6,p_values)
p_values = p_gen_physio_w(5,7,p_values)
p_values = p_gen_physio_w(5,8,p_values)

p_values = p_gen_physio_w(6,7,p_values)
p_values = p_gen_physio_w(6,8,p_values)

p_values = p_gen_physio_w(7,8,p_values)

p_values
# Out:
# {'Gabtoli Dhalwes | Gabtoli Turag': 1.414622753441703e-09,
#  'Gabtoli Dhalwes | Shah Cement': 3.888673731439952e-06,
#  'Gabtoli Dhalwes | Hazaribag': 0.10471813582635915,
#  'Gabtoli Dhalwes | Rayerbazar': 0.02500033142473817,
#  'Gabtoli Dhalwes | Kholamora': 0.003626666424726122,
#  'Gabtoli Dhalwes | Zinzira': 0.0010424507454679334,
#  'Gabtoli Dhalwes | Sadarghat Terminal': 0.03043734651646469,
#  'Gabtoli Dhalwes | Postogola Bri': 1.1919411897355503e-06,
#  'Gabtoli Turag | Shah Cement': 5.659978277393238e-07,
#  'Gabtoli Turag | Hazaribag': 0.07857670924110086,
#  'Gabtoli Turag | Rayerbazar': 0.01755873062345048,
#  'Gabtoli Turag | Kholamora': 0.002189529518189554,
#  'Gabtoli Turag | Zinzira': 0.0005629940331783321,
#  'Gabtoli Turag | Sadarghat Terminal': 0.020235223121161668,
#  'Gabtoli Turag | Postogola Bri': 2.907620956111698e-07,
#  'Shah Cement | Hazaribag': 0.05259494838803697,
#  'Shah Cement | Rayerbazar': 0.016015127297125745,
#  'Shah Cement | Kholamora': 0.002110851420421057,
#  'Shah Cement | Zinzira': 0.000517506929665725,
#  'Shah Cement | Sadarghat Terminal': 0.010864415583489781,
#  'Shah Cement | Postogola Bri': 1.953174876522876e-06,
#  'Hazaribag | Rayerbazar': 6.827465129289607e-05,
#  'Hazaribag | Kholamora': 0.0008542803880860184,
#  'Hazaribag | Zinzira': 0.0023550918852201885,
#  'Hazaribag | Sadarghat Terminal': 1.6582157460969456e-05,
#  'Hazaribag | Postogola Bri': 0.043845634457188566,
#  'Rayerbazar | Kholamora': 3.3840736358505237e-06,
#  'Rayerbazar | Zinzira': 6.545894716583611e-05,
#  'Rayerbazar | Sadarghat Terminal': 5.107999586231088e-05,
#  'Rayerbazar | Postogola Bri': 0.008337577736219879,
#  'Kholamora | Zinzira': 5.87515636804731e-08,
#  'Kholamora | Sadarghat Terminal': 0.00013293470682256367,
#  'Kholamora | Postogola Bri': 0.0007148072243030252,
#  'Zinzira | Sadarghat Terminal': 0.00036928726299036943,
#  'Zinzira | Postogola Bri': 0.00011020639081910006,
#  'Sadarghat Terminal | Postogola Bri': 0.01210771033294704}

# %%
temp_cod_w = pd.DataFrame(data={
    "Point": p_values.keys(),
    "p value": p_values.values()
})
temp_cod_w
# Out:
#                                    Point       p value
# 0        Gabtoli Dhalwes | Gabtoli Turag  1.159340e-03
# 1          Gabtoli Dhalwes | Shah Cement  1.688172e-02
# 2            Gabtoli Dhalwes | Hazaribag  4.077603e-02
# 3           Gabtoli Dhalwes | Rayerbazar  3.161256e-06
# 4            Gabtoli Dhalwes | Kholamora  3.085347e-03
# 5              Gabtoli Dhalwes | Zinzira  2.665214e-04
# 6   Gabtoli Dhalwes | Sadarghat Terminal  4.070536e-03
# 7        Gabtoli Dhalwes | Postogola Bri  1.593964e-02
# 8            Gabtoli Turag | Shah Cement  2.700738e-05
# 9              Gabtoli Turag | Hazaribag  1.797134e-01
# 10            Gabtoli Turag | Rayerbazar  5.254050e-03
# 11             Gabtoli Turag | Kholamora  2.586615e-08
# 12               Gabtoli Turag | Zinzira  2.845227e-04
# 13    Gabtoli Turag | Sadarghat Terminal  6.242165e-02
# 14         Gabtoli Turag | Postogola Bri  1.625660e-01
# 15               Shah Cement | Hazaribag  3.358983e-01
# 16              Shah Cement | Rayerbazar  4.788324e-02
# 17               Shah Cement | Kholamora  1.732731e-05
# 18                 Shah Cement | Zinzira  2.531489e-03
# 19      Shah Cement | Sadarghat Terminal  1.658065e-01
# 20           Shah Cement | Postogola Bri  3.556362e-01
# 21                Hazaribag | Rayerbazar  2.265543e-02
# 22                 Hazaribag | Kholamora  2.097843e-01
# 23                   Hazaribag | Zinzira  3.751835e-02
# 24        Hazaribag | Sadarghat Terminal  1.619140e-02
# 25             Hazaribag | Postogola Bri  2.453730e-02
# 26                Rayerbazar | Kholamora  9.177551e-03
# 27                  Rayerbazar | Zinzira  1.120487e-03
# 28       Rayerbazar | Sadarghat Terminal  3.128823e-03
# 29            Rayerbazar | Postogola Bri  9.160254e-03
# 30                   Kholamora | Zinzira  7.846007e-04
# 31        Kholamora | Sadarghat Terminal  9.347553e-02
# 32             Kholamora | Postogola Bri  2.182994e-01
# 33          Zinzira | Sadarghat Terminal  2.309287e-02
# 34               Zinzira | Postogola Bri  7.243390e-02
# 35    Sadarghat Terminal | Postogola Bri  3.734015e-06

# %%
def p_gen_hm_w(i,j,p_values):
    a,b = wT.columns[i], wT.columns[j] 
    p = stats.pearsonr(wT[a][18:], wT[b][18:])
    notation = a + ' | ' + b
    p_values[notation] = p[1]
    
    return p_values

# %%
p_values = {}
p_values = p_gen_hm_w(0,1,p_values)

# %%
p_values = p_gen_hm_w(0,2,p_values)
p_values = p_gen_hm_w(0,3,p_values)
p_values = p_gen_hm_w(0,4,p_values)
p_values = p_gen_hm_w(0,5,p_values)
p_values = p_gen_hm_w(0,6,p_values)
p_values = p_gen_hm_w(0,7,p_values)
p_values = p_gen_hm_w(0,8,p_values)

p_values = p_gen_hm_w(1,2,p_values)
p_values = p_gen_hm_w(1,3,p_values)
p_values = p_gen_hm_w(1,4,p_values)
p_values = p_gen_hm_w(1,5,p_values)
p_values = p_gen_hm_w(1,6,p_values)
p_values = p_gen_hm_w(1,7,p_values)
p_values = p_gen_hm_w(1,8,p_values)

p_values = p_gen_hm_w(2,3,p_values)
p_values = p_gen_hm_w(2,4,p_values)
p_values = p_gen_hm_w(2,5,p_values)
p_values = p_gen_hm_w(2,6,p_values)
p_values = p_gen_hm_w(2,7,p_values)
p_values = p_gen_hm_w(2,8,p_values)

p_values = p_gen_hm_w(3,4,p_values)
p_values = p_gen_hm_w(3,5,p_values)
p_values = p_gen_hm_w(3,6,p_values)
p_values = p_gen_hm_w(3,7,p_values)
p_values = p_gen_hm_w(3,8,p_values)

p_values = p_gen_hm_w(4,5,p_values)
p_values = p_gen_hm_w(4,6,p_values)
p_values = p_gen_hm_w(4,7,p_values)
p_values = p_gen_hm_w(4,8,p_values)

p_values = p_gen_hm_w(5,6,p_values)
p_values = p_gen_hm_w(5,7,p_values)
p_values = p_gen_hm_w(5,8,p_values)

p_values = p_gen_hm_w(6,7,p_values)
p_values = p_gen_hm_w(6,8,p_values)

p_values = p_gen_hm_w(7,8,p_values)

p_values
# Out:
# {'Gabtoli Dhalwes | Gabtoli Turag': 0.0011593404684158994,
#  'Gabtoli Dhalwes | Shah Cement': 0.01688172339397065,
#  'Gabtoli Dhalwes | Hazaribag': 0.04077603153696984,
#  'Gabtoli Dhalwes | Rayerbazar': 3.1612558526369316e-06,
#  'Gabtoli Dhalwes | Kholamora': 0.0030853467511890134,
#  'Gabtoli Dhalwes | Zinzira': 0.0002665213965901073,
#  'Gabtoli Dhalwes | Sadarghat Terminal': 0.004070535606516923,
#  'Gabtoli Dhalwes | Postogola Bri': 0.01593963746733034,
#  'Gabtoli Turag | Shah Cement': 2.7007379442456274e-05,
#  'Gabtoli Turag | Hazaribag': 0.17971338334759474,
#  'Gabtoli Turag | Rayerbazar': 0.0052540501484198395,
#  'Gabtoli Turag | Kholamora': 2.5866152883048795e-08,
#  'Gabtoli Turag | Zinzira': 0.0002845227201583058,
#  'Gabtoli Turag | Sadarghat Terminal': 0.0624216459670924,
#  'Gabtoli Turag | Postogola Bri': 0.1625660181496564,
#  'Shah Cement | Hazaribag': 0.3358982851789129,
#  'Shah Cement | Rayerbazar': 0.047883237330029825,
#  'Shah Cement | Kholamora': 1.7327307076082124e-05,
#  'Shah Cement | Zinzira': 0.0025314886001868366,
#  'Shah Cement | Sadarghat Terminal': 0.16580652014058128,
#  'Shah Cement | Postogola Bri': 0.3556362398325534,
#  'Hazaribag | Rayerbazar': 0.022655434192689915,
#  'Hazaribag | Kholamora': 0.20978428504404864,
#  'Hazaribag | Zinzira': 0.03751835463650342,
#  'Hazaribag | Sadarghat Terminal': 0.01619140102445879,
#  'Hazaribag | Postogola Bri': 0.02453730273673509,
#  'Rayerbazar | Kholamora': 0.009177550660203882,
#  'Rayerbazar | Zinzira': 0.0011204873134124924,
#  'Rayerbazar | Sadarghat Terminal': 0.003128823230873349,
#  'Rayerbazar | Postogola Bri': 0.009160253568715755,
#  'Kholamora | Zinzira': 0.0007846007178954875,
#  'Kholamora | Sadarghat Terminal': 0.09347552914971889,
#  'Kholamora | Postogola Bri': 0.21829935676773138,
#  'Zinzira | Sadarghat Terminal': 0.023092868622325492,
#  'Zinzira | Postogola Bri': 0.0724339035584934,
#  'Sadarghat Terminal | Postogola Bri': 3.7340153635591096e-06}

# %%
hm_w = pd.DataFrame(data={
    "Point": p_values.keys(),
    "p value": p_values.values()
})
hm_w
# Out:
#                                    Point       p value
# 0        Gabtoli Dhalwes | Gabtoli Turag  1.159340e-03
# 1          Gabtoli Dhalwes | Shah Cement  1.688172e-02
# 2            Gabtoli Dhalwes | Hazaribag  4.077603e-02
# 3           Gabtoli Dhalwes | Rayerbazar  3.161256e-06
# 4            Gabtoli Dhalwes | Kholamora  3.085347e-03
# 5              Gabtoli Dhalwes | Zinzira  2.665214e-04
# 6   Gabtoli Dhalwes | Sadarghat Terminal  4.070536e-03
# 7        Gabtoli Dhalwes | Postogola Bri  1.593964e-02
# 8            Gabtoli Turag | Shah Cement  2.700738e-05
# 9              Gabtoli Turag | Hazaribag  1.797134e-01
# 10            Gabtoli Turag | Rayerbazar  5.254050e-03
# 11             Gabtoli Turag | Kholamora  2.586615e-08
# 12               Gabtoli Turag | Zinzira  2.845227e-04
# 13    Gabtoli Turag | Sadarghat Terminal  6.242165e-02
# 14         Gabtoli Turag | Postogola Bri  1.625660e-01
# 15               Shah Cement | Hazaribag  3.358983e-01
# 16              Shah Cement | Rayerbazar  4.788324e-02
# 17               Shah Cement | Kholamora  1.732731e-05
# 18                 Shah Cement | Zinzira  2.531489e-03
# 19      Shah Cement | Sadarghat Terminal  1.658065e-01
# 20           Shah Cement | Postogola Bri  3.556362e-01
# 21                Hazaribag | Rayerbazar  2.265543e-02
# 22                 Hazaribag | Kholamora  2.097843e-01
# 23                   Hazaribag | Zinzira  3.751835e-02
# 24        Hazaribag | Sadarghat Terminal  1.619140e-02
# 25             Hazaribag | Postogola Bri  2.453730e-02
# 26                Rayerbazar | Kholamora  9.177551e-03
# 27                  Rayerbazar | Zinzira  1.120487e-03
# 28       Rayerbazar | Sadarghat Terminal  3.128823e-03
# 29            Rayerbazar | Postogola Bri  9.160254e-03
# 30                   Kholamora | Zinzira  7.846007e-04
# 31        Kholamora | Sadarghat Terminal  9.347553e-02
# 32             Kholamora | Postogola Bri  2.182994e-01
# 33          Zinzira | Sadarghat Terminal  2.309287e-02
# 34               Zinzira | Postogola Bri  7.243390e-02
# 35    Sadarghat Terminal | Postogola Bri  3.734015e-06

# %%
temp_cod_s.to_excel("p_val/temp_cod_summer.xlsx")
temp_cod_w.to_excel("p_val/temp_cod_winter.xlsx")

hm_s.to_excel("p_val/hm_summer.xlsx")
hm_w.to_excel("p_val/hm_winter.xlsx")

# %%
summer
# Out:
#         SamplingPoint  Temperature    pH    EC  TSS  Turbidity  Salinity  \
# 0     Gabtoli Dhalwes         30.4  6.17  1790  309        108       639
# 1       Gabtoli Turag         30.7  5.89  1453  322        126       702
# 2         Shah Cement         32.7  5.02  2047  434        174       730
# 3           Hazaribag         32.8  4.37   538  461        162       360
# 4          Rayerbazar         29.5  6.59   692  178         82       244
# 5           Kholamora         32.2  5.33  1596  296         76       930
# 6             Zinzira         30.1  6.78  1963  302        108      1070
# 7  Sadarghat Terminal         32.9  4.11  2119  464        175      1156
# 8       Postogola Bri         32.4  5.24  2550  387        162      1332
#
#     TDS    DO   COD  ...    Br     Cd     Cr     Ni     Cu     Zn     Mn  \
# 0   852  0.96   700  ...  0.61  0.003  0.044  0.107  0.458  0.187  0.995
# 1  1208  0.73   718  ...  0.45  0.007  0.083  0.495  0.932  0.659  1.178
# 2   783  0.15   870  ...  0.42  0.018  0.082  0.149  1.597  0.573  1.073
# 3  1790  0.12   912  ...  0.66  2.100  1.139  0.065  0.988  0.602  3.450
# 4   825  1.10   655  ...  0.80  0.005  0.029  0.089  0.114  0.309  1.002
# 5  2009  0.51   725  ...  0.79  0.007  0.045  0.216  1.976  0.759  0.872
# 6  2036  1.39   530  ...  0.41  0.106  0.198  1.023  1.851  0.755  3.107
# 7  2377  0.00  1180  ...  0.35  0.193  1.133  0.451  0.633  0.442  2.456
# 8  1895  0.27   879  ...  0.32  0.069  0.370  0.385  0.115  0.292  1.114
#
#       Hg     As     Pb
# 0  0.009  0.109  0.188
# 1  0.027  0.102  0.452
# 2  0.108  0.063  0.337
# 3  0.176  0.098  1.836
# 4  0.093  0.057  0.119
# 5  0.017  0.075  0.178
# 6  0.089  0.112  1.457
# 7  0.255  0.161  2.144
# 8  0.198  0.059  1.075
#
# [9 rows x 28 columns]
