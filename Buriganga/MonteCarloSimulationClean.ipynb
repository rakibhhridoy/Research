# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/heavymetalSummer_Winter.csv")


param_adult= {
    "IR" : 2.5,
    "EF": 365,
    "ED": 70,
    "BW": 70,
    "AT": 365 * 70,
    "SA": 18000,
    "ET": 0.58,
    "CF": 10**-3,
    'Kp': {
        "Mn": 0.001,
        "Cr": 0.002,
        "Ni": 0.0002,
        "Cu": 0.001,
        "Zn": 0.0006,
        "As": 0.001,
        "Cd": 0.001,
        "Hg": 0.001,
        "Pb": 0.0001
    },
    'RfDing': {
        "Mn": 0.024,
        "Cr": 0.003,
        "Ni": 0.025,
        "Cu": 0.04,
        "Zn": 0.3,
        "As": 0.0003,
        "Cd": 0.0005,
        "Hg": 0.00016,
        "Pb": 0.0035
    },
    "RfDderm": {
        "Mn": 0.00096,
        "Cr": 0.0195,
        "Ni": 0.0054,
        "Cu": 0.04,
        "Zn": 0.06,
        "As": 0.0003,
        "Cd": 0.000025,
        "Hg": 0.00016,
        "Pb": 0.042
        
    },
    "CSFing": {
        "Cd": 0.38,
        "Cr": 0.5,
        "As": 1.5,
        "Pb": 0.0085,
        "Ni": 1.7
    },
    "CSFderm": {
        "Cd": 0.38,
        "Cr": 0.5,
        "As": 1.5,
        "Pb": 0.0085,
        "Ni": 1.7
    }
    

}

param_child= {
    "IR" : 0.64,
    "EF": 365,
    "ED": 6,
    "BW": 25,
    "AT": 365 * 6,
    "SA": 6600,
    "ET": 1,
    "CF": 10**-3,
    'Kp': {
        "Mn": 0.001,
        "Cr": 0.002,
        "Ni": 0.0002,
        "Cu": 0.001,
        "Zn": 0.0006,
        "As": 0.001,
        "Cd": 0.001,
        "Hg": 0.001,
        "Pb": 0.0001
    },
    'RfDing': {
        "Mn": 0.024,
        "Cr": 0.003,
        "Ni": 0.025,
        "Cu": 0.04,
        "Zn": 0.3,
        "As": 0.0003,
        "Cd": 0.0005,
        "Hg": 0.00016,
        "Pb": 0.0035
    },
    "RfDderm": {
        "Mn": 0.00096,
        "Cr": 0.0195,
        "Ni": 0.0054,
        "Cu": 0.04,
        "Zn": 0.06,
        "As": 0.0003,
        "Cd": 0.000025,
        "Hg": 0.00016,
        "Pb": 0.042
    },
    "CSFing": {
        "Cd": 0.38,
        "Cr": 0.5,
        "As": 1.5,
        "Pb": 0.0085,
        "Ni": 1.7
    },
    "CSFderm": {
        "Cd": 0.38,
        "Cr": 0.5,
        "As": 1.5,
        "Pb": 0.0085,
        "Ni": 1.7
    }
    

}

# %%
def HI_WA(df):
    shil = pd.DataFrame(data={
        "Cd": df.CdW,
        "Cr": df.CrW,
        "Ni": df.NiW,
        "Cu": df.CuW,
        "Zn": df.ZnW,
        "Mn": df.MnW,
        "Hg": df.HgW,
        "As": df.AsW,
        "Pb": df.PbW,
    })

    Mn = (shil["Mn"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cr = (shil["Cr"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Ni = (shil["Ni"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cu = (shil["Cu"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Zn = (shil["Zn"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    As = (shil["As"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cd = (shil["Cd"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Hg = (shil["Hg"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Pb = (shil["Pb"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])

    cdi_ing = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    hqMn = cdi_ing["Mn"] / param_adult["RfDing"]["Mn"]
    hqCr = cdi_ing["Cr"] / param_adult["RfDing"]["Cr"]
    hqCu = cdi_ing["Cu"] / param_adult["RfDing"]["Cu"]
    hqZn = cdi_ing["Zn"] / param_adult["RfDing"]["Zn"]
    hqAs = cdi_ing["As"] / param_adult["RfDing"]["As"]
    hqCd = cdi_ing["Cd"] / param_adult["RfDing"]["Cd"]
    hqHg = cdi_ing["Hg"] / param_adult["RfDing"]["Hg"]
    hqPb = cdi_ing["Pb"] / param_adult["RfDing"]["Pb"]
    hqNi = cdi_ing["Ni"] / param_adult["RfDing"]["Ni"]

    hq_ingwa = pd.DataFrame(data = {
        "Mn": hqMn,
        "Cr": hqCr,
        "Ni": hqNi,
        "Cu": hqCu,
        "Zn": hqZn,
        "As": hqAs,
        "Cd": hqCd,
        "Hg": hqHg,
        "Pb": hqPb
    }
    )

    Mn = (shil["Mn"] * param_adult["SA"] * param_adult["Kp"]["Mn"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cr = (shil["Cr"] * param_adult["SA"] * param_adult["Kp"]["Cr"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Ni = (shil["Ni"] * param_adult["SA"] * param_adult["Kp"]["Ni"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cu = (shil["Cu"] * param_adult["SA"] * param_adult["Kp"]["Cu"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Zn = (shil["Zn"] * param_adult["SA"] * param_adult["Kp"]["Zn"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    As = (shil["As"] * param_adult["SA"] * param_adult["Kp"]["As"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cd = (shil["Cd"] * param_adult["SA"] * param_adult["Kp"]["Cd"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Hg = (shil["Hg"] * param_adult["SA"] * param_adult["Kp"]["Hg"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Pb = (shil["Pb"] * param_adult["SA"] * param_adult["Kp"]["Pb"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])

    cdi_derm = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    hqMn = cdi_derm["Mn"] / param_adult["RfDderm"]["Mn"]
    hqCr = cdi_derm["Cr"] / param_adult["RfDderm"]["Cr"]
    hqCu = cdi_derm["Cu"] / param_adult["RfDderm"]["Cu"]
    hqZn = cdi_derm["Zn"] / param_adult["RfDderm"]["Zn"]
    hqAs = cdi_derm["As"] / param_adult["RfDderm"]["As"]
    hqCd = cdi_derm["Cd"] / param_adult["RfDderm"]["Cd"]
    hqHg = cdi_derm["Hg"] / param_adult["RfDderm"]["Hg"]
    hqPb = cdi_derm["Pb"] / param_adult["RfDderm"]["Pb"]
    hqNi = cdi_derm["Ni"] / param_adult["RfDderm"]["Ni"]

    hq_dermwa = pd.DataFrame(data = {
        "Mn": hqMn,
        "Cr": hqCr,
        "Ni": hqNi,
        "Cu": hqCu,
        "Zn": hqZn,
        "As": hqAs,
        "Cd": hqCd,
        "Hg": hqHg,
        "Pb": hqPb
    }
    )

    hi = hq_dermwa + hq_ingwa
    hiwa = hi.sum(axis=1)

    return hi, hiwa




def CR_WA(df):

    shil = pd.DataFrame(data={
        "Cd": df.CdW,
        "Cr": df.CrW,
        "Ni": df.NiW,
        "Cu": df.CuW,
        "Zn": df.ZnW,
        "Mn": df.MnW,
        "Hg": df.HgW,
        "As": df.AsW,
        "Pb": df.PbW,
    })

    Mn = (shil["Mn"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cr = (shil["Cr"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Ni = (shil["Ni"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cu = (shil["Cu"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Zn = (shil["Zn"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    As = (shil["As"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cd = (shil["Cd"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Hg = (shil["Hg"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Pb = (shil["Pb"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])

    cdi_ing = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    Mn = (shil["Mn"] * param_adult["SA"] * param_adult["Kp"]["Mn"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cr = (shil["Cr"] * param_adult["SA"] * param_adult["Kp"]["Cr"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Ni = (shil["Ni"] * param_adult["SA"] * param_adult["Kp"]["Ni"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cu = (shil["Cu"] * param_adult["SA"] * param_adult["Kp"]["Cu"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Zn = (shil["Zn"] * param_adult["SA"] * param_adult["Kp"]["Zn"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    As = (shil["As"] * param_adult["SA"] * param_adult["Kp"]["As"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cd = (shil["Cd"] * param_adult["SA"] * param_adult["Kp"]["Cd"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Hg = (shil["Hg"] * param_adult["SA"] * param_adult["Kp"]["Hg"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Pb = (shil["Pb"] * param_adult["SA"] * param_adult["Kp"]["Pb"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])

    cdi_derm = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    Cd = cdi_ing.Cd * param_adult["CSFing"]["Cd"]
    Cr = cdi_ing.Cr * param_adult["CSFing"]["Cr"]
    As = cdi_ing.As * param_adult["CSFing"]["As"]
    Pb = cdi_ing.Pb * param_adult["CSFing"]["Pb"]
    Ni = cdi_ing.Ni * param_adult["CSFing"]["Ni"]


    ilcr_ingwa = pd.DataFrame(data={
        "Cd": Cd,
        "Cr": Cr,
        "As": As,
        "Pb": Pb,
        "Ni": Ni
    })

    Cd = cdi_derm.Cd * param_adult["CSFderm"]["Cd"]
    Cr = cdi_derm.Cr * param_adult["CSFderm"]["Cr"]
    As = cdi_derm.As * param_adult["CSFderm"]["As"]
    Pb = cdi_derm.Pb * param_adult["CSFderm"]["Pb"]
    Ni = cdi_derm.Ni * param_adult["CSFderm"]["Ni"]

    ilcr_dermwa = pd.DataFrame(data={
        "Cd": Cd,
        "Cr": Cr,
        "As": As,
        "Pb": Pb,
        "Ni": Ni
    })

    ilcr = ilcr_ingwa + ilcr_dermwa
    ilcr_wadult = ilcr.sum(axis=1)

    return ilcr, ilcr_wadult




def HI_SA(df):
    shil = pd.DataFrame(data={
        "Cd": df.CdS,
        "Cr": df.CrS,
        "Ni": df.NiS,
        "Cu": df.CuS,
        "Zn": df.ZnS,
        "Mn": df.MnS,
        "Hg": df.HgS,
        "As": df.AsS,
        "Pb": df.PbS,
    })

    Mn = (shil["Mn"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cr = (shil["Cr"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Ni = (shil["Ni"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cu = (shil["Cu"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Zn = (shil["Zn"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    As = (shil["As"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cd = (shil["Cd"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Hg = (shil["Hg"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Pb = (shil["Pb"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])

    cdi_ing = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    hqMn = cdi_ing["Mn"] / param_adult["RfDing"]["Mn"]
    hqCr = cdi_ing["Cr"] / param_adult["RfDing"]["Cr"]
    hqCu = cdi_ing["Cu"] / param_adult["RfDing"]["Cu"]
    hqZn = cdi_ing["Zn"] / param_adult["RfDing"]["Zn"]
    hqAs = cdi_ing["As"] / param_adult["RfDing"]["As"]
    hqCd = cdi_ing["Cd"] / param_adult["RfDing"]["Cd"]
    hqHg = cdi_ing["Hg"] / param_adult["RfDing"]["Hg"]
    hqPb = cdi_ing["Pb"] / param_adult["RfDing"]["Pb"]
    hqNi = cdi_ing["Ni"] / param_adult["RfDing"]["Ni"]

    hq_ingsa = pd.DataFrame(data = {
        "Mn": hqMn,
        "Cr": hqCr,
        "Ni": hqNi,
        "Cu": hqCu,
        "Zn": hqZn,
        "As": hqAs,
        "Cd": hqCd,
        "Hg": hqHg,
        "Pb": hqPb
    }
    )

    Mn = (shil["Mn"] * param_adult["SA"] * param_adult["Kp"]["Mn"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cr = (shil["Cr"] * param_adult["SA"] * param_adult["Kp"]["Cr"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Ni = (shil["Ni"] * param_adult["SA"] * param_adult["Kp"]["Ni"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cu = (shil["Cu"] * param_adult["SA"] * param_adult["Kp"]["Cu"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Zn = (shil["Zn"] * param_adult["SA"] * param_adult["Kp"]["Zn"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    As = (shil["As"] * param_adult["SA"] * param_adult["Kp"]["As"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cd = (shil["Cd"] * param_adult["SA"] * param_adult["Kp"]["Cd"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Hg = (shil["Hg"] * param_adult["SA"] * param_adult["Kp"]["Hg"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Pb = (shil["Pb"] * param_adult["SA"] * param_adult["Kp"]["Pb"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])

    cdi_derm = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    hqMn = cdi_derm["Mn"] / param_adult["RfDderm"]["Mn"]
    hqCr = cdi_derm["Cr"] / param_adult["RfDderm"]["Cr"]
    hqCu = cdi_derm["Cu"] / param_adult["RfDderm"]["Cu"]
    hqZn = cdi_derm["Zn"] / param_adult["RfDderm"]["Zn"]
    hqAs = cdi_derm["As"] / param_adult["RfDderm"]["As"]
    hqCd = cdi_derm["Cd"] / param_adult["RfDderm"]["Cd"]
    hqHg = cdi_derm["Hg"] / param_adult["RfDderm"]["Hg"]
    hqPb = cdi_derm["Pb"] / param_adult["RfDderm"]["Pb"]
    hqNi = cdi_derm["Ni"] / param_adult["RfDderm"]["Ni"]

    hq_dermsa = pd.DataFrame(data = {
        "Mn": hqMn,
        "Cr": hqCr,
        "Ni": hqNi,
        "Cu": hqCu,
        "Zn": hqZn,
        "As": hqAs,
        "Cd": hqCd,
        "Hg": hqHg,
        "Pb": hqPb
    }
    )

    hi = hq_dermsa + hq_ingsa
    hisa = hi.sum(axis=1)

    return hi, hisa


def CR_SA(df):

    shil = pd.DataFrame(data={
        "Cd": df.CdS,
        "Cr": df.CrS,
        "Ni": df.NiS,
        "Cu": df.CuS,
        "Zn": df.ZnS,
        "Mn": df.MnS,
        "Hg": df.HgS,
        "As": df.AsS,
        "Pb": df.PbS,
    })

    Mn = (shil["Mn"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cr = (shil["Cr"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Ni = (shil["Ni"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cu = (shil["Cu"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Zn = (shil["Zn"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    As = (shil["As"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Cd = (shil["Cd"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Hg = (shil["Hg"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])
    Pb = (shil["Pb"] * param_adult["IR"] * param_adult["EF"] * param_adult["ED"])/ (param_adult["BW"]* param_adult["AT"])

    cdi_ing = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    Mn = (shil["Mn"] * param_adult["SA"] * param_adult["Kp"]["Mn"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cr = (shil["Cr"] * param_adult["SA"] * param_adult["Kp"]["Cr"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Ni = (shil["Ni"] * param_adult["SA"] * param_adult["Kp"]["Ni"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cu = (shil["Cu"] * param_adult["SA"] * param_adult["Kp"]["Cu"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Zn = (shil["Zn"] * param_adult["SA"] * param_adult["Kp"]["Zn"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    As = (shil["As"] * param_adult["SA"] * param_adult["Kp"]["As"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Cd = (shil["Cd"] * param_adult["SA"] * param_adult["Kp"]["Cd"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Hg = (shil["Hg"] * param_adult["SA"] * param_adult["Kp"]["Hg"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])
    Pb = (shil["Pb"] * param_adult["SA"] * param_adult["Kp"]["Pb"] * param_adult["ET"] * param_adult["EF"] * param_adult["ED"] * param_adult["CF"])/ (param_adult["BW"]* param_adult["AT"])

    cdi_derm = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    Cd = cdi_ing.Cd * param_adult["CSFing"]["Cd"]
    Cr = cdi_ing.Cr * param_adult["CSFing"]["Cr"]
    As = cdi_ing.As * param_adult["CSFing"]["As"]
    Pb = cdi_ing.Pb * param_adult["CSFing"]["Pb"]
    Ni = cdi_ing.Ni * param_adult["CSFing"]["Ni"]


    ilcr_ingsa = pd.DataFrame(data={
        "Cd": Cd,
        "Cr": Cr,
        "As": As,
        "Pb": Pb,
        "Ni": Ni
    })

    Cd = cdi_derm.Cd * param_adult["CSFderm"]["Cd"]
    Cr = cdi_derm.Cr * param_adult["CSFderm"]["Cr"]
    As = cdi_derm.As * param_adult["CSFderm"]["As"]
    Pb = cdi_derm.Pb * param_adult["CSFderm"]["Pb"]
    Ni = cdi_derm.Pb * param_adult["CSFderm"]["Ni"]


    ilcr_dermsa = pd.DataFrame(data={
        "Cd": Cd,
        "Cr": Cr,
        "As": As,
        "Pb": Pb,
        "Ni": Ni
    })

    ilcr = ilcr_ingsa + ilcr_dermsa
    ilcr_sadult = ilcr.sum(axis=1)

    return ilcr, ilcr_sadult




def random_genW(df):
    cdW = []
    crW = []
    niW = []
    cuW = []
    znW = []
    mnW = []
    hgW = []
    asW = []
    pbW = []

    metals = [cdW, 
            crW, 
            niW, 
            cuW, 
            znW, 
            mnW, 
            hgW, 
            asW, 
            pbW]

    def logic(x, elem):
        if x > 0:
            elem.append(x)


    metalsW = [df.CdW, 
            df.CrW, 
            df.NiW, 
            df.CuW,
            df.ZnW, 
            df.MnW,
            df.HgW, 
            df.AsW,
            df.PbW]



    for j in range(9):
        i = 0        
        while i < 10000:
            x = np.random.normal(metalsW[j].mean(), metalsW[j].std())
            logic(x, metals[j])    
            i = len(metals[j])
    return metals

def random_genS(df):
    cdS = []
    crS = []
    niS = []
    cuS = []
    znS = []
    mnS = []
    hgS = []
    asS = []
    pbS = []

    metals = [cdS, 
            crS, 
            niS, 
            cuS, 
            znS, 
            mnS, 
            hgS, 
            asS, 
            pbS]

    def logic(x, elem):
        if x > 0:
            elem.append(x)


    metalsS = [df.CdS, 
            df.CrS, 
            df.NiS, 
            df.CuS,
            df.ZnS, 
            df.MnS,
            df.HgS, 
            df.AsS,
            df.PbS]



    for j in range(9):
        i = 0        
        while i < 10000:
            x = np.random.normal(metalsS[j].mean(), metalsS[j].std())
            logic(x, metals[j])    
            i = len(metals[j])
    return metals

# %%
winter = ["Winter" for i in range(10000)]
summer = ["Summer" for i in range(10000)]

# %%
metalsW = random_genW(df)
dataW = pd.DataFrame(data={
        "CdW":metalsW[0],
        "CrW":metalsW[1],
        "NiW":metalsW[2],
        "CuW":metalsW[3],
        "ZnW":metalsW[4],
        "MnW":metalsW[5],
        "HgW":metalsW[6],
        "AsW":metalsW[7],
        "PbW":metalsW[8],
    })



metalsS = random_genS(df)
dataS = pd.DataFrame(data={
        "CdS":metalsS[0],
        "CrS":metalsS[1],
        "NiS":metalsS[2],
        "CuS":metalsS[3],
        "ZnS":metalsS[4],
        "MnS":metalsS[5],
        "HgS":metalsS[6],
        "AsS":metalsS[7],
        "PbS":metalsS[8],
    })


dataW.to_csv("monteData/simul/orig_dataW.csv")
dataS.to_csv("monteData/simul/orig_dataS.csv")



rawHiW, hiWA = HI_WA(dataW)
rawHiS, hiSA = HI_SA(dataS)

rawCRW, crWA = CR_WA(dataW)
rawCRS, crSA = CR_SA(dataS)



Whi = pd.DataFrame(data={
    "Values": hiWA,
    "Seasons": winter
})

Shi = pd.DataFrame(data={
    "Values": hiSA,
    "Seasons": summer
})

Wcr = pd.DataFrame(data={
    "Values": crWA,
    "Seasons": winter
})

Scr = pd.DataFrame(data={
    "Values": crSA,
    "Seasons": summer
})



hiA = pd.concat([Whi, Shi])
crA = pd.concat([Wcr, Scr])


hiA.to_csv("monteData/simul/hiA_orig.csv")
crA.to_csv("monteData/simul/crA_orig.csv")

# %%
def iteration(df, n):
    
    for i in range(n):
        metalsW = random_genW(df)
        dataW = pd.DataFrame(data={
                "CdW":metalsW[0],
                "CrW":metalsW[1],
                "NiW":metalsW[2],
                "CuW":metalsW[3],
                "ZnW":metalsW[4],
                "MnW":metalsW[5],
                "HgW":metalsW[6],
                "AsW":metalsW[7],
                "PbW":metalsW[8],
            })



        metalsS = random_genS(df)
        dataS = pd.DataFrame(data={
                "CdS":metalsS[0],
                "CrS":metalsS[1],
                "NiS":metalsS[2],
                "CuS":metalsS[3],
                "ZnS":metalsS[4],
                "MnS":metalsS[5],
                "HgS":metalsS[6],
                "AsS":metalsS[7],
                "PbS":metalsS[8],
            })


        dataW.to_csv("monteData/simul/orig_dataW{}.csv".format(i))
        dataS.to_csv("monteData/simul/orig_dataS{}.csv".format(i))



        rawHiW, hiWA = HI_WA(dataW)
        rawHiS, hiSA = HI_SA(dataS)

        rawCRW, crWA = CR_WA(dataW)
        rawCRS, crSA = CR_SA(dataS)



        crWA.to_csv("monteData/simul/crWA{}.csv".format(i))
        crSA.to_csv("monteData/simul/crSA{}.csv".format(i))

        hiWA.to_csv("monteData/simul/hiWA{}.csv".format(i))
        hiSA.to_csv("monteData/simul/hiSA{}.csv".format(i))

        Whi = pd.DataFrame(data={
            "Values": hiWA,
            "Seasons": winter
        })

        Shi = pd.DataFrame(data={
            "Values": hiSA,
            "Seasons": summer
        })

        Wcr = pd.DataFrame(data={
            "Values": crWA,
            "Seasons": winter
        })

        Scr = pd.DataFrame(data={
            "Values": crSA,
            "Seasons": summer
        })



        hiA = pd.concat([Whi, Shi])
        crA = pd.concat([Wcr, Scr])


        hiA.to_csv("monteData/simul/hiA_orig{}.csv".format(i))
        crA.to_csv("monteData/simul/crA_orig{}.csv".format(i))

        
        print("Mean of hiWA{}: {}".format(i, hiWA.mean() ))
        print("Mean of hiSA{}: {}".format(i, hiSA.mean()))

        print("Mean of crWA{}: {}".format(i, crWA.mean()))
        print("Mean of crSA{}: {}".format(i, crSA.mean()))
        print("===========================")
        print("===========================")

# %%
iteration(df, 100)
# Out:
# Mean of hiWA0: 104.2920840079835
# Mean of hiSA0: 111.77499297669972
# Mean of crWA0: 0.0552686609787688
# Mean of crSA0: 0.048692599965626075
# ===========================
# ===========================
# Mean of hiWA1: 104.37225344224382
# Mean of hiSA1: 111.69456098444878
# Mean of crWA1: 0.05578125400924856
# Mean of crSA1: 0.0486005023234925
# ===========================
# ===========================
# Mean of hiWA2: 104.59542266441117
# Mean of hiSA2: 111.79846842860898
# Mean of crWA2: 0.055699933440172995
# Mean of crSA2: 0.04878775003341736
# ===========================
# ===========================
# Mean of hiWA3: 104.29825054314145
# Mean of hiSA3: 111.9154169757872
# Mean of crWA3: 0.0555648706381383
# Mean of crSA3: 0.048656266004137805
# ===========================
# ===========================
# Mean of hiWA4: 104.74697173371169
# Mean of hiSA4: 111.12726507018735
# Mean of crWA4: 0.055503659398643775
# Mean of crSA4: 0.04865475570080291
# ===========================
# ===========================
# Mean of hiWA5: 104.16546498969895
# Mean of hiSA5: 112.72554058232235
# Mean of crWA5: 0.05590467948886726
# Mean of crSA5: 0.04884197402508017
# ===========================
# ===========================
# Mean of hiWA6: 104.06157413422673
# Mean of hiSA6: 112.5866216926131
# Mean of crWA6: 0.05547070792382018
# Mean of crSA6: 0.04875080839421375
# ===========================
# ===========================
# Mean of hiWA7: 104.70093686692181
# Mean of hiSA7: 111.96113729936548
# Mean of crWA7: 0.05584185468092406
# Mean of crSA7: 0.04868845500891098
# ===========================
# ===========================
# Mean of hiWA8: 104.07480306303962
# Mean of hiSA8: 112.55693484924673
# Mean of crWA8: 0.05574501098403832
# Mean of crSA8: 0.04851197255643253
# ===========================
# ===========================
# Mean of hiWA9: 105.08784496644179
# Mean of hiSA9: 112.41460897501157
# Mean of crWA9: 0.05549610981551111
# Mean of crSA9: 0.048507924379019005
# ===========================
# ===========================
# Mean of hiWA10: 104.33883328901138
# Mean of hiSA10: 111.83524004664989
# Mean of crWA10: 0.05566029013355761
# Mean of crSA10: 0.048598821263758196
# ===========================
# ===========================
# Mean of hiWA11: 105.32013264173482
# Mean of hiSA11: 112.0255483608207
# Mean of crWA11: 0.05550215900331125
# Mean of crSA11: 0.04906257396186276
# ===========================
# ===========================
# Mean of hiWA12: 104.30539038877998
# Mean of hiSA12: 112.61044916059677
# Mean of crWA12: 0.05565288746086793
# Mean of crSA12: 0.04882782068481644
# ===========================
# ===========================
# Mean of hiWA13: 104.53779828137996
# Mean of hiSA13: 112.45027928786506
# Mean of crWA13: 0.055823301993829684
# Mean of crSA13: 0.04879250839446605
# ===========================
# ===========================
# Mean of hiWA14: 104.20254154946083
# Mean of hiSA14: 112.24559668013455
# Mean of crWA14: 0.05534999582014791
# Mean of crSA14: 0.04890418815325602
# ===========================
# ===========================
# Mean of hiWA15: 105.48837965128571
# Mean of hiSA15: 112.05543167108381
# Mean of crWA15: 0.05575221463158622
# Mean of crSA15: 0.04869613155877078
# ===========================
# ===========================
# Mean of hiWA16: 104.83286394025258
# Mean of hiSA16: 112.14631595254046
# Mean of crWA16: 0.05577784194594744
# Mean of crSA16: 0.04858513179333175
# ===========================
# ===========================
# Mean of hiWA17: 105.18114181866274
# Mean of hiSA17: 112.24885325600188
# Mean of crWA17: 0.05549444350891821
# Mean of crSA17: 0.048734377621902476
# ===========================
# ===========================
# Mean of hiWA18: 104.86783566125084
# Mean of hiSA18: 111.92503570081652
# Mean of crWA18: 0.0558332259481997
# Mean of crSA18: 0.048294794646722296
# ===========================
# ===========================
# Mean of hiWA19: 104.38088016403904
# Mean of hiSA19: 112.01190989072035
# Mean of crWA19: 0.05566454549180692
# Mean of crSA19: 0.048820259467339686
# ===========================
# ===========================
# Mean of hiWA20: 104.94664437498687
# Mean of hiSA20: 111.54354087025062
# Mean of crWA20: 0.05554635535367276
# Mean of crSA20: 0.048957387730528726
# ===========================
# ===========================
# Mean of hiWA21: 104.42793412631183
# Mean of hiSA21: 112.67235856697631
# Mean of crWA21: 0.055256656203978856
# Mean of crSA21: 0.04881337483719344
# ===========================
# ===========================
# Mean of hiWA22: 104.63773589208229
# Mean of hiSA22: 112.64312762201745
# Mean of crWA22: 0.05526277891311043
# Mean of crSA22: 0.048925025967418295
# ===========================
# ===========================
# Mean of hiWA23: 104.86362420290497
# Mean of hiSA23: 111.75306672431762
# Mean of crWA23: 0.055430512567793105
# Mean of crSA23: 0.04856401715738154
# ===========================
# ===========================
# Mean of hiWA24: 104.35836615217679
# Mean of hiSA24: 111.48687733783933
# Mean of crWA24: 0.05525463497157622
# Mean of crSA24: 0.04845813014233143
# ===========================
# ===========================
# Mean of hiWA25: 104.32001411604435
# Mean of hiSA25: 111.73503156445982
# Mean of crWA25: 0.0556162956760253
# Mean of crSA25: 0.048738358778616916
# ===========================
# ===========================
# Mean of hiWA26: 104.42429227114454
# Mean of hiSA26: 112.28617439524214
# Mean of crWA26: 0.05558130739768208
# Mean of crSA26: 0.04845515327680879
# ===========================
# ===========================
# Mean of hiWA27: 105.10450941238669
# Mean of hiSA27: 112.02977142597753
# Mean of crWA27: 0.05527467442963613
# Mean of crSA27: 0.04874122364901164
# ===========================
# ===========================
# Mean of hiWA28: 105.01084032178474
# Mean of hiSA28: 112.49261375217431
# Mean of crWA28: 0.05547071695003462
# Mean of crSA28: 0.04862664113463876
# ===========================
# ===========================
# Mean of hiWA29: 104.46050497319389
# Mean of hiSA29: 112.53374373827273
# Mean of crWA29: 0.055272399351736536
# Mean of crSA29: 0.048822673855193496
# ===========================
# ===========================
# Mean of hiWA30: 104.0977134270161
# Mean of hiSA30: 111.60530335937906
# Mean of crWA30: 0.05515069566872032
# Mean of crSA30: 0.04858123707124058
# ===========================
# ===========================
# Mean of hiWA31: 104.09591174277813
# Mean of hiSA31: 112.25077866109743
# Mean of crWA31: 0.05528955604478966
# Mean of crSA31: 0.048644306254147514
# ===========================
# ===========================
# Mean of hiWA32: 105.28456612307701
# Mean of hiSA32: 112.23879195210942
# Mean of crWA32: 0.05563937083116752
# Mean of crSA32: 0.048648702046578875
# ===========================
# ===========================
# Mean of hiWA33: 104.02092653804917
# Mean of hiSA33: 112.33504499618137
# Mean of crWA33: 0.05533723546609102
# Mean of crSA33: 0.048469001071973446
# ===========================
# ===========================
# Mean of hiWA34: 103.96381733467496
# Mean of hiSA34: 111.6797472422861
# Mean of crWA34: 0.05523427033938901
# Mean of crSA34: 0.04871763682725912
# ===========================
# ===========================
# Mean of hiWA35: 103.74221617494679
# Mean of hiSA35: 112.38091780334075
# Mean of crWA35: 0.05511139977291714
# Mean of crSA35: 0.048835389874323315
# ===========================
# ===========================
# Mean of hiWA36: 103.64602429065059
# Mean of hiSA36: 111.79743411672958
# Mean of crWA36: 0.05553123307721116
# Mean of crSA36: 0.048485429287537705
# ===========================
# ===========================
# Mean of hiWA37: 104.97114915173822
# Mean of hiSA37: 111.84997307565813
# Mean of crWA37: 0.055509911983805706
# Mean of crSA37: 0.0486491021379131
# ===========================
# ===========================
# Mean of hiWA38: 104.43105894017083
# Mean of hiSA38: 112.21008951085567
# Mean of crWA38: 0.05592378924294036
# Mean of crSA38: 0.04857743249893059
# ===========================
# ===========================
# Mean of hiWA39: 104.59155248982215
# Mean of hiSA39: 111.730204653221
# Mean of crWA39: 0.05581829233574206
# Mean of crSA39: 0.04875016579812569
# ===========================
# ===========================
# Mean of hiWA40: 105.00153427542048
# Mean of hiSA40: 112.32675148217874
# Mean of crWA40: 0.05550375896788101
# Mean of crSA40: 0.04905201366894079
# ===========================
# ===========================
# Mean of hiWA41: 104.90374658190774
# Mean of hiSA41: 111.81818592243076
# Mean of crWA41: 0.05542305788359243
# Mean of crSA41: 0.04850492325872904
# ===========================
# ===========================
# Mean of hiWA42: 104.71226165381913
# Mean of hiSA42: 112.15900379264008
# Mean of crWA42: 0.05581589603256316
# Mean of crSA42: 0.04872749977438156
# ===========================
# ===========================
# Mean of hiWA43: 103.74878082836837
# Mean of hiSA43: 112.10846569675063
# Mean of crWA43: 0.05561441702457555
# Mean of crSA43: 0.04889785943762174
# ===========================
# ===========================
# Mean of hiWA44: 104.17738585900867
# Mean of hiSA44: 112.38899434580081
# Mean of crWA44: 0.05530325162133098
# Mean of crSA44: 0.04893523246829399
# ===========================
# ===========================
# Mean of hiWA45: 104.0241264672645
# Mean of hiSA45: 112.6637452731841
# Mean of crWA45: 0.05541165818040054
# Mean of crSA45: 0.0486872213228074
# ===========================
# ===========================
# Mean of hiWA46: 103.7319461597236
# Mean of hiSA46: 112.40439839174105
# Mean of crWA46: 0.05580310539222364
# Mean of crSA46: 0.04883298129098959
# ===========================
# ===========================
# Mean of hiWA47: 103.83565361957366
# Mean of hiSA47: 111.7170876584122
# Mean of crWA47: 0.05555168669577504
# Mean of crSA47: 0.04875725536368805
# ===========================
# ===========================
# Mean of hiWA48: 104.72204742467203
# Mean of hiSA48: 111.42615665654789
# Mean of crWA48: 0.05580984156719372
# Mean of crSA48: 0.04874107008641636
# ===========================
# ===========================
# Mean of hiWA49: 104.10019363709978
# Mean of hiSA49: 112.02977749767345
# Mean of crWA49: 0.05575293886832061
# Mean of crSA49: 0.04908829810967021
# ===========================
# ===========================
# Mean of hiWA50: 105.04690235821158
# Mean of hiSA50: 112.27973673903158
# Mean of crWA50: 0.0557002615399376
# Mean of crSA50: 0.04889921479430327
# ===========================
# ===========================
# Mean of hiWA51: 104.08115478155399
# Mean of hiSA51: 111.8162742919928
# Mean of crWA51: 0.055591631200088275
# Mean of crSA51: 0.04876396114523756
# ===========================
# ===========================
# Mean of hiWA52: 104.8437953838722
# Mean of hiSA52: 111.62800961134496
# Mean of crWA52: 0.05584285124541283
# Mean of crSA52: 0.048739548597286526
# ===========================
# ===========================
# Mean of hiWA53: 104.57344286674729
# Mean of hiSA53: 112.00367759864973
# Mean of crWA53: 0.05548907677929841
# Mean of crSA53: 0.04877887297776478
# ===========================
# ===========================
# Mean of hiWA54: 105.06402585983226
# Mean of hiSA54: 111.84713245385825
# Mean of crWA54: 0.05581091053427831
# Mean of crSA54: 0.04860142067375714
# ===========================
# ===========================
# Mean of hiWA55: 104.89793912707268
# Mean of hiSA55: 112.61464402501909
# Mean of crWA55: 0.05583251611127361
# Mean of crSA55: 0.04869648368724287
# ===========================
# ===========================
# Mean of hiWA56: 104.64561000511227
# Mean of hiSA56: 112.34999462556728
# Mean of crWA56: 0.055573033965712296
# Mean of crSA56: 0.04883378138885798
# ===========================
# ===========================
# Mean of hiWA57: 105.00042333195516
# Mean of hiSA57: 111.95249252709152
# Mean of crWA57: 0.05543844787327769
# Mean of crSA57: 0.048527493617256466
# ===========================
# ===========================
# Mean of hiWA58: 104.61700825028588
# Mean of hiSA58: 112.24847997792345
# Mean of crWA58: 0.05532874591143435
# Mean of crSA58: 0.0485291326753614
# ===========================
# ===========================
# Mean of hiWA59: 104.58433673611263
# Mean of hiSA59: 112.73306635339011
# Mean of crWA59: 0.055865697914648876
# Mean of crSA59: 0.04871426274872046
# ===========================
# ===========================
# Mean of hiWA60: 104.17102816002027
# Mean of hiSA60: 111.98393624034154
# Mean of crWA60: 0.05546908698808121
# Mean of crSA60: 0.04861874223659464
# ===========================
# ===========================
# Mean of hiWA61: 104.28471070635709
# Mean of hiSA61: 112.00015147683979
# Mean of crWA61: 0.055223021587843674
# Mean of crSA61: 0.048796956238166336
# ===========================
# ===========================
# Mean of hiWA62: 104.4905058121479
# Mean of hiSA62: 112.48620474766153
# Mean of crWA62: 0.055415111073636544
# Mean of crSA62: 0.048762588760202695
# ===========================
# ===========================
# Mean of hiWA63: 104.36432936795882
# Mean of hiSA63: 112.42296297036373
# Mean of crWA63: 0.055536330191216066
# Mean of crSA63: 0.04874128893401698
# ===========================
# ===========================
# Mean of hiWA64: 104.49529871096782
# Mean of hiSA64: 111.47689773549028
# Mean of crWA64: 0.05542824815749144
# Mean of crSA64: 0.04833331986089338
# ===========================
# ===========================
# Mean of hiWA65: 105.13646076704403
# Mean of hiSA65: 112.45727185689667
# Mean of crWA65: 0.05553073298673787
# Mean of crSA65: 0.0487309488564539
# ===========================
# ===========================
# Mean of hiWA66: 104.79209733653671
# Mean of hiSA66: 111.88673304791786
# Mean of crWA66: 0.055635557271619736
# Mean of crSA66: 0.04874833742304032
# ===========================
# ===========================
# Mean of hiWA67: 104.27067357830963
# Mean of hiSA67: 112.07842468751241
# Mean of crWA67: 0.055748000079338916
# Mean of crSA67: 0.04866916072585607
# ===========================
# ===========================
# Mean of hiWA68: 104.1852051621344
# Mean of hiSA68: 112.50476345723062
# Mean of crWA68: 0.05532039655723031
# Mean of crSA68: 0.048536608850755815
# ===========================
# ===========================
# Mean of hiWA69: 104.23503042409871
# Mean of hiSA69: 112.76490468452278
# Mean of crWA69: 0.05552852499591458
# Mean of crSA69: 0.04853704904886527
# ===========================
# ===========================
# Mean of hiWA70: 104.03601361603727
# Mean of hiSA70: 111.82986824251265
# Mean of crWA70: 0.05514321515005059
# Mean of crSA70: 0.048566618318179954
# ===========================
# ===========================
# Mean of hiWA71: 104.84567694247255
# Mean of hiSA71: 112.83293286597856
# Mean of crWA71: 0.05558228941595789
# Mean of crSA71: 0.04863994695322044
# ===========================
# ===========================
# Mean of hiWA72: 104.19266459869019
# Mean of hiSA72: 111.93169051352216
# Mean of crWA72: 0.0554159914919274
# Mean of crSA72: 0.048753067821647435
# ===========================
# ===========================
# Mean of hiWA73: 104.56527101519404
# Mean of hiSA73: 112.27769277991557
# Mean of crWA73: 0.05546905705558039
# Mean of crSA73: 0.04869671167654692
# ===========================
# ===========================
# Mean of hiWA74: 105.32239051656167
# Mean of hiSA74: 111.51265411283954
# Mean of crWA74: 0.05610118227044917
# Mean of crSA74: 0.0490819777546395
# ===========================
# ===========================
# Mean of hiWA75: 104.77378755702965
# Mean of hiSA75: 111.93569485810164
# Mean of crWA75: 0.055377897084183725
# Mean of crSA75: 0.04896905265970444
# ===========================
# ===========================
# Mean of hiWA76: 104.77711666762957
# Mean of hiSA76: 112.14165989855319
# Mean of crWA76: 0.05541223058919253
# Mean of crSA76: 0.048501197393859545
# ===========================
# ===========================
# Mean of hiWA77: 104.15749520696376
# Mean of hiSA77: 113.15203994303697
# Mean of crWA77: 0.05555914269038455
# Mean of crSA77: 0.04883467384412599
# ===========================
# ===========================
# Mean of hiWA78: 103.83885195751114
# Mean of hiSA78: 112.27430643744708
# Mean of crWA78: 0.05514232712226702
# Mean of crSA78: 0.04883463388593995
# ===========================
# ===========================
# Mean of hiWA79: 104.38307630531418
# Mean of hiSA79: 111.7684950464668
# Mean of crWA79: 0.05558200002805202
# Mean of crSA79: 0.04860957429558272
# ===========================
# ===========================
# Mean of hiWA80: 105.18858990295196
# Mean of hiSA80: 112.26692233773589
# Mean of crWA80: 0.055735980402237796
# Mean of crSA80: 0.04864260494001995
# ===========================
# ===========================
# Mean of hiWA81: 104.52378476139077
# Mean of hiSA81: 112.64861218840471
# Mean of crWA81: 0.0555687659219502
# Mean of crSA81: 0.048763696825283975
# ===========================
# ===========================
# Mean of hiWA82: 104.44343273413139
# Mean of hiSA82: 111.97907923582045
# Mean of crWA82: 0.05566598523899707
# Mean of crSA82: 0.04852233083187687
# ===========================
# ===========================
# Mean of hiWA83: 104.43922967040234
# Mean of hiSA83: 112.14772877360133
# Mean of crWA83: 0.055438363055540195
# Mean of crSA83: 0.04879730167970947
# ===========================
# ===========================
# Mean of hiWA84: 104.53455441053582
# Mean of hiSA84: 111.77775257594486
# Mean of crWA84: 0.05496996740279742
# Mean of crSA84: 0.04864643143696318
# ===========================
# ===========================
# Mean of hiWA85: 104.72468943065613
# Mean of hiSA85: 112.20813799435713
# Mean of crWA85: 0.0555027774671441
# Mean of crSA85: 0.04891738698152907
# ===========================
# ===========================
# Mean of hiWA86: 104.83389734983784
# Mean of hiSA86: 111.90887294451647
# Mean of crWA86: 0.05556809954648575
# Mean of crSA86: 0.04840820309368583
# ===========================
# ===========================
# Mean of hiWA87: 104.44299449507068
# Mean of hiSA87: 111.99870514368138
# Mean of crWA87: 0.05530064957332962
# Mean of crSA87: 0.0487986803194488
# ===========================
# ===========================
# Mean of hiWA88: 104.73343818910465
# Mean of hiSA88: 112.16958243910207
# Mean of crWA88: 0.055433089986765376
# Mean of crSA88: 0.048582321440901785
# ===========================
# ===========================
# Mean of hiWA89: 105.16740663668236
# Mean of hiSA89: 112.58811488176053
# Mean of crWA89: 0.055667326294157125
# Mean of crSA89: 0.048719850929941334
# ===========================
# ===========================
# Mean of hiWA90: 104.63050624087424
# Mean of hiSA90: 112.43362514454178
# Mean of crWA90: 0.05593106356426296
# Mean of crSA90: 0.04891556341474831
# ===========================
# ===========================
# Mean of hiWA91: 104.3375526928403
# Mean of hiSA91: 112.36262202202282
# Mean of crWA91: 0.05547868382757427
# Mean of crSA91: 0.04839276320447131
# ===========================
# ===========================
# Mean of hiWA92: 104.4947123339712
# Mean of hiSA92: 112.9301839193432
# Mean of crWA92: 0.05585160593165008
# Mean of crSA92: 0.04887164763846604
# ===========================
# ===========================
# Mean of hiWA93: 104.77481239836794
# Mean of hiSA93: 112.24009476851028
# Mean of crWA93: 0.05544249789745864
# Mean of crSA93: 0.04895721776316115
# ===========================
# ===========================
# Mean of hiWA94: 104.6088773550107
# Mean of hiSA94: 111.90868949094803
# Mean of crWA94: 0.05538373569893814
# Mean of crSA94: 0.048702774349100156
# ===========================
# ===========================
# Mean of hiWA95: 104.92725993979217
# Mean of hiSA95: 112.29932950272304
# Mean of crWA95: 0.05561319723389694
# Mean of crSA95: 0.04838002692266904
# ===========================
# ===========================
# Mean of hiWA96: 105.0256428307401
# Mean of hiSA96: 113.0308592594126
# Mean of crWA96: 0.05545592785998581
# Mean of crSA96: 0.04887679241971517
# ===========================
# ===========================
# Mean of hiWA97: 104.54408699935335
# Mean of hiSA97: 112.16268431955152
# Mean of crWA97: 0.055311343329936195
# Mean of crSA97: 0.04883844416033514
# ===========================
# ===========================
# Mean of hiWA98: 104.27472400574015
# Mean of hiSA98: 112.28776607438317
# Mean of crWA98: 0.05522935012880604
# Mean of crSA98: 0.04889938226607371
# ===========================
# ===========================
# Mean of hiWA99: 104.3014128222693
# Mean of hiSA99: 111.74503691043176
# Mean of crWA99: 0.05504941098432573
# Mean of crSA99: 0.04865828325011333
# ===========================
# ===========================

# %% [markdown]
# # Child

# %%
def HI_SC(df):
    
    shil = pd.DataFrame(data={
        "Cd": df.CdS,
        "Cr": df.CrS,
        "Ni": df.NiS,
        "Cu": df.CuS,
        "Zn": df.ZnS,
        "Mn": df.MnS,
        "Hg": df.HgS,
        "As": df.AsS,
        "Pb": df.PbS,
    })

    Mn = (shil["Mn"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cr = (shil["Cr"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Ni = (shil["Ni"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cu = (shil["Cu"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Zn = (shil["Zn"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    As = (shil["As"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cd = (shil["Cd"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Hg = (shil["Hg"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Pb = (shil["Pb"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])

    cdi_ing = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    hqMn = cdi_ing["Mn"] / param_child["RfDing"]["Mn"]
    hqCr = cdi_ing["Cr"] / param_child["RfDing"]["Cr"]
    hqCu = cdi_ing["Cu"] / param_child["RfDing"]["Cu"]
    hqZn = cdi_ing["Zn"] / param_child["RfDing"]["Zn"]
    hqAs = cdi_ing["As"] / param_child["RfDing"]["As"]
    hqCd = cdi_ing["Cd"] / param_child["RfDing"]["Cd"]
    hqHg = cdi_ing["Hg"] / param_child["RfDing"]["Hg"]
    hqPb = cdi_ing["Pb"] / param_child["RfDing"]["Pb"]
    hqNi = cdi_ing["Ni"] / param_child["RfDing"]["Ni"]

    hq_ingsc = pd.DataFrame(data = {
        "Mn": hqMn,
        "Cr": hqCr,
        "Ni": hqNi,
        "Cu": hqCu,
        "Zn": hqZn,
        "As": hqAs,
        "Cd": hqCd,
        "Hg": hqHg,
        "Pb": hqPb
    }
    )

    Mn = (shil["Mn"] * param_child["SA"] * param_child["Kp"]["Mn"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cr = (shil["Cr"] * param_child["SA"] * param_child["Kp"]["Cr"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Ni = (shil["Ni"] * param_child["SA"] * param_child["Kp"]["Ni"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cu = (shil["Cu"] * param_child["SA"] * param_child["Kp"]["Cu"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Zn = (shil["Zn"] * param_child["SA"] * param_child["Kp"]["Zn"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    As = (shil["As"] * param_child["SA"] * param_child["Kp"]["As"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cd = (shil["Cd"] * param_child["SA"] * param_child["Kp"]["Cd"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Hg = (shil["Hg"] * param_child["SA"] * param_child["Kp"]["Hg"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Pb = (shil["Pb"] * param_child["SA"] * param_child["Kp"]["Pb"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])

    cdi_derm = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    hqMn = cdi_derm["Mn"] / param_child["RfDderm"]["Mn"]
    hqCr = cdi_derm["Cr"] / param_child["RfDderm"]["Cr"]
    hqCu = cdi_derm["Cu"] / param_child["RfDderm"]["Cu"]
    hqZn = cdi_derm["Zn"] / param_child["RfDderm"]["Zn"]
    hqAs = cdi_derm["As"] / param_child["RfDderm"]["As"]
    hqCd = cdi_derm["Cd"] / param_child["RfDderm"]["Cd"]
    hqHg = cdi_derm["Hg"] / param_child["RfDderm"]["Hg"]
    hqPb = cdi_derm["Pb"] / param_child["RfDderm"]["Pb"]
    hqNi = cdi_derm["Ni"] / param_child["RfDderm"]["Ni"]

    hq_dermsc = pd.DataFrame(data = {
        "Mn": hqMn,
        "Cr": hqCr,
        "Ni": hqNi,
        "Cu": hqCu,
        "Zn": hqZn,
        "As": hqAs,
        "Cd": hqCd,
        "Hg": hqHg,
        "Pb": hqPb
    }
    )

    hi = hq_dermsc + hq_ingsc
    hisc = hi.sum(axis=1)
    return hi, hisc

def CR_SC(df):

    shil = pd.DataFrame(data={
        "Cd": df.CdS,
        "Cr": df.CrS,
        "Ni": df.NiS,
        "Cu": df.CuS,
        "Zn": df.ZnS,
        "Mn": df.MnS,
        "Hg": df.HgS,
        "As": df.AsS,
        "Pb": df.PbS,
    })

    Mn = (shil["Mn"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cr = (shil["Cr"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Ni = (shil["Ni"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cu = (shil["Cu"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Zn = (shil["Zn"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    As = (shil["As"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cd = (shil["Cd"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Hg = (shil["Hg"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Pb = (shil["Pb"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])

    cdi_ing = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    Mn = (shil["Mn"] * param_child["SA"] * param_child["Kp"]["Mn"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cr = (shil["Cr"] * param_child["SA"] * param_child["Kp"]["Cr"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Ni = (shil["Ni"] * param_child["SA"] * param_child["Kp"]["Ni"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cu = (shil["Cu"] * param_child["SA"] * param_child["Kp"]["Cu"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Zn = (shil["Zn"] * param_child["SA"] * param_child["Kp"]["Zn"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    As = (shil["As"] * param_child["SA"] * param_child["Kp"]["As"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cd = (shil["Cd"] * param_child["SA"] * param_child["Kp"]["Cd"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Hg = (shil["Hg"] * param_child["SA"] * param_child["Kp"]["Hg"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Pb = (shil["Pb"] * param_child["SA"] * param_child["Kp"]["Pb"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])

    cdi_derm = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    Cd = cdi_ing.Cd * param_child["CSFing"]["Cd"]
    Cr = cdi_ing.Cr * param_child["CSFing"]["Cr"]
    As = cdi_ing.As * param_child["CSFing"]["As"]
    Pb = cdi_ing.Pb * param_child["CSFing"]["Pb"]
    Ni = cdi_ing.Ni * param_child["CSFing"]["Ni"]

    ilcr_ingsc = pd.DataFrame(data={
        "Cd": Cd,
        "Cr": Cr,
        "As": As,
        "Pb": Pb,
        "Ni": Ni
    })

    Cd = cdi_derm.Cd * param_child["CSFderm"]["Cd"]
    Cr = cdi_derm.Cr * param_child["CSFderm"]["Cr"]
    As = cdi_derm.As * param_child["CSFderm"]["As"]
    Pb = cdi_derm.Pb * param_child["CSFderm"]["Pb"]
    Ni = cdi_derm.Ni * param_child["CSFderm"]["Ni"]


    ilcr_dermsc = pd.DataFrame(data={
        "Cd": Cd,
        "Cr": Cr,
        "As": As,
        "Pb": Pb,
        "Ni": Ni
    })

    ilcr = ilcr_ingsc + ilcr_dermsc
    ilcr_schild = ilcr.sum(axis=1)
    return ilcr, ilcr_schild

# %%
def HI_WC(df):
    shil = pd.DataFrame(data={
        "Cd": df.CdW,
        "Cr": df.CrW,
        "Ni": df.NiW,
        "Cu": df.CuW,
        "Zn": df.ZnW,
        "Mn": df.MnW,
        "Hg": df.HgW,
        "As": df.AsW,
        "Pb": df.PbW,
    })

    Mn = (shil["Mn"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cr = (shil["Cr"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Ni = (shil["Ni"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cu = (shil["Cu"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Zn = (shil["Zn"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    As = (shil["As"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cd = (shil["Cd"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Hg = (shil["Hg"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Pb = (shil["Pb"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])

    cdi_ing = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    hqMn = cdi_ing["Mn"] / param_child["RfDing"]["Mn"]
    hqCr = cdi_ing["Cr"] / param_child["RfDing"]["Cr"]
    hqCu = cdi_ing["Cu"] / param_child["RfDing"]["Cu"]
    hqZn = cdi_ing["Zn"] / param_child["RfDing"]["Zn"]
    hqAs = cdi_ing["As"] / param_child["RfDing"]["As"]
    hqCd = cdi_ing["Cd"] / param_child["RfDing"]["Cd"]
    hqHg = cdi_ing["Hg"] / param_child["RfDing"]["Hg"]
    hqPb = cdi_ing["Pb"] / param_child["RfDing"]["Pb"]
    hqNi = cdi_ing["Ni"] / param_child["RfDing"]["Ni"]

    hq_ingwc = pd.DataFrame(data = {
        "Mn": hqMn,
        "Cr": hqCr,
        "Ni": hqNi,
        "Cu": hqCu,
        "Zn": hqZn,
        "As": hqAs,
        "Cd": hqCd,
        "Hg": hqHg,
        "Pb": hqPb
    }
    )

    Mn = (shil["Mn"] * param_child["SA"] * param_child["Kp"]["Mn"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cr = (shil["Cr"] * param_child["SA"] * param_child["Kp"]["Cr"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Ni = (shil["Ni"] * param_child["SA"] * param_child["Kp"]["Ni"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cu = (shil["Cu"] * param_child["SA"] * param_child["Kp"]["Cu"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Zn = (shil["Zn"] * param_child["SA"] * param_child["Kp"]["Zn"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    As = (shil["As"] * param_child["SA"] * param_child["Kp"]["As"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cd = (shil["Cd"] * param_child["SA"] * param_child["Kp"]["Cd"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Hg = (shil["Hg"] * param_child["SA"] * param_child["Kp"]["Hg"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Pb = (shil["Pb"] * param_child["SA"] * param_child["Kp"]["Pb"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])

    cdi_derm = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    hqMn = cdi_derm["Mn"] / param_child["RfDderm"]["Mn"]
    hqCr = cdi_derm["Cr"] / param_child["RfDderm"]["Cr"]
    hqCu = cdi_derm["Cu"] / param_child["RfDderm"]["Cu"]
    hqZn = cdi_derm["Zn"] / param_child["RfDderm"]["Zn"]
    hqAs = cdi_derm["As"] / param_child["RfDderm"]["As"]
    hqCd = cdi_derm["Cd"] / param_child["RfDderm"]["Cd"]
    hqHg = cdi_derm["Hg"] / param_child["RfDderm"]["Hg"]
    hqPb = cdi_derm["Pb"] / param_child["RfDderm"]["Pb"]
    hqNi = cdi_derm["Ni"] / param_child["RfDderm"]["Ni"]

    hq_dermwc = pd.DataFrame(data = {
        "Mn": hqMn,
        "Cr": hqCr,
        "Ni": hqNi,
        "Cu": hqCu,
        "Zn": hqZn,
        "As": hqAs,
        "Cd": hqCd,
        "Hg": hqHg,
        "Pb": hqPb
    }
    )

    hi = hq_dermwc + hq_ingwc
    hiwc = hi.sum(axis=1)
    return hi, hiwc


def CR_WC(df):
    shil = pd.DataFrame(data={
        "Cd": df.CdW,
        "Cr": df.CrW,
        "Ni": df.NiW,
        "Cu": df.CuW,
        "Zn": df.ZnW,
        "Mn": df.MnW,
        "Hg": df.HgW,
        "As": df.AsW,
        "Pb": df.PbW,
    })


    Mn = (shil["Mn"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cr = (shil["Cr"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Ni = (shil["Ni"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cu = (shil["Cu"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Zn = (shil["Zn"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    As = (shil["As"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Cd = (shil["Cd"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Hg = (shil["Hg"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])
    Pb = (shil["Pb"] * param_child["IR"] * param_child["EF"] * param_child["ED"])/ (param_child["BW"]* param_child["AT"])

    cdi_ing = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    Mn = (shil["Mn"] * param_child["SA"] * param_child["Kp"]["Mn"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cr = (shil["Cr"] * param_child["SA"] * param_child["Kp"]["Cr"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Ni = (shil["Ni"] * param_child["SA"] * param_child["Kp"]["Ni"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cu = (shil["Cu"] * param_child["SA"] * param_child["Kp"]["Cu"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Zn = (shil["Zn"] * param_child["SA"] * param_child["Kp"]["Zn"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    As = (shil["As"] * param_child["SA"] * param_child["Kp"]["As"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Cd = (shil["Cd"] * param_child["SA"] * param_child["Kp"]["Cd"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Hg = (shil["Hg"] * param_child["SA"] * param_child["Kp"]["Hg"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])
    Pb = (shil["Pb"] * param_child["SA"] * param_child["Kp"]["Pb"] * param_child["ET"] * param_child["EF"] * param_child["ED"] * param_child["CF"])/ (param_child["BW"]* param_child["AT"])

    cdi_derm = pd.DataFrame(data = {
        "Mn": Mn,
        "Cr": Cr,
        "Ni": Ni,
        "Cu": Cu,
        "Zn": Zn,
        "As": As,
        "Cd": Cd,
        "Hg": Hg,
        "Pb": Pb
    }
    )

    Cd = cdi_ing.Cd * param_child["CSFing"]["Cd"]
    Cr = cdi_ing.Cr * param_child["CSFing"]["Cr"]
    As = cdi_ing.As * param_child["CSFing"]["As"]
    Pb = cdi_ing.Pb * param_child["CSFing"]["Pb"]
    Ni = cdi_ing.Ni * param_child["CSFing"]["Ni"]

    ilcr_ingwc = pd.DataFrame(data={
        "Cd": Cd,
        "Cr": Cr,
        "As": As,
        "Pb": Pb,
        "Ni": Ni
    })

    Cd = cdi_derm.Cd * param_child["CSFderm"]["Cd"]
    Cr = cdi_derm.Cr * param_child["CSFderm"]["Cr"]
    As = cdi_derm.As * param_child["CSFderm"]["As"]
    Pb = cdi_derm.Pb * param_child["CSFderm"]["Pb"]
    Ni = cdi_derm.Ni * param_child["CSFderm"]["Ni"]


    ilcr_dermwc = pd.DataFrame(data={
        "Cd": Cd,
        "Cr": Cr,
        "As": As,
        "Pb": Pb,
        "Ni": Ni
    })

    ilcr = ilcr_ingwc + ilcr_dermwc
    ilcr_wchild = ilcr.sum(axis=1)
    return ilcr, ilcr_wchild

# %%
def iterationC(df, n):
    
    for i in range(n):
        metalsW = random_genW(df)
        dataW = pd.DataFrame(data={
                "CdW":metalsW[0],
                "CrW":metalsW[1],
                "NiW":metalsW[2],
                "CuW":metalsW[3],
                "ZnW":metalsW[4],
                "MnW":metalsW[5],
                "HgW":metalsW[6],
                "AsW":metalsW[7],
                "PbW":metalsW[8],
            })



        metalsS = random_genS(df)
        dataS = pd.DataFrame(data={
                "CdS":metalsS[0],
                "CrS":metalsS[1],
                "NiS":metalsS[2],
                "CuS":metalsS[3],
                "ZnS":metalsS[4],
                "MnS":metalsS[5],
                "HgS":metalsS[6],
                "AsS":metalsS[7],
                "PbS":metalsS[8],
            })


        dataW.to_csv("monteData/simul/orig_dataWC{}.csv".format(i))
        dataS.to_csv("monteData/simul/orig_dataSC{}.csv".format(i))



        rawHiW, hiWC = HI_WC(dataW)
        rawHiS, hiSC = HI_SC(dataS)

        rawCRW, crWC = CR_WC(dataW)
        rawCRS, crSC = CR_SC(dataS)



        crWC.to_csv("monteData/simul/crWC{}.csv".format(i))
        crSC.to_csv("monteData/simul/crSC{}.csv".format(i))

        hiWC.to_csv("monteData/simul/hiWC{}.csv".format(i))
        hiSC.to_csv("monteData/simul/hiSC{}.csv".format(i))

        Whi = pd.DataFrame(data={
            "Values": hiWC,
            "Seasons": winter
        })

        Shi = pd.DataFrame(data={
            "Values": hiSC,
            "Seasons": summer
        })

        Wcr = pd.DataFrame(data={
            "Values": crWC,
            "Seasons": winter
        })

        Scr = pd.DataFrame(data={
            "Values": crSC,
            "Seasons": summer
        })



        hiA = pd.concat([Whi, Shi])
        crA = pd.concat([Wcr, Scr])


        hiA.to_csv("monteData/simul/hiA_origC{}.csv".format(i))
        crA.to_csv("monteData/simul/crA_origC{}.csv".format(i))

        
        print("Mean of hiWC{}: {}".format(i, hiWC.mean() ))
        print("Mean of hiSC{}: {}".format(i, hiSC.mean()))

        print("Mean of crWC{}: {}".format(i, crWC.mean()))
        print("Mean of crSC{}: {}".format(i, crSC.mean()))
        print("===========================")
        print("===========================")

# %%
iterationC(df, 100)

# %% [markdown]
# ```
# Mean of hiWC0: 79.5878493504077
# Mean of hiSC0: 84.85142885140947
# Mean of crWC0: 0.04002725309659229
# Mean of crSC0: 0.034871563681091615
# ===========================
# ===========================
# Mean of hiWC1: 79.77293361750998
# Mean of hiSC1: 85.05178803456437
# Mean of crWC1: 0.03987092594625834
# Mean of crSC1: 0.034933074361510344
# ===========================
# ===========================
# Mean of hiWC2: 79.74827046486658
# Mean of hiSC2: 85.48101946512367
# Mean of crWC2: 0.04015348538596632
# Mean of crSC2: 0.03510671820356545
# ===========================
# ===========================
# Mean of hiWC3: 79.69550063421966
# Mean of hiSC3: 85.50005586941917
# Mean of crWC3: 0.03990662546071179
# Mean of crSC3: 0.03485401651516535
# ===========================
# ===========================
# Mean of hiWC4: 79.74836343876825
# Mean of hiSC4: 85.12170132082018
# Mean of crWC4: 0.04035717371422195
# Mean of crSC4: 0.03510997052745795
# ===========================
# ===========================
# Mean of hiWC5: 80.24481497786005
# Mean of hiSC5: 85.05164696771605
# Mean of crWC5: 0.03998115823161231
# Mean of crSC5: 0.035163796388172124
# ===========================
# ===========================
# Mean of hiWC6: 79.50411434347014
# Mean of hiSC6: 84.98910662882454
# Mean of crWC6: 0.040179640102596656
# Mean of crSC6: 0.03495339404112957
# ===========================
# ===========================
# Mean of hiWC7: 80.13376649501078
# Mean of hiSC7: 85.4313603522494
# Mean of crWC7: 0.039950711415665856
# Mean of crSC7: 0.035163913563964484
# ===========================
# ===========================
# Mean of hiWC8: 79.32079232836848
# Mean of hiSC8: 85.1715464794367
# Mean of crWC8: 0.03976452502893059
# Mean of crSC8: 0.03540308296121369
# ===========================
# ===========================
# Mean of hiWC9: 79.71068929582816
# Mean of hiSC9: 85.72575032188367
# Mean of crWC9: 0.03996040183583471
# Mean of crSC9: 0.03491154123777473
# ===========================
# ===========================
# Mean of hiWC10: 80.21895763699398
# Mean of hiSC10: 85.36303608965163
# Mean of crWC10: 0.04029165366036453
# Mean of crSC10: 0.03493612624562451
# ===========================
# ===========================
# Mean of hiWC11: 79.82456752673288
# Mean of hiSC11: 85.1402065922794
# Mean of crWC11: 0.039810447216856434
# Mean of crSC11: 0.035020471813082495
# ===========================
# ===========================
# Mean of hiWC12: 79.79603988940485
# Mean of hiSC12: 84.80470985860178
# Mean of crWC12: 0.040192684739547985
# Mean of crSC12: 0.03502282330386596
# ===========================
# ===========================
# Mean of hiWC13: 79.81261010162304
# Mean of hiSC13: 84.75734887938913
# Mean of crWC13: 0.03963290898880772
# Mean of crSC13: 0.034788124084153854
# ===========================
# ===========================
# Mean of hiWC14: 79.61769466024082
# Mean of hiSC14: 84.88488697498634
# Mean of crWC14: 0.03980764725336394
# Mean of crSC14: 0.03525611280748821
# ===========================
# ===========================
# Mean of hiWC15: 79.47218945890077
# Mean of hiSC15: 84.80741190591668
# Mean of crWC15: 0.04004135775698051
# Mean of crSC15: 0.03514693222500296
# ===========================
# ===========================
# Mean of hiWC16: 79.66655677870622
# Mean of hiSC16: 85.05540106630315
# Mean of crWC16: 0.04002625376979693
# Mean of crSC16: 0.03496734113198184
# ===========================
# ===========================
# Mean of hiWC17: 80.24317138713447
# Mean of hiSC17: 85.37703223344086
# Mean of crWC17: 0.0402164426081823
# Mean of crSC17: 0.03518774579182389
# ===========================
# ===========================
# Mean of hiWC18: 79.72820977682707
# Mean of hiSC18: 85.17345707803014
# Mean of crWC18: 0.040145705428377344
# Mean of crSC18: 0.035068409283008924
# ===========================
# ===========================
# Mean of hiWC19: 79.66248614075279
# Mean of hiSC19: 85.49222521331393
# Mean of crWC19: 0.03984341316145028
# Mean of crSC19: 0.03522964437618764
# ===========================
# ===========================
# Mean of hiWC20: 80.0304551190766
# Mean of hiSC20: 84.9221275422823
# Mean of crWC20: 0.040186593721516735
# Mean of crSC20: 0.03496373398946674
# ===========================
# ===========================
# Mean of hiWC21: 79.85862848085394
# Mean of hiSC21: 85.54218403098834
# Mean of crWC21: 0.04002670834252011
# Mean of crSC21: 0.03531739319519057
# ===========================
# ===========================
# Mean of hiWC22: 80.01656093887739
# Mean of hiSC22: 84.65198922346292
# Mean of crWC22: 0.03991345451612912
# Mean of crSC22: 0.03502724260216336
# ===========================
# ===========================
# Mean of hiWC23: 79.614828498556
# Mean of hiSC23: 85.09925628186672
# Mean of crWC23: 0.03981160681693961
# Mean of crSC23: 0.035196766452551244
# ===========================
# ===========================
# Mean of hiWC24: 79.57857819742611
# Mean of hiSC24: 85.54906621952466
# Mean of crWC24: 0.03964469219412021
# Mean of crSC24: 0.035340454919196546
# ===========================
# ===========================
# Mean of hiWC25: 79.61827394860664
# Mean of hiSC25: 85.27317127077046
# Mean of crWC25: 0.03982342217742317
# Mean of crSC25: 0.03503431629992587
# ===========================
# ===========================
# Mean of hiWC26: 79.92977277162136
# Mean of hiSC26: 85.18332852003816
# Mean of crWC26: 0.03986873145298139
# Mean of crSC26: 0.0350556336194634
# ===========================
# ===========================
# Mean of hiWC27: 79.36380474273929
# Mean of hiSC27: 84.83022328567947
# Mean of crWC27: 0.039789950565159125
# Mean of crSC27: 0.03501700449724034
# ===========================
# ===========================
# Mean of hiWC28: 80.10317144754028
# Mean of hiSC28: 84.84799243465422
# Mean of crWC28: 0.040061765052496756
# Mean of crSC28: 0.035037996227047265
# ===========================
# ===========================
# Mean of hiWC29: 79.90564227669765
# Mean of hiSC29: 85.2682458336388
# Mean of crWC29: 0.039911512908517924
# Mean of crSC29: 0.03510761827858342
# ===========================
# ===========================
# Mean of hiWC30: 79.61361238815002
# Mean of hiSC30: 85.24734162322467
# Mean of crWC30: 0.04017504495300145
# Mean of crSC30: 0.035329554556119365
# ===========================
# ===========================
# Mean of hiWC31: 79.94646446565481
# Mean of hiSC31: 85.19851366356377
# Mean of crWC31: 0.04016118373810093
# Mean of crSC31: 0.03514177327518533
# ===========================
# ===========================
# Mean of hiWC32: 79.93574670287282
# Mean of hiSC32: 85.34936614146788
# Mean of crWC32: 0.04007991222048738
# Mean of crSC32: 0.03520742800095463
# ===========================
# ===========================
# Mean of hiWC33: 79.74249075392625
# Mean of hiSC33: 85.56880913544533
# Mean of crWC33: 0.040040242429981825
# Mean of crSC33: 0.03519313182061287
# ===========================
# ===========================
# Mean of hiWC34: 79.92590394358065
# Mean of hiSC34: 85.32280027923512
# Mean of crWC34: 0.039800645210093924
# Mean of crSC34: 0.03487935807526669
# ===========================
# ===========================
# Mean of hiWC35: 79.68861810742459
# Mean of hiSC35: 85.12057051289216
# Mean of crWC35: 0.039892855215277884
# Mean of crSC35: 0.03498601161332012
# ===========================
# ===========================
# Mean of hiWC36: 79.36578407881848
# Mean of hiSC36: 85.10532930419086
# Mean of crWC36: 0.039815538224182004
# Mean of crSC36: 0.034842804440434125
# ===========================
# ===========================
# Mean of hiWC37: 80.14946983481255
# Mean of hiSC37: 85.1597902640383
# Mean of crWC37: 0.03979099776205714
# Mean of crSC37: 0.035119174893764135
# ===========================
# ===========================
# Mean of hiWC38: 79.92137482330921
# Mean of hiSC38: 85.22258390503967
# Mean of crWC38: 0.040051725001258885
# Mean of crSC38: 0.03529246006551341
# ===========================
# ===========================
# Mean of hiWC39: 79.54343678238135
# Mean of hiSC39: 84.89698452728376
# Mean of crWC39: 0.0399304906664856
# Mean of crSC39: 0.035073624186389506
# ===========================
# ===========================
# Mean of hiWC40: 79.67731129670419
# Mean of hiSC40: 85.35413207274165
# Mean of crWC40: 0.04003927188748213
# Mean of crSC40: 0.03518546391705199
# ===========================
# ===========================
# Mean of hiWC41: 79.4831078193068
# Mean of hiSC41: 84.71001418886449
# Mean of crWC41: 0.039999403235123895
# Mean of crSC41: 0.03499689994227393
# ===========================
# ===========================
# Mean of hiWC42: 79.391149670417
# Mean of hiSC42: 85.06436716407512
# Mean of crWC42: 0.03996188376125094
# Mean of crSC42: 0.035061987738711047
# ===========================
# ===========================
# Mean of hiWC43: 79.66709217349441
# Mean of hiSC43: 84.89776285361238
# Mean of crWC43: 0.03980071196419641
# Mean of crSC43: 0.035095772079510354
# ===========================
# ===========================
# Mean of hiWC44: 79.68769089851419
# Mean of hiSC44: 84.86152878249625
# Mean of crWC44: 0.03998237600055224
# Mean of crSC44: 0.03517464750470517
# ===========================
# ===========================
# Mean of hiWC45: 80.02309274216412
# Mean of hiSC45: 85.51835400915837
# Mean of crWC45: 0.03991883673187307
# Mean of crSC45: 0.03508857370582855
# ===========================
# ===========================
# Mean of hiWC46: 79.73420190086678
# Mean of hiSC46: 84.86111105979921
# Mean of crWC46: 0.03993953232610004
# Mean of crSC46: 0.0349335218638131
# ===========================
# ===========================
# Mean of hiWC47: 80.07161957953312
# Mean of hiSC47: 84.45085648162525
# Mean of crWC47: 0.04014280933437032
# Mean of crSC47: 0.03513337091959241
# ===========================
# ===========================
# Mean of hiWC48: 79.85571669879471
# Mean of hiSC48: 84.94931118204889
# Mean of crWC48: 0.040049439299604216
# Mean of crSC48: 0.03522294967733721
# ===========================
# ===========================
# Mean of hiWC49: 79.63856588284065
# Mean of hiSC49: 84.79048143340454
# Mean of crWC49: 0.040087438715004836
# Mean of crSC49: 0.03504298464386727
# ===========================
# ===========================
# Mean of hiWC50: 79.92714115143498
# Mean of hiSC50: 85.04767440422364
# Mean of crWC50: 0.0399762786493082
# Mean of crSC50: 0.03533751096004419
# ===========================
# ===========================
# Mean of hiWC51: 79.54457205818166
# Mean of hiSC51: 84.80812132229926
# Mean of crWC51: 0.039974417388149705
# Mean of crSC51: 0.03540995941382657
# ===========================
# ===========================
# Mean of hiWC52: 80.25475332252545
# Mean of hiSC52: 85.27910558706894
# Mean of crWC52: 0.039807968208318355
# Mean of crSC52: 0.03505937461224107
# ===========================
# ===========================
# Mean of hiWC53: 79.89576094116653
# Mean of hiSC53: 84.75797368163325
# Mean of crWC53: 0.04009817626639151
# Mean of crSC53: 0.034934762284342336
# ===========================
# ===========================
# Mean of hiWC54: 79.8245306815084
# Mean of hiSC54: 85.19227649186915
# Mean of crWC54: 0.0400589905262609
# Mean of crSC54: 0.035024308605008055
# ===========================
# ===========================
# Mean of hiWC55: 80.16897956329038
# Mean of hiSC55: 84.52770870508806
# Mean of crWC55: 0.04015429374755525
# Mean of crSC55: 0.034920229468209864
# ===========================
# ===========================
# Mean of hiWC56: 79.86278196628808
# Mean of hiSC56: 84.77913879354567
# Mean of crWC56: 0.03987690116957406
# Mean of crSC56: 0.03505577556048899
# ===========================
# ===========================
# Mean of hiWC57: 79.20645991207618
# Mean of hiSC57: 84.84422464789577
# Mean of crWC57: 0.039761279486448836
# Mean of crSC57: 0.03503368631957396
# ===========================
# ===========================
# Mean of hiWC58: 80.14732298807995
# Mean of hiSC58: 85.1774849606199
# Mean of crWC58: 0.03998331348734696
# Mean of crSC58: 0.035113565205704994
# ===========================
# ===========================
# Mean of hiWC59: 79.92481949844668
# Mean of hiSC59: 85.29245701437172
# Mean of crWC59: 0.04004812528582955
# Mean of crSC59: 0.035077056591652375
# ===========================
# ===========================
# Mean of hiWC60: 79.8514809954299
# Mean of hiSC60: 84.96162554440936
# Mean of crWC60: 0.040125192301171946
# Mean of crSC60: 0.03519969616743533
# ===========================
# ===========================
# Mean of hiWC61: 79.67070822832997
# Mean of hiSC61: 84.53653240866831
# Mean of crWC61: 0.04004856352123665
# Mean of crSC61: 0.034997752989302015
# ===========================
# ===========================
# Mean of hiWC62: 79.73347165040899
# Mean of hiSC62: 84.66587053691688
# Mean of crWC62: 0.04006252552243398
# Mean of crSC62: 0.034930831943728056
# ===========================
# ===========================
# Mean of hiWC63: 80.02459259394162
# Mean of hiSC63: 85.34499000358952
# Mean of crWC63: 0.040163368067709246
# Mean of crSC63: 0.035077293246167186
# ===========================
# ===========================
# Mean of hiWC64: 79.59378319675196
# Mean of hiSC64: 85.1888511805595
# Mean of crWC64: 0.03994223390165575
# Mean of crSC64: 0.035209127726425274
# ===========================
# ===========================
# Mean of hiWC65: 79.85357751708823
# Mean of hiSC65: 84.6570059299252
# Mean of crWC65: 0.04013863696575404
# Mean of crSC65: 0.0351628493557267
# ===========================
# ===========================
# Mean of hiWC66: 79.76478493555469
# Mean of hiSC66: 84.9353717514499
# Mean of crWC66: 0.039755554037926806
# Mean of crSC66: 0.03504775360939755
# ===========================
# ===========================
# Mean of hiWC67: 79.76388543273892
# Mean of hiSC67: 84.33866215534705
# Mean of crWC67: 0.039725426185725665
# Mean of crSC67: 0.034885230207487045
# ===========================
# ===========================
# Mean of hiWC68: 79.60609534254102
# Mean of hiSC68: 85.10394842190382
# Mean of crWC68: 0.03997815691203926
# Mean of crSC68: 0.03500427969029984
# ===========================
# ===========================
# Mean of hiWC69: 79.60433794390478
# Mean of hiSC69: 85.22902660369783
# Mean of crWC69: 0.03986098346869319
# Mean of crSC69: 0.03541855407090882
# ===========================
# ===========================
# Mean of hiWC70: 79.59503562652813
# Mean of hiSC70: 85.28742492044695
# Mean of crWC70: 0.04015541926833979
# Mean of crSC70: 0.035120458439894614
# ===========================
# ===========================
# Mean of hiWC71: 79.83858021362897
# Mean of hiSC71: 84.51395302015976
# Mean of crWC71: 0.03988425904987922
# Mean of crSC71: 0.034943797177107015
# ===========================
# ===========================
# Mean of hiWC72: 79.56602682346
# Mean of hiSC72: 84.7445878657345
# Mean of crWC72: 0.04001217419149888
# Mean of crSC72: 0.03507943944707008
# ===========================
# ===========================
# Mean of hiWC73: 79.76401287092969
# Mean of hiSC73: 85.15869097342949
# Mean of crWC73: 0.039962866223454845
# Mean of crSC73: 0.035074562319709505
# ===========================
# ===========================
# Mean of hiWC74: 79.79085858475594
# Mean of hiSC74: 85.066606840708
# Mean of crWC74: 0.03997453608196253
# Mean of crSC74: 0.03511448128930318
# ===========================
# ===========================
# Mean of hiWC75: 79.41948665090904
# Mean of hiSC75: 85.45491024995918
# Mean of crWC75: 0.0399766854178465
# Mean of crSC75: 0.03529814868718743
# ===========================
# ===========================
# Mean of hiWC76: 79.5358181994074
# Mean of hiSC76: 84.53817993841979
# Mean of crWC76: 0.040099025354967066
# Mean of crSC76: 0.03495159187313108
# ===========================
# ===========================
# Mean of hiWC77: 79.72921278642832
# Mean of hiSC77: 84.90244371270315
# Mean of crWC77: 0.03992565986253715
# Mean of crSC77: 0.0352215393165063
# ===========================
# ===========================
# Mean of hiWC78: 80.14587835855065
# Mean of hiSC78: 85.31988257242992
# Mean of crWC78: 0.039847559489620474
# Mean of crSC78: 0.03517048363165823
# ===========================
# ===========================
# Mean of hiWC79: 79.78488789341624
# Mean of hiSC79: 85.4258439923739
# Mean of crWC79: 0.04001727938603588
# Mean of crSC79: 0.03523473653522176
# ===========================
# ===========================
# Mean of hiWC80: 80.41503421681983
# Mean of hiSC80: 84.97188207014915
# Mean of crWC80: 0.04003987536613694
# Mean of crSC80: 0.03507028202915268
# ===========================
# ===========================
# Mean of hiWC81: 80.3251288663407
# Mean of hiSC81: 85.1259493958171
# Mean of crWC81: 0.04035204064653888
# Mean of crSC81: 0.03507782844939274
# ===========================
# ===========================
# Mean of hiWC82: 79.80273054864715
# Mean of hiSC82: 85.23262922994685
# Mean of crWC82: 0.03995790293615009
# Mean of crSC82: 0.03511520827703102
# ===========================
# ===========================
# Mean of hiWC83: 78.85619434714292
# Mean of hiSC83: 85.07557541819493
# Mean of crWC83: 0.03974400951419833
# Mean of crSC83: 0.03485709740640457
# ===========================
# ===========================
# Mean of hiWC84: 80.14070340122322
# Mean of hiSC84: 85.4379447998303
# Mean of crWC84: 0.03997918900953826
# Mean of crSC84: 0.03507017082435779
# ===========================
# ===========================
# Mean of hiWC85: 79.7800515550941
# Mean of hiSC85: 85.31986909438932
# Mean of crWC85: 0.040102684583957944
# Mean of crSC85: 0.035161407095592026
# ===========================
# ===========================
# Mean of hiWC86: 79.44908934307234
# Mean of hiSC86: 85.39198398624423
# Mean of crWC86: 0.039894941551476715
# Mean of crSC86: 0.03536634928252971
# ===========================
# ===========================
# Mean of hiWC87: 79.60626274495655
# Mean of hiSC87: 84.79033633687436
# Mean of crWC87: 0.03989744501233165
# Mean of crSC87: 0.035116974407639195
# ===========================
# ===========================
# Mean of hiWC88: 79.32925753400744
# Mean of hiSC88: 85.22005874666581
# Mean of crWC88: 0.03984410425968173
# Mean of crSC88: 0.035236280831671976
# ===========================
# ===========================
# Mean of hiWC89: 80.1115509129692
# Mean of hiSC89: 85.0816962047605
# Mean of crWC89: 0.03995955874688233
# Mean of crSC89: 0.03500012214121705
# ===========================
# ===========================
# Mean of hiWC90: 80.04387715557283
# Mean of hiSC90: 85.13464111071727
# Mean of crWC90: 0.03992339093744532
# Mean of crSC90: 0.03502174849249141
# ===========================
# ===========================
# Mean of hiWC91: 80.18583700100426
# Mean of hiSC91: 84.9167263757146
# Mean of crWC91: 0.03985539739615318
# Mean of crSC91: 0.03495513458489351
# ===========================
# ===========================
# Mean of hiWC92: 80.2074817372128
# Mean of hiSC92: 85.2792050307471
# Mean of crWC92: 0.0401323830284358
# Mean of crSC92: 0.03496947744902923
# ===========================
# ===========================
# Mean of hiWC93: 79.71936592151337
# Mean of hiSC93: 85.27513330263129
# Mean of crWC93: 0.039916461592682445
# Mean of crSC93: 0.03525149719430151
# ===========================
# ===========================
# Mean of hiWC94: 79.41683809950584
# Mean of hiSC94: 85.55863826319221
# Mean of crWC94: 0.03983863668530248
# Mean of crSC94: 0.03519266766916946
# ===========================
# ===========================
# Mean of hiWC95: 79.59478840804981
# Mean of hiSC95: 85.05326015515585
# Mean of crWC95: 0.03993182208963038
# Mean of crSC95: 0.03524455819532811
# ===========================
# ===========================
# Mean of hiWC96: 79.73874182747434
# Mean of hiSC96: 85.85871148799869
# Mean of crWC96: 0.039923013314926384
# Mean of crSC96: 0.035105676662146854
# ===========================
# ===========================
# Mean of hiWC97: 79.78382522621447
# Mean of hiSC97: 85.25784415121547
# Mean of crWC97: 0.0399276526445227
# Mean of crSC97: 0.03506570392295666
# ===========================
# ===========================
# Mean of hiWC98: 79.93928656700454
# Mean of hiSC98: 85.46917772193939
# Mean of crWC98: 0.040188199114386015
# Mean of crSC98: 0.0350271035476936
# ===========================
# ===========================
# Mean of hiWC99: 79.41341547342645
# Mean of hiSC99: 85.16689401313158
# Mean of crWC99: 0.03977967460106521
# Mean of crSC99: 0.03510224317594624
# ===========================
# ===========================
#
# ```

# %%
! ls monteData/simul/
# Out:
# crA_orig0.csv	 crWA0.csv	  hiSA0.csv	   orig_dataS10.csv
# crA_orig10.csv	 crWA10.csv	  hiSA10.csv	   orig_dataS11.csv
# crA_orig11.csv	 crWA11.csv	  hiSA11.csv	   orig_dataS12.csv
# crA_orig12.csv	 crWA12.csv	  hiSA12.csv	   orig_dataS13.csv
# crA_orig13.csv	 crWA13.csv	  hiSA13.csv	   orig_dataS14.csv
# crA_orig14.csv	 crWA14.csv	  hiSA14.csv	   orig_dataS15.csv
# crA_orig15.csv	 crWA15.csv	  hiSA15.csv	   orig_dataS16.csv
# crA_orig16.csv	 crWA16.csv	  hiSA16.csv	   orig_dataS17.csv
# crA_orig17.csv	 crWA17.csv	  hiSA17.csv	   orig_dataS18.csv
# crA_orig18.csv	 crWA18.csv	  hiSA18.csv	   orig_dataS19.csv
# crA_orig19.csv	 crWA19.csv	  hiSA19.csv	   orig_dataS1.csv
# crA_orig1.csv	 crWA1.csv	  hiSA1.csv	   orig_dataS20.csv
# crA_orig20.csv	 crWA20.csv	  hiSA20.csv	   orig_dataS21.csv
# crA_orig21.csv	 crWA21.csv	  hiSA21.csv	   orig_dataS22.csv
# crA_orig22.csv	 crWA22.csv	  hiSA22.csv	   orig_dataS23.csv
# crA_orig23.csv	 crWA23.csv	  hiSA23.csv	   orig_dataS24.csv
# crA_orig24.csv	 crWA24.csv	  hiSA24.csv	   orig_dataS25.csv
# crA_orig25.csv	 crWA25.csv	  hiSA25.csv	   orig_dataS26.csv
# crA_orig26.csv	 crWA26.csv	  hiSA26.csv	   orig_dataS27.csv
# crA_orig27.csv	 crWA27.csv	  hiSA27.csv	   orig_dataS28.csv
# crA_orig28.csv	 crWA28.csv	  hiSA28.csv	   orig_dataS29.csv
# crA_orig29.csv	 crWA29.csv	  hiSA29.csv	   orig_dataS2.csv
# crA_orig2.csv	 crWA2.csv	  hiSA2.csv	   orig_dataS30.csv
# crA_orig30.csv	 crWA30.csv	  hiSA30.csv	   orig_dataS31.csv
# crA_orig31.csv	 crWA31.csv	  hiSA31.csv	   orig_dataS32.csv
# crA_orig32.csv	 crWA32.csv	  hiSA32.csv	   orig_dataS33.csv
# crA_orig33.csv	 crWA33.csv	  hiSA33.csv	   orig_dataS34.csv
# crA_orig34.csv	 crWA34.csv	  hiSA34.csv	   orig_dataS35.csv
# crA_orig35.csv	 crWA35.csv	  hiSA35.csv	   orig_dataS36.csv
# crA_orig36.csv	 crWA36.csv	  hiSA36.csv	   orig_dataS37.csv
# crA_orig37.csv	 crWA37.csv	  hiSA37.csv	   orig_dataS38.csv
# crA_orig38.csv	 crWA38.csv	  hiSA38.csv	   orig_dataS39.csv
# crA_orig39.csv	 crWA39.csv	  hiSA39.csv	   orig_dataS3.csv
# crA_orig3.csv	 crWA3.csv	  hiSA3.csv	   orig_dataS40.csv
# crA_orig40.csv	 crWA40.csv	  hiSA40.csv	   orig_dataS41.csv
# crA_orig41.csv	 crWA41.csv	  hiSA41.csv	   orig_dataS42.csv
# crA_orig42.csv	 crWA42.csv	  hiSA42.csv	   orig_dataS43.csv
# crA_orig43.csv	 crWA43.csv	  hiSA43.csv	   orig_dataS44.csv
# crA_orig44.csv	 crWA44.csv	  hiSA44.csv	   orig_dataS45.csv
# crA_orig45.csv	 crWA45.csv	  hiSA45.csv	   orig_dataS46.csv
# crA_orig46.csv	 crWA46.csv	  hiSA46.csv	   orig_dataS47.csv
# crA_orig47.csv	 crWA47.csv	  hiSA47.csv	   orig_dataS48.csv
# crA_orig48.csv	 crWA48.csv	  hiSA48.csv	   orig_dataS49.csv
# crA_orig49.csv	 crWA49.csv	  hiSA49.csv	   orig_dataS4.csv
# crA_orig4.csv	 crWA4.csv	  hiSA4.csv	   orig_dataS50.csv
# crA_orig50.csv	 crWA50.csv	  hiSA50.csv	   orig_dataS51.csv
# crA_orig51.csv	 crWA51.csv	  hiSA51.csv	   orig_dataS52.csv
# crA_orig52.csv	 crWA52.csv	  hiSA52.csv	   orig_dataS53.csv
# crA_orig53.csv	 crWA53.csv	  hiSA53.csv	   orig_dataS54.csv
# crA_orig54.csv	 crWA54.csv	  hiSA54.csv	   orig_dataS55.csv
# crA_orig55.csv	 crWA55.csv	  hiSA55.csv	   orig_dataS56.csv
# crA_orig56.csv	 crWA56.csv	  hiSA56.csv	   orig_dataS57.csv
# crA_orig57.csv	 crWA57.csv	  hiSA57.csv	   orig_dataS58.csv
# crA_orig58.csv	 crWA58.csv	  hiSA58.csv	   orig_dataS59.csv
# crA_orig59.csv	 crWA59.csv	  hiSA59.csv	   orig_dataS5.csv
# crA_orig5.csv	 crWA5.csv	  hiSA5.csv	   orig_dataS60.csv
# crA_orig60.csv	 crWA60.csv	  hiSA60.csv	   orig_dataS61.csv
# crA_orig61.csv	 crWA61.csv	  hiSA61.csv	   orig_dataS62.csv
# crA_orig62.csv	 crWA62.csv	  hiSA62.csv	   orig_dataS63.csv
# crA_orig63.csv	 crWA63.csv	  hiSA63.csv	   orig_dataS64.csv
# crA_orig64.csv	 crWA64.csv	  hiSA64.csv	   orig_dataS65.csv
# crA_orig65.csv	 crWA65.csv	  hiSA65.csv	   orig_dataS66.csv
# crA_orig66.csv	 crWA66.csv	  hiSA66.csv	   orig_dataS67.csv
# crA_orig67.csv	 crWA67.csv	  hiSA67.csv	   orig_dataS68.csv
# crA_orig68.csv	 crWA68.csv	  hiSA68.csv	   orig_dataS69.csv
# crA_orig69.csv	 crWA69.csv	  hiSA69.csv	   orig_dataS6.csv
# crA_orig6.csv	 crWA6.csv	  hiSA6.csv	   orig_dataS70.csv
# crA_orig70.csv	 crWA70.csv	  hiSA70.csv	   orig_dataS71.csv
# crA_orig71.csv	 crWA71.csv	  hiSA71.csv	   orig_dataS72.csv
# crA_orig72.csv	 crWA72.csv	  hiSA72.csv	   orig_dataS73.csv
# crA_orig73.csv	 crWA73.csv	  hiSA73.csv	   orig_dataS74.csv
# crA_orig74.csv	 crWA74.csv	  hiSA74.csv	   orig_dataS75.csv
# crA_orig75.csv	 crWA75.csv	  hiSA75.csv	   orig_dataS76.csv
# crA_orig76.csv	 crWA76.csv	  hiSA76.csv	   orig_dataS77.csv
# crA_orig77.csv	 crWA77.csv	  hiSA77.csv	   orig_dataS78.csv
# crA_orig78.csv	 crWA78.csv	  hiSA78.csv	   orig_dataS79.csv
# crA_orig79.csv	 crWA79.csv	  hiSA79.csv	   orig_dataS7.csv
# crA_orig7.csv	 crWA7.csv	  hiSA7.csv	   orig_dataS80.csv
# crA_orig80.csv	 crWA80.csv	  hiSA80.csv	   orig_dataS81.csv
# crA_orig81.csv	 crWA81.csv	  hiSA81.csv	   orig_dataS82.csv
# crA_orig82.csv	 crWA82.csv	  hiSA82.csv	   orig_dataS83.csv
# crA_orig83.csv	 crWA83.csv	  hiSA83.csv	   orig_dataS84.csv
# crA_orig84.csv	 crWA84.csv	  hiSA84.csv	   orig_dataS85.csv
# crA_orig85.csv	 crWA85.csv	  hiSA85.csv	   orig_dataS86.csv
# crA_orig86.csv	 crWA86.csv	  hiSA86.csv	   orig_dataS87.csv
# crA_orig87.csv	 crWA87.csv	  hiSA87.csv	   orig_dataS88.csv
# crA_orig88.csv	 crWA88.csv	  hiSA88.csv	   orig_dataS89.csv
# crA_orig89.csv	 crWA89.csv	  hiSA89.csv	   orig_dataS8.csv
# crA_orig8.csv	 crWA8.csv	  hiSA8.csv	   orig_dataS90.csv
# crA_orig90.csv	 crWA90.csv	  hiSA90.csv	   orig_dataS91.csv
# crA_orig91.csv	 crWA91.csv	  hiSA91.csv	   orig_dataS92.csv
# crA_orig92.csv	 crWA92.csv	  hiSA92.csv	   orig_dataS93.csv
# crA_orig93.csv	 crWA93.csv	  hiSA93.csv	   orig_dataS94.csv
# crA_orig94.csv	 crWA94.csv	  hiSA94.csv	   orig_dataS95.csv
# crA_orig95.csv	 crWA95.csv	  hiSA95.csv	   orig_dataS96.csv
# crA_orig96.csv	 crWA96.csv	  hiSA96.csv	   orig_dataS97.csv
# crA_orig97.csv	 crWA97.csv	  hiSA97.csv	   orig_dataS98.csv
# crA_orig98.csv	 crWA98.csv	  hiSA98.csv	   orig_dataS99.csv
# crA_orig99.csv	 crWA99.csv	  hiSA99.csv	   orig_dataS9.csv
# crA_orig9.csv	 crWA9.csv	  hiSA9.csv	   orig_dataSC0.csv
# crA_origC0.csv	 crWC0.csv	  hiSC0.csv	   orig_dataSC10.csv
# crA_origC10.csv  crWC10.csv	  hiSC10.csv	   orig_dataSC11.csv
# crA_origC11.csv  crWC11.csv	  hiSC11.csv	   orig_dataSC12.csv
# crA_origC12.csv  crWC12.csv	  hiSC12.csv	   orig_dataSC13.csv
# crA_origC13.csv  crWC13.csv	  hiSC13.csv	   orig_dataSC14.csv
# crA_origC14.csv  crWC14.csv	  hiSC14.csv	   orig_dataSC15.csv
# crA_origC15.csv  crWC15.csv	  hiSC15.csv	   orig_dataSC16.csv
# crA_origC16.csv  crWC16.csv	  hiSC16.csv	   orig_dataSC17.csv
# crA_origC17.csv  crWC17.csv	  hiSC17.csv	   orig_dataSC18.csv
# crA_origC18.csv  crWC18.csv	  hiSC18.csv	   orig_dataSC19.csv
# crA_origC19.csv  crWC19.csv	  hiSC19.csv	   orig_dataSC1.csv
# crA_origC1.csv	 crWC1.csv	  hiSC1.csv	   orig_dataSC20.csv
# crA_origC20.csv  crWC20.csv	  hiSC20.csv	   orig_dataSC21.csv
# crA_origC21.csv  crWC21.csv	  hiSC21.csv	   orig_dataSC22.csv
# crA_origC22.csv  crWC22.csv	  hiSC22.csv	   orig_dataSC23.csv
# crA_origC23.csv  crWC23.csv	  hiSC23.csv	   orig_dataSC24.csv
# crA_origC24.csv  crWC24.csv	  hiSC24.csv	   orig_dataSC25.csv
# crA_origC25.csv  crWC25.csv	  hiSC25.csv	   orig_dataSC26.csv
# crA_origC26.csv  crWC26.csv	  hiSC26.csv	   orig_dataSC27.csv
# crA_origC27.csv  crWC27.csv	  hiSC27.csv	   orig_dataSC28.csv
# crA_origC28.csv  crWC28.csv	  hiSC28.csv	   orig_dataSC29.csv
# crA_origC29.csv  crWC29.csv	  hiSC29.csv	   orig_dataSC2.csv
# crA_origC2.csv	 crWC2.csv	  hiSC2.csv	   orig_dataSC30.csv
# crA_origC30.csv  crWC30.csv	  hiSC30.csv	   orig_dataSC31.csv
# crA_origC31.csv  crWC31.csv	  hiSC31.csv	   orig_dataSC32.csv
# crA_origC32.csv  crWC32.csv	  hiSC32.csv	   orig_dataSC33.csv
# crA_origC33.csv  crWC33.csv	  hiSC33.csv	   orig_dataSC34.csv
# crA_origC34.csv  crWC34.csv	  hiSC34.csv	   orig_dataSC35.csv
# crA_origC35.csv  crWC35.csv	  hiSC35.csv	   orig_dataSC36.csv
# crA_origC36.csv  crWC36.csv	  hiSC36.csv	   orig_dataSC37.csv
# crA_origC37.csv  crWC37.csv	  hiSC37.csv	   orig_dataSC38.csv
# crA_origC38.csv  crWC38.csv	  hiSC38.csv	   orig_dataSC39.csv
# crA_origC39.csv  crWC39.csv	  hiSC39.csv	   orig_dataSC3.csv
# crA_origC3.csv	 crWC3.csv	  hiSC3.csv	   orig_dataSC40.csv
# crA_origC40.csv  crWC40.csv	  hiSC40.csv	   orig_dataSC41.csv
# crA_origC41.csv  crWC41.csv	  hiSC41.csv	   orig_dataSC42.csv
# crA_origC42.csv  crWC42.csv	  hiSC42.csv	   orig_dataSC43.csv
# crA_origC43.csv  crWC43.csv	  hiSC43.csv	   orig_dataSC44.csv
# crA_origC44.csv  crWC44.csv	  hiSC44.csv	   orig_dataSC45.csv
# crA_origC45.csv  crWC45.csv	  hiSC45.csv	   orig_dataSC46.csv
# crA_origC46.csv  crWC46.csv	  hiSC46.csv	   orig_dataSC47.csv
# crA_origC47.csv  crWC47.csv	  hiSC47.csv	   orig_dataSC48.csv
# crA_origC48.csv  crWC48.csv	  hiSC48.csv	   orig_dataSC49.csv
# crA_origC49.csv  crWC49.csv	  hiSC49.csv	   orig_dataSC4.csv
# crA_origC4.csv	 crWC4.csv	  hiSC4.csv	   orig_dataSC50.csv
# crA_origC50.csv  crWC50.csv	  hiSC50.csv	   orig_dataSC51.csv
# crA_origC51.csv  crWC51.csv	  hiSC51.csv	   orig_dataSC52.csv
# crA_origC52.csv  crWC52.csv	  hiSC52.csv	   orig_dataSC53.csv
# crA_origC53.csv  crWC53.csv	  hiSC53.csv	   orig_dataSC54.csv
# crA_origC54.csv  crWC54.csv	  hiSC54.csv	   orig_dataSC55.csv
# crA_origC55.csv  crWC55.csv	  hiSC55.csv	   orig_dataSC56.csv
# crA_origC56.csv  crWC56.csv	  hiSC56.csv	   orig_dataSC57.csv
# crA_origC57.csv  crWC57.csv	  hiSC57.csv	   orig_dataSC58.csv
# crA_origC58.csv  crWC58.csv	  hiSC58.csv	   orig_dataSC59.csv
# crA_origC59.csv  crWC59.csv	  hiSC59.csv	   orig_dataSC5.csv
# crA_origC5.csv	 crWC5.csv	  hiSC5.csv	   orig_dataSC60.csv
# crA_origC60.csv  crWC60.csv	  hiSC60.csv	   orig_dataSC61.csv
# crA_origC61.csv  crWC61.csv	  hiSC61.csv	   orig_dataSC62.csv
# crA_origC62.csv  crWC62.csv	  hiSC62.csv	   orig_dataSC63.csv
# crA_origC63.csv  crWC63.csv	  hiSC63.csv	   orig_dataSC64.csv
# crA_origC64.csv  crWC64.csv	  hiSC64.csv	   orig_dataSC65.csv
# crA_origC65.csv  crWC65.csv	  hiSC65.csv	   orig_dataSC66.csv
# crA_origC66.csv  crWC66.csv	  hiSC66.csv	   orig_dataSC67.csv
# crA_origC67.csv  crWC67.csv	  hiSC67.csv	   orig_dataSC68.csv
# crA_origC68.csv  crWC68.csv	  hiSC68.csv	   orig_dataSC69.csv
# crA_origC69.csv  crWC69.csv	  hiSC69.csv	   orig_dataSC6.csv
# crA_origC6.csv	 crWC6.csv	  hiSC6.csv	   orig_dataSC70.csv
# crA_origC70.csv  crWC70.csv	  hiSC70.csv	   orig_dataSC71.csv
# crA_origC71.csv  crWC71.csv	  hiSC71.csv	   orig_dataSC72.csv
# crA_origC72.csv  crWC72.csv	  hiSC72.csv	   orig_dataSC73.csv
# crA_origC73.csv  crWC73.csv	  hiSC73.csv	   orig_dataSC74.csv
# crA_origC74.csv  crWC74.csv	  hiSC74.csv	   orig_dataSC75.csv
# crA_origC75.csv  crWC75.csv	  hiSC75.csv	   orig_dataSC76.csv
# crA_origC76.csv  crWC76.csv	  hiSC76.csv	   orig_dataSC77.csv
# crA_origC77.csv  crWC77.csv	  hiSC77.csv	   orig_dataSC78.csv
# crA_origC78.csv  crWC78.csv	  hiSC78.csv	   orig_dataSC79.csv
# crA_origC79.csv  crWC79.csv	  hiSC79.csv	   orig_dataSC7.csv
# crA_origC7.csv	 crWC7.csv	  hiSC7.csv	   orig_dataSC80.csv
# crA_origC80.csv  crWC80.csv	  hiSC80.csv	   orig_dataSC81.csv
# crA_origC81.csv  crWC81.csv	  hiSC81.csv	   orig_dataSC82.csv
# crA_origC82.csv  crWC82.csv	  hiSC82.csv	   orig_dataSC83.csv
# crA_origC83.csv  crWC83.csv	  hiSC83.csv	   orig_dataSC84.csv
# crA_origC84.csv  crWC84.csv	  hiSC84.csv	   orig_dataSC85.csv
# crA_origC85.csv  crWC85.csv	  hiSC85.csv	   orig_dataSC86.csv
# crA_origC86.csv  crWC86.csv	  hiSC86.csv	   orig_dataSC87.csv
# crA_origC87.csv  crWC87.csv	  hiSC87.csv	   orig_dataSC88.csv
# crA_origC88.csv  crWC88.csv	  hiSC88.csv	   orig_dataSC89.csv
# crA_origC89.csv  crWC89.csv	  hiSC89.csv	   orig_dataSC8.csv
# crA_origC8.csv	 crWC8.csv	  hiSC8.csv	   orig_dataSC90.csv
# crA_origC90.csv  crWC90.csv	  hiSC90.csv	   orig_dataSC91.csv
# crA_origC91.csv  crWC91.csv	  hiSC91.csv	   orig_dataSC92.csv
# crA_origC92.csv  crWC92.csv	  hiSC92.csv	   orig_dataSC93.csv
# crA_origC93.csv  crWC93.csv	  hiSC93.csv	   orig_dataSC94.csv
# crA_origC94.csv  crWC94.csv	  hiSC94.csv	   orig_dataSC95.csv
# crA_origC95.csv  crWC95.csv	  hiSC95.csv	   orig_dataSC96.csv
# crA_origC96.csv  crWC96.csv	  hiSC96.csv	   orig_dataSC97.csv
# crA_origC97.csv  crWC97.csv	  hiSC97.csv	   orig_dataSC98.csv
# crA_origC98.csv  crWC98.csv	  hiSC98.csv	   orig_dataSC99.csv
# crA_origC99.csv  crWC99.csv	  hiSC99.csv	   orig_dataSC9.csv
# crA_origC9.csv	 crWC9.csv	  hiSC9.csv	   orig_dataS.csv
# crA_orig.csv	 hiA_orig0.csv	  hiWA0.csv	   orig_dataW0.csv
# crSA0.csv	 hiA_orig10.csv   hiWA10.csv	   orig_dataW10.csv
# crSA10.csv	 hiA_orig11.csv   hiWA11.csv	   orig_dataW11.csv
# crSA11.csv	 hiA_orig12.csv   hiWA12.csv	   orig_dataW12.csv
# crSA12.csv	 hiA_orig13.csv   hiWA13.csv	   orig_dataW13.csv
# crSA13.csv	 hiA_orig14.csv   hiWA14.csv	   orig_dataW14.csv
# crSA14.csv	 hiA_orig15.csv   hiWA15.csv	   orig_dataW15.csv
# crSA15.csv	 hiA_orig16.csv   hiWA16.csv	   orig_dataW16.csv
# crSA16.csv	 hiA_orig17.csv   hiWA17.csv	   orig_dataW17.csv
# crSA17.csv	 hiA_orig18.csv   hiWA18.csv	   orig_dataW18.csv
# crSA18.csv	 hiA_orig19.csv   hiWA19.csv	   orig_dataW19.csv
# crSA19.csv	 hiA_orig1.csv	  hiWA1.csv	   orig_dataW1.csv
# crSA1.csv	 hiA_orig20.csv   hiWA20.csv	   orig_dataW20.csv
# crSA20.csv	 hiA_orig21.csv   hiWA21.csv	   orig_dataW21.csv
# crSA21.csv	 hiA_orig22.csv   hiWA22.csv	   orig_dataW22.csv
# crSA22.csv	 hiA_orig23.csv   hiWA23.csv	   orig_dataW23.csv
# crSA23.csv	 hiA_orig24.csv   hiWA24.csv	   orig_dataW24.csv
# crSA24.csv	 hiA_orig25.csv   hiWA25.csv	   orig_dataW25.csv
# crSA25.csv	 hiA_orig26.csv   hiWA26.csv	   orig_dataW26.csv
# crSA26.csv	 hiA_orig27.csv   hiWA27.csv	   orig_dataW27.csv
# crSA27.csv	 hiA_orig28.csv   hiWA28.csv	   orig_dataW28.csv
# crSA28.csv	 hiA_orig29.csv   hiWA29.csv	   orig_dataW29.csv
# crSA29.csv	 hiA_orig2.csv	  hiWA2.csv	   orig_dataW2.csv
# crSA2.csv	 hiA_orig30.csv   hiWA30.csv	   orig_dataW30.csv
# crSA30.csv	 hiA_orig31.csv   hiWA31.csv	   orig_dataW31.csv
# crSA31.csv	 hiA_orig32.csv   hiWA32.csv	   orig_dataW32.csv
# crSA32.csv	 hiA_orig33.csv   hiWA33.csv	   orig_dataW33.csv
# crSA33.csv	 hiA_orig34.csv   hiWA34.csv	   orig_dataW34.csv
# crSA34.csv	 hiA_orig35.csv   hiWA35.csv	   orig_dataW35.csv
# crSA35.csv	 hiA_orig36.csv   hiWA36.csv	   orig_dataW36.csv
# crSA36.csv	 hiA_orig37.csv   hiWA37.csv	   orig_dataW37.csv
# crSA37.csv	 hiA_orig38.csv   hiWA38.csv	   orig_dataW38.csv
# crSA38.csv	 hiA_orig39.csv   hiWA39.csv	   orig_dataW39.csv
# crSA39.csv	 hiA_orig3.csv	  hiWA3.csv	   orig_dataW3.csv
# crSA3.csv	 hiA_orig40.csv   hiWA40.csv	   orig_dataW40.csv
# crSA40.csv	 hiA_orig41.csv   hiWA41.csv	   orig_dataW41.csv
# crSA41.csv	 hiA_orig42.csv   hiWA42.csv	   orig_dataW42.csv
# crSA42.csv	 hiA_orig43.csv   hiWA43.csv	   orig_dataW43.csv
# crSA43.csv	 hiA_orig44.csv   hiWA44.csv	   orig_dataW44.csv
# crSA44.csv	 hiA_orig45.csv   hiWA45.csv	   orig_dataW45.csv
# crSA45.csv	 hiA_orig46.csv   hiWA46.csv	   orig_dataW46.csv
# crSA46.csv	 hiA_orig47.csv   hiWA47.csv	   orig_dataW47.csv
# crSA47.csv	 hiA_orig48.csv   hiWA48.csv	   orig_dataW48.csv
# crSA48.csv	 hiA_orig49.csv   hiWA49.csv	   orig_dataW49.csv
# crSA49.csv	 hiA_orig4.csv	  hiWA4.csv	   orig_dataW4.csv
# crSA4.csv	 hiA_orig50.csv   hiWA50.csv	   orig_dataW50.csv
# crSA50.csv	 hiA_orig51.csv   hiWA51.csv	   orig_dataW51.csv
# crSA51.csv	 hiA_orig52.csv   hiWA52.csv	   orig_dataW52.csv
# crSA52.csv	 hiA_orig53.csv   hiWA53.csv	   orig_dataW53.csv
# crSA53.csv	 hiA_orig54.csv   hiWA54.csv	   orig_dataW54.csv
# crSA54.csv	 hiA_orig55.csv   hiWA55.csv	   orig_dataW55.csv
# crSA55.csv	 hiA_orig56.csv   hiWA56.csv	   orig_dataW56.csv
# crSA56.csv	 hiA_orig57.csv   hiWA57.csv	   orig_dataW57.csv
# crSA57.csv	 hiA_orig58.csv   hiWA58.csv	   orig_dataW58.csv
# crSA58.csv	 hiA_orig59.csv   hiWA59.csv	   orig_dataW59.csv
# crSA59.csv	 hiA_orig5.csv	  hiWA5.csv	   orig_dataW5.csv
# crSA5.csv	 hiA_orig60.csv   hiWA60.csv	   orig_dataW60.csv
# crSA60.csv	 hiA_orig61.csv   hiWA61.csv	   orig_dataW61.csv
# crSA61.csv	 hiA_orig62.csv   hiWA62.csv	   orig_dataW62.csv
# crSA62.csv	 hiA_orig63.csv   hiWA63.csv	   orig_dataW63.csv
# crSA63.csv	 hiA_orig64.csv   hiWA64.csv	   orig_dataW64.csv
# crSA64.csv	 hiA_orig65.csv   hiWA65.csv	   orig_dataW65.csv
# crSA65.csv	 hiA_orig66.csv   hiWA66.csv	   orig_dataW66.csv
# crSA66.csv	 hiA_orig67.csv   hiWA67.csv	   orig_dataW67.csv
# crSA67.csv	 hiA_orig68.csv   hiWA68.csv	   orig_dataW68.csv
# crSA68.csv	 hiA_orig69.csv   hiWA69.csv	   orig_dataW69.csv
# crSA69.csv	 hiA_orig6.csv	  hiWA6.csv	   orig_dataW6.csv
# crSA6.csv	 hiA_orig70.csv   hiWA70.csv	   orig_dataW70.csv
# crSA70.csv	 hiA_orig71.csv   hiWA71.csv	   orig_dataW71.csv
# crSA71.csv	 hiA_orig72.csv   hiWA72.csv	   orig_dataW72.csv
# crSA72.csv	 hiA_orig73.csv   hiWA73.csv	   orig_dataW73.csv
# crSA73.csv	 hiA_orig74.csv   hiWA74.csv	   orig_dataW74.csv
# crSA74.csv	 hiA_orig75.csv   hiWA75.csv	   orig_dataW75.csv
# crSA75.csv	 hiA_orig76.csv   hiWA76.csv	   orig_dataW76.csv
# crSA76.csv	 hiA_orig77.csv   hiWA77.csv	   orig_dataW77.csv
# crSA77.csv	 hiA_orig78.csv   hiWA78.csv	   orig_dataW78.csv
# crSA78.csv	 hiA_orig79.csv   hiWA79.csv	   orig_dataW79.csv
# crSA79.csv	 hiA_orig7.csv	  hiWA7.csv	   orig_dataW7.csv
# crSA7.csv	 hiA_orig80.csv   hiWA80.csv	   orig_dataW80.csv
# crSA80.csv	 hiA_orig81.csv   hiWA81.csv	   orig_dataW81.csv
# crSA81.csv	 hiA_orig82.csv   hiWA82.csv	   orig_dataW82.csv
# crSA82.csv	 hiA_orig83.csv   hiWA83.csv	   orig_dataW83.csv
# crSA83.csv	 hiA_orig84.csv   hiWA84.csv	   orig_dataW84.csv
# crSA84.csv	 hiA_orig85.csv   hiWA85.csv	   orig_dataW85.csv
# crSA85.csv	 hiA_orig86.csv   hiWA86.csv	   orig_dataW86.csv
# crSA86.csv	 hiA_orig87.csv   hiWA87.csv	   orig_dataW87.csv
# crSA87.csv	 hiA_orig88.csv   hiWA88.csv	   orig_dataW88.csv
# crSA88.csv	 hiA_orig89.csv   hiWA89.csv	   orig_dataW89.csv
# crSA89.csv	 hiA_orig8.csv	  hiWA8.csv	   orig_dataW8.csv
# crSA8.csv	 hiA_orig90.csv   hiWA90.csv	   orig_dataW90.csv
# crSA90.csv	 hiA_orig91.csv   hiWA91.csv	   orig_dataW91.csv
# crSA91.csv	 hiA_orig92.csv   hiWA92.csv	   orig_dataW92.csv
# crSA92.csv	 hiA_orig93.csv   hiWA93.csv	   orig_dataW93.csv
# crSA93.csv	 hiA_orig94.csv   hiWA94.csv	   orig_dataW94.csv
# crSA94.csv	 hiA_orig95.csv   hiWA95.csv	   orig_dataW95.csv
# crSA95.csv	 hiA_orig96.csv   hiWA96.csv	   orig_dataW96.csv
# crSA96.csv	 hiA_orig97.csv   hiWA97.csv	   orig_dataW97.csv
# crSA97.csv	 hiA_orig98.csv   hiWA98.csv	   orig_dataW98.csv
# crSA98.csv	 hiA_orig99.csv   hiWA99.csv	   orig_dataW99.csv
# crSA99.csv	 hiA_orig9.csv	  hiWA9.csv	   orig_dataW9.csv
# crSA9.csv	 hiA_origC0.csv   hiWC0.csv	   orig_dataWC0.csv
# crSC0.csv	 hiA_origC10.csv  hiWC10.csv	   orig_dataWC10.csv
# crSC10.csv	 hiA_origC11.csv  hiWC11.csv	   orig_dataWC11.csv
# crSC11.csv	 hiA_origC12.csv  hiWC12.csv	   orig_dataWC12.csv
# crSC12.csv	 hiA_origC13.csv  hiWC13.csv	   orig_dataWC13.csv
# crSC13.csv	 hiA_origC14.csv  hiWC14.csv	   orig_dataWC14.csv
# crSC14.csv	 hiA_origC15.csv  hiWC15.csv	   orig_dataWC15.csv
# crSC15.csv	 hiA_origC16.csv  hiWC16.csv	   orig_dataWC16.csv
# crSC16.csv	 hiA_origC17.csv  hiWC17.csv	   orig_dataWC17.csv
# crSC17.csv	 hiA_origC18.csv  hiWC18.csv	   orig_dataWC18.csv
# crSC18.csv	 hiA_origC19.csv  hiWC19.csv	   orig_dataWC19.csv
# crSC19.csv	 hiA_origC1.csv   hiWC1.csv	   orig_dataWC1.csv
# crSC1.csv	 hiA_origC20.csv  hiWC20.csv	   orig_dataWC20.csv
# crSC20.csv	 hiA_origC21.csv  hiWC21.csv	   orig_dataWC21.csv
# crSC21.csv	 hiA_origC22.csv  hiWC22.csv	   orig_dataWC22.csv
# crSC22.csv	 hiA_origC23.csv  hiWC23.csv	   orig_dataWC23.csv
# crSC23.csv	 hiA_origC24.csv  hiWC24.csv	   orig_dataWC24.csv
# crSC24.csv	 hiA_origC25.csv  hiWC25.csv	   orig_dataWC25.csv
# crSC25.csv	 hiA_origC26.csv  hiWC26.csv	   orig_dataWC26.csv
# crSC26.csv	 hiA_origC27.csv  hiWC27.csv	   orig_dataWC27.csv
# crSC27.csv	 hiA_origC28.csv  hiWC28.csv	   orig_dataWC28.csv
# crSC28.csv	 hiA_origC29.csv  hiWC29.csv	   orig_dataWC29.csv
# crSC29.csv	 hiA_origC2.csv   hiWC2.csv	   orig_dataWC2.csv
# crSC2.csv	 hiA_origC30.csv  hiWC30.csv	   orig_dataWC30.csv
# crSC30.csv	 hiA_origC31.csv  hiWC31.csv	   orig_dataWC31.csv
# crSC31.csv	 hiA_origC32.csv  hiWC32.csv	   orig_dataWC32.csv
# crSC32.csv	 hiA_origC33.csv  hiWC33.csv	   orig_dataWC33.csv
# crSC33.csv	 hiA_origC34.csv  hiWC34.csv	   orig_dataWC34.csv
# crSC34.csv	 hiA_origC35.csv  hiWC35.csv	   orig_dataWC35.csv
# crSC35.csv	 hiA_origC36.csv  hiWC36.csv	   orig_dataWC36.csv
# crSC36.csv	 hiA_origC37.csv  hiWC37.csv	   orig_dataWC37.csv
# crSC37.csv	 hiA_origC38.csv  hiWC38.csv	   orig_dataWC38.csv
# crSC38.csv	 hiA_origC39.csv  hiWC39.csv	   orig_dataWC39.csv
# crSC39.csv	 hiA_origC3.csv   hiWC3.csv	   orig_dataWC3.csv
# crSC3.csv	 hiA_origC40.csv  hiWC40.csv	   orig_dataWC40.csv
# crSC40.csv	 hiA_origC41.csv  hiWC41.csv	   orig_dataWC41.csv
# crSC41.csv	 hiA_origC42.csv  hiWC42.csv	   orig_dataWC42.csv
# crSC42.csv	 hiA_origC43.csv  hiWC43.csv	   orig_dataWC43.csv
# crSC43.csv	 hiA_origC44.csv  hiWC44.csv	   orig_dataWC44.csv
# crSC44.csv	 hiA_origC45.csv  hiWC45.csv	   orig_dataWC45.csv
# crSC45.csv	 hiA_origC46.csv  hiWC46.csv	   orig_dataWC46.csv
# crSC46.csv	 hiA_origC47.csv  hiWC47.csv	   orig_dataWC47.csv
# crSC47.csv	 hiA_origC48.csv  hiWC48.csv	   orig_dataWC48.csv
# crSC48.csv	 hiA_origC49.csv  hiWC49.csv	   orig_dataWC49.csv
# crSC49.csv	 hiA_origC4.csv   hiWC4.csv	   orig_dataWC4.csv
# crSC4.csv	 hiA_origC50.csv  hiWC50.csv	   orig_dataWC50.csv
# crSC50.csv	 hiA_origC51.csv  hiWC51.csv	   orig_dataWC51.csv
# crSC51.csv	 hiA_origC52.csv  hiWC52.csv	   orig_dataWC52.csv
# crSC52.csv	 hiA_origC53.csv  hiWC53.csv	   orig_dataWC53.csv
# crSC53.csv	 hiA_origC54.csv  hiWC54.csv	   orig_dataWC54.csv
# crSC54.csv	 hiA_origC55.csv  hiWC55.csv	   orig_dataWC55.csv
# crSC55.csv	 hiA_origC56.csv  hiWC56.csv	   orig_dataWC56.csv
# crSC56.csv	 hiA_origC57.csv  hiWC57.csv	   orig_dataWC57.csv
# crSC57.csv	 hiA_origC58.csv  hiWC58.csv	   orig_dataWC58.csv
# crSC58.csv	 hiA_origC59.csv  hiWC59.csv	   orig_dataWC59.csv
# crSC59.csv	 hiA_origC5.csv   hiWC5.csv	   orig_dataWC5.csv
# crSC5.csv	 hiA_origC60.csv  hiWC60.csv	   orig_dataWC60.csv
# crSC60.csv	 hiA_origC61.csv  hiWC61.csv	   orig_dataWC61.csv
# crSC61.csv	 hiA_origC62.csv  hiWC62.csv	   orig_dataWC62.csv
# crSC62.csv	 hiA_origC63.csv  hiWC63.csv	   orig_dataWC63.csv
# crSC63.csv	 hiA_origC64.csv  hiWC64.csv	   orig_dataWC64.csv
# crSC64.csv	 hiA_origC65.csv  hiWC65.csv	   orig_dataWC65.csv
# crSC65.csv	 hiA_origC66.csv  hiWC66.csv	   orig_dataWC66.csv
# crSC66.csv	 hiA_origC67.csv  hiWC67.csv	   orig_dataWC67.csv
# crSC67.csv	 hiA_origC68.csv  hiWC68.csv	   orig_dataWC68.csv
# crSC68.csv	 hiA_origC69.csv  hiWC69.csv	   orig_dataWC69.csv
# crSC69.csv	 hiA_origC6.csv   hiWC6.csv	   orig_dataWC6.csv
# crSC6.csv	 hiA_origC70.csv  hiWC70.csv	   orig_dataWC70.csv
# crSC70.csv	 hiA_origC71.csv  hiWC71.csv	   orig_dataWC71.csv
# crSC71.csv	 hiA_origC72.csv  hiWC72.csv	   orig_dataWC72.csv
# crSC72.csv	 hiA_origC73.csv  hiWC73.csv	   orig_dataWC73.csv
# crSC73.csv	 hiA_origC74.csv  hiWC74.csv	   orig_dataWC74.csv
# crSC74.csv	 hiA_origC75.csv  hiWC75.csv	   orig_dataWC75.csv
# crSC75.csv	 hiA_origC76.csv  hiWC76.csv	   orig_dataWC76.csv
# crSC76.csv	 hiA_origC77.csv  hiWC77.csv	   orig_dataWC77.csv
# crSC77.csv	 hiA_origC78.csv  hiWC78.csv	   orig_dataWC78.csv
# crSC78.csv	 hiA_origC79.csv  hiWC79.csv	   orig_dataWC79.csv
# crSC79.csv	 hiA_origC7.csv   hiWC7.csv	   orig_dataWC7.csv
# crSC7.csv	 hiA_origC80.csv  hiWC80.csv	   orig_dataWC80.csv
# crSC80.csv	 hiA_origC81.csv  hiWC81.csv	   orig_dataWC81.csv
# crSC81.csv	 hiA_origC82.csv  hiWC82.csv	   orig_dataWC82.csv
# crSC82.csv	 hiA_origC83.csv  hiWC83.csv	   orig_dataWC83.csv
# crSC83.csv	 hiA_origC84.csv  hiWC84.csv	   orig_dataWC84.csv
# crSC84.csv	 hiA_origC85.csv  hiWC85.csv	   orig_dataWC85.csv
# crSC85.csv	 hiA_origC86.csv  hiWC86.csv	   orig_dataWC86.csv
# crSC86.csv	 hiA_origC87.csv  hiWC87.csv	   orig_dataWC87.csv
# crSC87.csv	 hiA_origC88.csv  hiWC88.csv	   orig_dataWC88.csv
# crSC88.csv	 hiA_origC89.csv  hiWC89.csv	   orig_dataWC89.csv
# crSC89.csv	 hiA_origC8.csv   hiWC8.csv	   orig_dataWC8.csv
# crSC8.csv	 hiA_origC90.csv  hiWC90.csv	   orig_dataWC90.csv
# crSC90.csv	 hiA_origC91.csv  hiWC91.csv	   orig_dataWC91.csv
# crSC91.csv	 hiA_origC92.csv  hiWC92.csv	   orig_dataWC92.csv
# crSC92.csv	 hiA_origC93.csv  hiWC93.csv	   orig_dataWC93.csv
# crSC93.csv	 hiA_origC94.csv  hiWC94.csv	   orig_dataWC94.csv
# crSC94.csv	 hiA_origC95.csv  hiWC95.csv	   orig_dataWC95.csv
# crSC95.csv	 hiA_origC96.csv  hiWC96.csv	   orig_dataWC96.csv
# crSC96.csv	 hiA_origC97.csv  hiWC97.csv	   orig_dataWC97.csv
# crSC97.csv	 hiA_origC98.csv  hiWC98.csv	   orig_dataWC98.csv
# crSC98.csv	 hiA_origC99.csv  hiWC99.csv	   orig_dataWC99.csv
# crSC99.csv	 hiA_origC9.csv   hiWC9.csv	   orig_dataWC9.csv
# crSC9.csv	 hiA_orig.csv	  orig_dataS0.csv  orig_dataW.csv

# %%
! ls -l monteData/simul/hiA_orig36.csv monteData/simul/hiA_origC83.csv
# Out:
# -rw-r--r-- 1 RHHLab RHHLab 605164 May 25 22:11 monteData/simul/hiA_orig36.csv
# -rw-r--r-- 1 RHHLab RHHLab 602216 May 25 23:12 monteData/simul/hiA_origC83.csv

# %%
import pandas as pd

# %%
hi36 = pd.read_csv("monteData/simul/hiA_orig36.csv")
cr36 = pd.read_csv("monteData/simul/crA_orig36.csv")

hi83 = pd.read_csv("monteData/simul/hiA_origC83.csv")
cr83 = pd.read_csv("monteData/simul/crA_origC83.csv")

# %%
hi36.groupby("Seasons").mean()
# Out:
#          Unnamed: 0      Values
# Seasons
# Summer       4999.5  111.797434
# Winter       4999.5  103.646024

# %%
hi83.groupby("Seasons").mean()
# Out:
#          Unnamed: 0     Values
# Seasons
# Summer       4999.5  85.075575
# Winter       4999.5  78.856194

# %% [markdown]
# # Sensitivity

# %%
hiWA = pd.read_csv("monteData/simul/hiWA36.csv")
crWA = pd.read_csv("monteData/simul/crWA36.csv")

hiSA = pd.read_csv("monteData/simul/hiSA36.csv")
crSA = pd.read_csv("monteData/simul/crSA36.csv")

hiWC = pd.read_csv("monteData/simul/hiWC83.csv")
crWC = pd.read_csv("monteData/simul/crWC83.csv")

hiSC = pd.read_csv("monteData/simul/hiSC83.csv")
crSC = pd.read_csv("monteData/simul/crSC83.csv")

# %%
hiWA
# Out:
#       Unnamed: 0           0
# 0              0   59.597346
# 1              1  104.527388
# 2              2   30.545610
# 3              3  150.534010
# 4              4   83.134348
# ...          ...         ...
# 9995        9995  114.191206
# 9996        9996   89.999398
# 9997        9997   75.836806
# 9998        9998   45.565692
# 9999        9999  100.641343
#
# [10000 rows x 2 columns]

# %%
dataWA = pd.read_csv("monteData/simul/orig_dataW36.csv")
dataSA = pd.read_csv("monteData/simul/orig_dataS36.csv")

dataWC = pd.read_csv("monteData/simul/orig_dataWC83.csv")
dataSC = pd.read_csv("monteData/simul/orig_dataSC83.csv")

# %%
rawHiWA, hiWA = HI_WA(dataWA)
rawHiSA, hiSA = HI_SA(dataSA)

rawCRWA, crWA = CR_WA(dataWA)
rawCRSA, crSA = CR_SA(dataSA)


rawHiWC, hiWC = HI_WC(dataWC)
rawHiSC, hiSC = HI_SC(dataSC)

rawCRWC, crWC = CR_WC(dataWC)
rawCRSC, crSC = CR_SC(dataSC)

# %%
hiWA[:9999].mean(), hiWC[:9999].mean(),hiSA[:9999].mean(),hiSC[:9999].mean()
# Out:
# (103.64632478887737, 78.84974708248004, 111.80333702479697, 85.07811071676556)

# %%
crWA[:9999].mean(), crWC[:9999].mean(),crSA[:9999].mean(),crSC[:9999].mean()
# Out:
# (0.05553156563526996,
#  0.039742642847213544,
#  0.04848624138456539,
#  0.034857430064302176)

# %%
hi36.groupby("Seasons").mean(), hi83.groupby("Seasons").mean()
# Out:
# (         Unnamed: 0      Values
#  Seasons
#  Summer       4999.5  111.797434
#  Winter       4999.5  103.646024,
#           Unnamed: 0     Values
#  Seasons
#  Summer       4999.5  85.075575
#  Winter       4999.5  78.856194)

# %%
cr36.groupby("Seasons").mean(), cr83.groupby("Seasons").mean()
# Out:
# (         Unnamed: 0    Values
#  Seasons
#  Summer       4999.5  0.048485
#  Winter       4999.5  0.055531,
#           Unnamed: 0    Values
#  Seasons
#  Summer       4999.5  0.034857
#  Winter       4999.5  0.039744)

# %%
rawHiSA
# Out:
#             Mn         Cr        Ni        Cu        Zn         As  \
# 0     1.841466   1.795154  0.690470  0.637351  0.078715  11.330661
# 1     4.550528   1.620046  0.493639  0.210018  0.051091  11.711489
# 2     2.639681   9.314524  0.673762  1.470807  0.025151   7.047449
# 3     2.275313   8.193212  0.897703  0.657580  0.035407  13.662773
# 4     3.182994   9.210434  0.888500  0.967749  0.105085   8.120128
# ...        ...        ...       ...       ...       ...        ...
# 9995  3.213010   6.011043  0.388064  1.198295  0.036017  12.782784
# 9996  2.067576   6.614858  0.538036  1.293970  0.084294   9.677797
# 9997  2.302027   6.422751  0.771285  0.676144  0.048315  11.429561
# 9998  1.649678   2.362377  0.520439  0.196600  0.028471  11.720832
# 9999  3.720618  10.808695  0.434201  1.161126  0.046940   6.826213
#
#               Cd         Hg         Pb
# 0      48.655479  48.156530   8.154720
# 1      16.589324  27.071349  18.624237
# 2      55.162317  32.049543   5.394376
# 3     145.362252   7.141538   6.637622
# 4      42.266167  34.107206  12.994637
# ...          ...        ...        ...
# 9995   74.426201  18.168686  21.726123
# 9996   24.028353  23.508327  12.344767
# 9997   25.465493  30.214351  11.806327
# 9998   19.031245  77.005476   4.957764
# 9999   14.378580  13.796095   1.601790
#
# [10000 rows x 9 columns]

# %%
hiWA = rawHiWA.sum(axis = 1)
hiSA = rawHiSA.sum(axis = 1)

hiWC = rawHiWC.sum(axis = 1)
hiSC = rawHiSC.sum(axis = 1)

crWA = rawCRWA.sum(axis = 1)
crSA = rawCRSA.sum(axis = 1)

crWC = rawCRWC.sum(axis = 1)
crSC = rawCRSC.sum(axis = 1)

# %%
rawHiWA["HI"] = hiWA
rawHiSA["HI"] = hiSA
rawHiWC["HI"] = hiWC
rawHiSC["HI"] = hiSC

rawCRWA["CR"] = crWA
rawCRSA["CR"] = crSA
rawCRWC["CR"] = crWC
rawCRSC["CR"] = crSC

# %%
rawHiWA
# Out:
#             Mn         Cr        Ni        Cu        Zn         As         Cd  \
# 0     2.677529   2.608047  1.826412  1.289706  0.071672  11.733247   6.127146
# 1     4.450396   7.761057  0.236931  0.912647  0.039833  15.172613  45.320382
# 2     2.886587   6.105857  0.136369  0.198645  0.044102  11.575280   2.534334
# 3     1.683953  16.521914  1.025152  0.828798  0.062454   8.437512  94.773548
# 4     5.565827  15.242081  0.723561  0.175259  0.043821  20.875537  13.552755
# ...        ...        ...       ...       ...       ...        ...        ...
# 9995  2.933254   4.366904  0.367054  0.510260  0.039000  14.786094  65.471476
# 9996  4.976858   3.882985  0.356024  0.286222  0.044949  11.854105  49.088580
# 9997  4.145648  10.503240  0.681081  0.553445  0.073245  13.650056  20.631783
# 9998  2.127102   5.922780  0.214136  0.294975  0.065984   3.691878   9.338131
# 9999  0.465644  15.859296  0.354751  0.358391  0.024571   8.606354  51.822714
#
#              Hg         Pb          HI
# 0     32.718663   0.544924   59.597346
# 1     18.027562  12.605966  104.527388
# 2      2.130164   4.934271   30.545610
# 3     25.557141   1.643538  150.534010
# 4     18.834904   8.120603   83.134348
# ...         ...        ...         ...
# 9995  16.550051   9.167112  114.191206
# 9996   8.944040  10.565634   89.999398
# 9997  11.004818  14.593491   75.836806
# 9998  11.928420  11.982285   45.565692
# 9999  15.771039   7.378583  100.641343
#
# [10000 rows x 10 columns]

# %%
def percent(df):
    mn = (df["Mn"].sum() / df["HI"].sum())* 100
    cr = (df["Cr"].sum() / df["HI"].sum())* 100
    ni = (df["Ni"].sum() / df["HI"].sum())* 100
    cu = (df["Cu"].sum() / df["HI"].sum())* 100
    zn = (df["Zn"].sum() / df["HI"].sum())* 100
    As = (df["As"].sum() / df["HI"].sum())* 100
    cd = (df["Cd"].sum() / df["HI"].sum())* 100
    hg = (df["Hg"].sum() / df["HI"].sum())* 100
    pb = (df["Pb"].sum() / df["HI"].sum())* 100


    metals = [mn, cr, ni, cu, zn, As, cd, hg, pb]
    return metals

# %%
def percentCR(df):
    cr = (df["Cr"].sum() / df["CR"].sum())* 100
    ni = (df["Ni"].sum() / df["CR"].sum())* 100
    As = (df["As"].sum() / df["CR"].sum())* 100
    cd = (df["Cd"].sum() / df["CR"].sum())* 100
    pb = (df["Pb"].sum() / df["CR"].sum())* 100
    
    metals = [cr, ni, As, cd, pb]
    return metals

# %%
def HI_percent(metals):
    df = pd.DataFrame(data={
    
        "metals": ["Mn", "Cr","Ni","Cu","Zn","As","Cd","Hg","Pb"],
        "percent": metals
    })
    
    return df

# %%
def CR_percent(metals):
    df = pd.DataFrame(data={
    
        "metals": ["Cr","Ni","As","Cd","Pb"],
        "percent": metals
    })
    
    return df

# %%
percenthiWA = percent(rawHiWA)
percenthiSA = percent(rawHiSA)

percenthiWC = percent(rawHiWC)
percenthiSC = percent(rawHiSC)

percentcrWA = percentCR(rawCRWA)
percentcrSA = percentCR(rawCRSA)

percentcrWC = percentCR(rawCRWC)
percentcrSC = percentCR(rawCRSC)

# %%
perHiWA = HI_percent(percenthiWA)
perHiSA = HI_percent(percenthiSA)

perHiWC = HI_percent(percenthiWC)
perHiSC = HI_percent(percenthiSC)

percrWA = CR_percent(percentcrWA)
percrSA = CR_percent(percentcrSA)

percrWC = CR_percent(percentcrWC)
percrSC = CR_percent(percentcrSC)

# %%
perHiA = pd.concat([perHiWA, perHiSA])
perHiC = pd.concat([perHiWC, perHiSC])

percrA = pd.concat([percrWA, percrSA])
percrC = pd.concat([percrWC, percrSC])

# %%
winter = ["Winter" for _ in range(9)]
summer = ["Summer" for _ in range(9)]

# %%
winter = pd.Series(winter)
summer = pd.Series(summer)

# %%
seasons = pd.concat([winter, summer])

# %%
perHiA["Seasons"] = seasons
perHiC["Seasons"] = seasons

# %%
winter = ["Winter" for _ in range(5)]
summer = ["Summer" for _ in range(5)]
winter = pd.Series(winter)
summer = pd.Series(summer)
seasons = pd.concat([winter, summer])

# %%
percrA["Seasons"] = seasons
percrC["Seasons"] = seasons

# %%
perHiA.to_csv("monteData/simul/percent_HiA.csv")
perHiC.to_csv("monteData/simul/percent_HiC.csv")
percrA.to_csv("monteData/simul/percent_crA.csv")
percrC.to_csv("monteData/simul/percent_crC.csv")

# %% [markdown]
# ### percentages

# %%
perHiA = pd.read_csv("monteData/simul/percent_HiA.csv")
perHiC = pd.read_csv("monteData/simul/percent_HiC.csv")
percrA = pd.read_csv("monteData/simul/percent_crA.csv")
percrC = pd.read_csv("monteData/simul/percent_crC.csv")

# %%
perHiA
# Out:
#     Unnamed: 0 metals    percent Seasons
# 0            0     Mn   3.157036  Winter
# 1            1     Cr   6.946854  Winter
# 2            2     Ni   0.667932  Winter
# 3            3     Cu   0.769199  Winter
# 4            4     Zn   0.057320  Winter
# 5            5     As  12.250657  Winter
# 6            6     Cd  51.213410  Winter
# 7            7     Hg  16.478027  Winter
# 8            8     Pb   8.459567  Winter
# 9            0     Mn   2.653139  Summer
# 10           1     Cr   5.571989  Summer
# 11           2     Ni   0.522263  Summer
# 12           3     Cu   0.885741  Summer
# 13           4     Zn   0.055515  Summer
# 14           5     As   9.967325  Summer
# 15           6     Cd  45.683586  Summer
# 16           7     Hg  24.992237  Summer
# 17           8     Pb   9.668203  Summer

# %%
perHiC
# Out:
#     Unnamed: 0 metals    percent Seasons
# 0            0     Mn   3.378657  Winter
# 1            1     Cr   6.501942  Winter
# 2            2     Ni   0.628471  Winter
# 3            3     Cu   0.733904  Winter
# 4            4     Zn   0.054913  Winter
# 5            5     As  11.612587  Winter
# 6            6     Cd  53.446202  Winter
# 7            7     Hg  15.746504  Winter
# 8            8     Pb   7.896821  Winter
# 9            0     Mn   2.845002  Summer
# 10           1     Cr   5.283712  Summer
# 11           2     Ni   0.491583  Summer
# 12           3     Cu   0.826095  Summer
# 13           4     Zn   0.052973  Summer
# 14           5     As   9.438411  Summer
# 15           6     Cd  48.077984  Summer
# 16           7     Hg  23.821850  Summer
# 17           8     Pb   9.162390  Summer

# %%
percrA
# Out:
#    Unnamed: 0 metals    percent Seasons
# 0           0     Cr  19.586157  Winter
# 1           1     Ni  52.822993  Winter
# 2           2     As  10.289333  Winter
# 3           3     Cd  16.831605  Winter
# 4           4     Pb   0.469912  Winter
# 5           0     Cr  19.407814  Summer
# 6           1     Ni  51.038112  Summer
# 7           2     As  10.342171  Summer
# 8           3     Cd  18.548435  Summer
# 9           4     Pb   0.663467  Summer

# %%
hiWA
# Out:
#       Unnamed: 0           0
# 0              0   59.597346
# 1              1  104.527388
# 2              2   30.545610
# 3              3  150.534010
# 4              4   83.134348
# ...          ...         ...
# 9995        9995  114.191206
# 9996        9996   89.999398
# 9997        9997   75.836806
# 9998        9998   45.565692
# 9999        9999  100.641343
#
# [10000 rows x 2 columns]
